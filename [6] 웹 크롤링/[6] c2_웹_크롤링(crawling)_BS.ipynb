# %% [markdown]
# Beautiful Soup Documentation
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
import warnings
warnings.filterwarnings('ignore')

import random
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats
from scipy.stats import t, norm, chi2, chi2_contingency

import math, scipy, sympy
from bs4 import BeautifulSoup as BS
import requests, re, urllib

from urllib import robotparser
from urllib.request import urlopen
import chardet

from matplotlib import rc
rc('font', family='Malgun Gothic')      #한글 폰트설정
plt.rcParams['axes.unicode_minus']=False      #마이너스 부호 출력 설정

# %% [markdown]
# findall은 요소의 태그 이름과 속성 값을 기준으로 검색하고, select는 CSS 선택자(요소의 태그 이름, 클래스, ID, 속성 등)를 사용하여 요소를 선택
# #### => 사용법 비슷. 요소를 선택하는 방법에서 차이가 있을 뿐.

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<div></div>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
from bs4 import BeautifulSoup as BS
soup = BS(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <div>
#   </div>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
print(soup.title,'\n')
print(soup.title.name,'\n')
print(soup.title.parent.name,'\n')
print(soup.p,'\n')   # p태그 첫 번째 데이터
print(soup.a,'\n')   # a태그 첫 번째 데이터
print(soup.find('a'),'\n')   # a태그 첫 번째 데이터
print(soup.a['class'],'\n')   # a의 클래스
print(soup.find_all('a'),'\n')   # 모든 a태그 데이터
print(soup.find_all(class_='sister'),'\n')   # 언더바 주의
print(soup.find(id='link3'),'\n')
print(soup.find(class_='story'),'\n')
# Out:
# <title>The Dormouse's story</title>
#
# title
#
# head
#
# <p class="title"><b>The Dormouse's story</b></p>
#
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
#
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
#
# ['sister']
#
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
#
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
#
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>
#
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
soup.find_all()
# Out:
# [<html><head><title>The Dormouse's story</title></head>
#  <body>
#  <div></div>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  </body></html>,
#  <head><title>The Dormouse's story</title></head>,
#  <title>The Dormouse's story</title>,
#  <body>
#  <div></div>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  </body>,
#  <div></div>,
#  <p class="title"><b>The Dormouse's story</b></p>,
#  <b>The Dormouse's story</b>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>,
#  <p class="story">...</p>]

# %% [markdown]
# #### string vs. get_text() vs. text
# - BeautifulSoup 객체에서 text 속성, get_text() 메서드, string 속성은 모두 HTML 또는 XML 문서에서 텍스트 데이터를 추출하는 데 사용
# - text 속성은 해당 태그에서 모든 텍스트 데이터를 가져오며,
# - get_text() 메서드도 동일한 결과를 반환합니다.
# - string 속성은 해당 태그에서 첫 번째로 발견된 문자열 데이터만 가져옵니다.

# %%
html = '''
<html>
<body>
<div>
Hello,world!
</div>
<div>
<p>
Hello,<b>world!</b>
</p>
</div>        
</body>
</html>
'''

# %%
from bs4 import BeautifulSoup as BS
soup = BS(html, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <div>
#    Hello,world!
#   </div>
#   <div>
#    <p>
#     Hello,
#     <b>
#      world!
#     </b>
#    </p>
#   </div>
#  </body>
# </html>

# %%
print(soup.div.text)
print(soup.div.get_text())
print(soup.div.string)
# Out:
# Hello,world!
#
#
# Hello,world!
#
#
# Hello,world!

# %%
# text 속성
print(soup.p.text)

# get_text 메서드
print(soup.p.get_text())

# string 속성
print(soup.p.string)
print(soup.p.b.string)
print(soup.b.string)
# Out:
# Hello,world!
#
#
# Hello,world!
#
# None
# world!
# world!

# %%
# body에 있는 모든 text
bs = soup.body.text
bs = re.findall('.+',bs)
for i in bs:
    print(i)
# Out:
# Hello,world!
# Hello,world!

# %%
bs = soup.body.text
bs = re.findall('.+',bs)
print(' '.join(bs))
# Out:
# Hello,world! Hello,world!

# %%
bs = soup.body.text
re.sub(r'\n',' ',bs)
# Out:
# '  Hello,world!    Hello,world!   '

# %%
bs = soup.body.text
bs = re.findall('.+',bs)

li = ''
for t in bs:
    li += t
    li += ' '
print(li)
# Out:
# Hello,world! Hello,world!

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<div></div>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>
"""
soup = BS(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <div>
#   </div>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
bs = str(soup)
print(bs,'\n',type(bs))
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <div></div>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>
#  <class 'str'>

# %%
# 영어 텍스트만 출력
p = re.findall('[a-zA-Z]+',bs)
' '.join(p)
# Out:
# 'html head title The Dormouse s story title head body div div p class title b The Dormouse s story b p p class story Once upon a time there were three little sisters and their names were a class sister href http example com elsie id link Elsie a a class sister href http example com lacie id link Lacie a and a class sister href http example com tillie id link Tillie a and they lived at the bottom of a well p p class story p body html'

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(soup.get_text())
print(soup.text)
# Out:
# The Dormouse's story
#
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...
#
# The Dormouse's story
#
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
texts = soup.find_all('body')
li=''
for t in texts:
    li +=t.text
print(li)
# Out:
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
re.sub('\n','',li)
# Out:
# "The Dormouse's storyOnce upon a time there were three little sisters; and their names wereElsie,Lacie andTillie;and they lived at the bottom of a well...."

# %%
texts = soup.find_all('body')
a=''
for i in texts:
    t = re.findall('.+', i.text)
    a+=' '.join(t)
a
# Out:
# "The Dormouse's story Once upon a time there were three little sisters; and their names were Elsie, Lacie and Tillie; and they lived at the bottom of a well. ..."

# %%
texts = soup.body.text
t = re.findall('.+',texts)
' '.join(t)
# Out:
# "The Dormouse's story Once upon a time there were three little sisters; and their names were Elsie, Lacie and Tillie; and they lived at the bottom of a well. ..."

# %% [markdown]
# bs<br>
# https://hi-guten-tag.tistory.com/8

# %% [markdown]
# #### html.parser vs. lxml
# - 파이썬에서 HTML 및 XML 문서를 파싱(parsing)하는 라이브러리
# - html.parser는 HTML 문서를 파싱하는 데에 적합한 파서. 파이썬의 기본 라이브러리로 제공되며 파이썬 내부적으로 구현되어 있으며, 외부 종속성이 없으므로 파이썬과 함께 설치되는 패키지만 사용할 수 있습니다.
# - lxml은 C 언어로 작성된 파이썬 외부 라이브러리로서 HTML 및 XML 문서를 파싱하는 데에 적합하며, 파서 성능이 매우 우수합니다.
# - HTML 문서를 파싱하는 경우에는 html.parser를 사용하는 것이 간단하고 편리하며, 대부분의 경우에는 충분한 성능을 제공합니다. 그러나 대용량의 XML 문서나 매우 복잡한 HTML 문서를 파싱해야 하는 경우에는 lxml을 사용하는 것이 더 효율적입니다.

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\h\anaconda3\lib\site-packages (4.9.1)

# %% [markdown]
# #### urllib + bs

# %%
url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'
html = urllib.request.urlopen(url)
bs = BS(html, 'html.parser')
bs
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="정치 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image">
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" name="twitter:description"/>
# <title>정치 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Tue May 02 10:09:11 KST 2023";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </meta></meta></meta></meta></head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>02</strong><span class="day">(화)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
# <ul class="nav">
# <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a></li>
# <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
# <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
# <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
# <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
# <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/081/0003358019?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/081/2023/05/02/3358019.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/081/0003358019?sid=100">이진복, ‘태영호 녹취록’ 논란에 “공천 줄 위치 있지 않고 논의도 없었다”</a>
# <div class="cluster_text_lede">이진복 정무수석, “한일 관계·공천 얘기 전혀 한 적 없어” “공천 문제 당에서 하는 것, 대통령실이 하는 것 아니다” 이진복 대통령실 정무수석은 2일  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news081,0003358019',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울신문</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news028,0002638107',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한겨레</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/028/0002638107?sid=100">이진복, 태영호에 공천 언급하며 한일관계 옹호 발언 요청 의혹</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003761224',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761224?sid=100">대통령실이 ‘공천’ 거론하며 도움 요청? 태영호 “과장 섞인 내용”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news032,0003220886',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">경향신문</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220886?sid=100">“이진복 수석, 공천 거론하며 한·일관계 옹호 발언 요청”…태영호 녹취록 나왔다</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305012010_00000017&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=081&amp;aid=0003358019"><span class="cluster_foot_more_icon_num">62</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277097?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2023/05/01/3277097.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277097?sid=100">尹 "'프라미스' 성공은 외교 역량 성과"…작전 참가자 노고 치하</a>
# <div class="cluster_text_lede">윤석열 대통령은 1일 군벌 간 무력 충돌이 발생한 수단에서 우리 교민을 구출하는 '프라미스'(Promise·약속) 작전을 성공적으로 수행한 참가자들을 격 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277097',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0005124325',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/009/0005124325?sid=100">尹, 수단 교민 탈출 이끈 ‘프라미스’ 작전 참가자 격려</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006780836',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006780836?sid=100">尹 "국민 생명·안전이 최우선…재외 국민도 예외일 수 없어"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011476376',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">KBS</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011476376?sid=100">윤 대통령 “수단 교민 구출 ‘프라미스 작전’은 우리 외교 역량의 성과”</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011050_00000024&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003277097"><span class="cluster_foot_more_icon_num">28</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253182?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/277/2023/05/01/5253182.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253182?sid=100">대통령실 "尹, 野지도부 회동…여야 원대 합의시 마다할 이유없어"</a>
# <div class="cluster_text_lede">대통령실은 1일 윤석열 대통령의 미국 국빈 방문 성과 설명에 대한 여야 지도부 회동 가능성에 대해 "그런 (대통령 회동) 부분이 여야 원내대표들 간 모임 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005253182',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003761144',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761144?sid=100">“野 원내대표 만남, 마다할 이유 없다”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137658',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137658?sid=100">대통령실 “尹·여야 원내대표 만남, 여야 합의되면 마다할 이유 없어”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003494750',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">동아일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003494750?sid=100">대통령실 “尹-여야 원내대표 회동, 마다할 이유 없다”</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011810_00000031&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=277&amp;aid=0005253182"><span class="cluster_foot_more_icon_num">21</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797969?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/029/2023/05/01/2797969.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797969?sid=100">민주당 원내수석부대표에 비명 송기헌</a>
# <div class="cluster_text_lede">박광온 더불어민주당 원내대표는 1일 신임 원내수석부대표(운영수석)에 재선 송기헌(사진) 의원을 선임했다. 송 의원은 열린우리당 원주시 당협위원장과 민주당 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news029,0002797969',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">디지털타임스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277016',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277016?sid=100">박광온, 민주 신임 원내대표단 구성…원내수석에 송기헌</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277137',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277137?sid=100">박광온 “대의원제 폐지, 돈봉투 해법 아니다” 친명계와 시각차</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185480',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185480?sid=100">민주 원내 진용 새단장…비명·소장파 전면에</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011210_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=029&amp;aid=0002797969"><span class="cluster_foot_more_icon_num">62</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898098?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/05/01/898098.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898098?sid=100">與 윤리위, 김재원·태영호 징계하기로 결정… 오는 8일 징계 수위 정할 듯</a>
# <div class="cluster_text_lede">황정근 윤리위원장 “절차 개시되면 당사자 출석해 소명” 홍준표·천하람·유승민 등에 대한 징계 개시하지 않기로 ’국민 정서와 동떨어진 언행’ 구체화 논의도 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898098',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269997?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/01/1269997.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269997?sid=100">실언·막말 논란 김재원·태영호 징계 개시‥이르면 8일 수위 결정</a>
# <div class="cluster_text_lede">국민의힘 태영호 최고위원은 제주 4.3사건 관련 발언 등으로도 당내 징계 대상에 올라있습니다. 국민의힘은 오늘 김기현 대표 체제에서 첫 윤리위원회 회의를 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269997',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=366&amp;aid=0000898098"><span class="cluster_foot_more_icon_num">98</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006780977?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/01/6780977.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006780977?sid=100">전세사기특별법 불발…與 "보증금 지원 안돼" 野 "우선매수권 어려워"(종합)</a>
# <div class="cluster_text_lede">여야는 1일 전세 사기 피해자 구제를 위한 특별법 제정에 머리를 맞댔지만 피해자 요건과 지원 요건 등을 두고 이견을 재확인하며 추후 논의키로 했다. 국회 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006780977',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/437/0000341403?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/437/2023/05/02/341403.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/437/0000341403?sid=100">'전세사기 특별법' 논의 불발…'피해자 기준' 입장 차</a>
# <div class="cluster_text_lede">국회 전세사기 특별법 논의가 결국 불발됐습니다. 누구를 피해자로 볼 건지 피해자 기준에 대한 입장 차 때문이었습니다. 국회 논의가 늦어지는 가운데, 피해 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news437,0000341403',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">JTBC</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304261610_00000094&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=421&amp;aid=0006780977"><span class="cluster_foot_more_icon_num">79</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277167?sid=100">윤 대통령 “한·미 동맹, 미래 세대에 기회의 플랫폼 돼야”</a>
# <div class="cluster_text_lede">윤석열 대통령과 대통령실은 1일 국빈 방미 성과를 알리는 데 주력했다. 윤 대통령은 수석비서관회의에서 “이번 한·미 정상회담은 안보를 비롯해 산업, 과학기술, 교육, 문화 등 모든 면으로 동맹을 확장시켰다는 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277167',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220722?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/032/2023/05/01/3220722.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220722?sid=100">윤 대통령 “업그레이드된 한·미 동맹, 청년에게 기회의 플랫폼 되어야”</a>
# <div class="cluster_text_lede">5박7일간 미국 국빈 방문을 마치고 전날 귀국한 윤석열 대통령은 1일 “업그레이드되고 확장된 한·미 동맹은 청년 미래 세대에게 기회의 플랫폼이 되어야 한 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news032,0003220722',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">경향신문</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011110_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003277167"><span class="cluster_foot_more_icon_num">28</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277104?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2023/05/01/3277104.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277104?sid=100">국회 온 美하원의원단 "尹, 환상적"…김진표 "의원연맹 만들자"</a>
# <div class="cluster_text_lede">번 뷰캐넌 의원이 이끄는 미국 하원의원단은 1일 윤석열 대통령의 미국 국빈 방문에 대해 “환상적인 방미”라고 평가했다. 국회의장실에 따르면 뷰캐넌 의원은 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277104',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054743?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/02/1054743.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054743?sid=100">김 의장 만난 미 하원의원단 "윤 대통령, 환상적인 방미"</a>
# <div class="cluster_text_lede">▲ 김진표 의장, 미국 하원의원 방한단 접견 번 뷰캐넌 의원이 이끄는 미국 하원의원단은 1일 윤석열 대통령의 미국 국빈 방문을 두고 "환상적인 방미"라고 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054743',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011620_00000009&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003277104"><span class="cluster_foot_more_icon_num">17</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013914794?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13914794.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013914794?sid=100">박대출 "방송법 국회 통과하면 대통령이 거부권 행사해야"(종합)</a>
# <div class="cluster_text_lede">KBS라디오 좌파매체에 점령당해…野 방송법 강행, 공영방송 장악 꼼수" 김기현, MBC 관련 세미나에서 "편향성 안돼, 방송 기본정신으로 돌아가야" 국민 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013914794',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881725?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/008/2023/05/01/4881725.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881725?sid=100">"정권 바뀔 때마다 난리"…총선 1년 앞두고 또 방송법 갈등 폭발</a>
# <div class="cluster_text_lede">'방송법 개정안'(이하 방송법)이 야당인 더불어민주당 주도로 국회 본회의에 부의되면서 방송법 처리 여부가 3월 '쌀 의무매입법'(양곡관리법 개정안), 4 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881725',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304300910_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013914794"><span class="cluster_foot_more_icon_num">27</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834794?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/02/11834794.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834794?sid=100">이원욱, 송영길 檢출석에 "실효성 없어…지도부, 돈봉투 정치적 결단 빨리 해야"</a>
# <div class="cluster_text_lede">이원욱 더불어민주당 의원은 2일 지난 송영길 전 대표가 '전당대회 돈 봉투' 의혹과 관련해 이날 검찰 출석을 예고한 것에는 "책임지겠다고 하는 자세는 있 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011834794',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834775?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/02/11834775.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834775?sid=100">이원욱 "이재명, 총선 어렵다 생각하면 그만둘 가능성 있어"</a>
# <div class="cluster_text_lede">기사내용 요약 "정권 심판론 우세…野 반사이익 못 누려" "비명계 박광온 선출, 지도부 변화 예고" [서울=뉴이원욱 더불어민주당 의원은 2일 민주당의 내 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011834775',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305020920_00000031&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011834794"><span class="cluster_foot_more_icon_num">8</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/449/0000248771?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/449/2023/05/02/248771.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/449/0000248771?sid=100">첫 회의 주재한 박광온 “지지자들만으로 선거 이길 수 없어”</a>
# <div class="cluster_text_lede">취임 첫 원내대책회의를 주재한 박광온 더불어민주당 신임 원내대표가 "지지자들만으로 선거에서 이길 수 없고, 반사 이익만으로 이길 수 없다"며 중도 확장과 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news449,0000248771',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">채널A</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220923?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/032/2023/05/02/3220923.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220923?sid=100">박광온 “내년 총선은 확장성 싸움···맞벌이 학부모 주 4일제 추진”</a>
# <div class="cluster_text_lede">박광온 더불어민주당 원내대표는 2일 “내년 총선은 확장성의 싸움이 될 것”이라며 “경제 정책에서 국민의 신뢰를 받는 민주당이 되겠다”고 밝혔다. 박 원내 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news032,0003220923',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">경향신문</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305021000_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=449&amp;aid=0000248771"><span class="cluster_foot_more_icon_num">5</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/002/0002284321?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/002/2023/05/01/2284321.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/002/0002284321?sid=100">북한 "워싱턴 선언 부정적 후과"…중·러 반발 집중 조명</a>
# <div class="cluster_text_lede">'한미일' 공조 강화에 '북중러' 연대 맞불 한국과 미국이 북핵 위협 대응 방안으로 합의한 '워싱턴 선언'에 대해 북한이 1일 강하게 반발했다. 북한 관 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news002,0002284321',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">프레시안</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765179?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/079/2023/05/01/3765179.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765179?sid=100">北, 중·러 반응에 미·일 보도까지 인용 여론전 "국제사회 강한 우려"</a>
# <div class="cluster_text_lede">핵심요약 김여정·조선중앙통신논평 노동신문 게재로 워싱턴선언 北주민에 공개 중·러 대변인 반응 자세히 소개…중 매체에 미·일 보도도 인용 북한은 1일 중국 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003765179',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010800_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=002&amp;aid=0002284321"><span class="cluster_foot_more_icon_num">12</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/660/0000033732?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/660/2023/05/01/33732.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/660/0000033732?sid=100">'방첩사 사칭' 민간인, 해병대 영내 2시간 반 활보</a>
# <div class="cluster_text_lede">국군 방첩사령부 소속이라고 사칭한 민간인이 해병대 영내에 무단 침입했다 적발돼 군사경찰이 수사에 나섰습니다. 해병대에 따르면, 지난달 28일 오후 경북  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news660,0000033732',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">kbc광주방송</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185627?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/02/4185627.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185627?sid=100">"나 방첩사 소속이야" 사칭 민간인, 해병대 부대 2시간 넘게 활보하다 검거</a>
# <div class="cluster_text_lede">국군 방첩사령부 소속을 사칭한 민간인이 해병대 영내를 무단 침입해 2시간가량 활보하는 사건이 발생했다. 방첩사는 군 보안 업무를 담당하는 조직이다. 지난 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185627',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011710_00000074&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=660&amp;aid=0000033732"><span class="cluster_foot_more_icon_num">20</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253217?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/277/2023/05/02/5253217.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253217?sid=100">⑤지지부진한 3대 개혁…돌파구는?[尹정부 1년]</a>
# <div class="cluster_text_lede">윤석열 대통령이 국정 과제로 내건 '3대(노동·교육·연금) 개혁'은 최근 논의가 지지부진하다. '초등학교 입학 연령 만 5세로 하향 조정'을 골자로 한  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005253217',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185529?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/02/4185529.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185529?sid=100">국민의힘 노동개혁특위 오늘 출범</a>
# <div class="cluster_text_lede">국민의힘은 윤재옥 원내대표 취임 후 첫 원내 특별위원회인 ‘노동개혁특별위원회’를 2일 발족한다. 위원회는 정부의 3대 개혁 과제 중 하나인 노동개혁 입법 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185529',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305020610_00000100&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=277&amp;aid=0005253217"><span class="cluster_foot_more_icon_num">7</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137437?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2023/05/01/2137437.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137437?sid=100">尹, 한일·한미일 연쇄회담...5월 외교안보 ‘큰 장’</a>
# <div class="cluster_text_lede">윤석열 대통령이 5박 7일간의 국빈 방미 일정을 모두 마치며, ‘워싱턴 선언’ 채택 등 한미 간 전략적 안보동맹을 더욱 강화했다는 평가 나오는 가운데 이 …</div>
# ...
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/655/0000009618?ntype=RANKING&amp;sid=001">청주동물원 이전 여부 외부용역 의회서 제동..출구전략은?</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=655"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/655/2022/01/20/logo_655_56_20220120164501.png" width="16"/></span>CJB청주방송</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024362?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/661/2023/05/02/24362.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024362?ntype=RANKING&amp;sid=001">국민연금 月 200만원 ↑ 고액수령자 한달새 3배 '껑충' …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16"/></span>JIBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014464?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/657/2023/05/01/14464.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014464?ntype=RANKING&amp;sid=001">[뉴스비하인드] 대구경북신공항, 새로운 하늘길인가? 꽉 막 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=657"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/657/2022/01/19/logo_657_56_20220119135625.png" width="16"/></span>대구MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/666/2023/05/02/10203.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&amp;sid=001">학교 다녀오면 ‘꼬르륵’…학생·학부모, 부실 급식 뿔났다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=666"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png" width="16"/></span>경기일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018628?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2023/05/01/18628.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018628?ntype=RANKING&amp;sid=001">호텔신라 50주년 생일 경품 잔치연다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001879861?sid=100" title='[뉴스라이더] 대통령실, 공천 거론하며 옹호 발언 요청?...태영호 "사실 아냐"'>[뉴스라이더] 대통령실, 공천 거론하며 옹호 발언 요청?...태영호 "사실 아냐"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834805?sid=100" title="전세사기 특별법, 보증금 최대 4.5억까지 구제">전세사기 특별법, 보증금 최대 4.5억까지 구제</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808429?sid=100" title="‘막말’ 김재원·태영호 징계 돌입… 리스크 털고 분위기 반전시킬 수 있을까">‘막말’ 김재원·태영호 징계 돌입… 리스크 털고 분위기 반전시킬 수 있을까</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/009/0005124425?sid=104" title="“한국인 손해 막심하다”...휴지조각 위기에 빠진 서학개미 순매수 5위 주식 [월가월부]">“한국인 손해 막심하다”...휴지조각 위기에 빠진 서학개미 순매수 5위 주식 [월가월부]</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/014/0005005630?sid=104" title='기시다 "7~8일 韓 방문", 尹과 마음 터놓고 대화 기대'>기시다 "7~8일 韓 방문", 尹과 마음 터놓고 대화 기대</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834641?sid=101" title="4월 물가 14개월만에 3%대…전기요금 인상·환율 '변수'(종합)">4월 물가 14개월만에 3%대…전기요금 인상·환율 '변수'(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/008/0004882074?sid=101" title="SK E&amp;S, 미국 업체와 손잡고 국내 수소산업에 1조원 투자">SK E&amp;S, 미국 업체와 손잡고 국내 수소산업에 1조원 투자</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/469/0000737102?sid=101" title="[단독] '연금 신뢰 속 평등·연대' 갈구 프랑스…한국과 결 다른 국민연금 세대갈등">[단독] '연금 신뢰 속 평등·연대' 갈구 프랑스…한국과 결 다른 국민연금 세대갈등</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/030/0003095650?sid=105" title="LG유플러스, MDS테크와 산업용 스마트 무전 서비스 확대">LG유플러스, MDS테크와 산업용 스마트 무전 서비스 확대</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834711?sid=105" title='"반찬·국물 많은 韓매장에 최적"…KT, 차세대 AI 서비스로봇 출시'>"반찬·국물 많은 韓매장에 최적"…KT, 차세대 AI 서비스로봇 출시</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808473?sid=102" title="“조사받겠다”는 송영길… “조사 불가”라는 검찰">“조사받겠다”는 송영길… “조사 불가”라는 검찰</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/057/0001739426?sid=102" title="길 걷던 부부 덮친 음주운전 차량…아내 사망·남편 중상">길 걷던 부부 덮친 음주운전 차량…아내 사망·남편 중상</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765355?sid=102" title="'시작부터 극한대립' 내년 최저임금 첫 회의…주요 쟁점은?">'시작부터 극한대립' 내년 최저임금 첫 회의…주요 쟁점은?</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/215/0001098845?sid=103" title="'게임체인저' 기아 EV9 사전계약 시작…7337만원부터">'게임체인저' 기아 EV9 사전계약 시작…7337만원부터</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004185587?sid=103" title="세련미 강조된 '2024 셀토스'…주차보조 시스템도 태웠다">세련미 강조된 '2024 셀토스'…주차보조 시스템도 태웠다</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
text1 = bs.find('p')
print(text1,'\n')

text2 = bs.find('p').string   # string는 태그의 첫줄만 뽑아냄 (첫줄 값->없음)
print(text2,'\n')

text3 = bs.find('p').get_text()   # get_text로 해야 전부 나옴
print(text3)
# Out:
# <p class="airs_info_inner"><i class="airs_info_icon_airs">AiRS</i><span class="airs_info_text"><b>추천</b>으로 구성된 뉴스를 제공합니다.</span></p>
#
# None
#
# AiRS추천으로 구성된 뉴스를 제공합니다.

# %%
texts = bs.find_all('p')
for t in texts:
    print(t.text)
# Out:
# AiRS추천으로 구성된 뉴스를 제공합니다.
# 오전 9시~오전 10시까지 집계한 결과입니다.
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.

# %% [markdown]
# #### bs4에서 headers는
# headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
#
# - HTTP 요청을 보낼 때 요청 헤더를 설정하는 데 사용됩니다.
# - 일반적으로 웹 사이트에서 데이터를 스크래핑하려면, 해당 웹 사이트에서 HTTP 요청을 받을 때 자신이 웹 브라우저인 것처럼 보이도록 요청 헤더를 설정해야 합니다.
# - 이를 통해 웹 사이트는 봇이나 크롤러와 같은 자동화된 스크래핑 도구에서 요청을 보내는 것으로 인식하는 것을 방지할 수 있습니다.

# %% [markdown]
# chardet.detect(response.content)['encoding']
# response.content
# encoding 변수에 저장한 후, response.content를 이 encoding 방식으로 디코딩하여 html 변수에 저장하고 출력

# %% [markdown]
# #### ConnectionError: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
# 이때 헤더를 설정해줌으로서 웹사이트에 접근 가능

# %%
import chardet

# HTTP 요청에서 사용될 헤더 정보를 설정
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

# 웹사이트에서 스크래핑할 URL을 지정
url  = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'

# 지정된 URL에 HTTP GET요청을 전달
response = requests.get(url, headers=headers)

# HTTP 요청이 성공적으로 전달되었다면, 웹사이트의 HTML코드 출력
if response.status_code==200:
    encoding = chardet.detect(response.content)['encoding']
    print(response.content.decode(encoding))   #웹사이트의 HTML코드를 포함하는 이진(바이너리) 데이터를 반환
#     print(response.text)  #웹사이트의 HTML코드를 문자열 형태로 반환
else:
    print('HTTP request failed.')
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="euc-kr">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="referrer" contents="always">
# <meta http-equiv="refresh" content="600" />
# <meta name="viewport" content="width=1106" />
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <meta property="og:title"       content="정치 : 네이버 뉴스">
# <meta property="og:type"        content="website">
# <meta property="og:url"         content="https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100">
# <meta property="og:image"       content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png"/>
# <meta property="og:description" content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공">
# <meta property="og:article:author"	content="네이버"/>
#
# <meta name="twitter:card"		content="summary">
# <meta name="twitter:title"		content="정치 : 네이버 뉴스">
# <meta name="twitter:site"       content="네이버 뉴스">
# <meta name="twitter:creator"    content="네이버 뉴스">
# <meta name="twitter:image"		content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
# <meta name="twitter:description" content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공">
#
#
#
#
#
#
#
# <title>정치 홈 : 네이버 뉴스	</title>
# <link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" />
#
#
#
#
#
#
#
#
#
#
# 		<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css"/>
# 		<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css"/>
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" charset="euc-kr"></script>
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" charset="utf-8"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Tue May 02 10:09:12 KST 2023";
# </script>
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" charset="euc-kr"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
#
#
# </head>
#
# <body>
# 	<div id="wrap">
# 		<!-- 광고적용 태그 추가 -->
# 		<div id="da_base"></div>
# 		<div id="da_stake"></div>
#
#
#
# <div id="header" class="header">
#
# 	<div id="u_skip">
# 		<a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# 		<a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# 	</div>
#
#
# 	<div class="snb_area">
# 		<div class="snb_inner">
#
# <div class="gnb_area">
#    <div class="gnb_wrap">
#
#       <div id="gnb" class="gnb_dark_type2"></div>
#
#    </div>
#    <div class="gnb_search is_hidden _search_content">
#    </div>
#    <div id="gnb_search_tool" class="gnb_tool">
#       <a href="javascript:;" class="tool_button _search_content_toggle_btn nclicks(gnb.sch)"><span class="icon_search">검색</span></a>
#    </div>
# </div>
#
#
#
# <div id="snb_wrap">
#     <h1>
#         <a href="https://www.naver.com/" class="h_logo nclicks(gnb.naver)"><span class="blind">NAVER</span></a>
#         <a href="/" class="h_news nclicks(gnb.news)"><span class="blind">뉴스</span></a>
#     </h1>
#     <ul class="snb_related_service">
#         <li><span class="snb_bdr"></span><a href="https://entertain.naver.com/home" class="entertain nclicks(gnb.enter)">TV연예</a></li>
#         <li><span class="snb_bdr"></span><a href="https://sports.news.naver.com" class="sports nclicks(gnb.sports)">스포츠</a></li>
#         <li><span class="snb_bdr"></span><a href="https://weather.naver.com" class="weather nclicks(gnb.weather)">날씨</a></li>
#         <li><span class="snb_bdr"></span><a href="https://contents.premium.naver.com" class="premium nclicks(gnb.premium)">프리미엄</a></li>
#     </ul>
# </div>
# 		</div>
# 	</div>
# 	<div class="lnb_area">
# 		<div class="lnb_inner">
#
#
#
#
#
#
#
# <div class="lnb_both">
# 	<div class="lnb_left">
# 		<div id="lnb" class="lnb_menu">
# 			<ul>
# 				<li><a href="/" class="nclicks(lnb.pcmedia)"><span class="tx">언론사별</span> </a></li>
# 				<li class="on"><a href="/main/main.naver?mode=LSD&mid=shm&sid1=100" class="nclicks(lnb.pol)"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=101" class="nclicks(lnb.eco)"><span class="tx">경제</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=102" class="nclicks(lnb.soc)"><span class="tx">사회</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=103" class="nclicks(lnb.lif)"><span class="tx">생활/문화</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=105" class="nclicks(lnb.sci)"><span class="tx">IT/과학</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=104" class="nclicks(lnb.wor)"><span class="tx">세계</span> </a></li>
# 				<li><a href="/main/ranking/popularDay.naver?mid=etc&sid1=111" class="nclicks(lnb.rankin)"><span class="tx">랭킹</span> </a></li>
# 				<li><a href="/newspaper/home" class="nclicks(lnb.paper)"><span class="tx">신문보기</span> </a></li>
# 				<li><a href="/opinion/home" class="nclicks(lnb.opi)"><span class="tx">오피니언</span> </a></li>
# 				<li><a href="/main/tv/index.naver?mid=tvh" class="nclicks(lnb.tv)"><span class="tx">TV</span> </a></li>
# 				<li><a href="/main/factcheck/main.naver" class="nclicks(lnb.fact)"><span class="tx">팩트체크</span> </a></li>
#
# 			</ul>
# 		</div>
# 	</div>
# 	<div class="lnb_right">
# 		<div class="lnb_extra">
#
#
# 			<div class="lnb_extra_menu">
# 				<ul class="lnb_extra_menu_list">
# 					<li class="lnb_extra_menu_item"><a href="https://news.naver.com/main/officeList.naver" class="lnb_extra_menu_link nclicks(nct.right3)" title="전체 언론사">전체 언론사</a></li>
# 					<li class="lnb_extra_menu_item"><a href="https://newsstand.naver.com/" class="lnb_extra_menu_link nclicks(STA.newsstand)" title="뉴스스탠드" target="_blank">뉴스스탠드</a></li>
# 					<li class="lnb_extra_menu_item"><a href="https://newslibrary.naver.com/search/searchByDate.nhn" class="lnb_extra_menu_link nclicks(nct.right4)" title="라이브러리" target="_blank">라이브러리</a></li>
# 				</ul>
# 			</div>
# 		</div>
# 	</div>
# </div>
#
# 		</div>
# 	</div>
#
#
#
#     <div class="lnb">
#
#
#
#
#         <span class="lnb_date"><strong>05</strong>.<strong>02</strong><span class="day">(화)</span></span>
#
#         <ul class="lnb_side" tabindex="0">
#             <li><a href="https://news.naver.com/main/officeList.naver" class="nclicks(slb.allmedia)" title="전체 언론사">전체 언론사</a></li>
#             <li><a href="https://newsstand.naver.com/" class="nclicks(slb.newsstand)" title="뉴스스탠드" target="_blank" >뉴스스탠드</a></li>
#             <li><a href="https://newslibrary.naver.com/search/searchByDate.nhn" class="nclicks(slb.library)" title="라이브러리" target="_blank">라이브러리</a></li>
#         </ul>
#     </div>
#
# </div>
# 		<hr>
#
# 		<table cellpadding="0" cellspacing="0" class="container">
# 			<caption class="blind">기사목록</caption>
# 			<colgroup>
# 				<col class="col_snb">
# 				<col class="col_content">
# 				<col class="col_aside">
# 			</colgroup>
# 			<tr>
# 				<td class="snb">
# 					<div id="snb" class="snb">
#
#
#
#
#
#
#
#
#
# <h2 class="h2"><a href="/main/main.naver?mode=LSD&mid=shm&sid1=100" class="nclicks(lmn_pol.home)">정치</a></h2>
# <ul class="nav">
#
#
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=264" class="snb_s11 nclicks(lmn_pol.mnl,,1)">대통령실 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=265" class="snb_s12 nclicks(lmn_pol.mnl,,2)">국회/정당 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=268" class="snb_s13 nclicks(lmn_pol.mnl,,3)">북한 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=266" class="snb_s14 nclicks(lmn_pol.mnl,,4)">행정 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=267" class="snb_s15 nclicks(lmn_pol.mnl,,5)">국방/외교 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=269" class="snb_s16 nclicks(lmn_pol.mnl,,6)">정치일반 </a></li>
# </ul>
#
#
#
# <div class="snb_banner">
#  <a href="https://media.naver.com/channel/setting?back=main" class="nclicks(lmn_pol.pmb,,1)"><img src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71" height="74" alt="언론사 구독하기" /></a>
# </div>
# <div class="snb_banner">
#  <a href="https://contents.premium.naver.com/" class="nclicks(lmn_pol.pmb,,1)"><img src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71" height="74" alt="네이버 프리미엄콘텐츠" /></a>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					</div>
# 				</td>
# 				<td class="content">
# 					<div id="main_content" class="content">
# 						<div class="list_body section_index">
#
#         <div class="cluster">
#                 <div class="cluster_title">
#                     <span class="cluster_title_inner"><a href="#biF7L" class="cluster_title_icon_link _news_cluster_layer_btn "><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
#
#                     <div class="cluster_title_layer _news_cluster_layer is_hidden">
#                         <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
#                         <div class="cluster_title_layer_image"></div>
#                         <button type="button" class="cluster_title_layer_close _news_cluster_layer_close_btn">닫기</button>
#                     </div>
#                 </div>
#         </div>
#
#
#             <div class="_persist">
#                 <div class="cluster">
#
#
#
#
#
#
#
#
#
#
#                                 <div class="cluster_group _cluster_content" >
#
#                                     <div class="cluster_body">
#                                         <ul class="cluster_list">
#
#
#
#
#                                                         <li class="cluster_item">
#
#
#
#                                                                 <div class="cluster_thumb">
#                                                                     <div class="cluster_thumb_inner">
#                                                                         <a href="https://n.news.naver.com/mnews/article/023/0003760990?sid=100" class="cluster_thumb_link nclicks(cls_pol.clsart)">
#
#                                                                             <img src="https://imgnews.pstatic.net/image/origin/023/2023/05/01/3760990.jpg?type=ofullfill132_90" width="132" height="90" alt="" onError="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;">
#
#                                                                         </a>
#                                                                     </div>
#                                                                 </div>
#
#                                                             <div class="cluster_text">
#                                                                 <a href="https://n.news.naver.com/mnews/article/023/0003760990?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">野 ‘이재명 방탄’ 소급입법까지... ‘허위사실 공표’ 처벌 못하게 法개정 추진</a>
#                                                                 <div class="cluster_text_lede">선거법 개정안 소급 적용 추진 민주당 일부 의원이 이재명 대표가 공직선거법 위반으로 기소되기 13일 전인 작년 8월 26일 이 대표 기소의 근거 조항을  …</div>
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003760990',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">조선일보</div>
#                                                                 </div>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137733',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">헤럴드경제</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/016/0002137733?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">與 “이재명 처벌근거 삭제법은 ‘방탄’” vs 장경태 “이제와서? 의도 의심”</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011834410',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">뉴시스</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/003/0011834410?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">與 "이재명 방탄 선거법 개정…음흉한 시도" vs 野 "방탄 관련 없어"(종합)</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013914140',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">연합뉴스</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/001/0013914140?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">與 "野 5월 국회 소집, 작년 8월부터 '방탄국회' 여념없어"</a>
#                                                             </div>
#                                                         </li>
#
#
#
#                                         </ul>
#                                     </div>
#
#                                         <div class="cluster_foot">
#                                             <div class="cluster_foot_inner">
#                                                 <a href="/main/clusterArticles.naver?id=c_202305011150_00000579&mode=LSD&mid=shm&sid1=100&oid=023&aid=0003760990" class="cluster_foot_more nclicks(cls_pol.clstitle)"><span class="cluster_foot_more_icon_num">15</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#                                             </div>
#                                         </div>
#
#                                 </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 <div class="cluster_group _cluster_content" >
#
#                                     <div class="cluster_body">
#                                         <ul class="cluster_list">
#
#
#
#
#                                                         <li class="cluster_item">
#
#
#
#                                                                 <div class="cluster_thumb">
#                                                                     <div class="cluster_thumb_inner">
#                                                                         <a href="https://n.news.naver.com/mnews/article/016/0002137678?sid=100" class="cluster_thumb_link nclicks(cls_pol.clsart)">
#
#                                                                             <img src="https://imgnews.pstatic.net/image/origin/016/2023/05/01/2137678.jpg?type=ofullfill132_90" width="132" height="90" alt="" onError="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;">
#
#                                                                         </a>
#                                                                     </div>
#                                                                 </div>
#
#                                                             <div class="cluster_text">
#                                                                 <a href="https://n.news.naver.com/mnews/article/016/0002137678?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">정부, 전세피해 특별법 지원요건 6개→4개 축소안 제시</a>
#                                                                 <div class="cluster_text_lede">국토교통부가 전세사기 피해지원 특별법 적용 기준 4가지로 줄인 수정안을 제시했다. 기존에 나왔던 6가지 기준이 협소하다는 지적에 따라 적용 범위를 일부  …</div>
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137678',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">헤럴드경제</div>
#                                                                 </div>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001270018',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">MBC</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/214/0001270018?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">여야, 전세사기 특별법 합의 불발‥추후 재논의 예정</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0005124197',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">매일경제</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/009/0005124197?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)"> '전세사기' 늪에 빠진 대한민국 정부, 특별법 만들어 구제 나서[NIE 경제기사 이렇게 읽어요]</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news005,0001605350',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">국민일보</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/005/0001605350?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">전세사기 특별법 합의 불발… ‘선매입-후구상’ 놓고 이견</a>
#                                                             </div>
#                                                         </li>
#
#
#
#                                         </ul>
#                                     </div>
#
#                                         <div class="cluster_foot">
#                                             <div class="cluster_foot_inner">
#                                                 <a href="/main/clusterArticles.naver?id=c_202304261610_00000094&mode=LSD&mid=shm&sid1=100&oid=016&aid=0002137678" class="cluster_foot_more nclicks(cls_pol.clstitle)"><span class="cluster_foot_more_icon_num">79</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#                                             </div>
#                                         </div>
#
#                                 </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 <div class="cluster_group _cluster_content" >
#
#                                     <div class="cluster_body">
#                                         <ul class="cluster_list">
#
#
#
#
#                                                         <li class="cluster_item">
#
#
#
#                                                                 <div class="cluster_thumb">
#                                                                     <div class="cluster_thumb_inner">
#                                                                         <a href="https://n.news.naver.com/mnews/article/055/0001054634?sid=100" class="cluster_thumb_link nclicks(cls_pol.clsart)">
#
#                                                                             <img src="https://imgnews.pstatic.net/image/origin/055/2023/05/01/1054634.jpg?type=ofullfill132_90" width="132" height="90" alt="" onError="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;">
#
#                                                                         </a>
#                                                                     </div>
#                                                                 </div>
#
#                                                             <div class="cluster_text">
#                                                                 <a href="https://n.news.naver.com/mnews/article/055/0001054634?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">[단독] "미 전략핵잠, '핵 무장'하고 방한"…중하순 유력</a>
#                                                                 <div class="cluster_text_lede">▲ 오하이오급 잠수함에서 발사되는 트라이던트 SLBM 한미 정상의 워싱턴 선언에 따라 우리 항구에 기항할 미 해군 전략핵잠수함이 핵탄두를 탑재하는지 관심 …</div>
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054634',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">SBS</div>
#                                                                 </div>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news082,0001210176',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">부산일보</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/082/0001210176?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">[단독]핵탄두 탑재 SSBN 오는 19일 부산 첫 기항 유력</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003760997',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">조선일보</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/023/0003760997?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">한국 올 美핵잠, 北을 지도에서 지워버릴 위력</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054643',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">SBS</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/055/0001054643?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">[단독] 미군, "잠수함 핵무장" 공식화…G7 맞춰 한국으로</a>
#                                                             </div>
#                                                         </li>
#
#
#
#                                         </ul>
#                                     </div>
#
#                                         <div class="cluster_foot">
#                                             <div class="cluster_foot_inner">
#                                                 <a href="/main/clusterArticles.naver?id=c_202304261620_00000195&mode=LSD&mid=shm&sid1=100&oid=055&aid=0001054634" class="cluster_foot_more nclicks(cls_pol.clstitle)"><span class="cluster_foot_more_icon_num">9</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#                                             </div>
#                                         </div>
#
#                                 </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 <div class="cluster_group _cluster_content" >
#
#                                     <div class="cluster_body">
#                                         <ul class="cluster_list">
#
#
#
#
#                                                         <li class="cluster_item">
#
#
#
#                                                                 <div class="cluster_thumb">
#                                                                     <div class="cluster_thumb_inner">
#                                                                         <a href="https://n.news.naver.com/mnews/article/011/0004185341?sid=100" class="cluster_thumb_link nclicks(cls_pol.clsart)">
#
#                                                                             <img src="https://imgnews.pstatic.net/image/origin/011/2023/05/01/4185341.jpg?type=ofullfill132_90" width="132" height="90" alt="" onError="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;">
#
#                                                                         </a>
#                                                                     </div>
#                                                                 </div>
#
#                                                             <div class="cluster_text">
#                                                                 <a href="https://n.news.naver.com/mnews/article/011/0004185341?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">민주, 신임 원내수석에 ‘비명’ 송기헌…원내대표 비서실장에 ‘친명’ 민병덕</a>
#                                                                 <div class="cluster_text_lede">박광온 더불어민주당 원내대표는 1일 신임 원내수석부대표로 재선의 송기헌(강원 원주을) 의원을 선임했다. 박 원내대표는 1일 오후 국회에서 기자회견을 열고 …</div>
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185341',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">서울경제</div>
#                                                                 </div>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277137',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">중앙일보</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/025/0003277137?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">박광온 “대의원제 폐지, 돈봉투 해법 아니다” 친명계와 시각차</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004839602',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">한국경제</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/015/0004839602?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">박광온號 첫 시험대는 사법 리스크…"쇄신 의총 열 것"</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137588',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">헤럴드경제</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/016/0002137588?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">민주당 신임 원내수석에 ‘비명' 송기헌·대변인에 김한규·이소영</a>
#                                                             </div>
#                                                         </li>
#
#
#
#                                         </ul>
#                                     </div>
#
#                                         <div class="cluster_foot">
#                                             <div class="cluster_foot_inner">
#                                                 <a href="/main/clusterArticles.naver?id=c_202305011210_00000002&mode=LSD&mid=shm&sid1=100&oid=011&aid=0004185341" class="cluster_foot_more nclicks(cls_pol.clstitle)"><span class="cluster_foot_more_icon_num">62</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#                                             </div>
#                                         </div>
#
#                                 </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             <div class="cluster_group _cluster_content" >
#
#                                 <div class="cluster_body">
#                                     <ul class="cluster_list">
#
#
#                                         <li class="cluster_item">
#
#
#
#                                                 <div class="cluster_thumb">
#                                                     <div class="cluster_thumb_inner">
#                                                         <a href="https://n.news.naver.com/mnews/article/056/0011476070?sid=100" class="cluster_thumb_link nclicks(cls_pol.clsart)">
#
#                                                             <img src="https://imgnews.pstatic.net/image/origin/056/2023/05/01/11476070.jpg?type=ofullfill132_90" width="132" height="90" alt="" onError="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;">
#
#                                                         </a>
#                                                     </div>
#                                                 </div>
#
#                                             <div class="cluster_text">
#                                                 <a href="https://n.news.naver.com/mnews/article/056/0011476070?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">윤 대통령 “업그레이드 한미동맹, 청년 기회의 플랫폼 돼야”</a>
#                                                 <div class="cluster_text_lede">윤석열 대통령이 한미정상회담 결과가 청년 미래 세대에게 기회의 플랫폼이 되도록 후속조치를 구체화해 달라고 지시했습니다. 윤 대통령은 오늘(1일) 용산 대 …</div>
#                     <div class="cluster_text_info _rcount"    data-comment="{gno:'news056,0011476070',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                     <div class="cluster_text_press">KBS</div>
#                                                 </div>
#                                             </div>
#                                         </li>
#
#
#                                         <li class="cluster_item">
#
#
#
#                                                 <div class="cluster_thumb">
#                                                     <div class="cluster_thumb_inner">
#                                                         <a href="https://n.news.naver.com/mnews/article/277/0005253026?sid=100" class="cluster_thumb_link nclicks(cls_pol.clsart)">
#
#                                                             <img src="https://imgnews.pstatic.net/image/origin/277/2023/05/01/5253026.jpg?type=ofullfill132_90" width="132" height="90" alt="" onError="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;">
#
#                                                         </a>
#                                                     </div>
#                                                 </div>
#
#                                             <div class="cluster_text">
# ...
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/666/2023/05/02/10203.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">학교 다녀오면 ‘꼬르륵’…학생·학부모, 부실 급식 뿔났다</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=666"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png" width="16" height="16" alt=""></span>경기일보</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/145/0000018628?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/145/2023/05/01/18628.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/145/0000018628?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">호텔신라 50주년 생일 경품 잔치연다</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16" height="16" alt=""></span>레이디경향</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#     </ul>
#
#
#
#
#
#
#     <button type="button" class="refresh_button nclicks('rig.renws2new') _refreshButton">더보기</button>
#
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
#
#
#
#                     <div class="side_ad" id="glad_ad_sidebox"></div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 <div class="section" style="margin-bottom:20px; white-space:nowrap;" id="right_dailyList">
#  <h4>분야별 주요뉴스</h4>
#  <div class="classfy sd" style="display:block">
#   <ul class="list_txt">
#    <li> <a href="https://n.news.naver.com/mnews/article/052/0001879861?sid=100" class="nclicks(rig.secteco)" title="[뉴스라이더] 대통령실, 공천 거론하며 옹호 발언 요청?...태영호 &quot;사실 아냐&quot;">[뉴스라이더] 대통령실, 공천 거론하며 옹호 발언 요청?...태영호 &quot;사실 아냐&quot;</a> </li>
#    <li> <a href="https://n.news.naver.com/mnews/article/003/0011834805?sid=100" class="nclicks(rig.secteco)" title="전세사기 특별법, 보증금 최대 4.5억까지 구제">전세사기 특별법, 보증금 최대 4.5억까지 구제</a> </li>
#    <li> <a href="https://n.news.naver.com/mnews/article/022/0003808429?sid=100" class="nclicks(rig.secteco)" title="‘막말’ 김재원&middot;태영호 징계 돌입… 리스크 털고 분위기 반전시킬 수 있을까">‘막말’ 김재원&middot;태영호 징계 돌입… 리스크 털고 분위기 반전시킬 수 있을까</a> </li>
#    <li> <a href="https://n.news.naver.com/mnews/article/009/0005124425?sid=104" class="nclicks(rig.secteco)" title="“한국인 손해 막심하다”...휴지조각 위기에 빠진 서학개미 순매수 5위 주식 [월가월부]">“한국인 손해 막심하다”...휴지조각 위기에 빠진 서학개미 순매수 5위 주식 [월가월부]</a> </li>
#    <li> <a href="https://n.news.naver.com/mnews/article/014/0005005630?sid=104" class="nclicks(rig.secteco)" title="기시다 &quot;7~8일 韓 방문&quot;, 尹과 마음 터놓고 대화 기대">기시다 &quot;7~8일 韓 방문&quot;, 尹과 마음 터놓고 대화 기대</a> </li>
#   </ul>
#   <ul class="list_txt">
#    <ul class="list_txt">
#     <li> <a href="https://n.news.naver.com/mnews/article/003/0011834641?sid=101" class="nclicks(rig.secteco)" title="4월 물가 14개월만에 3%대…전기요금 인상&middot;환율 '변수'(종합)">4월 물가 14개월만에 3%대…전기요금 인상&middot;환율 '변수'(종합)</a> </li>
#     <li> <a href="https://n.news.naver.com/mnews/article/008/0004882074?sid=101" class="nclicks(rig.secteco)" title="SK E&amp;S, 미국 업체와 손잡고 국내 수소산업에 1조원 투자">SK E&amp;S, 미국 업체와 손잡고 국내 수소산업에 1조원 투자</a> </li>
#     <li> <a href="https://n.news.naver.com/mnews/article/469/0000737102?sid=101" class="nclicks(rig.secteco)" title="[단독] '연금 신뢰 속 평등&middot;연대' 갈구 프랑스…한국과 결 다른 국민연금 세대갈등">[단독] '연금 신뢰 속 평등&middot;연대' 갈구 프랑스…한국과 결 다른 국민연금 세대갈등</a> </li>
#     <li> <a href="https://n.news.naver.com/mnews/article/030/0003095650?sid=105" class="nclicks(rig.secteco)" title="LG유플러스, MDS테크와 산업용 스마트 무전 서비스 확대">LG유플러스, MDS테크와 산업용 스마트 무전 서비스 확대</a> </li>
#     <li> <a href="https://n.news.naver.com/mnews/article/003/0011834711?sid=105" class="nclicks(rig.secteco)" title="&quot;반찬&middot;국물 많은 韓매장에 최적&quot;…KT, 차세대 AI 서비스로봇 출시">&quot;반찬&middot;국물 많은 韓매장에 최적&quot;…KT, 차세대 AI 서비스로봇 출시</a> </li>
#    </ul>
#    <ul class="list_txt">
#     <ul class="list_txt">
#      <li> <a href="https://n.news.naver.com/mnews/article/022/0003808473?sid=102" class="nclicks(rig.secteco)" title="“조사받겠다”는 송영길… “조사 불가”라는 검찰">“조사받겠다”는 송영길… “조사 불가”라는 검찰</a> </li>
#      <li> <a href="https://n.news.naver.com/mnews/article/057/0001739426?sid=102" class="nclicks(rig.secteco)" title="길 걷던 부부 덮친 음주운전 차량…아내 사망&middot;남편 중상">길 걷던 부부 덮친 음주운전 차량…아내 사망&middot;남편 중상</a> </li>
#      <li> <a href="https://n.news.naver.com/mnews/article/079/0003765355?sid=102" class="nclicks(rig.secteco)" title="'시작부터 극한대립' 내년 최저임금 첫 회의…주요 쟁점은?">'시작부터 극한대립' 내년 최저임금 첫 회의…주요 쟁점은?</a> </li>
#      <li> <a href="https://n.news.naver.com/mnews/article/215/0001098845?sid=103" class="nclicks(rig.secteco)" title="'게임체인저' 기아 EV9 사전계약 시작…7337만원부터">'게임체인저' 기아 EV9 사전계약 시작…7337만원부터</a> </li>
#      <li> <a href="https://n.news.naver.com/mnews/article/011/0004185587?sid=103" class="nclicks(rig.secteco)" title="세련미 강조된 '2024 셀토스'…주차보조 시스템도 태웠다">세련미 강조된 '2024 셀토스'…주차보조 시스템도 태웠다</a> </li>
#     </ul>
#    </ul>
#   </ul>
#  </div>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <div class="banner">
#   <a href="https://media.naver.com/channel/settings" class="nclicks(rig.banner)"> <img src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300" alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" /> </a>
#  </div>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <a href="https://news.naver.com/main/assembly/index.naver" class="nclicks(rig.banner)" target="_blank"> <img src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300" height="60" border="0" alt="내일을 여는 국민의 국회" class="banner" /> </a>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <div class="banner">
#   <a href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" class="nclicks(rig.banner)" target="_blank"> <img src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300" alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" /> </a>
#  </div>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <h4> <a href="https://news.naver.com/main/ombudsman/index.naver" class="nclicks(rig.text)"> 서비스 안내 </a> </h4>
#  <ul class="list_txt">
#   <li> <a href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb" class="nclicks(rig.text)"> 고침 기사 모음 </a> </li>
#   <li> <a href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb" class="nclicks(rig.text)"> 정정&middot;반론&middot;추후 보도 기사 모음 </a> </li>
#   <li> <a href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb" class="nclicks(rig.text)"> 불공정 선거 보도 기사 모음 </a> </li>
#  </ul>
#  <a href="https://news.naver.com/main/ombudsman/index.naver" class="more_link nclicks(rig.text)"><span class="blind">서비스 안내</span>더보기</a>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
#
# 					</div>
# 				</td>
# 			</tr>
# 		</table>
# 	</div>
#
# 	<hr>
# <div class="index">
#
#
#
# <div class="index_inner">
#
# 	<div class="floating_btn" >
# 		<div class="floating_inner">
# 			<a href="javascript:history.back();" class="floating_btn_back"><span class="blind">이젠 페이지</span></a>
# 			<a href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;" class="floating_btn_top"><span class="blind">맨위로</span></a>
# 		</div>
# 	</div>
# 	<div id="index.press_category" class="index_tab">
# 		<a id="index.press.btn" href="#" class="spr stit nclicks(fot.press)">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# 		<div id="index.press.area" class="index_content is_hidden"></div>
# 		<a id="index.category.btn" href="#" class="spr stit2 nclicks(fot.section)">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# 		<div id="index.category.area" class="index_content02 is_hidden"></div>
# 	</div>
# </div>
#
#
# </div>
# <hr>
# <div id="footer">
#
# <ul>
# <li class="first"><a href="http://www.naver.com/rules/service.html" class="nclicks(fot.agreement)">이용약관</a></li>
# <li><a href="/main/ombudsman/index.naver" class="nclicks(fot.guide)">서비스 안내</a></li>
# <li><a href="/main/ombudsman/edit.naver?mid=omb" class="nclicks(fot.editor)">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a href="http://www.naver.com/rules/privacy.html" class="nclicks(fot.privacy)">개인정보처리방침</a></strong></li>
# <li><a href="http://www.naver.com/rules/disclaimer.html" class="nclicks(fot.disclaimer)">책임의 한계와 법적고지</a></li>
# <li><a href="#" title="새창" onclick="news.external.OPS.helpNews(); return false;" class="nclicks(fot.help)">뉴스 고객센터</a></li>
# </ul>
# 	<p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
#
#
# 	<address class="address_nhn">
# 	<a href="https://www.navercorp.com/" target="_blank" class="logo nclicks(fot.naver)"><span class="blind">NAVER</span></a>
# 	<em>Copyright &copy;</em>
# 	<a href="https://www.navercorp.com/" target="_blank" class="nclicks(fot.navercorp)">NAVER Corp.</a>
# 	<span>All Rights Reserved.</span>
# </address>
# 	<!-- -->
#
#
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
# 한글만 뽑기
text = response.content.decode(encoding)
result = ' '.join(re.findall('[가-힣]+',text))
print(result)
# Out:
# 정치 네이버 뉴스 국회 행정 국방 외교 등 정치 분야 뉴스 제공 네이버 정치 네이버 뉴스 네이버 뉴스 네이버 뉴스 국회 행정 국방 외교 등 정치 분야 뉴스 제공 정치 홈 네이버 뉴스 광고적용 태그 추가 메인 메뉴로 바로가기 본문으로 바로가기 검색 뉴스 연예 스포츠 날씨 프리미엄 언론사별 정치 선택됨 경제 사회 생활 문화 과학 세계 랭킹 신문보기 오피니언 팩트체크 전체 언론사 전체 언론사 뉴스스탠드 뉴스스탠드 라이브러리 라이브러리 화 전체 언론사 전체 언론사 뉴스스탠드 뉴스스탠드 라이브러리 라이브러리 기사목록 정치 대통령실 국회 정당 북한 행정 국방 외교 정치일반 언론사 구독하기 네이버 프리미엄콘텐츠 안내 헤드라인 뉴스 헤드라인 뉴스와 각 기사묶음 타이틀은 기사 내용을 기반으로 자동 추출 됩니다 닫기 이재명 방탄 소급입법까지 허위사실 공표 처벌 못하게 개정 추진 선거법 개정안 소급 적용 추진 민주당 일부 의원이 이재명 대표가 공직선거법 위반으로 기소되기 일 전인 작년 월 일 이 대표 기소의 근거 조항을 조선일보 헤럴드경제 이재명 처벌근거 삭제법은 방탄 장경태 이제와서 의도 의심 뉴시스 이재명 방탄 선거법 개정 음흉한 시도 방탄 관련 없어 종합 연합뉴스 월 국회 소집 작년 월부터 방탄국회 여념없어 개의 관련뉴스 더보기 정부 전세피해 특별법 지원요건 개 개 축소안 제시 국토교통부가 전세사기 피해지원 특별법 적용 기준 가지로 줄인 수정안을 제시했다 기존에 나왔던 가지 기준이 협소하다는 지적에 따라 적용 범위를 일부 헤럴드경제 여야 전세사기 특별법 합의 불발 추후 재논의 예정 매일경제 전세사기 늪에 빠진 대한민국 정부 특별법 만들어 구제 나서 경제기사 이렇게 읽어요 국민일보 전세사기 특별법 합의 불발 선매입 후구상 놓고 이견 개의 관련뉴스 더보기 단독 미 전략핵잠 핵 무장 하고 방한 중하순 유력 오하이오급 잠수함에서 발사되는 트라이던트 한미 정상의 워싱턴 선언에 따라 우리 항구에 기항할 미 해군 전략핵잠수함이 핵탄두를 탑재하는지 관심 부산일보 단독 핵탄두 탑재 오는 일 부산 첫 기항 유력 조선일보 한국 올 핵잠 을 지도에서 지워버릴 위력 단독 미군 잠수함 핵무장 공식화 맞춰 한국으로 개의 관련뉴스 더보기 민주 신임 원내수석에 비명 송기헌 원내대표 비서실장에 친명 민병덕 박광온 더불어민주당 원내대표는 일 신임 원내수석부대표로 재선의 송기헌 강원 원주을 의원을 선임했다 박 원내대표는 일 오후 국회에서 기자회견을 열고 서울경제 중앙일보 박광온 대의원제 폐지 돈봉투 해법 아니다 친명계와 시각차 한국경제 박광온 첫 시험대는 사법 리스크 쇄신 의총 열 것 헤럴드경제 민주당 신임 원내수석에 비명 송기헌 대변인에 김한규 이소영 개의 관련뉴스 더보기 윤 대통령 업그레이드 한미동맹 청년 기회의 플랫폼 돼야 윤석열 대통령이 한미정상회담 결과가 청년 미래 세대에게 기회의 플랫폼이 되도록 후속조치를 구체화해 달라고 지시했습니다 윤 대통령은 오늘 일 용산 대 확장된 한미동맹 미래세대 기회 플랫폼 돼야 윤석열 대통령은 일 확장억제 강화 각 분야 협력 확대 등이 합의한 한미정상회담 결과와 관련해 청년 미래 세대에게 기회의 플랫폼이 되도록 후속 조치를 아시아경제 개의 관련뉴스 더보기 태영호 녹취록 파문 에 당내서도 역풍 거짓말 멈추고 국회 떠나라 유승민 대통령실이 현역 의원에게 하수인 역할 하도록 공천 협박 태영호 보좌진에 과장 섞어 말해 이진복 공천 전혀 언급 안 해 징계 위기에 몰린 시사저널 정무수석 태영호 공천 이야기 논의조차 안 돼 사과 받아 이진복 대통령실 정무수석은 일 태영호 국민의힘 최고위원에게 공천 문제를 거론하며 한일 관계에 대해 옹호 발언을 해달라고 요청했다 는 의혹에 대해 그 아시아경제 개의 관련뉴스 더보기 박대출 방송법 국회 통과하면 대통령이 거부권 행사해야 종합 라디오 좌파매체에 점령당해 방송법 강행 공영방송 장악 꼼수 김기현 관련 세미나에서 편향성 안돼 방송 기본정신으로 돌아가야 국민 연합뉴스 어떤 정치세력도 공영방송 과점 못하게 방송법 개정 필요 윤창현 언론노조위원장 독립성이 권력 언론 관계에서 최고 가치 윤창현 전국언론노동조합 위원장은 방송법 개정안이 여당 반대 속에 국회 본회의에 부의된 것 연합뉴스 개의 관련뉴스 더보기 속보 대통령실 여야 원내대표와 대통령 회동 마다할 이유 없다 대통령실이 일 여야 원내대표가 서로 합의한다면 윤석열 대통령은 여야 원내대표와의 만남을 마다할 이유가 없다 고 밝혔다 대통령실 관계자는 이날 서울 서울경제 원내대표 만남 마다할 이유 없다 대통령실 여야가 합의한다면 방미 성과 공유하는 자리 가능 과 지도부는 만난 적 없어 실제 회동 성사 여부 지켜봐야 대통령실은 일 윤석열 대통령과 조선일보 개의 관련뉴스 더보기 동영상기사 김재원 태영호 징계 절차 개시 공천 영향 관심 국민의힘 윤리위원회가 잇단 설화로 논란이 됐던 김재원 태영호 최고위원에 대한 징계 절차에 착수했습니다 다음 주 두 최고위원의 소명을 듣고 징계 여부와 윤리위 김재원 태영호 징계 절차 개시 호 징계 수위는 윤리위 첫 회의 열고 징계 개시 결정 월 자숙 김재원은 최고위 복귀 국민의힘 윤리위원회가 일 김재원 태영호 최고위원의 징계 절차를 개시했다 김 서울신문 개의 관련뉴스 더보기 김진표 하원의원 방한단 접견 올해 안에 한미의원연맹 창설하자 김진표 국회의장은 일 미국 하원의원 방한단과 만나 한미동맹 주년을 맞아 추진 중인 한미 미한의원연맹 창설에 공감대를 형성했다 김 의장은 일 뉴스 김 의장 만난 미 하원의원단 윤 대통령 환상적인 방미 김진표 의장 미국 하원의원 방한단 접견 번 뷰캐넌 의원이 이끄는 미국 하원의원단은 일 윤석열 대통령의 미국 국빈 방문을 두고 환상적인 방미 라고 개의 관련뉴스 더보기 프라미스 성공 외교 역량의 성과 국민 이송 당연한 일 종합 기사내용 요약 수단 대사관 외교부 직원들 노고에 감사하다 우리 정부 우방국과 신뢰 쌓아와서 가능한 일 서울 뉴윤석열 대통령은 일 군벌 간 무 뉴시스 프라미스 성공은 외교 역량 성과 작전 참가자 노고 치하 윤석열 대통령은 일 군벌 간 무력 충돌이 발생한 수단에서 우리 교민을 구출하는 프라미스 약속 작전을 성공적으로 수행한 참가자들을 격 중앙일보 개의 관련뉴스 더보기 이달 회의 때 한미일 정상회담 한미일 국 정상회담이 이달 일본에서 열리는 주요 개국 정상회의 기간에 개최된다고 미국 정부가 밝혔습니다 미 행정부 고위 당국자는 현지시간으로 한미일 정상회담 히로시마 정상회의 맞춰 실시 매체 한미일 정상회담이 오는 일 일본 히로시마에서 열리는 주요 개국 정상회의 기간에 맞춰 열린다고 지지통신이 일 보도했다 지지통신은 미국 정부 뉴스 개의 관련뉴스 더보기 나 방첩사야 사칭 민간인 해병대 영내 활보하다 검거 종합 국군 방첩사령부 소속을 사칭한 민간인이 해병대 영내를 무단 침입해 시간가량 활보하는 사건이 발생했다 일 군 소식통에 따르면 지난달 일 오후 시 연합뉴스 해병대 행사 틈타 침입 방첩사 사칭한 민간인 시간 활보 국군 방첩사령부 소속을 사칭한 민간인이 해병대 영내를 무단 침입해 시간가량 활보하는 사건이 발생했다 일 군 소식통에 따르면 지난달 일 오후 시 중앙일보 개의 관련뉴스 더보기 윤재옥 의료대란 우려 민주당 간호법 대안 협조해야 윤재옥 국민의힘 원내대표는 일 더불어민주당을 향해 의료 서비스 발전과 국민 건강을 생각한다면 특정 단체와 손잡고 정부를 압박할 것이 아니라 반대하는 이데일리 윤재옥 송영길 꼼수 출두 쇼 대신 국민 앞에 사죄해야 수사 방해 여론호도 목적 의료계 총파업 예고엔 민주당의 입법독주 탓 국민의힘 윤재옥 원내대표는 일 더불어민주당 년 전당대회 돈 봉투 의 연합뉴스 개의 관련뉴스 더보기 국제사회 워싱턴선언 부정적후과 우려 중러보도 인용해 반발 북한이 일 북핵 위협에 대응해 한미 정상이 채택한 워싱턴선언 을 두고 중국 러시아 보도를 인용해 반발을 이어갔다 조선중앙통신과 노동당 기관지 노동 서울경제 북 매체 중러 워싱턴선언 비판 조명 부정적 후과 우려해 북한은 일 한국과 미국이 북핵 위협에 대응해 합의한 워싱턴 선언 을 두고 중국과 러시아 등 주요 우방국에서 내놓는 비판 목소리에 힘을 실으며 여론전에 연합뉴스 개의 관련뉴스 더보기 이원욱 송영길 자진출두 어리둥절 민주당 정치적 책임져야 최강시사 송 ...

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url  = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'

html = requests.get(url, headers=headers).text
bs = BS(html, 'lxml')
print(bs.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=1106" name="viewport"/>
# <meta content="정치 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" name="twitter:description"/>
# <title>정치 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Tue May 02 10:09:13 KST 2023";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>02</strong><span class="day">(화)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
# <ul class="nav">
# <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a></li>
# <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
# <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
# <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
# <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
# <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834229?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11834229.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834229?sid=100">與 윤리위, 김재원·태영호 징계 개시 오는 8일 당사자 소명 [뉴시스Pic]</a>
# <div class="cluster_text_lede">국민의힘 중앙당 윤리위원회는 잇단 설화로 물의를 일으킨 김재원·태영호 최고위원에 대한 징계 절차를 개시하기로 했다. 이날 오전에 김재원 최고위원이 한 달 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011834229',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277011',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277011?sid=100">[속보] 與윤리위, '설화' 김재원·태영호 징계절차 개시</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0005124101',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/009/0005124101?sid=100">與윤리위, 김재원·태영호 징계 개시…김재원 “대단히 죄송”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003494780',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">동아일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003494780?sid=100">與, ‘설화’ 김재원 징계절차 개시… 金 “사퇴 생각 안해”</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011834229"><span class="cluster_foot_more_icon_num">98</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054742?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/02/1054742.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054742?sid=100">"나 방첩사야" 사칭 민간인, 해병대 영내 활보하다 검거</a>
# <div class="cluster_text_lede">국군 방첩사령부 소속을 사칭한 민간인이 해병대 영내를 무단 침입해 2시간가량 활보하는 사건이 발생했습니다. 군 소식통에 따르면 지난달 28일 오후 4시  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054742',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news448,0000407175',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">TV조선</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/448/0000407175?sid=100">"나 방첩사 소속이야"…차량에 경광등 단 민간인에 뚫린 해병대</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005253156',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253156?sid=100">민간인이 해병대 침입해 영내 2시간 활보…“방첩사 사칭”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185627',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185627?sid=100">"나 방첩사 소속이야" 사칭 민간인, 해병대 부대 2시간 넘게 활보하다 검거</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011710_00000074&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=055&amp;aid=0001054742"><span class="cluster_foot_more_icon_num">20</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253217?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/277/2023/05/02/5253217.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253217?sid=100">⑤지지부진한 3대 개혁…돌파구는?[尹정부 1년]</a>
# <div class="cluster_text_lede">윤석열 대통령이 국정 과제로 내건 '3대(노동·교육·연금) 개혁'은 최근 논의가 지지부진하다. '초등학교 입학 연령 만 5세로 하향 조정'을 골자로 한  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005253217',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879802',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879802?sid=100">與 노동개혁특위 오늘 출범..."개혁 입법 방안 논의"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054749',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054749?sid=100">국민의힘 노동개혁특위 출범…'공정채용법' 추진</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006781090',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006781090?sid=100">與, 오늘 노동개혁특위 출범…공정성·노사법치 등 대안 마련</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305020610_00000100&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=277&amp;aid=0005253217"><span class="cluster_foot_more_icon_num">7</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005476607?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2023/05/01/5476607.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005476607?sid=100">한총리, 美 하원의원과 만나…"IRA 상호협력 방향으로 가야"</a>
# <div class="cluster_text_lede">한덕수 국무총리가 1일 정부서울청사에서 번 뷰캐넌(Vern Buchanan) 미 하원 민주주의 파트너십 의장이 이끄는 의원단을 만나 인플레이션 감축법(I …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005476607',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">이데일리</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013915082',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915082?sid=100">김의장 만난 美하원의원단 "尹대통령, 환상적인 방미"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news081,0003357970',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울신문</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/081/0003357970?sid=100">美 하원의원단 만난 韓총리 “IRA, 상호 투자 증진의 계기”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005005400',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">파이낸셜뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005005400?sid=100">한총리 "한미 정상, 북 비핵화 공조 의지 확인"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011620_00000009&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=018&amp;aid=0005476607"><span class="cluster_foot_more_icon_num">17</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013914209?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13914209.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013914209?sid=100">민주 원내수석에 '비명' 송기헌…원내대변인은 김한규·이소영</a>
# <div class="cluster_text_lede">미래에셋 출신 홍성국은 경제 담당 대변인…비서실장은 민병덕 더불어민주당 신임 원내수석부대표에 비명(비이재명)계인 재선의 송기헌(강원 원주을) 의원이 선임 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013914209',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185480?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/01/4185480.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185480?sid=100">민주 원내 진용 새단장…비명·소장파 전면에</a>
# <div class="cluster_text_lede">박광온 더불어민주당 신임 원내대표가 비명계 소장파 중심으로 원내대표단을 구성했다. 당 지도부가 친명계를 주축으로 진용을 갖춘 가운데 비명계가 원내 지도부 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185480',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011210_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013914209"><span class="cluster_foot_more_icon_num">62</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/009/0005124371?sid=100">전세사기 피해 특별법 적용대상 대폭 늘린다</a>
# <div class="cluster_text_lede">국토부 수정안 국회 제출 주택 면적 요건 없애고 보증금 3억→4.5억으로 정부가 전세사기 피해 임차인들을 위해 지난주 내놓은 특별법에 대한 야당과 피해 임차인들의 거센 불만이 지속되자 기존 특별법 적용 대상 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0005124371',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797933?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/029/2023/05/01/2797933.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797933?sid=100">전세사기 피해, 미추홀은 맞지만 동탄은 아니다?</a>
# <div class="cluster_text_lede">국회, '전세사기 특별법' 심사…피해자들 "인정기준 까다롭고 모호해" "피해가 명백히 예정됐는데도, 전세 만기 후 전세보증금 반환 소송을 내 승소 판결문 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news029,0002797933',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">디지털타임스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304261610_00000094&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=009&amp;aid=0005124371"><span class="cluster_foot_more_icon_num">79</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761149?sid=100">尹 “한미 산업·교육동맹 확장… 청년 위한 플랫폼으로”</a>
# <div class="cluster_text_lede">윤석열 대통령은 1일 “이번 한미 정상회담은 안보를 비롯해 산업·과학기술·교육·문화 등 모든 면으로 동맹을 확장시켰다는 데 큰 의미가 있다”면서 대통령실과 내각에 “무엇보다 청년 미래 세대에게 기회의 플랫폼 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003761149',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220722?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/032/2023/05/01/3220722.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220722?sid=100">윤 대통령 “업그레이드된 한·미 동맹, 청년에게 기회의 플랫폼 되어야”</a>
# <div class="cluster_text_lede">5박7일간 미국 국빈 방문을 마치고 전날 귀국한 윤석열 대통령은 1일 “업그레이드되고 확장된 한·미 동맹은 청년 미래 세대에게 기회의 플랫폼이 되어야 한 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news032,0003220722',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">경향신문</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011110_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003761149"><span class="cluster_foot_more_icon_num">28</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915601?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/02/13915601.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915601?sid=100">한총리, 정부대표로 英 찰스 대관식 참석…6박8일간 유럽 4개국 순방</a>
# <div class="cluster_text_lede">대관식 참석 후 스웨덴·오스트리아·루마니아 방문 "각국과 경제안보·첨단산업 등 협력 논의…부산엑스포 유치 교섭도" 한덕수 국무총리가 이달 4∼11일 6박 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013915601',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277218?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2023/05/02/3277218.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277218?sid=100">한총리, 6박8일 일정 유럽 4개국 순방…찰스 3세 국왕 대관식 참석</a>
# <div class="cluster_text_lede">한덕수 국무총리가 4일부터 11일까지 6박 8일 일정으로 영국, 스웨덴, 오스트리아, 루마니아를 방문한다고 2일 총리실이 전했다. 총리실에 따르면 한 총 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277218',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305020850_00000029&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013915601"><span class="cluster_foot_more_icon_num">10</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879562?sid=100">與 박대출 "방송법 통과하면, 대통령이 거부권 행사해야"</a>
# <div class="cluster_text_lede">국민의힘 박대출 정책위의장은 더불어민주당 주도로 국회 본회의에 직회부된 공영방송 지배구조 개편을 위한 방송법 개정안 등과 관련해, 법안이 국회를 통과하면 대통령은 거부권, 재의요구권을 행사해야 마땅할 것이라 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879562',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185508?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/01/4185508.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185508?sid=100">“친야 패널 7배 많았다”…與 'KBS1 라디오' 尹방미 보도 편향성 지적</a>
# <div class="cluster_text_lede">국민의힘이 윤석열 대통령의 미국 순방을 다룬 KBS1 라디오 출연진이 “극도로 편향돼 있었다”고 반발했다. 여당 측 인사보다 야당 측 인사가 7배 더 많 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185508',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304300910_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001879562"><span class="cluster_foot_more_icon_num">27</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000737105?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/469/2023/05/02/737105.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000737105?sid=100">尹, 기시다 답방·한미일 협력 강화로 '외교 주도권' 이어간다</a>
# <div class="cluster_text_lede">윤석열 대통령이 12년 만의 국빈 방미 성과로 도출한 '워싱턴 선언'을 바탕으로 한미일 3국 협력 강화와 더 나아가 '글로벌 중추국가' 실현을 위해 속도 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news469,0000737105',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881714?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/008/2023/05/01/4881714.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881714?sid=100">尹대통령, 동북아 판을 바꾼 '美국빈방문'…일본이 급해졌다</a>
# <div class="cluster_text_lede">'워싱턴 선언'이란 성과를 남긴 윤석열 대통령의 5박7일 미국 국빈 방문이 끝났다. 한미동맹 70주년을 맞아 핵전력을 포함하는 사실상 제2의 상호방위조약 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881714',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010730_00000154&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=469&amp;aid=0000737105"><span class="cluster_foot_more_icon_num">30</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898137?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/05/01/898137.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898137?sid=100">尹대통령 “‘프라미스’ 성공, 외교 역량의 성과”… 작전 참가자도 격려</a>
# <div class="cluster_text_lede">수단 교민 구출한 외교·국방 관계자들, 용산 대통령실로 초청 남궁환 주수단 대사 “수송기·청해부대 파견 등 신속·과감한 지원해 준 尹대통령에 감사” 윤석 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898137',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/082/0001210024?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/082/2023/05/01/1210024.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/082/0001210024?sid=100">윤 대통령, 귀국 후 첫 공식일정은 '수단 교민 구출팀' 격려</a>
# <div class="cluster_text_lede">윤석열 대통령은 1일 군벌 간 무력 충돌이 발생한 수단에서 우리 교민을 구출하는 '프라미스'(Promise·약속) 작전을 성공적으로 수행한 참가자들을 격 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news082,0001210024',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">부산일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011050_00000024&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=366&amp;aid=0000898137"><span class="cluster_foot_more_icon_num">28</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913535?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13913535.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913535?sid=100">북 매체, 중러 '워싱턴선언' 비판 조명…"부정적 후과 우려해"</a>
# <div class="cluster_text_lede">북한은 1일 한국과 미국이 북핵 위협에 대응해 합의한 '워싱턴 선언'을 두고 중국과 러시아 등 주요 우방국에서 내놓는 비판 목소리에 힘을 실으며 여론전에 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913535',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779675?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/01/6779675.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779675?sid=100">북한 "국제사회도 '워싱턴 선언'에 커다란 우려 표시"</a>
# <div class="cluster_text_lede">북한이 지난달 26일(현지시간) 한미정상회담에서 도출된 '워싱턴 선언'에 대해 국제사회가 부정적 결과를 우려하고 있다며 재차 반발했다. 북한 노동당 기관 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779675',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010800_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013913535"><span class="cluster_foot_more_icon_num">12</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834410?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11834410.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834410?sid=100">與 "이재명 방탄 선거법 개정…음흉한 시도" vs 野 "방탄 관련 없어"(종합)</a>
# <div class="cluster_text_lede">기사내용 요약 "이재명 방탄 위해 선거를 '아무말 대잔치'로" "'김문기 몰랐다'는 이재명 유죄 시 면소 판결" 장경태 해명 "작년 8월 발의…여, 취지 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011834410',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137733?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2023/05/02/2137733.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137733?sid=100">與 “이재명 처벌근거 삭제법은 ‘방탄’” vs 장경태 “이제와서? 의도 의심”</a>
# <div class="cluster_text_lede">국민의힘은 지난해 더불어민주당이 공직선거법상 허위사실 공표 대상을 줄이는 내용의 법안을 발의한 것을 두고 “이재명 구하기”라고 맹비난했다. 대표발의한 장 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137733',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011150_00000579&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011834410"><span class="cluster_foot_more_icon_num">15</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760997?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2023/05/01/3760997.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760997?sid=100">한국 올 美핵잠, 北을 지도에서 지워버릴 위력</a>
# <div class="cluster_text_lede">한국 항구에 기항 예고… 美의 전략 핵잠수함은 전략 핵잠수함(SSBN)은 핵탄두 장착 잠수함 발사 탄도미사일(SLBM)을 탑재한 핵추진 잠수함이다. 타국 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003760997',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054716?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/02/1054716.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054716?sid=100">'핵 무장' 잠수함, 한국 방문…이번 달 중순 G7 기간 유력</a>
# <div class="cluster_text_lede">이번 한미 정상회담에서 채택된 워싱턴 선언에는 미국 전략핵 잠수함이 우리 항구를 정기적으로 들른다는 뜻의 '한국 기항'이라는 문구가 포함돼 있습니다. 관 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054716',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304261620_00000195&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003760997"><span class="cluster_foot_more_icon_num">9</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000737139?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/469/2023/05/02/737139.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000737139?sid=100">이진복 "태영호와 공천 얘기한 적 없다" 공천 거론 의혹 부인</a>
# <div class="cluster_text_lede">이진복 대통령실 정무수석은 2일 태영호 국민의힘 최고위원의 녹취록과 관련해 '공천 문제를 거론하며 한일관계에 대해 옹호 발언을 해달라고 요청했다'는 의혹 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news469,0000737139',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915591?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/02/13915591.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915591?sid=100">이진복 "태영호와 공천 얘기 나눈 적 없다"</a>
# <div class="cluster_text_lede">'공천 영향력 행사' 의혹 보도 부인 이진복 대통령실 정무수석은 2일 국민의힘 태영호 최고위원과 관련해 '공천 문제를 거론하며 한일 관계에 대해 옹호 발 …</div>
# ...
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/655/0000009618?ntype=RANKING&amp;sid=001">청주동물원 이전 여부 외부용역 의회서 제동..출구전략은?</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=655"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/655/2022/01/20/logo_655_56_20220120164501.png" width="16"/></span>CJB청주방송</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024362?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/661/2023/05/02/24362.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024362?ntype=RANKING&amp;sid=001">국민연금 月 200만원 ↑ 고액수령자 한달새 3배 '껑충' …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16"/></span>JIBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014464?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/657/2023/05/01/14464.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014464?ntype=RANKING&amp;sid=001">[뉴스비하인드] 대구경북신공항, 새로운 하늘길인가? 꽉 막 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=657"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/657/2022/01/19/logo_657_56_20220119135625.png" width="16"/></span>대구MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/666/2023/05/02/10203.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&amp;sid=001">학교 다녀오면 ‘꼬르륵’…학생·학부모, 부실 급식 뿔났다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=666"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png" width="16"/></span>경기일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018628?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2023/05/01/18628.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018628?ntype=RANKING&amp;sid=001">호텔신라 50주년 생일 경품 잔치연다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001879861?sid=100" title='[뉴스라이더] 대통령실, 공천 거론하며 옹호 발언 요청?...태영호 "사실 아냐"'>[뉴스라이더] 대통령실, 공천 거론하며 옹호 발언 요청?...태영호 "사실 아냐"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834805?sid=100" title="전세사기 특별법, 보증금 최대 4.5억까지 구제">전세사기 특별법, 보증금 최대 4.5억까지 구제</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808429?sid=100" title="‘막말’ 김재원·태영호 징계 돌입… 리스크 털고 분위기 반전시킬 수 있을까">‘막말’ 김재원·태영호 징계 돌입… 리스크 털고 분위기 반전시킬 수 있을까</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/009/0005124425?sid=104" title="“한국인 손해 막심하다”...휴지조각 위기에 빠진 서학개미 순매수 5위 주식 [월가월부]">“한국인 손해 막심하다”...휴지조각 위기에 빠진 서학개미 순매수 5위 주식 [월가월부]</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/014/0005005630?sid=104" title='기시다 "7~8일 韓 방문", 尹과 마음 터놓고 대화 기대'>기시다 "7~8일 韓 방문", 尹과 마음 터놓고 대화 기대</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834641?sid=101" title="4월 물가 14개월만에 3%대…전기요금 인상·환율 '변수'(종합)">4월 물가 14개월만에 3%대…전기요금 인상·환율 '변수'(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/008/0004882074?sid=101" title="SK E&amp;S, 미국 업체와 손잡고 국내 수소산업에 1조원 투자">SK E&amp;S, 미국 업체와 손잡고 국내 수소산업에 1조원 투자</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/469/0000737102?sid=101" title="[단독] '연금 신뢰 속 평등·연대' 갈구 프랑스…한국과 결 다른 국민연금 세대갈등">[단독] '연금 신뢰 속 평등·연대' 갈구 프랑스…한국과 결 다른 국민연금 세대갈등</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/030/0003095650?sid=105" title="LG유플러스, MDS테크와 산업용 스마트 무전 서비스 확대">LG유플러스, MDS테크와 산업용 스마트 무전 서비스 확대</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834711?sid=105" title='"반찬·국물 많은 韓매장에 최적"…KT, 차세대 AI 서비스로봇 출시'>"반찬·국물 많은 韓매장에 최적"…KT, 차세대 AI 서비스로봇 출시</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808473?sid=102" title="“조사받겠다”는 송영길… “조사 불가”라는 검찰">“조사받겠다”는 송영길… “조사 불가”라는 검찰</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/057/0001739426?sid=102" title="길 걷던 부부 덮친 음주운전 차량…아내 사망·남편 중상">길 걷던 부부 덮친 음주운전 차량…아내 사망·남편 중상</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765355?sid=102" title="'시작부터 극한대립' 내년 최저임금 첫 회의…주요 쟁점은?">'시작부터 극한대립' 내년 최저임금 첫 회의…주요 쟁점은?</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/215/0001098845?sid=103" title="'게임체인저' 기아 EV9 사전계약 시작…7337만원부터">'게임체인저' 기아 EV9 사전계약 시작…7337만원부터</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004185587?sid=103" title="세련미 강조된 '2024 셀토스'…주차보조 시스템도 태웠다">세련미 강조된 '2024 셀토스'…주차보조 시스템도 태웠다</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>>

# %%
bs.find('div')
# Out:
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>02</strong><span class="day">(화)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
# <ul class="nav">
# <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a></li>
# <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
# <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
# <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
# <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
# <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834229?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11834229.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834229?sid=100">與 윤리위, 김재원·태영호 징계 개시 오는 8일 당사자 소명 [뉴시스Pic]</a>
# <div class="cluster_text_lede">국민의힘 중앙당 윤리위원회는 잇단 설화로 물의를 일으킨 김재원·태영호 최고위원에 대한 징계 절차를 개시하기로 했다. 이날 오전에 김재원 최고위원이 한 달 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011834229',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277011',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277011?sid=100">[속보] 與윤리위, '설화' 김재원·태영호 징계절차 개시</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0005124101',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/009/0005124101?sid=100">與윤리위, 김재원·태영호 징계 개시…김재원 “대단히 죄송”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003494780',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">동아일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003494780?sid=100">與, ‘설화’ 김재원 징계절차 개시… 金 “사퇴 생각 안해”</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011834229"><span class="cluster_foot_more_icon_num">98</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054742?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/02/1054742.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054742?sid=100">"나 방첩사야" 사칭 민간인, 해병대 영내 활보하다 검거</a>
# <div class="cluster_text_lede">국군 방첩사령부 소속을 사칭한 민간인이 해병대 영내를 무단 침입해 2시간가량 활보하는 사건이 발생했습니다. 군 소식통에 따르면 지난달 28일 오후 4시  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054742',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news448,0000407175',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">TV조선</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/448/0000407175?sid=100">"나 방첩사 소속이야"…차량에 경광등 단 민간인에 뚫린 해병대</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005253156',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253156?sid=100">민간인이 해병대 침입해 영내 2시간 활보…“방첩사 사칭”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185627',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185627?sid=100">"나 방첩사 소속이야" 사칭 민간인, 해병대 부대 2시간 넘게 활보하다 검거</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011710_00000074&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=055&amp;aid=0001054742"><span class="cluster_foot_more_icon_num">20</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253217?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/277/2023/05/02/5253217.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253217?sid=100">⑤지지부진한 3대 개혁…돌파구는?[尹정부 1년]</a>
# <div class="cluster_text_lede">윤석열 대통령이 국정 과제로 내건 '3대(노동·교육·연금) 개혁'은 최근 논의가 지지부진하다. '초등학교 입학 연령 만 5세로 하향 조정'을 골자로 한  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005253217',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879802',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879802?sid=100">與 노동개혁특위 오늘 출범..."개혁 입법 방안 논의"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054749',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054749?sid=100">국민의힘 노동개혁특위 출범…'공정채용법' 추진</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006781090',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006781090?sid=100">與, 오늘 노동개혁특위 출범…공정성·노사법치 등 대안 마련</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305020610_00000100&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=277&amp;aid=0005253217"><span class="cluster_foot_more_icon_num">7</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005476607?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2023/05/01/5476607.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005476607?sid=100">한총리, 美 하원의원과 만나…"IRA 상호협력 방향으로 가야"</a>
# <div class="cluster_text_lede">한덕수 국무총리가 1일 정부서울청사에서 번 뷰캐넌(Vern Buchanan) 미 하원 민주주의 파트너십 의장이 이끄는 의원단을 만나 인플레이션 감축법(I …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005476607',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">이데일리</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013915082',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915082?sid=100">김의장 만난 美하원의원단 "尹대통령, 환상적인 방미"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news081,0003357970',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울신문</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/081/0003357970?sid=100">美 하원의원단 만난 韓총리 “IRA, 상호 투자 증진의 계기”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005005400',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">파이낸셜뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005005400?sid=100">한총리 "한미 정상, 북 비핵화 공조 의지 확인"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011620_00000009&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=018&amp;aid=0005476607"><span class="cluster_foot_more_icon_num">17</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013914209?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13914209.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013914209?sid=100">민주 원내수석에 '비명' 송기헌…원내대변인은 김한규·이소영</a>
# <div class="cluster_text_lede">미래에셋 출신 홍성국은 경제 담당 대변인…비서실장은 민병덕 더불어민주당 신임 원내수석부대표에 비명(비이재명)계인 재선의 송기헌(강원 원주을) 의원이 선임 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013914209',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185480?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/01/4185480.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185480?sid=100">민주 원내 진용 새단장…비명·소장파 전면에</a>
# <div class="cluster_text_lede">박광온 더불어민주당 신임 원내대표가 비명계 소장파 중심으로 원내대표단을 구성했다. 당 지도부가 친명계를 주축으로 진용을 갖춘 가운데 비명계가 원내 지도부 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185480',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011210_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013914209"><span class="cluster_foot_more_icon_num">62</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/009/0005124371?sid=100">전세사기 피해 특별법 적용대상 대폭 늘린다</a>
# <div class="cluster_text_lede">국토부 수정안 국회 제출 주택 면적 요건 없애고 보증금 3억→4.5억으로 정부가 전세사기 피해 임차인들을 위해 지난주 내놓은 특별법에 대한 야당과 피해 임차인들의 거센 불만이 지속되자 기존 특별법 적용 대상 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0005124371',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797933?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/029/2023/05/01/2797933.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797933?sid=100">전세사기 피해, 미추홀은 맞지만 동탄은 아니다?</a>
# <div class="cluster_text_lede">국회, '전세사기 특별법' 심사…피해자들 "인정기준 까다롭고 모호해" "피해가 명백히 예정됐는데도, 전세 만기 후 전세보증금 반환 소송을 내 승소 판결문 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news029,0002797933',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">디지털타임스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304261610_00000094&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=009&amp;aid=0005124371"><span class="cluster_foot_more_icon_num">79</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761149?sid=100">尹 “한미 산업·교육동맹 확장… 청년 위한 플랫폼으로”</a>
# <div class="cluster_text_lede">윤석열 대통령은 1일 “이번 한미 정상회담은 안보를 비롯해 산업·과학기술·교육·문화 등 모든 면으로 동맹을 확장시켰다는 데 큰 의미가 있다”면서 대통령실과 내각에 “무엇보다 청년 미래 세대에게 기회의 플랫폼 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003761149',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220722?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/032/2023/05/01/3220722.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220722?sid=100">윤 대통령 “업그레이드된 한·미 동맹, 청년에게 기회의 플랫폼 되어야”</a>
# <div class="cluster_text_lede">5박7일간 미국 국빈 방문을 마치고 전날 귀국한 윤석열 대통령은 1일 “업그레이드되고 확장된 한·미 동맹은 청년 미래 세대에게 기회의 플랫폼이 되어야 한 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news032,0003220722',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">경향신문</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011110_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003761149"><span class="cluster_foot_more_icon_num">28</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915601?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/02/13915601.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915601?sid=100">한총리, 정부대표로 英 찰스 대관식 참석…6박8일간 유럽 4개국 순방</a>
# <div class="cluster_text_lede">대관식 참석 후 스웨덴·오스트리아·루마니아 방문 "각국과 경제안보·첨단산업 등 협력 논의…부산엑스포 유치 교섭도" 한덕수 국무총리가 이달 4∼11일 6박 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013915601',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277218?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2023/05/02/3277218.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277218?sid=100">한총리, 6박8일 일정 유럽 4개국 순방…찰스 3세 국왕 대관식 참석</a>
# <div class="cluster_text_lede">한덕수 국무총리가 4일부터 11일까지 6박 8일 일정으로 영국, 스웨덴, 오스트리아, 루마니아를 방문한다고 2일 총리실이 전했다. 총리실에 따르면 한 총 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277218',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305020850_00000029&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013915601"><span class="cluster_foot_more_icon_num">10</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879562?sid=100">與 박대출 "방송법 통과하면, 대통령이 거부권 행사해야"</a>
# <div class="cluster_text_lede">국민의힘 박대출 정책위의장은 더불어민주당 주도로 국회 본회의에 직회부된 공영방송 지배구조 개편을 위한 방송법 개정안 등과 관련해, 법안이 국회를 통과하면 대통령은 거부권, 재의요구권을 행사해야 마땅할 것이라 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879562',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185508?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/01/4185508.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185508?sid=100">“친야 패널 7배 많았다”…與 'KBS1 라디오' 尹방미 보도 편향성 지적</a>
# <div class="cluster_text_lede">국민의힘이 윤석열 대통령의 미국 순방을 다룬 KBS1 라디오 출연진이 “극도로 편향돼 있었다”고 반발했다. 여당 측 인사보다 야당 측 인사가 7배 더 많 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185508',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304300910_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001879562"><span class="cluster_foot_more_icon_num">27</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000737105?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/469/2023/05/02/737105.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000737105?sid=100">尹, 기시다 답방·한미일 협력 강화로 '외교 주도권' 이어간다</a>
# <div class="cluster_text_lede">윤석열 대통령이 12년 만의 국빈 방미 성과로 도출한 '워싱턴 선언'을 바탕으로 한미일 3국 협력 강화와 더 나아가 '글로벌 중추국가' 실현을 위해 속도 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news469,0000737105',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881714?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/008/2023/05/01/4881714.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881714?sid=100">尹대통령, 동북아 판을 바꾼 '美국빈방문'…일본이 급해졌다</a>
# <div class="cluster_text_lede">'워싱턴 선언'이란 성과를 남긴 윤석열 대통령의 5박7일 미국 국빈 방문이 끝났다. 한미동맹 70주년을 맞아 핵전력을 포함하는 사실상 제2의 상호방위조약 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881714',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010730_00000154&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=469&amp;aid=0000737105"><span class="cluster_foot_more_icon_num">30</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898137?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/05/01/898137.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898137?sid=100">尹대통령 “‘프라미스’ 성공, 외교 역량의 성과”… 작전 참가자도 격려</a>
# <div class="cluster_text_lede">수단 교민 구출한 외교·국방 관계자들, 용산 대통령실로 초청 남궁환 주수단 대사 “수송기·청해부대 파견 등 신속·과감한 지원해 준 尹대통령에 감사” 윤석 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898137',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/082/0001210024?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/082/2023/05/01/1210024.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/082/0001210024?sid=100">윤 대통령, 귀국 후 첫 공식일정은 '수단 교민 구출팀' 격려</a>
# <div class="cluster_text_lede">윤석열 대통령은 1일 군벌 간 무력 충돌이 발생한 수단에서 우리 교민을 구출하는 '프라미스'(Promise·약속) 작전을 성공적으로 수행한 참가자들을 격 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news082,0001210024',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">부산일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011050_00000024&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=366&amp;aid=0000898137"><span class="cluster_foot_more_icon_num">28</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913535?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13913535.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913535?sid=100">북 매체, 중러 '워싱턴선언' 비판 조명…"부정적 후과 우려해"</a>
# <div class="cluster_text_lede">북한은 1일 한국과 미국이 북핵 위협에 대응해 합의한 '워싱턴 선언'을 두고 중국과 러시아 등 주요 우방국에서 내놓는 비판 목소리에 힘을 실으며 여론전에 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913535',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779675?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/01/6779675.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779675?sid=100">북한 "국제사회도 '워싱턴 선언'에 커다란 우려 표시"</a>
# <div class="cluster_text_lede">북한이 지난달 26일(현지시간) 한미정상회담에서 도출된 '워싱턴 선언'에 대해 국제사회가 부정적 결과를 우려하고 있다며 재차 반발했다. 북한 노동당 기관 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779675',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010800_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013913535"><span class="cluster_foot_more_icon_num">12</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834410?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11834410.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834410?sid=100">與 "이재명 방탄 선거법 개정…음흉한 시도" vs 野 "방탄 관련 없어"(종합)</a>
# <div class="cluster_text_lede">기사내용 요약 "이재명 방탄 위해 선거를 '아무말 대잔치'로" "'김문기 몰랐다'는 이재명 유죄 시 면소 판결" 장경태 해명 "작년 8월 발의…여, 취지 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011834410',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137733?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2023/05/02/2137733.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137733?sid=100">與 “이재명 처벌근거 삭제법은 ‘방탄’” vs 장경태 “이제와서? 의도 의심”</a>
# <div class="cluster_text_lede">국민의힘은 지난해 더불어민주당이 공직선거법상 허위사실 공표 대상을 줄이는 내용의 법안을 발의한 것을 두고 “이재명 구하기”라고 맹비난했다. 대표발의한 장 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137733',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011150_00000579&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011834410"><span class="cluster_foot_more_icon_num">15</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760997?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2023/05/01/3760997.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760997?sid=100">한국 올 美핵잠, 北을 지도에서 지워버릴 위력</a>
# <div class="cluster_text_lede">한국 항구에 기항 예고… 美의 전략 핵잠수함은 전략 핵잠수함(SSBN)은 핵탄두 장착 잠수함 발사 탄도미사일(SLBM)을 탑재한 핵추진 잠수함이다. 타국 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003760997',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054716?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/02/1054716.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054716?sid=100">'핵 무장' 잠수함, 한국 방문…이번 달 중순 G7 기간 유력</a>
# <div class="cluster_text_lede">이번 한미 정상회담에서 채택된 워싱턴 선언에는 미국 전략핵 잠수함이 우리 항구를 정기적으로 들른다는 뜻의 '한국 기항'이라는 문구가 포함돼 있습니다. 관 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054716',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304261620_00000195&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003760997"><span class="cluster_foot_more_icon_num">9</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000737139?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/469/2023/05/02/737139.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000737139?sid=100">이진복 "태영호와 공천 얘기한 적 없다" 공천 거론 의혹 부인</a>
# <div class="cluster_text_lede">이진복 대통령실 정무수석은 2일 태영호 국민의힘 최고위원의 녹취록과 관련해 '공천 문제를 거론하며 한일관계에 대해 옹호 발언을 해달라고 요청했다'는 의혹 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news469,0000737139',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915591?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/02/13915591.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915591?sid=100">이진복 "태영호와 공천 얘기 나눈 적 없다"</a>
# <div class="cluster_text_lede">'공천 영향력 행사' 의혹 보도 부인 이진복 대통령실 정무수석은 2일 국민의힘 태영호 최고위원과 관련해 '공천 문제를 거론하며 한일 관계에 대해 옹호 발 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013915591',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305012010_00000017&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=469&amp;aid=0000737139"><span class="cluster_foot_more_icon_num">62</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/022/0003808422?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/022/2023/05/02/3808422.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/022/0003808422?sid=100">대통령실 “尹·여야 원내대표 만남 마다할 이유 없다”</a>
# <div class="cluster_text_lede">방미성과 관련 회동 여부 질문에 “여야 합의 땐 가능” 긍정적 언급 핵협의그룹 통해 韓 발언권 획득 美 핵전력·韓 공동훈련 합의 ‘성과’ “여론 지지 못 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news022,0003808422',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">세계일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001605374?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/005/2023/05/02/1605374.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001605374?sid=100">이재명 안 만나고…대통령실 “尹·박광온 회동 마다안해”</a>
# <div class="cluster_text_lede">대통령실은 여야 합의 시 윤석열 대통령과 여야 원내대표 회동이 이뤄질 수 있다고 밝혔다. 대통령실 관계자는 1일 용산 대통령실 브리핑에서 ‘윤 대통령이  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news005,0001605374',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">국민일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011810_00000031&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=022&amp;aid=0003808422"><span class="cluster_foot_more_icon_num">21</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# </div>
# <div class="cluster _news_cluster_more_layer">
# <div class="cluster_more">
# <a class="cluster_more_inner _news_cluster_more_btn nclicks(cls_pol.clsmore)" href="#">헤드라인 더보기</a>
# </div>
# </div>
# ...
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=655"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/655/2022/01/20/logo_655_56_20220120164501.png" width="16"/></span>CJB청주방송</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024362?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/661/2023/05/02/24362.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024362?ntype=RANKING&amp;sid=001">국민연금 月 200만원 ↑ 고액수령자 한달새 3배 '껑충' …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16"/></span>JIBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014464?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/657/2023/05/01/14464.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014464?ntype=RANKING&amp;sid=001">[뉴스비하인드] 대구경북신공항, 새로운 하늘길인가? 꽉 막 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=657"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/657/2022/01/19/logo_657_56_20220119135625.png" width="16"/></span>대구MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/666/2023/05/02/10203.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&amp;sid=001">학교 다녀오면 ‘꼬르륵’…학생·학부모, 부실 급식 뿔났다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=666"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png" width="16"/></span>경기일보</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList80" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/655/0000009618?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/655/2023/05/01/9618.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/655/0000009618?ntype=RANKING&amp;sid=001">청주동물원 이전 여부 외부용역 의회서 제동..출구전략은?</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=655"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/655/2022/01/20/logo_655_56_20220120164501.png" width="16"/></span>CJB청주방송</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024362?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/661/2023/05/02/24362.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024362?ntype=RANKING&amp;sid=001">국민연금 月 200만원 ↑ 고액수령자 한달새 3배 '껑충' …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16"/></span>JIBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014464?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/657/2023/05/01/14464.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014464?ntype=RANKING&amp;sid=001">[뉴스비하인드] 대구경북신공항, 새로운 하늘길인가? 꽉 막 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=657"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/657/2022/01/19/logo_657_56_20220119135625.png" width="16"/></span>대구MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/666/2023/05/02/10203.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&amp;sid=001">학교 다녀오면 ‘꼬르륵’…학생·학부모, 부실 급식 뿔났다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=666"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png" width="16"/></span>경기일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018628?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2023/05/01/18628.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018628?ntype=RANKING&amp;sid=001">호텔신라 50주년 생일 경품 잔치연다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001879861?sid=100" title='[뉴스라이더] 대통령실, 공천 거론하며 옹호 발언 요청?...태영호 "사실 아냐"'>[뉴스라이더] 대통령실, 공천 거론하며 옹호 발언 요청?...태영호 "사실 아냐"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834805?sid=100" title="전세사기 특별법, 보증금 최대 4.5억까지 구제">전세사기 특별법, 보증금 최대 4.5억까지 구제</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808429?sid=100" title="‘막말’ 김재원·태영호 징계 돌입… 리스크 털고 분위기 반전시킬 수 있을까">‘막말’ 김재원·태영호 징계 돌입… 리스크 털고 분위기 반전시킬 수 있을까</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/009/0005124425?sid=104" title="“한국인 손해 막심하다”...휴지조각 위기에 빠진 서학개미 순매수 5위 주식 [월가월부]">“한국인 손해 막심하다”...휴지조각 위기에 빠진 서학개미 순매수 5위 주식 [월가월부]</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/014/0005005630?sid=104" title='기시다 "7~8일 韓 방문", 尹과 마음 터놓고 대화 기대'>기시다 "7~8일 韓 방문", 尹과 마음 터놓고 대화 기대</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834641?sid=101" title="4월 물가 14개월만에 3%대…전기요금 인상·환율 '변수'(종합)">4월 물가 14개월만에 3%대…전기요금 인상·환율 '변수'(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/008/0004882074?sid=101" title="SK E&amp;S, 미국 업체와 손잡고 국내 수소산업에 1조원 투자">SK E&amp;S, 미국 업체와 손잡고 국내 수소산업에 1조원 투자</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/469/0000737102?sid=101" title="[단독] '연금 신뢰 속 평등·연대' 갈구 프랑스…한국과 결 다른 국민연금 세대갈등">[단독] '연금 신뢰 속 평등·연대' 갈구 프랑스…한국과 결 다른 국민연금 세대갈등</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/030/0003095650?sid=105" title="LG유플러스, MDS테크와 산업용 스마트 무전 서비스 확대">LG유플러스, MDS테크와 산업용 스마트 무전 서비스 확대</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834711?sid=105" title='"반찬·국물 많은 韓매장에 최적"…KT, 차세대 AI 서비스로봇 출시'>"반찬·국물 많은 韓매장에 최적"…KT, 차세대 AI 서비스로봇 출시</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808473?sid=102" title="“조사받겠다”는 송영길… “조사 불가”라는 검찰">“조사받겠다”는 송영길… “조사 불가”라는 검찰</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/057/0001739426?sid=102" title="길 걷던 부부 덮친 음주운전 차량…아내 사망·남편 중상">길 걷던 부부 덮친 음주운전 차량…아내 사망·남편 중상</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765355?sid=102" title="'시작부터 극한대립' 내년 최저임금 첫 회의…주요 쟁점은?">'시작부터 극한대립' 내년 최저임금 첫 회의…주요 쟁점은?</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/215/0001098845?sid=103" title="'게임체인저' 기아 EV9 사전계약 시작…7337만원부터">'게임체인저' 기아 EV9 사전계약 시작…7337만원부터</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004185587?sid=103" title="세련미 강조된 '2024 셀토스'…주차보조 시스템도 태웠다">세련미 강조된 '2024 셀토스'…주차보조 시스템도 태웠다</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>

# %%
bs.find('div', id=True)   # id가 존재하는 div
# Out:
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>02</strong><span class="day">(화)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
# <ul class="nav">
# <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a></li>
# <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
# <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
# <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
# <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
# <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834229?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11834229.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834229?sid=100">與 윤리위, 김재원·태영호 징계 개시 오는 8일 당사자 소명 [뉴시스Pic]</a>
# <div class="cluster_text_lede">국민의힘 중앙당 윤리위원회는 잇단 설화로 물의를 일으킨 김재원·태영호 최고위원에 대한 징계 절차를 개시하기로 했다. 이날 오전에 김재원 최고위원이 한 달 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011834229',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277011',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277011?sid=100">[속보] 與윤리위, '설화' 김재원·태영호 징계절차 개시</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0005124101',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/009/0005124101?sid=100">與윤리위, 김재원·태영호 징계 개시…김재원 “대단히 죄송”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003494780',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">동아일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003494780?sid=100">與, ‘설화’ 김재원 징계절차 개시… 金 “사퇴 생각 안해”</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011834229"><span class="cluster_foot_more_icon_num">98</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054742?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/02/1054742.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054742?sid=100">"나 방첩사야" 사칭 민간인, 해병대 영내 활보하다 검거</a>
# <div class="cluster_text_lede">국군 방첩사령부 소속을 사칭한 민간인이 해병대 영내를 무단 침입해 2시간가량 활보하는 사건이 발생했습니다. 군 소식통에 따르면 지난달 28일 오후 4시  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054742',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news448,0000407175',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">TV조선</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/448/0000407175?sid=100">"나 방첩사 소속이야"…차량에 경광등 단 민간인에 뚫린 해병대</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005253156',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253156?sid=100">민간인이 해병대 침입해 영내 2시간 활보…“방첩사 사칭”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185627',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185627?sid=100">"나 방첩사 소속이야" 사칭 민간인, 해병대 부대 2시간 넘게 활보하다 검거</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011710_00000074&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=055&amp;aid=0001054742"><span class="cluster_foot_more_icon_num">20</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253217?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/277/2023/05/02/5253217.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253217?sid=100">⑤지지부진한 3대 개혁…돌파구는?[尹정부 1년]</a>
# <div class="cluster_text_lede">윤석열 대통령이 국정 과제로 내건 '3대(노동·교육·연금) 개혁'은 최근 논의가 지지부진하다. '초등학교 입학 연령 만 5세로 하향 조정'을 골자로 한  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005253217',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879802',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879802?sid=100">與 노동개혁특위 오늘 출범..."개혁 입법 방안 논의"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054749',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054749?sid=100">국민의힘 노동개혁특위 출범…'공정채용법' 추진</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006781090',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006781090?sid=100">與, 오늘 노동개혁특위 출범…공정성·노사법치 등 대안 마련</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305020610_00000100&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=277&amp;aid=0005253217"><span class="cluster_foot_more_icon_num">7</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005476607?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2023/05/01/5476607.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005476607?sid=100">한총리, 美 하원의원과 만나…"IRA 상호협력 방향으로 가야"</a>
# <div class="cluster_text_lede">한덕수 국무총리가 1일 정부서울청사에서 번 뷰캐넌(Vern Buchanan) 미 하원 민주주의 파트너십 의장이 이끄는 의원단을 만나 인플레이션 감축법(I …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005476607',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">이데일리</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013915082',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915082?sid=100">김의장 만난 美하원의원단 "尹대통령, 환상적인 방미"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news081,0003357970',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울신문</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/081/0003357970?sid=100">美 하원의원단 만난 韓총리 “IRA, 상호 투자 증진의 계기”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005005400',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">파이낸셜뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005005400?sid=100">한총리 "한미 정상, 북 비핵화 공조 의지 확인"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011620_00000009&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=018&amp;aid=0005476607"><span class="cluster_foot_more_icon_num">17</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013914209?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13914209.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013914209?sid=100">민주 원내수석에 '비명' 송기헌…원내대변인은 김한규·이소영</a>
# <div class="cluster_text_lede">미래에셋 출신 홍성국은 경제 담당 대변인…비서실장은 민병덕 더불어민주당 신임 원내수석부대표에 비명(비이재명)계인 재선의 송기헌(강원 원주을) 의원이 선임 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013914209',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185480?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/01/4185480.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185480?sid=100">민주 원내 진용 새단장…비명·소장파 전면에</a>
# <div class="cluster_text_lede">박광온 더불어민주당 신임 원내대표가 비명계 소장파 중심으로 원내대표단을 구성했다. 당 지도부가 친명계를 주축으로 진용을 갖춘 가운데 비명계가 원내 지도부 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185480',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011210_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013914209"><span class="cluster_foot_more_icon_num">62</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/009/0005124371?sid=100">전세사기 피해 특별법 적용대상 대폭 늘린다</a>
# <div class="cluster_text_lede">국토부 수정안 국회 제출 주택 면적 요건 없애고 보증금 3억→4.5억으로 정부가 전세사기 피해 임차인들을 위해 지난주 내놓은 특별법에 대한 야당과 피해 임차인들의 거센 불만이 지속되자 기존 특별법 적용 대상 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0005124371',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797933?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/029/2023/05/01/2797933.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797933?sid=100">전세사기 피해, 미추홀은 맞지만 동탄은 아니다?</a>
# <div class="cluster_text_lede">국회, '전세사기 특별법' 심사…피해자들 "인정기준 까다롭고 모호해" "피해가 명백히 예정됐는데도, 전세 만기 후 전세보증금 반환 소송을 내 승소 판결문 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news029,0002797933',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">디지털타임스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304261610_00000094&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=009&amp;aid=0005124371"><span class="cluster_foot_more_icon_num">79</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761149?sid=100">尹 “한미 산업·교육동맹 확장… 청년 위한 플랫폼으로”</a>
# <div class="cluster_text_lede">윤석열 대통령은 1일 “이번 한미 정상회담은 안보를 비롯해 산업·과학기술·교육·문화 등 모든 면으로 동맹을 확장시켰다는 데 큰 의미가 있다”면서 대통령실과 내각에 “무엇보다 청년 미래 세대에게 기회의 플랫폼 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003761149',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220722?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/032/2023/05/01/3220722.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220722?sid=100">윤 대통령 “업그레이드된 한·미 동맹, 청년에게 기회의 플랫폼 되어야”</a>
# <div class="cluster_text_lede">5박7일간 미국 국빈 방문을 마치고 전날 귀국한 윤석열 대통령은 1일 “업그레이드되고 확장된 한·미 동맹은 청년 미래 세대에게 기회의 플랫폼이 되어야 한 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news032,0003220722',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">경향신문</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011110_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003761149"><span class="cluster_foot_more_icon_num">28</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915601?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/02/13915601.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915601?sid=100">한총리, 정부대표로 英 찰스 대관식 참석…6박8일간 유럽 4개국 순방</a>
# <div class="cluster_text_lede">대관식 참석 후 스웨덴·오스트리아·루마니아 방문 "각국과 경제안보·첨단산업 등 협력 논의…부산엑스포 유치 교섭도" 한덕수 국무총리가 이달 4∼11일 6박 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013915601',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277218?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2023/05/02/3277218.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277218?sid=100">한총리, 6박8일 일정 유럽 4개국 순방…찰스 3세 국왕 대관식 참석</a>
# <div class="cluster_text_lede">한덕수 국무총리가 4일부터 11일까지 6박 8일 일정으로 영국, 스웨덴, 오스트리아, 루마니아를 방문한다고 2일 총리실이 전했다. 총리실에 따르면 한 총 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277218',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305020850_00000029&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013915601"><span class="cluster_foot_more_icon_num">10</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879562?sid=100">與 박대출 "방송법 통과하면, 대통령이 거부권 행사해야"</a>
# <div class="cluster_text_lede">국민의힘 박대출 정책위의장은 더불어민주당 주도로 국회 본회의에 직회부된 공영방송 지배구조 개편을 위한 방송법 개정안 등과 관련해, 법안이 국회를 통과하면 대통령은 거부권, 재의요구권을 행사해야 마땅할 것이라 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879562',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185508?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/01/4185508.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185508?sid=100">“친야 패널 7배 많았다”…與 'KBS1 라디오' 尹방미 보도 편향성 지적</a>
# <div class="cluster_text_lede">국민의힘이 윤석열 대통령의 미국 순방을 다룬 KBS1 라디오 출연진이 “극도로 편향돼 있었다”고 반발했다. 여당 측 인사보다 야당 측 인사가 7배 더 많 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185508',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304300910_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001879562"><span class="cluster_foot_more_icon_num">27</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000737105?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/469/2023/05/02/737105.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000737105?sid=100">尹, 기시다 답방·한미일 협력 강화로 '외교 주도권' 이어간다</a>
# <div class="cluster_text_lede">윤석열 대통령이 12년 만의 국빈 방미 성과로 도출한 '워싱턴 선언'을 바탕으로 한미일 3국 협력 강화와 더 나아가 '글로벌 중추국가' 실현을 위해 속도 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news469,0000737105',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881714?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/008/2023/05/01/4881714.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881714?sid=100">尹대통령, 동북아 판을 바꾼 '美국빈방문'…일본이 급해졌다</a>
# <div class="cluster_text_lede">'워싱턴 선언'이란 성과를 남긴 윤석열 대통령의 5박7일 미국 국빈 방문이 끝났다. 한미동맹 70주년을 맞아 핵전력을 포함하는 사실상 제2의 상호방위조약 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881714',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010730_00000154&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=469&amp;aid=0000737105"><span class="cluster_foot_more_icon_num">30</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898137?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/05/01/898137.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898137?sid=100">尹대통령 “‘프라미스’ 성공, 외교 역량의 성과”… 작전 참가자도 격려</a>
# <div class="cluster_text_lede">수단 교민 구출한 외교·국방 관계자들, 용산 대통령실로 초청 남궁환 주수단 대사 “수송기·청해부대 파견 등 신속·과감한 지원해 준 尹대통령에 감사” 윤석 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898137',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/082/0001210024?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/082/2023/05/01/1210024.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/082/0001210024?sid=100">윤 대통령, 귀국 후 첫 공식일정은 '수단 교민 구출팀' 격려</a>
# <div class="cluster_text_lede">윤석열 대통령은 1일 군벌 간 무력 충돌이 발생한 수단에서 우리 교민을 구출하는 '프라미스'(Promise·약속) 작전을 성공적으로 수행한 참가자들을 격 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news082,0001210024',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">부산일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011050_00000024&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=366&amp;aid=0000898137"><span class="cluster_foot_more_icon_num">28</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913535?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13913535.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913535?sid=100">북 매체, 중러 '워싱턴선언' 비판 조명…"부정적 후과 우려해"</a>
# <div class="cluster_text_lede">북한은 1일 한국과 미국이 북핵 위협에 대응해 합의한 '워싱턴 선언'을 두고 중국과 러시아 등 주요 우방국에서 내놓는 비판 목소리에 힘을 실으며 여론전에 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913535',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779675?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/01/6779675.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779675?sid=100">북한 "국제사회도 '워싱턴 선언'에 커다란 우려 표시"</a>
# <div class="cluster_text_lede">북한이 지난달 26일(현지시간) 한미정상회담에서 도출된 '워싱턴 선언'에 대해 국제사회가 부정적 결과를 우려하고 있다며 재차 반발했다. 북한 노동당 기관 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779675',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010800_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013913535"><span class="cluster_foot_more_icon_num">12</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834410?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11834410.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834410?sid=100">與 "이재명 방탄 선거법 개정…음흉한 시도" vs 野 "방탄 관련 없어"(종합)</a>
# <div class="cluster_text_lede">기사내용 요약 "이재명 방탄 위해 선거를 '아무말 대잔치'로" "'김문기 몰랐다'는 이재명 유죄 시 면소 판결" 장경태 해명 "작년 8월 발의…여, 취지 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011834410',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137733?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2023/05/02/2137733.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137733?sid=100">與 “이재명 처벌근거 삭제법은 ‘방탄’” vs 장경태 “이제와서? 의도 의심”</a>
# <div class="cluster_text_lede">국민의힘은 지난해 더불어민주당이 공직선거법상 허위사실 공표 대상을 줄이는 내용의 법안을 발의한 것을 두고 “이재명 구하기”라고 맹비난했다. 대표발의한 장 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137733',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011150_00000579&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011834410"><span class="cluster_foot_more_icon_num">15</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760997?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2023/05/01/3760997.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760997?sid=100">한국 올 美핵잠, 北을 지도에서 지워버릴 위력</a>
# <div class="cluster_text_lede">한국 항구에 기항 예고… 美의 전략 핵잠수함은 전략 핵잠수함(SSBN)은 핵탄두 장착 잠수함 발사 탄도미사일(SLBM)을 탑재한 핵추진 잠수함이다. 타국 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003760997',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054716?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/02/1054716.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054716?sid=100">'핵 무장' 잠수함, 한국 방문…이번 달 중순 G7 기간 유력</a>
# <div class="cluster_text_lede">이번 한미 정상회담에서 채택된 워싱턴 선언에는 미국 전략핵 잠수함이 우리 항구를 정기적으로 들른다는 뜻의 '한국 기항'이라는 문구가 포함돼 있습니다. 관 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054716',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304261620_00000195&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003760997"><span class="cluster_foot_more_icon_num">9</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000737139?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/469/2023/05/02/737139.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/469/0000737139?sid=100">이진복 "태영호와 공천 얘기한 적 없다" 공천 거론 의혹 부인</a>
# <div class="cluster_text_lede">이진복 대통령실 정무수석은 2일 태영호 국민의힘 최고위원의 녹취록과 관련해 '공천 문제를 거론하며 한일관계에 대해 옹호 발언을 해달라고 요청했다'는 의혹 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news469,0000737139',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915591?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/02/13915591.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915591?sid=100">이진복 "태영호와 공천 얘기 나눈 적 없다"</a>
# <div class="cluster_text_lede">'공천 영향력 행사' 의혹 보도 부인 이진복 대통령실 정무수석은 2일 국민의힘 태영호 최고위원과 관련해 '공천 문제를 거론하며 한일 관계에 대해 옹호 발 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013915591',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305012010_00000017&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=469&amp;aid=0000737139"><span class="cluster_foot_more_icon_num">62</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/022/0003808422?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/022/2023/05/02/3808422.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/022/0003808422?sid=100">대통령실 “尹·여야 원내대표 만남 마다할 이유 없다”</a>
# <div class="cluster_text_lede">방미성과 관련 회동 여부 질문에 “여야 합의 땐 가능” 긍정적 언급 핵협의그룹 통해 韓 발언권 획득 美 핵전력·韓 공동훈련 합의 ‘성과’ “여론 지지 못 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news022,0003808422',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">세계일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001605374?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/005/2023/05/02/1605374.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001605374?sid=100">이재명 안 만나고…대통령실 “尹·박광온 회동 마다안해”</a>
# <div class="cluster_text_lede">대통령실은 여야 합의 시 윤석열 대통령과 여야 원내대표 회동이 이뤄질 수 있다고 밝혔다. 대통령실 관계자는 1일 용산 대통령실 브리핑에서 ‘윤 대통령이  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news005,0001605374',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">국민일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011810_00000031&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=022&amp;aid=0003808422"><span class="cluster_foot_more_icon_num">21</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# </div>
# <div class="cluster _news_cluster_more_layer">
# <div class="cluster_more">
# <a class="cluster_more_inner _news_cluster_more_btn nclicks(cls_pol.clsmore)" href="#">헤드라인 더보기</a>
# </div>
# </div>
# ...
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=655"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/655/2022/01/20/logo_655_56_20220120164501.png" width="16"/></span>CJB청주방송</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024362?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/661/2023/05/02/24362.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024362?ntype=RANKING&amp;sid=001">국민연금 月 200만원 ↑ 고액수령자 한달새 3배 '껑충' …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16"/></span>JIBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014464?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/657/2023/05/01/14464.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014464?ntype=RANKING&amp;sid=001">[뉴스비하인드] 대구경북신공항, 새로운 하늘길인가? 꽉 막 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=657"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/657/2022/01/19/logo_657_56_20220119135625.png" width="16"/></span>대구MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/666/2023/05/02/10203.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&amp;sid=001">학교 다녀오면 ‘꼬르륵’…학생·학부모, 부실 급식 뿔났다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=666"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png" width="16"/></span>경기일보</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList80" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/655/0000009618?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/655/2023/05/01/9618.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/655/0000009618?ntype=RANKING&amp;sid=001">청주동물원 이전 여부 외부용역 의회서 제동..출구전략은?</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=655"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/655/2022/01/20/logo_655_56_20220120164501.png" width="16"/></span>CJB청주방송</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024362?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/661/2023/05/02/24362.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024362?ntype=RANKING&amp;sid=001">국민연금 月 200만원 ↑ 고액수령자 한달새 3배 '껑충' …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16"/></span>JIBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014464?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/657/2023/05/01/14464.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014464?ntype=RANKING&amp;sid=001">[뉴스비하인드] 대구경북신공항, 새로운 하늘길인가? 꽉 막 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=657"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/657/2022/01/19/logo_657_56_20220119135625.png" width="16"/></span>대구MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/666/2023/05/02/10203.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&amp;sid=001">학교 다녀오면 ‘꼬르륵’…학생·학부모, 부실 급식 뿔났다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=666"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png" width="16"/></span>경기일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018628?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2023/05/01/18628.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018628?ntype=RANKING&amp;sid=001">호텔신라 50주년 생일 경품 잔치연다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001879861?sid=100" title='[뉴스라이더] 대통령실, 공천 거론하며 옹호 발언 요청?...태영호 "사실 아냐"'>[뉴스라이더] 대통령실, 공천 거론하며 옹호 발언 요청?...태영호 "사실 아냐"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834805?sid=100" title="전세사기 특별법, 보증금 최대 4.5억까지 구제">전세사기 특별법, 보증금 최대 4.5억까지 구제</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808429?sid=100" title="‘막말’ 김재원·태영호 징계 돌입… 리스크 털고 분위기 반전시킬 수 있을까">‘막말’ 김재원·태영호 징계 돌입… 리스크 털고 분위기 반전시킬 수 있을까</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/009/0005124425?sid=104" title="“한국인 손해 막심하다”...휴지조각 위기에 빠진 서학개미 순매수 5위 주식 [월가월부]">“한국인 손해 막심하다”...휴지조각 위기에 빠진 서학개미 순매수 5위 주식 [월가월부]</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/014/0005005630?sid=104" title='기시다 "7~8일 韓 방문", 尹과 마음 터놓고 대화 기대'>기시다 "7~8일 韓 방문", 尹과 마음 터놓고 대화 기대</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834641?sid=101" title="4월 물가 14개월만에 3%대…전기요금 인상·환율 '변수'(종합)">4월 물가 14개월만에 3%대…전기요금 인상·환율 '변수'(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/008/0004882074?sid=101" title="SK E&amp;S, 미국 업체와 손잡고 국내 수소산업에 1조원 투자">SK E&amp;S, 미국 업체와 손잡고 국내 수소산업에 1조원 투자</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/469/0000737102?sid=101" title="[단독] '연금 신뢰 속 평등·연대' 갈구 프랑스…한국과 결 다른 국민연금 세대갈등">[단독] '연금 신뢰 속 평등·연대' 갈구 프랑스…한국과 결 다른 국민연금 세대갈등</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/030/0003095650?sid=105" title="LG유플러스, MDS테크와 산업용 스마트 무전 서비스 확대">LG유플러스, MDS테크와 산업용 스마트 무전 서비스 확대</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834711?sid=105" title='"반찬·국물 많은 韓매장에 최적"…KT, 차세대 AI 서비스로봇 출시'>"반찬·국물 많은 韓매장에 최적"…KT, 차세대 AI 서비스로봇 출시</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808473?sid=102" title="“조사받겠다”는 송영길… “조사 불가”라는 검찰">“조사받겠다”는 송영길… “조사 불가”라는 검찰</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/057/0001739426?sid=102" title="길 걷던 부부 덮친 음주운전 차량…아내 사망·남편 중상">길 걷던 부부 덮친 음주운전 차량…아내 사망·남편 중상</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765355?sid=102" title="'시작부터 극한대립' 내년 최저임금 첫 회의…주요 쟁점은?">'시작부터 극한대립' 내년 최저임금 첫 회의…주요 쟁점은?</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/215/0001098845?sid=103" title="'게임체인저' 기아 EV9 사전계약 시작…7337만원부터">'게임체인저' 기아 EV9 사전계약 시작…7337만원부터</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004185587?sid=103" title="세련미 강조된 '2024 셀토스'…주차보조 시스템도 태웠다">세련미 강조된 '2024 셀토스'…주차보조 시스템도 태웠다</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>

# %%
bs.find('div', id='header')
# Out:
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>02</strong><span class="day">(화)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>

# %%
# div 중 '메인 메뉴로 바로가기' 출력
print(bs.div.find("a", href=True).get_text())
print(bs.div.find("a", href='#lnb').get_text())
print(bs.select_one("[tabindex = '1']").text)
# Out:
# 메인 메뉴로 바로가기
# 메인 메뉴로 바로가기
# 메인 메뉴로 바로가기

# %%
lists = bs.find('div',id=True).find_all('a')
for i in lists:
    print(i.text)
# Out:
# 메인 메뉴로 바로가기
# 본문으로 바로가기
# 검색
# NAVER
# 뉴스
# TV연예
# 스포츠
# 날씨
# 프리미엄
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 정치
# 대통령실
# 국회/정당
# 북한
# 행정
# 국방/외교
# 정치일반
#
#
# 안내헤드라인 뉴스
#
#
#
# 與 윤리위, 김재원·태영호 징계 개시 오는 8일 당사자 소명 [뉴시스Pic]
# [속보] 與윤리위, '설화' 김재원·태영호 징계절차 개시
# 與윤리위, 김재원·태영호 징계 개시…김재원 “대단히 죄송”
# 與, ‘설화’ 김재원 징계절차 개시… 金 “사퇴 생각 안해”
# 98개의 관련뉴스 더보기
#
#
#
# "나 방첩사야" 사칭 민간인, 해병대 영내 활보하다 검거
# "나 방첩사 소속이야"…차량에 경광등 단 민간인에 뚫린 해병대
# 민간인이 해병대 침입해 영내 2시간 활보…“방첩사 사칭”
# "나 방첩사 소속이야" 사칭 민간인, 해병대 부대 2시간 넘게 활보하다 검거
# 20개의 관련뉴스 더보기
#
#
#
# ⑤지지부진한 3대 개혁…돌파구는?[尹정부 1년]
# 與 노동개혁특위 오늘 출범..."개혁 입법 방안 논의"
# 국민의힘 노동개혁특위 출범…'공정채용법' 추진
# 與, 오늘 노동개혁특위 출범…공정성·노사법치 등 대안 마련
# 7개의 관련뉴스 더보기
#
#
#
# 한총리, 美 하원의원과 만나…"IRA 상호협력 방향으로 가야"
# 김의장 만난 美하원의원단 "尹대통령, 환상적인 방미"
# 美 하원의원단 만난 韓총리 “IRA, 상호 투자 증진의 계기”
# 한총리 "한미 정상, 북 비핵화 공조 의지 확인"
# 17개의 관련뉴스 더보기
#
#
#
# 민주 원내수석에 '비명' 송기헌…원내대변인은 김한규·이소영
#
#
#
# 민주 원내 진용 새단장…비명·소장파 전면에
# 62개의 관련뉴스 더보기
# 전세사기 피해 특별법 적용대상 대폭 늘린다
#
#
#
# 전세사기 피해, 미추홀은 맞지만 동탄은 아니다?
# 79개의 관련뉴스 더보기
# 尹 “한미 산업·교육동맹 확장… 청년 위한 플랫폼으로”
#
#
#
# 윤 대통령 “업그레이드된 한·미 동맹, 청년에게 기회의 플랫폼 되어야”
# 28개의 관련뉴스 더보기
#
#
#
# 한총리, 정부대표로 英 찰스 대관식 참석…6박8일간 유럽 4개국 순방
#
#
#
# 한총리, 6박8일 일정 유럽 4개국 순방…찰스 3세 국왕 대관식 참석
# 10개의 관련뉴스 더보기
# 與 박대출 "방송법 통과하면, 대통령이 거부권 행사해야"
#
#
#
# “친야 패널 7배 많았다”…與 'KBS1 라디오' 尹방미 보도 편향성 지적
# 27개의 관련뉴스 더보기
#
#
#
# 尹, 기시다 답방·한미일 협력 강화로 '외교 주도권' 이어간다
#
#
#
# 尹대통령, 동북아 판을 바꾼 '美국빈방문'…일본이 급해졌다
# 30개의 관련뉴스 더보기
#
#
#
# 尹대통령 “‘프라미스’ 성공, 외교 역량의 성과”… 작전 참가자도 격려
#
#
#
# 윤 대통령, 귀국 후 첫 공식일정은 '수단 교민 구출팀' 격려
# 28개의 관련뉴스 더보기
#
#
#
# 북 매체, 중러 '워싱턴선언' 비판 조명…"부정적 후과 우려해"
#
#
#
# 북한 "국제사회도 '워싱턴 선언'에 커다란 우려 표시"
# 12개의 관련뉴스 더보기
#
#
#
# 與 "이재명 방탄 선거법 개정…음흉한 시도" vs 野 "방탄 관련 없어"(종합)
#
#
#
# 與 “이재명 처벌근거 삭제법은 ‘방탄’” vs 장경태 “이제와서? 의도 의심”
# 15개의 관련뉴스 더보기
#
#
#
# 한국 올 美핵잠, 北을 지도에서 지워버릴 위력
#
#
# 동영상기사
#
# '핵 무장' 잠수함, 한국 방문…이번 달 중순 G7 기간 유력
# 9개의 관련뉴스 더보기
#
#
#
# 이진복 "태영호와 공천 얘기한 적 없다" 공천 거론 의혹 부인
#
#
#
# 이진복 "태영호와 공천 얘기 나눈 적 없다"
# 62개의 관련뉴스 더보기
#
#
#
# 대통령실 “尹·여야 원내대표 만남 마다할 이유 없다”
#
#
#
# 이재명 안 만나고…대통령실 “尹·박광온 회동 마다안해”
# 21개의 관련뉴스 더보기
# 헤드라인 더보기
#
# 연재보기
# 아는기자
#
#
#
# 동영상기사
#
# ‘외교의 달’ 된 5월…기시다 답방 빨라진 이유
# 한미 정상, 5차례 이상 만나…양국, 국빈 방문 평가는?
# 순방 외교서 ‘한일·한미일’ 이야기 많이 나온 이유는?
# ‘주가조작 의혹’ 8개는 어떤 종목인가?
#
#
#
#
# 14년 전 5만원권 등장 이후 달라졌다…지갑서 사라진 이것
# 중앙일보
#
#
#
# 中바이두 "삼겹살은 중국요리" 표현에 서경덕 "한식공정"  …
# 연합뉴스
#
#
#
# [단독]정순신 아들 학폭 청문회 '강원도교육청 담당 간부  …
# 노컷뉴스
#
#
# 동영상기사
#
# [단독] 한밤중 여성 집까지 쫓아와 폭행했는데‥그냥 보내준 …
# MBC
#
#
#
# 故백선엽 장녀, 美전광판서 아버지와 영상 재회
# 동아일보
#
#
#
# 中고교생에 “졸업하면 오라”... 외국 학생으로 99% 채 …
# 조선일보
#
#
#
# “임신 중인데 너무 배고파요”…손내민 사장님 [아살세]
# 국민일보
#
#
# 동영상기사
#
# 임창정, 라덕연 치켜세우며 "아주 종교야"…투자자 "할렐루 …
# JTBC
#
#
#
# 국민의힘 시의원 "베트남 애들 열 중 하나는 뽕" 혐오 발 …
# YTN
#
#
#
# '39년 한인가게 폐업합니다'…뉴욕 한복판서 벌어진 일
# 데일리안
#
#
#
# "촌구석에 스타벅스 생겼다"…시골 마을 흔든 삼성 효과 [ …
# 한국경제
#
#
#
# "김여정이 옆에 앉아 내 팔 만지작"…DMZ 美장교 황당순 …
# 서울경제
#
#
#
# “가격 올랐는데 퀄리티는 실망” 달라진 맛집, 손님은 불만
# 경향신문
#
#
#
# “연예인 광고에만 143억 쓰더니” 수백억 적자에 ‘낭패’
# 헤럴드경제
#
#
# 동영상기사
#
# 친명계, 갓 취임 박광온 흔들기…강성 지지층은 '사퇴 청원 …
# TV조선
#
#
#
# 지금까지 이런 영부인은 없었다…남편 재선 결심, 종결자 질 …
# 매일경제
#
#
#
# 정부, 리튬인산철 배터리 개발 착수…'세계 최고 품질 확보 …
# 전자신문
#
#
#
# 임창정, 라덕연 향해 “아주 종교야”…“할렐루야”
# 이데일리
#
#
#
# 1년간의 추락... 윤석열 정부의 국가시스템 붕괴와 국정혼 …
# 오마이뉴스
#
#
#
# "코인 투자금, 어떻게 돌려받을지…" 서세원 빈소에 나타난 …
# 아시아경제
#
#
#
# BTS 슈가, 美 공연서 "셀피는 갤럭시만 줘…아이폰 안  …
# 뉴스1
#
#
#
# [2보]대낮에 40대 부부 음주운전 車에 치여 아내 사망하 …
# 강원일보
#
#
#
# “그 대학 가기엔 넌 너무 섹시해”…‘낙방 파티’ 유행하는 …
# 서울신문
#
#
# 동영상기사
#
# "'5월 4일이 딱' 연차 냈다가 욕먹었다…신입은 안 되냐 …
# SBS
#
#
#
# 죽은 딸에게서 온 문자…'억대 연봉' 20대女 살해한 남친 …
# 머니투데이
#
#
#
# "2시간 노출 시 사망" 후쿠시마 원전 폐기물 41톤…회수 …
# MBN
#
#
#
# 이혼할때 어떤 감정?…남성 "애증교차" vs 여성 "해방감 …
# 뉴시스
#
#
#
# "여기 살다간 죽어요"... 무주 진안 장수엔 투석병원이  …
# 한국일보
#
#
#
# 조정훈 “영부인은 배우자다, 왜 설치냐?…조선시대 생각”
# 문화일보
#
#
#
# 주가 동향 수시로 보고받았던 김익래 회장... 작전세력 인 …
# 조선비즈
#
#
#
# '월7만2천원' 대중교통 무제한티켓 300만장 팔렸다
# 한국경제TV
#
#
# 동영상기사
#
# '법카'로 명품 수십억 어치 구매한 경리에 징역 7년
# 연합뉴스TV
#
#
#
# 여건상 ‘간병인’ 구하지만…열에 아홉은 “너무 비싸”
# KBS
#
#
#
# 간호조무사는 왜 의사협회가 주도하는 파업에 동참할까?
# 한겨레
#
#
#
# [이웃사랑] 남편 부조금 300만원으로 연명…"딸 공부만큼 …
# 매일신문
#
#
#
# 대통령실 “尹, 간호법 거부권 검토”… 의료연대, 2일 총 …
# 세계일보
#
#
#
# '태영호 녹취록' 메가톤급 파장…어떤 내용 담겼길래?
# 부산일보
#
#
#
# 투잡뛰며 홀로 두 아이 명문대까지 보냈는데.. 이젠 아들이 …
# 파이낸셜뉴스
#
#
#
# 아산 공영주차장서 30대 공무원 숨진 채 발견
# 더팩트
#
#
#
# 50대 이상이 생각하는 노후 생활비는 얼마일까?
# SBS Biz
#
#
#
# 송영길, ‘조사불가’ 檢입장에도 자진출두…중앙지검앞 회견
# 채널A
#
#
#
# "배달료 3천→4천원 올려야"...뿔난 배민 라이더, '근 …
# ZDNet Korea
#
#
#
# 7년만에 `슈퍼 엘니뇨` 온다…한 달 빠른 5월부터 발생
# 디지털타임스
#
#
#
# [단독] 이건그룹, 오너 2세 길 터주려 모태회사 희생시켰 …
# 시사저널
#
#
#
# 임창정, 라덕연 향해 "아주 종교야"…투자자들은 "할렐루야 …
# 아이뉴스24
#
#
#
# 노동자 분신 1면에 쓴 한겨레, 노동절 집회 교통체증 전한 …
# 미디어오늘
#
#
#
# [랜선인싸] 메이플스토리 월드로 제2의 인생 시작한 ‘관우 …
# 디지털데일리
#
#
#
# "카페 알바로 전전긍긍했는데…" 대한항공 객실승무원 복귀한 …
# 비즈워치
#
#
#
# 임창정 “라덕연, 아주 종교야” 찬양 포착…주가조작단과 한 …
# 이코노미스트
#
#
#
# 테슬라 신형 모델 X, 일반 스티어링 휠도 쓸만하네 [카미 …
# 블로터
#
#
#
# ‘진화된 n번방’ 우울증갤러리…피해자 취약성 악용해
# 한겨레21
#
#
#
# We don't need any forgiveness: L …
# 코리아헤럴드
#
#
#
# 10만원 저축에 정부지원, 3년 최대 1440만원 '청년내 …
# 여성신문
#
#
#
# “삼성전자는 좋겠네”...BTS 슈가, 콘서트장에서 ‘노  …
# 한경비즈니스
#
#
#
# 기억력 떨어뜨리는 뇌 독성물질… '이것' 먹으면 많이 쌓여
# 헬스조선
#
#
#
# 음주운전 ‘7회 이상’ 적발이 한 해 977명인 나라
# 시사IN
#
#
#
# Korea rising as a defense suppli …
# 코리아중앙데일리
#
#
#
# 김종인 "내년 총선에 한동훈 마스코트? 국민의힘 답답한 정 …
# 프레시안
#
#
#
# 김종인 “총선 마스코트 한동훈? 무모한 일” [+영상]
# 신동아
#
#
#
# 태영호 '대통령 옹호 발언 요구' 녹취록에… "독려차원 과 …
# 머니S
#
#
#
# KBS 감사한 감사원 "중대한 위법사실 없었다"
# 기자협회보
#
#
#
# 월간산 추천, 5월에 갈 만한 산 BEST 4
# 월간 산
#
#
#
# [속보] 4월 소비자물가 3.7%↑…14개월만에 3%대로
# 매경이코노미
#
#
#
# "이재명 그만 둘 수도... 일각서 '비대위' 가능성 제기 …
# 주간조선
#
#
#
# [속보] 이진복 정무수석 "공천은 당에서… 태영호와 공천  …
# 강원도민일보
#
#
#
# 중노년 싱글여성 과반 ‘노년에도 일해야 먹고 산다’
# 일다
#
#
#
# [오늘과학] 중국 화성 로버, 저위도 지역서 물 흔적 발견
# 동아사이언스
#
#
#
# 지갑서 사라진 10만원권 수표..이용금액도 12년 새 95 …
# kbc광주방송
#
#
#
# ‘역대급 실적’ 2차전지, 급등락 요동치는 주가
# 주간동아
#
#
#
# 걷기 자주 해도 체중 그대로.. 근력운동 필요한 이유?
# 코메디닷컴
#
#
# 동영상기사
#
# 갓길 걷던 40대 부부 음주 운전 차량에 치여 부인 숨져
# 전주MBC
#
#
#
# 尹 ‘한미회담’ 美 현지 반응…“아메리칸 파이 챙겼는데 코 …
# 조세일보
#
#
#
# '150조 백악관 노래방' 논란 속 대통령실 그들만의 뒤풀 …
# 국제신문
#
#
#
# [속보] 이진복, 태영호 녹취록에 "공천 줄 위치 아냐,  …
# 대전일보
#
#
#
# 2020~2023년, SKY 대학 정시 합격자 70% 수도 …
# 농민신문
#
#
#
# 73년 된 상속세, 어떻게 바뀌어야 하나
# 주간경향
#
#
# 동영상기사
#
# 청주동물원 이전 여부 외부용역 의회서 제동..출구전략은?
# CJB청주방송
#
#
#
# 국민연금 月 200만원 ↑ 고액수령자 한달새 3배 '껑충' …
# JIBS
#
#
#
# [뉴스비하인드] 대구경북신공항, 새로운 하늘길인가? 꽉 막 …
# 대구MBC
#
#
#
# 학교 다녀오면 ‘꼬르륵’…학생·학부모, 부실 급식 뿔났다
# 경기일보
#
#
# 동영상기사
#
# 청주동물원 이전 여부 외부용역 의회서 제동..출구전략은?
# CJB청주방송
#
#
#
# 국민연금 月 200만원 ↑ 고액수령자 한달새 3배 '껑충' …
# JIBS
#
#
#
# [뉴스비하인드] 대구경북신공항, 새로운 하늘길인가? 꽉 막 …
# 대구MBC
#
#
#
# 학교 다녀오면 ‘꼬르륵’…학생·학부모, 부실 급식 뿔났다
# 경기일보
#
#
#
# 호텔신라 50주년 생일 경품 잔치연다
# 레이디경향
# [뉴스라이더] 대통령실, 공천 거론하며 옹호 발언 요청?...태영호 "사실 아냐"
# 전세사기 특별법, 보증금 최대 4.5억까지 구제
# ‘막말’ 김재원·태영호 징계 돌입… 리스크 털고 분위기 반전시킬 수 있을까
# “한국인 손해 막심하다”...휴지조각 위기에 빠진 서학개미 순매수 5위 주식 [월가월부]
# 기시다 "7~8일 韓 방문", 尹과 마음 터놓고 대화 기대
# 4월 물가 14개월만에 3%대…전기요금 인상·환율 '변수'(종합)
# SK E&S, 미국 업체와 손잡고 국내 수소산업에 1조원 투자
# [단독] '연금 신뢰 속 평등·연대' 갈구 프랑스…한국과 결 다른 국민연금 세대갈등
# LG유플러스, MDS테크와 산업용 스마트 무전 서비스 확대
# "반찬·국물 많은 韓매장에 최적"…KT, 차세대 AI 서비스로봇 출시
# “조사받겠다”는 송영길… “조사 불가”라는 검찰
# 길 걷던 부부 덮친 음주운전 차량…아내 사망·남편 중상
# '시작부터 극한대립' 내년 최저임금 첫 회의…주요 쟁점은?
# '게임체인저' 기아 EV9 사전계약 시작…7337만원부터
# 세련미 강조된 '2024 셀토스'…주차보조 시스템도 태웠다
#
#
#
#  서비스 안내
#  고침 기사 모음
#  정정·반론·추후 보도 기사 모음
#  불공정 선거 보도 기사 모음
# 서비스 안내더보기

# %%
url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100' 
html = urllib.request.urlopen(url)

bs = BS(html, 'lxml')
text = bs.find_all('p')
print(text)
# Out:
# [<p class="airs_info_inner"><i class="airs_info_icon_airs">AiRS</i><span class="airs_info_text"><b>추천</b>으로 구성된 뉴스를 제공합니다.</span></p>, <p class="section_sub_txt">오전 9시~오전 10시까지 집계한 결과입니다.</p>, <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>]

# %%
for i in text:
    i = i.get_text()
    print(i)
# Out:
# AiRS추천으로 구성된 뉴스를 제공합니다.
# 오전 9시~오전 10시까지 집계한 결과입니다.
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.

# %%
print(bs.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta contents="always" name="referrer"/>
#   <meta content="600" http-equiv="refresh"/>
#   <meta content="width=1106" name="viewport"/>
#   <meta content="정치 : 네이버 뉴스" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" property="og:url"/>
#   <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
#   <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
#   <meta content="네이버" property="og:article:author"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
#   <meta content="네이버 뉴스" name="twitter:site"/>
#   <meta content="네이버 뉴스" name="twitter:creator"/>
#   <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
#   <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" name="twitter:description"/>
#   <title>
#    정치 홈 : 네이버 뉴스
#   </title>
#   <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css" rel="stylesheet" type="text/css"/>
#   <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css" rel="stylesheet" type="text/css"/>
#   <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" type="text/javascript">
#   </script>
#   <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Tue May 02 10:09:14 KST 2023";
#   </script>
#   <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" type="text/javascript">
#   </script>
#   <script>
#    var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
#   </script>
#  </head>
#  <body>
#   <div id="wrap">
#    <!-- 광고적용 태그 추가 -->
#    <div id="da_base">
#    </div>
#    <div id="da_stake">
#    </div>
#    <div class="header" id="header">
#     <div id="u_skip">
#      <a href="#lnb" tabindex="1">
#       <span>
#        메인 메뉴로 바로가기
#       </span>
#      </a>
#      <a href="#main_content" tabindex="2">
#       <span>
#        본문으로 바로가기
#       </span>
#      </a>
#     </div>
#     <div class="snb_area">
#      <div class="snb_inner">
#       <div class="gnb_area">
#        <div class="gnb_wrap">
#         <div class="gnb_dark_type2" id="gnb">
#         </div>
#        </div>
#        <div class="gnb_search is_hidden _search_content">
#        </div>
#        <div class="gnb_tool" id="gnb_search_tool">
#         <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;">
#          <span class="icon_search">
#           검색
#          </span>
#         </a>
#        </div>
#       </div>
#       <div id="snb_wrap">
#        <h1>
#         <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/">
#          <span class="blind">
#           NAVER
#          </span>
#         </a>
#         <a class="h_news nclicks(gnb.news)" href="/">
#          <span class="blind">
#           뉴스
#          </span>
#         </a>
#        </h1>
#        <ul class="snb_related_service">
#         <li>
#          <span class="snb_bdr">
#          </span>
#          <a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">
#           TV연예
#          </a>
#         </li>
#         <li>
#          <span class="snb_bdr">
#          </span>
#          <a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">
#           스포츠
#          </a>
#         </li>
#         <li>
#          <span class="snb_bdr">
#          </span>
#          <a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">
#           날씨
#          </a>
#         </li>
#         <li>
#          <span class="snb_bdr">
#          </span>
#          <a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">
#           프리미엄
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="lnb_area">
#      <div class="lnb_inner">
#       <div class="lnb_both">
#        <div class="lnb_left">
#         <div class="lnb_menu" id="lnb">
#          <ul>
#           <li>
#            <a class="nclicks(lnb.pcmedia)" href="/">
#             <span class="tx">
#              언론사별
#             </span>
#            </a>
#           </li>
#           <li class="on">
#            <a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">
#             <span class="tx">
#              정치
#             </span>
#             <span class="blind">
#              선택됨
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101">
#             <span class="tx">
#              경제
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102">
#             <span class="tx">
#              사회
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103">
#             <span class="tx">
#              생활/문화
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105">
#             <span class="tx">
#              IT/과학
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104">
#             <span class="tx">
#              세계
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111">
#             <span class="tx">
#              랭킹
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.paper)" href="/newspaper/home">
#             <span class="tx">
#              신문보기
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.opi)" href="/opinion/home">
#             <span class="tx">
#              오피니언
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh">
#             <span class="tx">
#              TV
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver">
#             <span class="tx">
#              팩트체크
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="lnb_right">
#         <div class="lnb_extra">
#          <div class="lnb_extra_menu">
#           <ul class="lnb_extra_menu_list">
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">
#              전체 언론사
#             </a>
#            </li>
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">
#              뉴스스탠드
#             </a>
#            </li>
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">
#              라이브러리
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="lnb">
#      <span class="lnb_date">
#       <strong>
#        05
#       </strong>
#       .
#       <strong>
#        02
#       </strong>
#       <span class="day">
#        (화)
#       </span>
#      </span>
#      <ul class="lnb_side" tabindex="0">
#       <li>
#        <a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">
#         전체 언론사
#        </a>
#       </li>
#       <li>
#        <a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">
#         뉴스스탠드
#        </a>
#       </li>
#       <li>
#        <a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">
#         라이브러리
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <hr/>
#    <table cellpadding="0" cellspacing="0" class="container">
#     <caption class="blind">
#      기사목록
#     </caption>
#     <colgroup>
#      <col class="col_snb"/>
#      <col class="col_content"/>
#      <col class="col_aside"/>
#     </colgroup>
#     <tr>
#      <td class="snb">
#       <div class="snb" id="snb">
#        <h2 class="h2">
#         <a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">
#          정치
#         </a>
#        </h2>
#        <ul class="nav">
#         <li>
#          <a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">
#           대통령실
#          </a>
#         </li>
#         <li>
#          <a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">
#           국회/정당
#          </a>
#         </li>
#         <li>
#          <a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">
#           북한
#          </a>
#         </li>
#         <li>
#          <a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">
#           행정
#          </a>
#         </li>
#         <li>
#          <a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">
#           국방/외교
#          </a>
#         </li>
#         <li>
#          <a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">
#           정치일반
#          </a>
#         </li>
#        </ul>
#        <div class="snb_banner">
#         <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main">
#          <img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/>
#         </a>
#        </div>
#        <div class="snb_banner">
#         <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/">
#          <img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/>
#         </a>
#        </div>
#       </div>
#      </td>
#      <td class="content">
#       <div class="content" id="main_content">
#        <div class="list_body section_index">
#         <div class="cluster">
#          <div class="cluster_title">
#           <span class="cluster_title_inner">
#            <a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L">
#             <i class="cluster_title_icon">
#              안내
#             </i>
#             헤드라인 뉴스
#            </a>
#           </span>
#           <div class="cluster_title_layer _news_cluster_layer is_hidden">
#            <div class="cluster_title_layer_text">
#             헤드라인 뉴스와 각 기사묶음 타이틀은
#             <br/>
#             기사 내용을 기반으로
#             <strong>
#              자동 추출
#             </strong>
#             됩니다.
#            </div>
#            <div class="cluster_title_layer_image">
#            </div>
#            <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">
#             닫기
#            </button>
#           </div>
#          </div>
#         </div>
#         <div class="_persist">
#          <div class="cluster">
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879690?sid=100">
#                 방첩사 사칭해 해병대 영내 무단 진입한 남성 검거
#                </a>
#                <div class="cluster_text_lede">
#                 국군 방첩사령부 소속을 사칭한 민간인이 해병대 영내를 무단 진입해 2시간 넘게 활보하는 사건이 발생했습니다. 군에 따르면 민간인 남성 A 씨는 지난달 28일 오후 4시 20분쯤 포항에 있는 해병대 모 사단에 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879690',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  YTN
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005005701',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  파이낸셜뉴스
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005005701?sid=100">
#                 “나 방첩사야”..구멍 뚫린 해병대, 민간인이 영내 2시간 활보
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005253158',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  아시아경제
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253158?sid=100">
#                 민간인 해병대 영내 무단 칩입…2시간 활보
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277092',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  중앙일보
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277092?sid=100">
#                 해병대 행사 틈타 침입…'방첩사' 사칭한 민간인 2시간 활보
#                </a>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011710_00000074&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001879690">
#               <span class="cluster_foot_more_icon_num">
#                20
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879861?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/052/2023/05/02/1879861.jpg?type=ofullfill132_90" width="132"/>
#                  <strong class="r_ico r_vod_medium">
#                   동영상기사
#                  </strong>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879861?sid=100">
#                 대통령실, 공천 거론하며 옹호 발언 요청?...태영호 "사실 아냐"[뉴스라이더]
#                </a>
#                <div class="cluster_text_lede">
#                 윤석열 대통령은 오늘 국무회의를 주재하고, 국빈 방미 성과를 공유하며 후속 조치를 지시합니다. 윤 대통령은 확장억제와 세일즈 외교 성과를 설명하고, 워싱 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879861',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  YTN
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013915591',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  연합뉴스
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013915591?sid=100">
#                 이진복 "태영호와 공천 얘기 나눈 적 없다"
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898149',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  조선비즈
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898149?sid=100">
#                 태영호, ‘이진복 한일관계 옹호 요청 보도’에 “언급한 사실 없다…과장 섞인 내용”
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005476722',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  이데일리
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005476722?sid=100">
#                 태영호 "尹 외교 만점", "토플 960점급"…이유 있었던 찬사?
#                </a>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305012010_00000017&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001879861">
#               <span class="cluster_foot_more_icon_num">
#                62
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879562?sid=100">
#                 與 박대출 "방송법 통과하면, 대통령이 거부권 행사해야"
#                </a>
#                <div class="cluster_text_lede">
#                 국민의힘 박대출 정책위의장은 더불어민주당 주도로 국회 본회의에 직회부된 공영방송 지배구조 개편을 위한 방송법 개정안 등과 관련해, 법안이 국회를 통과하면 대통령은 거부권, 재의요구권을 행사해야 마땅할 것이라 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879562',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  YTN
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005253129',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  아시아경제
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253129?sid=100">
#                 박대출 "방송법 국회 통과시 대통령 거부권 행사해야"
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news021,0002569508',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  문화일보
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/021/0002569508?sid=100">
#                 박대출 “KBS 방미비판 보도 도넘어… 출연진 중 야권성향이 여권성향의 7배”
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news448,0000407115',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  TV조선
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/448/0000407115?sid=100">
#                 박대출 "방송법 국회 통과하면 대통령이 거부권 행사해야"
#                </a>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304300910_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001879562">
#               <span class="cluster_foot_more_icon_num">
#                27
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269901?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/01/1269901.jpg?type=ofullfill132_90" width="132"/>
#                  <strong class="r_ico r_vod_medium">
#                   동영상기사
#                  </strong>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269901?sid=100">
#                 전세사기 피해자, 정부여당 특별법안 반대
#                </a>
#                <div class="cluster_text_lede">
#                 정부·여당이 내놓은 '전세사기 피해자 지원 및 주거 안정에 관한 특별법'에 대해, 전세 사기 피해자들이 반대 입장을 밝혔습니다. 피해자들은 오늘 오전 국 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269901',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  MBC
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005253153',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  아시아경제
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253153?sid=100">
#                 국토위, 전세사기특별법 심사 난항… 적용 대상 범위 등 충돌 계속
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news032,0003220784',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  경향신문
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/032/0003220784?sid=100">
#                 정부, 전세사기 피해자의 기존 전세대출 ‘20년간 분할상환’ 추진
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879750',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  YTN
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879750?sid=100">
#                 여야 '전세 사기 특별법' 합의 도출 실패...추가 논의 예정
#                </a>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304261610_00000094&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269901">
#               <span class="cluster_foot_more_icon_num">
#                79
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001270044?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/02/1270044.jpg?type=ofullfill132_90" width="132"/>
#                  <strong class="r_ico r_vod_medium">
#                   동영상기사
#                  </strong>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001270044?sid=100">
#                 '막말·설화' 태영호·김재원‥징계 돌입
#                </a>
#                <div class="cluster_text_lede">
#                 국민의힘이 전광훈 목사 관련 발언 등으로 물의를 빚은 김재원 최고위원에 대해 징계 절차에 들어갔습니다. 태영호 최고위원도 제주 4.3 발언 등으로 함께  …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001270044',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  MBC
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/030/0003095557?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/030/2023/05/01/3095557.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/030/0003095557?sid=100">
#                 與 윤리위 공식 출범…김재원·태영호 징계 착수
#                </a>
#                <div class="cluster_text_lede">
#                 국민의힘 윤리위원회가 김재원·태영호 최고위원에 대한 징계 절차를 개시하기로 했다. 잇단 설화에 시달려온 온 만큼 중앙당 윤리위원회의 본격적인 가동으로 새 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news030,0003095557',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  전자신문
#                 </div>
#                </div>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001270044">
#               <span class="cluster_foot_more_icon_num">
#                98
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185480?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/01/4185480.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185480?sid=100">
#                 민주 원내 진용 새단장…비명·소장파 전면에
#                </a>
#                <div class="cluster_text_lede">
#                 박광온 더불어민주당 신임 원내대표가 비명계 소장파 중심으로 원내대표단을 구성했다. 당 지도부가 친명계를 주축으로 진용을 갖춘 가운데 비명계가 원내 지도부 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185480',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  서울경제
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/087/0000967731?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/087/2023/05/01/967731.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/087/0000967731?sid=100">
#                 민주당 원내수석에 송기헌 의원 지명
#                </a>
#                <div class="cluster_text_lede">
#                 속보=더불어민주당 원내수석 부대표에 송기헌(원주을)국회의원이 지명(본보 1일자 3면 보도)됐다. 박광온 신임 원내대표는 1일 국회 소통관에서 기자회견을  …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news087,0000967731',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  강원일보
#                 </div>
#                </div>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011210_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=011&amp;aid=0004185480">
#               <span class="cluster_foot_more_icon_num">
#                62
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013914873?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13914873.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013914873?sid=100">
#                 한총리, 美 하원의원단 접견…국빈방미 결과·IRA 등 논의
#                </a>
#                <div class="cluster_text_lede">
#                 한총리 "IRA, 상호투자 협력 증진 방향으로 가야"…의원단 "관심 갖겠다" 한덕수 국무총리는 1일 정부서울청사에서 번 뷰캐넌 미국 하원 의원이 이끄는  …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013914873',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  연합뉴스
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006780867?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/01/6780867.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006780867?sid=100">
#                 외교1차관, 美하원의원단 만나 "물샐 틈 없는 북핵 공조" 당부
#                </a>
#                <div class="cluster_text_lede">
#                 장호진 외교부 제1차관이 1일 방한 중인 미국 하원 의원단과 만나 윤석열 대통령의 최근 국빈 방미 및 한미동맹 70주년 등에 관해 의견을 교환했다. 외교 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006780867',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  뉴스1
#                 </div>
#                </div>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011620_00000009&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013914873">
#               <span class="cluster_foot_more_icon_num">
#                17
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761079?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2023/05/01/3761079.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761079?sid=100">
#                 대통령실, 尹·박광온 野원내대표 회동 “마다할 이유 없다”
#                </a>
#                <div class="cluster_text_lede">
#                 여야 원내대표 합의하면 회동 가능 대통령실은 1일 여야(與野) 원내대표 간 합의가 된다면 윤석열 대통령과 여야 원내대표 회동도 가능하다고 밝혔다. 미국  …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003761079',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  조선일보
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137730?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2023/05/02/2137730.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137730?sid=100">
#                 이재명은 패싱? 박광온에게 먼저 '손' 내민 대통령실
#                </a>
#                <div class="cluster_text_lede">
#                 대통령실이 여야 원내대표와의 회동에 긍정적인 반응을 보였다. 박광온 더불어민주당 의원이 신임 원내대표로 선출된 후 나온 대통령실 입장이다. 이재명 민주당 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137730',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  헤럴드경제
#                 </div>
#                </div>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011810_00000031&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003761079">
#               <span class="cluster_foot_more_icon_num">
#                21
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content" style="display: none">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/022/0003808021?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/022/2023/05/01/3808021.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/022/0003808021?sid=100">
#                 ‘돈 봉투 의혹’ 민주, 재발 방지책…대의원제 축소 가능성은?
#                </a>
#                <div class="cluster_text_lede">
#                 '금권선거' 가능성 사전 차단? 뉴스1 '돈 봉투 의혹'으로 위기에 몰린 더불어민주당 내에서 재발 방지책으로 '대의원제'를 폐지하거나 축소해야 한다는 목 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news022,0003808021',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  세계일보
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765345?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/079/2023/05/02/3765345.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765345?sid=100">
#                 '돈봉투' 해법이 대의원제 폐지?…이재명·박광온 의견일치 볼까
#                </a>
#                <div class="cluster_text_lede">
#                 더불어민주당 이재명 대표가 '2021년 전당대회 돈 봉투' 의혹의 돌파구 중 하나로 당에 쇄신책을 주문한 것으로 전해진다. 현재 논의 중인 '대의원제 개 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003765345',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  노컷뉴스
#                 </div>
#                </div>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304300610_00000188&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=022&amp;aid=0003808021">
#               <span class="cluster_foot_more_icon_num">
#                5
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content" style="display: none">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/057/0001739413?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/057/2023/05/02/1739413.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/057/0001739413?sid=100">
#                 與 "선거법 개정안은 이재명 방탄 시즌2"…장경태 "이제와서?"
#                </a>
#                <div class="cluster_text_lede">
#                 국민의힘은 지난해 8월 장경태 더불어민주당 최고위원이 발의한 선거법 개정안과 관련해 "이재명 방탄 시즌2"라며 비판했습니다. 장 최고위원은 "이제와서 방 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news057,0001739413',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  MBN
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/449/0000248735?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/449/2023/05/01/248735.jpg?type=ofullfill132_90" width="132"/>
#                  <strong class="r_ico r_vod_medium">
#                   동영상기사
#                  </strong>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
# ...
#            <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/666/2023/05/02/10203.jpg?type=nf88_60" width="88"/>
#           </a>
#           <div class="list_text_wrap">
#            <div class="list_text">
#             <div class="list_text_inner">
#              <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010203?ntype=RANKING&amp;sid=001">
#               학교 다녀오면 ‘꼬르륵’…학생·학부모, 부실 급식 뿔났다
#              </a>
#              <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=666">
#               <span class="list_press_thumb">
#                <img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png" width="16"/>
#               </span>
#               경기일보
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li>
#           <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018628?ntype=RANKING&amp;sid=001">
#            <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2023/05/01/18628.jpg?type=nf88_60" width="88"/>
#           </a>
#           <div class="list_text_wrap">
#            <div class="list_text">
#             <div class="list_text_inner">
#              <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018628?ntype=RANKING&amp;sid=001">
#               호텔신라 50주년 생일 경품 잔치연다
#              </a>
#              <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145">
#               <span class="list_press_thumb">
#                <img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/>
#               </span>
#               레이디경향
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#         </ul>
#         <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">
#          더보기
#         </button>
#        </div>
#        <script type="text/javascript">
#         var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
#        </script>
#        <div class="side_ad" id="glad_ad_sidebox">
#        </div>
#        <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
#         <h4>
#          분야별 주요뉴스
#         </h4>
#         <div class="classfy sd" style="display:block">
#          <ul class="list_txt">
#           <li>
#            <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001879861?sid=100" title='[뉴스라이더] 대통령실, 공천 거론하며 옹호 발언 요청?...태영호 "사실 아냐"'>
#             [뉴스라이더] 대통령실, 공천 거론하며 옹호 발언 요청?...태영호 "사실 아냐"
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834805?sid=100" title="전세사기 특별법, 보증금 최대 4.5억까지 구제">
#             전세사기 특별법, 보증금 최대 4.5억까지 구제
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808429?sid=100" title="‘막말’ 김재원·태영호 징계 돌입… 리스크 털고 분위기 반전시킬 수 있을까">
#             ‘막말’ 김재원·태영호 징계 돌입… 리스크 털고 분위기 반전시킬 수 있을까
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/009/0005124425?sid=104" title="“한국인 손해 막심하다”...휴지조각 위기에 빠진 서학개미 순매수 5위 주식 [월가월부]">
#             “한국인 손해 막심하다”...휴지조각 위기에 빠진 서학개미 순매수 5위 주식 [월가월부]
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/014/0005005630?sid=104" title='기시다 "7~8일 韓 방문", 尹과 마음 터놓고 대화 기대'>
#             기시다 "7~8일 韓 방문", 尹과 마음 터놓고 대화 기대
#            </a>
#           </li>
#          </ul>
#          <ul class="list_txt">
#           <ul class="list_txt">
#            <li>
#             <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834641?sid=101" title="4월 물가 14개월만에 3%대…전기요금 인상·환율 '변수'(종합)">
#              4월 물가 14개월만에 3%대…전기요금 인상·환율 '변수'(종합)
#             </a>
#            </li>
#            <li>
#             <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/008/0004882074?sid=101" title="SK E&amp;S, 미국 업체와 손잡고 국내 수소산업에 1조원 투자">
#              SK E&amp;S, 미국 업체와 손잡고 국내 수소산업에 1조원 투자
#             </a>
#            </li>
#            <li>
#             <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/469/0000737102?sid=101" title="[단독] '연금 신뢰 속 평등·연대' 갈구 프랑스…한국과 결 다른 국민연금 세대갈등">
#              [단독] '연금 신뢰 속 평등·연대' 갈구 프랑스…한국과 결 다른 국민연금 세대갈등
#             </a>
#            </li>
#            <li>
#             <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/030/0003095650?sid=105" title="LG유플러스, MDS테크와 산업용 스마트 무전 서비스 확대">
#              LG유플러스, MDS테크와 산업용 스마트 무전 서비스 확대
#             </a>
#            </li>
#            <li>
#             <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834711?sid=105" title='"반찬·국물 많은 韓매장에 최적"…KT, 차세대 AI 서비스로봇 출시'>
#              "반찬·국물 많은 韓매장에 최적"…KT, 차세대 AI 서비스로봇 출시
#             </a>
#            </li>
#           </ul>
#           <ul class="list_txt">
#            <ul class="list_txt">
#             <li>
#              <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808473?sid=102" title="“조사받겠다”는 송영길… “조사 불가”라는 검찰">
#               “조사받겠다”는 송영길… “조사 불가”라는 검찰
#              </a>
#             </li>
#             <li>
#              <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/057/0001739426?sid=102" title="길 걷던 부부 덮친 음주운전 차량…아내 사망·남편 중상">
#               길 걷던 부부 덮친 음주운전 차량…아내 사망·남편 중상
#              </a>
#             </li>
#             <li>
#              <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765355?sid=102" title="'시작부터 극한대립' 내년 최저임금 첫 회의…주요 쟁점은?">
#               '시작부터 극한대립' 내년 최저임금 첫 회의…주요 쟁점은?
#              </a>
#             </li>
#             <li>
#              <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/215/0001098845?sid=103" title="'게임체인저' 기아 EV9 사전계약 시작…7337만원부터">
#               '게임체인저' 기아 EV9 사전계약 시작…7337만원부터
#              </a>
#             </li>
#             <li>
#              <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004185587?sid=103" title="세련미 강조된 '2024 셀토스'…주차보조 시스템도 태웠다">
#               세련미 강조된 '2024 셀토스'…주차보조 시스템도 태웠다
#              </a>
#             </li>
#            </ul>
#           </ul>
#          </ul>
#         </div>
#        </div>
#        <div class="section">
#         <div class="banner">
#          <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings">
#           <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"/>
#          </a>
#         </div>
#        </div>
#        <div class="section">
#         <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank">
#          <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"/>
#         </a>
#        </div>
#        <div class="section">
#         <div class="banner">
#          <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank">
#           <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"/>
#          </a>
#         </div>
#        </div>
#        <div class="section">
#         <h4>
#          <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver">
#           서비스 안내
#          </a>
#         </h4>
#         <ul class="list_txt">
#          <li>
#           <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb">
#            고침 기사 모음
#           </a>
#          </li>
#          <li>
#           <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb">
#            정정·반론·추후 보도 기사 모음
#           </a>
#          </li>
#          <li>
#           <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb">
#            불공정 선거 보도 기사 모음
#           </a>
#          </li>
#         </ul>
#         <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver">
#          <span class="blind">
#           서비스 안내
#          </span>
#          더보기
#         </a>
#        </div>
#        <script>
#         window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
#        </script>
#       </div>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <hr/>
#   <div class="index">
#    <div class="index_inner">
#     <div class="floating_btn">
#      <div class="floating_inner">
#       <a class="floating_btn_back" href="javascript:history.back();">
#        <span class="blind">
#         이젠 페이지
#        </span>
#       </a>
#       <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;">
#        <span class="blind">
#         맨위로
#        </span>
#       </a>
#      </div>
#     </div>
#     <div class="index_tab" id="index.press_category">
#      <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">
#       언론사 목록
#       <span class="_stit_tab_arrow stit_arrow">
#        <span class="blind">
#         열기
#        </span>
#       </span>
#       <span class="loading" style="display:none;">
#        로딩 중
#       </span>
#      </a>
#      <div class="index_content is_hidden" id="index.press.area">
#      </div>
#      <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">
#       분야별 목록
#       <span class="_stit_tab_arrow stit_arrow">
#        <span class="blind">
#         열기
#        </span>
#       </span>
#       <span class="loading" style="display:none;">
#        로딩 중
#       </span>
#      </a>
#      <div class="index_content02 is_hidden" id="index.category.area">
#      </div>
#     </div>
#    </div>
#   </div>
#   <hr/>
#   <div id="footer">
#    <ul>
#     <li class="first">
#      <a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">
#       이용약관
#      </a>
#     </li>
#     <li>
#      <a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">
#       서비스 안내
#      </a>
#     </li>
#     <li>
#      <a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">
#       기사배열 원칙 책임자 : 유봉석
#      </a>
#     </li>
#     <li>
#      청소년 보호 책임자 : 이희만
#     </li>
#     <li>
#      <strong>
#       <a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">
#        개인정보처리방침
#       </a>
#      </strong>
#     </li>
#     <li>
#      <a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">
#       책임의 한계와 법적고지
#      </a>
#     </li>
#     <li>
#      <a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">
#       뉴스 고객센터
#      </a>
#     </li>
#    </ul>
#    <p class="copyright">
#     본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.
#    </p>
#    <address class="address_nhn">
#     <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank">
#      <span class="blind">
#       NAVER
#      </span>
#     </a>
#     <em>
#      Copyright ©
#     </em>
#     <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">
#      NAVER Corp.
#     </a>
#     <span>
#      All Rights Reserved.
#     </span>
#    </address>
#    <!-- -->
#   </div>
#   <script type="text/javascript">
#    var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
#   </script>
#  </body>
# </html>

# %%
# p태그 데이터 모두 불러와 한글만 출력
for i in bs.find_all('p'):
    t = ' '.join(re.findall('[가-힣]+',i.text))
    print(t)
# Out:
# 추천으로 구성된 뉴스를 제공합니다
# 오전 시 오전 시까지 집계한 결과입니다
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다

# %%
# requests
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=105"

res = requests.get(url).text
soup = BS(res,'html.parser')
wf = soup.find('wf').text
text = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))

text
# Out:
# '(강수) 5일(금)은 강원도에 비가 내리겠으며, 강원영동은 6일(토) 오전까지 이어지겠습니다.(기온) 5일(금)~7일(일) 아침 기온은 6~17도로 평년(최저기온 6~12도)과 비슷하거나 조금 높겠고, 낮 기온은 13~22도로 평년(최고기온 17~25도)보다 조금 낮겠습니다. 8일(월)~12일(금) 아침 기온은 3~15도로 평년(최저기온 6~12도)과 비슷하거나 조금 낮겠고, 낮 기온은 16~24도로 평년(최고기온 17~24도)과 비슷하겠습니다.(해상) 동해중부해상의 물결은 5일(금)~6일(토)은 1.0~3.0m로 높게 일겠습니다.(주말전망) 6일(토)~7일(일)은 대체로 흐리겠으나, 6일(토) 오전에 강원영동은 비가 내리겠습니다. 아침 기온은 6~15도, 낮 기온은 13~21도가 되겠습니다. 6일(토)은 저기압의 위치와 이동 속도에 따라 강수 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 참고하기 바랍니다.'

# %%
api = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"

# 매개변수를 url인코딩 합니다
values = {'stnld':'109'}    # 서울 109, 강원도 105... 등
params = urllib.parse.urlencode(values)

# 요청 전용 url을 생성합니다
url = api+'?'+params
print('url = ',url)

res = urllib.request.urlopen(url)
soup = BS(res, 'html.parser')

wf = soup.find('wf').string
text = ' '.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]',wf))
text
# Out:
# url =  http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnld=109
# '(강수)  5일( 금) 은  전국  비,  6일( 토)  오전은  강원영동과  경상권,  제주도에  비가  오겠습니다. (기온)  5일( 금) ~6일( 토)  아침  기온은  14~ 19도로  평년( 최저기온  9~ 14도) 보다  높겠고,  7일( 일) ~12일( 금)  아침  기온은  8~ 15도로  평년과  비슷하겠습니다.  낮  기온은  18~ 25도로  평년( 최고기온  20~ 25도) 과  비슷하겠습니다. (주말전망)  6일( 토)  전국이  대체로  흐리고  오전에  강원영동과  경상권,  제주도에  비가  오겠습니다.  7일( 일) 은  전국이  구름많겠습니다.  아침  기온은  11~ 18도,  낮  기온은  18~ 22도가  되겠습니다.  6일( 토) 은  저기압의  위치와  이동  속도에  따라  강수  구역이  변경될  가능성이  있으니,  앞으로  발표되는  최신  예보를  참고하기  바랍니다.'

# %%
url = 'https://news.naver.com/'
html = urllib.request.urlopen(url)
bs = BS(html, 'lxml')
bs.find_all('p')
# Out:
# [<p class="cjs_d">‘SG증권발(發) 주가 폭락 사태’ 피해자라 주장해온 가수 임창정이 주가조작단과 동업한 정황이 포착됐다. 주범으로 지목된 라덕연 H투자자문사 대표를 ‘종교’라 칭하며 신뢰를 표한 모습 또한 공개됐다. 1일 JTBC </p>,
#  <p class="cjs_d">최근 4년간 ‘SKY’로 불리는 서울대학교·연세대학교·고려대학교의 정시모집 합격자 중 71.6%가 수도권 출신인 것으로 확인됐다. 강득구 더불어민주당 의원(경기 안양만안)과 교육랩공공장은 최근 국회에서 기자회견을 열</p>,
#  <p class="cjs_d">음주운전자에 의해 아까운 목숨들이 지고 있다. 지난 4월8일 대전시 둔산동 한 어린이보호구역에서 만취한 60대 운전자가 몰던 차량이 인도로 돌진했다. 차는 인도 위를 걸어가던 초등학생 4명을 덮쳤다. 배승아 양(만 </p>,
#  <p class="cjs_d">회원 수 40만명에 육박하는 네이버 1위 명품 구매대행 카페에서 판매자가 물건을 주지 않은 채 돈만 가로챈 이른바 '먹튀' 사기 피해 잇따라 발생했다. 해당 카페에서 구매대행 판매자 A씨에게 물건을 받지 못했다는 피</p>,
#  <p class="cjs_d">국민의힘 소속 양태석 거제시의원이 공식 석상에서 외국인 노동자 혐오 발언을 했다는 사실이 뒤늦게 알려져 여론의 뭇매를 맞고 있다. 지난달 20일, 양 의원은 거제시의회 경제관광위원회 외국인노동자 지원 조례안 심사 과</p>,
#  <p class="cjs_d">AV 배우 인터뷰한 &lt;성+인물&gt; 논란, 어떻게 봐야하나? "AV산업은 일본 내 ‘성착취 구조’의 첨단에 자리합니다. 그 구조에 대한 비판적 고려 없이 이를 콘텐츠화한다뇨." - 이나영 중앙대학교 사회학과 교수 AV(</p>,
#  <p class="cjs_d">인스타그램엔 하루에 9천500만 장의 사진이 올라온다. 이중 상당수는 자신의 모습이 담긴 셀카다. 사람들은 왜 셀카를 찍을까. 흔히 생각하는 바와는 달리, 자신을 과시하고 싶어 셀카를 찍는 것만은 아니라는 연구 결과</p>,
#  <p class="cjs_d">편집자주한국은 의료 가성비가 좋다고 하죠. 아프면 예약 없이 3,000~4,000원에 전문의를 보는 나라, 흔치 않으니까요. 그러나 건보 흑자, 일부 의료인의 희생 덕에 양질의 의료를 누렸던 시대도 끝나 갑니다. 미</p>,
#  <p class="cjs_d">태영호 국민의힘 최고위원이 이진복 대통령실 정무수석으로부터 한·일 관계와 관련해 윤석열 대통령을 옹호하는 발언을 해달라는 요청을 받았다는 녹취록에 대해 "사실 무근"이라는 입장을 밝혔다. 지난 1일 태 최고위원은 자</p>,
#  <p class="cjs_d">2023년 4월 13일 국회 본회의에서 '대구경북신공항 건설을 위한 특별법'이 통과됐습니다. 대구경북신공항은 현재 대구 도심에 있는 군 공항인 K2와 대구국제공항을 경북 의성군 비안면과 군위군 소보면으로 새롭게 옮기</p>,
#  <p class="cjs_d">요즘 4대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다. 이명박 전 대통령(이하 존칭 생략)은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 4대강도 방문할 예정이라고 한다. 4대강 추진본부장이었던 심명필은</p>,
#  <p class="cjs_d">국민연금으로 매달 200만원 이상을 받아 노후생활을 하는 사람이 1만5,000명을 넘어섰습니다. 국민연금공단에 따르면 1월 말 기준 월 200만원 이상 노령연금 수급자는 1만5,290명으로, 5,400여명이었던 지난</p>,
#  <p class="cjs_d">5월로 들어서면서 계절감이 회복됐습니다. 당분간 기온 계속 비슷하면서 온화하겠는데요. 다만, 오늘은 일교차가 10도 내외로 크겠습니다. 따라서 체온 관리에 특별히 신경 써주시면 좋겠습니다. 오늘은 오랜만에 하늘 구경</p>,
#  <p class="cjs_d">민주당 '전당대회 돈봉투 의혹' 송영길, 서울중앙지검 자진 출두 ※CBS노컷뉴스는 여러분의 제보로 함께 세상을 바꿉니다. 각종 비리와 부당대우, 사건사고와 미담 등 모든 얘깃거리를 알려주세요.이메일 : 카카오톡 : </p>,
#  <p class="cjs_d">“비상연락망을 확인하고, 고위험군인 주변인에게 연락할 것.” 성폭력 피해자 연대 활동을 하면서 매해 3~4월과 10~11월에 강조하는 일이다. 봄과 가을에는 계절성 우울증 등 여러 요인이 겹쳐 자살 고위험군인 피해자</p>,
#  <p class="cjs_d">뉴스를 통해 우리를 웃고 울렸던 어제의 오늘을 다시 만나봅니다. 2015년 5월 2일. 이모씨(당시 25세)는 이날 밤 11시쯤 자신이 지내던 서울 관악구 신림동의 한 오피스텔에서 여자친구 김모씨(당시 26세)를 목</p>,
#  <p class="cjs_d">가수 겸 배우 임창정 씨가 주가조작단이 개최한 한 투자자 모임에서 라덕연 대표에 대해 “아주 종교야!”라고 말한 모습이 공개됐다. 임씨는 자신도 주가조작의 피해자라고 호소하고 있다. 가수 겸 배우 임창정 (사진=뉴시</p>,
#  <p class="cjs_d">러시아-우크라이나 전쟁이 일 년을 훌쩍 넘겨 433일째(5월2일 기준)를 맞고 있다. 지난해 2월 시작된 전쟁이 교착국면에 빠져 장기화한 상태에서 오는 9일 러시아의 '전승절' 즈음에 우크라이나의 대반격이 임박했다는</p>,
#  <p class="cjs_d">국민연금공단의 '2023년 1월 기준 국민연금 통계' 자료를 보면, 올해 1월 말 기준으로 월 200만원 이상의 노령연금(10년 이상 가입하면 노후에 수령하는 일반 형태의 국민연금)을 받는 수급자는 1만5천290명에</p>,
#  <p class="cjs_d">올해 들어 퇴직 후에 국민연금을 매월 200만원 이상을 받는 사람이 1만5000명을 넘어섰다. 지난해 말 기준 5000명대와 비교하면 한 달 사이에 3배 가까이 급증했다. 2일 국민연금공단의 '2023년 1월 기준 </p>,
#  <p class="cjs_d">지난해 역대 최대 규모 적자를 낸 한국전력이 근로자의 날을 앞두고 직원들에게 10만원 상품권을 지급했다 회수하면서 빈축을 샀다. 최근 직장인 익명 커뮤니티 ‘블라인드’에는 한국전력 직원 A씨가 관련 내용을 공유한 글</p>,
#  <p class="cjs_d">어제(1일) 서울 서대문구 경찰청에서 열린 기자간담회에서 윤희근 경찰청장은 배우 유아인씨(37·본명 엄홍식)의 수사 계획을 밝혔습니다. 유씨는 현재 대마, 프로포폴, 코카인, 케타민 등 총 4종류의 마약류를 투약한 </p>,
#  <p class="cjs_d">흔히 네덜란드를 '세계 자전거의 수도'라고 부른다. 어린아이부터 노인까지 진심으로 자전거를 즐겨 탄다. 교통 수단 중 자전거가 차지하는 비중이 36% 남짓되고, 평균적으로 1인당 자전거를 1대 이상 가지고 있는 나라</p>,
#  <p class="cjs_d">봉화산烽火山(920m) 우리나라에서 가장 흔한 산 이름이 봉화산이다. 5월 산행지로 추천하는 봉화산은 남원과 장수 경계에 있는 백두대간 주능선의 봉화산이다. 전북 남원시 아영면과 장수군 번암면의 경계를 이루는 이 산</p>,
#  <p class="cjs_d">살을 빼려고 식사량을 줄이고 열심히 걷기 운동을 하는 사람이 있다. 먹는 양을 갑자기 줄이고, 한 시간 동안 걷는 데도 늘어난 체중은 변하지 않는다. 다이어트 방법이 잘못된 것일까? 덜 먹고 운동하는 데도 살이 안 </p>,
#  <p class="cjs_d">6월 美 파이브가이즈 국내 첫 오픈 결실… 한화 유통·서비스 부문 미래 성장동력 박차 미국 유명 수제버거 ‘파이브가이즈’가 6월 한국에 처음 매장을 연다. 김승연 한화그룹 회장의 삼남인 김동선 한화갤러리아 전략본부장</p>,
#  <p class="cjs_d">올 여름에는 7년 만에 닥칠 엘니뇨로 많은 비가 내릴 것으로 보인다. 기상청은 5~7월 태평양의 엘리뇨·랴니냐 감시구역(남위 5도부터 북위 5도, 서경 170~120도 구역)의 해수면 온도가 4월부터 급상승해, 5월</p>,
#  <p class="cjs_d">20대 국회 출판기념회 79건, 절반이 '총선 5개월 전' 열려 '북적북적' 출판기념회, 시중 판매는 뒷전…21대 의원 중 단 3명 공개 국회의원이 '작가'로 소개되는 장소. 출판기념회에서 의원들은 '책'을 팔지만,</p>,
#  <p class="cjs_d">서울 노원구 아파트값이 1년4개월 만에 반등에 성공했다. 직전 거래 가격보다 오른 가격에 팔리는 사례가 속속 생겨나면서 ‘영끌족’(영혼까지 끌어모아 대출로 집 산 사람)도 한숨을 돌리는 모습이다. 한국부동산원에 따르</p>,
#  <p class="cjs_d">더불어민주당 전당대회 돈봉투 의혹과 관련해 금품 살포의 최종 수혜자로 지목된 송영길 전 대표가 오늘(2일) 검찰 자진 출두를 강행합니다. 송 전 대표는 이날 오전 10시 서울중앙지방검찰청에 출두한 뒤, 기자회견을 통</p>,
#  <p class="cjs_d">일본의 중노년 싱글여성 단체인 ‘와쿠와쿠 시니어 싱글즈’가 릿쿄대학 유자와 나오미(湯澤直美) 씨와 북경JAC 협력으로 중고령 싱글여성의 생활실태를 조사했다. ‘와쿠와쿠’(두근두근이라는 뜻)는 2016년에 50세 이상</p>,
#  <p class="cjs_d">■ 'CFD는 코스닥 주가를 부풀릴 수 있다' 코스닥시장 종목들의 주가는 CFD 거래 후 상승한다. 2020년 발표된 한 논문의 결론이다. ( 레버리지 투자자의 매매 양태 분석-차액결제거래 계좌를 대상으로, 박수철)</p>,
#  <p class="cjs_d">대낮에 만취 운전을 한 20대 남성이 길을 가던 40대 부부를 들이받아 부인이 숨지는 사고가 발생했다. 2일 경찰에 따르면 전북 완주경찰서는 도로교통법상 음주운전 혐의로 20대 남성 A씨를 붙잡아 조사 중이다. A씨</p>,
#  <p class="cjs_d">최근 은행에서 주는 정기예금 이자의 약 90%는 연 3%대인 것으로 확인됐다. 기준금리와 비슷하거나 심지어는 밑도는 수준이다. 새 정기예금의 과반이 연 4~5%대 이자를 줬었던 지난해 말과 비교하면 불과 반년 만에 </p>,
#  <p class="cjs_d">인생에서 큰 행사 중 하나인 결혼식. 그런데 비용이 너무 많이 들면서, 젊은 부부들의 결혼식은 예전과 많이 달라진 모습입니다. 조금이라도 아끼면서 결혼하려는 사람들이 늘었는데, 어떻게 한 푼이라도 아끼면서 결혼식을 </p>,
#  <p class="cjs_d">윤석열 대통령의 미국 국빈 방문 성과를 두고 논란이 가중되는 가운데, 대통령실이 여당 지도부를 초청해 관련 논의를 위한 ‘뒤풀이’를 연다. 대통령실은 2일 저녁 용산 대통령실에서 국민의힘 지도부와 만찬을 하며 방미 </p>,
#  <p class="cjs_d">21대 국회의원의 국회 본회의 출석 전수조사 결과 국민의힘에선 김태호 의원(28회), 더불어민주당에서는 우상호 의원(27회)이 아무런 신고 없이 본회의에 불참한 횟수가 가장 많은 것으로 확인됐다. 두 의원을 포함한 </p>,
#  <p class="cjs_d">- 질병관리청, 의심증상 신고자의 개인정보는 보호되고 있으므로 적극적인 신고 당부 - 모르는 사람과의 밀접접촉을 피하고 의심증상이 있을 경우 타인과의 접촉 삼가 질병관리청(청장 지영미)은 국내 42번째 엠폭스 확진환</p>,
#  <p class="cjs_d">코로나19 이후 4년 만에 닷새 간의 황금연휴(4월 29일∼5월 3일)를 맞은 중국 곳곳이 '보복 관광'으로 인산인해를 이루고 있다. 숙소를 못 구한 이들이 화장실에서 밤을 지새우는가 하면, '낙타 신호등'까지 등장</p>,
#  <p class="cjs_d">■ JTBC 뉴스룸이 단독 보도한 '주가조작 의혹' 녹취파일 등의 저작권은 JTBC에 있습니다. 인용보도시 'JTBC 뉴스룸' 출처를 분명하게 인식할 수 있는 크기로 표기해 사용해주시기 바랍니다. 주가조작단은 자신들</p>,
#  <p class="cjs_d">암을 진단 받은 후 빨리 할수록 좋은 일이 있습니다. 바로 감정을 다스리는 일입니다. 국내 한 학회 설문 결과에 따르면, 암 환자들은 신체적 어려움(52%)만큼이나 정서적 어려움(42%)을 많이 겪습니다. 정서적 어</p>,
#  <p class="cjs_d">지난해 10월 한국수력원자력(이하 한수원)은 폴란드전력공사(PGE)와 폴란드 원전 건설과 관련한 협력의향서(LOI)을 체결했다. 사업 규모만 300억달러(약 40조원)에 달하는 대규모 수주였다. 그런데 최근 이 사업</p>,
#  <p class="cjs_d">화요일인 오늘(26일) 전국이 대체로 맑은 가운데 내륙을 중심으로 큰 일교차가 나타나겠습니다. 한낮 최고기온은 26도까지 오르겠습니다. 기상청에 따르면 오늘 따뜻한 남서풍의 영향을 받아 전국 대부분 지역 낮 기온이 </p>,
#  <p class="cjs_d">며칠 전 부산에서 굴러온 화물이 등굣길을 덮치면서 10살 초등학생이 숨지는 사고가 있었죠. 숨진 딸을 기억하는 아빠의 글이 안타까움을 더하고 있습니다. 어제(1일) 한 온라인 커뮤니티에 '부산 영도구 청학동 A 양 </p>,
#  <p class="cjs_d">조 의원 “‘女 설치는 꼴 보기 싫다’는 부적절 민주, 尹 정부 ‘약한 고리’로 金만 파고 들어 ‘한 놈만 패자’는 전략, 유효기간 다돼” 지적 국회 소수당인 시대전환의 조정훈 의원은 윤석열 대통령 국빈 방미 과정에</p>,
#  <p class="cjs_d">뜨겁게 달아올랐던 배달앱 시장이 차갑게 식었다. 배달 대신 외식 수요가 증가한 데다, 고물가로 소비자들이 주머니를 닫아버린 탓이다. 높아진 배달비 부담도 소비자가 배달앱에 등을 돌리는 계기로 작용했다. '배달의민족'</p>,
#  <p class="cjs_d">이건산업이 알짜 사업 및 자회사를 이건창호에 몰아준 이유 박승준 사장 등이 법인 손해만큼 시세차익 거둬 논란 예상 이건그룹이 최근 2세 경영 체제로의 전환을 서두르고 있다. 지주회사인 이건홀딩스는 3월29일 주주총회</p>,
#  <p class="cjs_d">민주당 '돈봉투 의혹' 송영길 중앙지검 도착</p>,
#  <p class="cjs_d">‘양심적 병역거부자’가 현행 대체복무제도가 위헌이라며 헌법재판소에 제기한 헌법소원은 100여 건에 달한다. 2021년 첫 헌법소원 접수 이후 약 2년 동안 제기된 숫자가 이렇다. 대체복무요원은 육군의 2배인 36개월</p>,
#  <p class="cjs_d">서울에서 차를 타고 1시간여 만에 도착한 강원도 춘천 남산면에 위치한 더존비즈온 강촌캠퍼스. 이름 그대로 대학 캠퍼스를 방불케 하는 이곳의 지하1층에는 총면적 3300㎡ 규모의 데이터센터 'D-클라우드센터'가 자리 </p>,
#  <p class="cjs_d">길가던 40대 부부가 음주 운전 차량에 치여 한 명이 숨졌습니다. 오늘(1일) 오후 4시쯤 완주군 봉동읍 한 도로에서 갓길을 걷던 40대 부부가 음주 상태인 20대가 몰던 승용차에 치여 부인이 숨졌습니다. 경찰은 붙</p>,
#  <p class="cjs_d">[속보] 정무수석, 태영호 녹취록 논란에 "공천은 당에서...논의조차 안해"</p>,
#  <p class="cjs_d">삼성전자와 LG전자가 글로벌 스마트홈 표준 '매터'(Matter)의 국내 적용·확산 사업에 나란히 참여한다. 정부 주도의 첫 매터 사업으로 8개 컨소시엄 간 치열한 수주전이 펼쳐진 가운데 삼성, LG는 각각 디바이스</p>,
#  <p class="cjs_d">10여년째 계획만 갖고 있는 청주동물원 이전 여부에 대해 청주시가 올해 안에 매듭을 짓겠다며 외부용역을 추진했는데 의회가 제동을 걸었습니다. 내년에 출범하는 시정연구원에 용역을 맡기라는 것인데 시간이 너무 지체된다는</p>,
#  <p class="cjs_d">GWANGJU -- In celebration of the 60th anniversary of diplomatic relations between Switzerland and South Korea, the Embas</p>,
#  <p class="cjs_d">이진복 대통령실 정무수석은 2일 국민의힘 태영호 최고위원과 관련해 '공천 문제를 거론하며 한일 관계에 대해 옹호 발언을 해달라고 요청했다'는 MBC 보도와 관련해 "그런 얘기를 전혀 나눈 적이 없다"고 말했다. 이 </p>,
#  <p class="cjs_d">프랑스계 증권사 소시에테제네랄(SG)증권발 폭락사태를 놓고 핵심 인사들이 공방을 벌이고 있다. 자신 또한 피해자이며 주가조작 사태를 알지 못했다는게 이들의 이야기다. 하지만 폭락사태의 대상이 된 삼천리와 서울도시가스</p>,
#  <p class="cjs_d">한 남성이 살아 있는 금붕어를 통째로 삼키는 장면을 공개해 논란이 일고 있다고 영국 매체 더 선이 최근 보도했다. 더선에 따르면 이 남성은 경주마 거래계에서 잘 알려진 유명 에이전트 해미쉬 마카오리로 아일랜드 더블린</p>,
#  <p class="cjs_d">U.S. allies and security partners worldwide looking to re-stock their arsenals are increasingly turning to Korean defens</p>,
#  <p class="cjs_d">지난달 27일 신형 테슬라 모델 X를 시승해봤습니다. 일반 스티어링 휠 장착됐고, 플래드 모델은 아닙니다. 지난 서울모빌리티쇼에서 보지 못했던 부분 위주로 추가 리뷰를 진행한 후, 오토파일럿 위주 주행 테스트도 했는</p>,
#  <p class="cjs_d">탈영병 속출에 만취 전투까지…. 러시아군이 병사들의 이런 심각한 기강 해이에 몸살을 앓고 있다. 급기야 문제 병사를 땅 구덩이 속에 넣는 등 중세 시대에나 했을 법한 가혹한 처벌로 내부 단속에 나섰다는 서방 군 당국</p>,
#  <p class="cjs_d">중국 노동절 황금연휴(4월 29일~5월 3일)를 맞아 중국 전역의 관광지가 인산인해를 이루고 있다. 일부 유명 관광지에는 호텔을 잡지 못한 관광객들이 화장실에서 쪽잠을 자는 진풍경도 펼쳐지고 있다. 2일 중국중앙TV</p>,
#  <p class="cjs_d">남양주∙화성∙시흥∙용인의 초등∙고등학교에서 제공된 급식. 온라인 카페 캡처 최근 경기도내 일부 학교에서 급식이 부실하다는 지적이 잇따르면서 학생들의 영양 불균형이 심화될 수</p>,
#  <p class="cjs_d">한국노총이 올해 26억원 규모의 정부 국고보조금 지원사업에서 탈락했다. 정부가 노조 회계자료 미제출을 빌미로 노동계 압박을 위해 본격적으로 돈줄을 쥐고 흔들고 나선 것으로, 노조 도움을 받던 ‘노동 약자’에게 피해가</p>,
#  <p class="cjs_d">4월 소비자물가 상승률이 3.7%를 기록했다. 한국은행은 소비자물가 상승률이 올해 중반까지 뚜렷한 둔화 흐름을 나타낼 것이라고 전망하면서도 근원물가 상승률은 당분간 소비자물가에 비해 더딘 둔화 흐름을 이어갈 것으로 </p>,
#  <p class="cjs_d">내년에 적용될 최저임금 수준을 결정하기 위한 최저임금위원회 제1차 전원회의가 오늘(2일) 오후 3시 정부세종청사에서 열린다. 첫 전원회의는 당초 지난달 18일 열릴 예정이었지만, 노동계 인사들이 공익위원 간사인 권순</p>,
#  <p class="cjs_d">중국의 화성 탐사 무인이동 로봇(로버) ‘주룽(祝融)’이 화성 저위도 지표면에서 액체 상태의 물이 존재했던 증거를 찾았다. 화성 고위도가 아닌 저위도 지역에서 발견한 최초 증거다. 적도에 물이 존재할 가능성이 높다는</p>,
#  <p class="cjs_d">전북 완주경찰서는 음주운전을 하다가 보행자를 치어 숨지게 한 혐의(교통사고처리 특례법 위반 등)로 20대 A 씨에 대해 구속영장을 신청했다고 2일 밝혔다. A 씨는 전날 오후 4시 6분께 완주군 봉동읍의 한 도로에서</p>,
#  <p class="cjs_d">다우데이타·서울가스 회장, 매도 직전 블록딜로 수백억원 챙겨 “오너일가, 분기별로 계열사 주가 동향 보고받아...이상 반응 인지 가능” 일각선 “내 재산 수백억 왔다 갔다 하는 데 배경 안 찾아본다고? 말 안된다” </p>,
#  <p class="cjs_d">일명 '계곡 살인' 혐의로 1심에 이어 2심에서도 무기징역이 선고된 이은해(32)가 판결에 불복해 상고했다. 2일 법조계 등에 따르면 이 씨는 전날 서울고법 형사6-1부(원종찬 박원철 이의영 부장판사)에 상고장을 제</p>,
#  <p class="cjs_d">1980년 5월 광주, 그가 목격한 장면과 소회 가 영화 &lt;송암동&gt;의 특별상영을 위한 펀딩을 진행합니다. 특전사 K의 새로운 증언을 비롯한 송암동 일대 사건을 연속 보도하면서, 5.18민주화운동 마지막 날인 5월 2</p>,
#  <p class="cjs_d">기사내용 요약 택배 사칭해 악성앱 유포하는 스미싱, 올해 들어 기승 가정의 달 맞아 가족이 보낸 택배 정보로 오인하지 말아야 【서울=뉴시스】송혜리 기자 = #[Web발신][CJ대한통운] 배송물가&amp;!:도로명불일치</p>,
#  <p class="cjs_d">소시에테제네랄(SG)증권발 폭락사태를 놓고 핵심 인사들이 공방을 벌이고 있다. 삼천리와 서울도시가스 등 8개 종목에서 증발된 자금만 모두 8조원. 가수 임창정을 포함해 고액을 투자한 자산가들은 주가조작 사태를 알지 </p>,
#  <p class="cjs_d">이른바 ‘계곡 살인사건’으로 1심과 항소심에서 모두 무기징역을 선고받은 이은해(32)가 판결에 불복해 상고했다. 1일 법조계에 따르면 이씨는 이날 서울고법 형사6-1부(부장판사 원종찬 박원철 이의영)에 상고장을 제출</p>,
#  <p class="cjs_d">정부가 저소득층 청년 저축액의 최대 3배까지 같은 금액을 추가 지원하는 '청년내일저축계좌' 신규 가입자 모집이 1일 시작된다. 중위소득 100% 이하 가구의 만19세~34세 일하는 청년이이라면 청년내일저축계좌를 개설</p>,
#  <p class="cjs_d">“유명 연예인 광고 포기 못하더니” 국내 가상자산 거래소 코빗이 지난해 수백억원대 영업손실 기록했다. 가상자산 시장 침체로 인한 거래수수료 급감과 광고비 집행이 전년 대비 5배 늘어난 것이 적자의 주요 원인으로 풀이</p>,
#  <p class="cjs_d">● 진중권 “尹, 박근혜 정권보다 퇴행적” ● 박성민 “민주당 분열 가능성 60%” [+영상] 윤석열 1년을 말하다 [+영상] 국민의힘을 말하다 [+영상] 민주당을 말하다 2024년 4월 10일 치러지는 22대 총선</p>,
#  <p class="cjs_d">마지막 남은 블루오션 우주. 미국과 러시아, 중국, 인도 등은 일찌감치 우주의 가치에 눈을 뜨고 그 공간을 개척하고 있습니다. 우리나라도 자체 기술로 만든 위성발사용 로켓 누리호를 쏘아올리고 ‘우주항공청’을 설립하면</p>,
#  <p class="cjs_d">이진복 대통령실 정무수석은 2일 국민의힘 태영호 최고위원과 관련해 '공천 문제를 거론하며 한일 관계에 대해 옹호 발언을 해달라고 요청했다'는 MBC 보도에 대해 "그런 얘기를 전혀 나눈 적이 없다"고 말했다. 이 수</p>,
#  <p class="cjs_d">감사원이 KBS를 상대로 실시한 국민감사에서 핵심 의혹에 대한 중대 위법 사실이 확인되지 않았다. KBS는 공식 입장을 내고 “국민감사를 통해 각종 억측과 왜곡으로부터 명예를 회복했다”고 밝혔다. 감사원은 1일 KB</p>,
#  <p class="cjs_d">중국 최대 포털사이트 바이두(百度)의 백과사전이 김치와 삼계탕에 이어 삼겹살이 중국의 요리라고 표현한 것과 관련해 서경덕 성신여대 교수가 "한식공정(韓食工程)을 막아내겠다"고 말했다. 서 교수는 2일 사회관계망서비스</p>,
#  <p class="cjs_d">송영길 전 더불어민주당 대표가 민주당 전당대회 돈봉투(불법 정치자금) 의혹을 수사 중인 서울중앙지검에 2일 자진 출석했다.</p>,
#  <p class="cjs_ht">
#
#
#                                  오늘 언론사가 발행한<br/>종이신문에 실린 뉴스 1면<br/>기사가 제공됩니다.
#
#
#
#                      </p>,
#  <p class="cjs_dept_desc">"의대 정시, 고3은 N수생 못 이겨요... 그래서 초등부터 준비하자는 거죠"</p>,
#  <p class="cjs_dept_desc">"사명감? 그게 뭐죠?"... 의대 차석은 메스 대신 레이저를 잡았다</p>,
#  <p class="cjs_dept_desc">"중환자 치료는 교도소 담장 걷기"... '이대목동 사건' 이후 모든 게 달라졌다</p>,
#  <p class="cjs_dept_desc">[THINK ENGLISH] 이르면 올해 거리에서 배달 로봇 보게 될 듯</p>,
#  <p class="cjs_dept_desc">[THINK ENGLISH] 윤 대통령, 전세사기 매물 경매 중단 지시</p>,
#  <p class="cjs_dept_desc">[THINK ENGLISH] 조선 회화사의 공백 채울 걸작들의 귀환</p>,
#  <p class="cjs_dept_desc">日기시다 "7∼8일 방한 조율…한일관계 가속·국제정세 논의"(종합)</p>,
#  <p class="cjs_dept_desc">日언론 "기시다 7∼8일 방한 확정적…셔틀외교 재개 신호탄"(종합)</p>,
#  <p class="cjs_dept_desc">尹, 이달 한일·한미일 연쇄회담…한미일 협력 심화 본격화(종합)</p>,
#  <p class="cjs_dept_desc">윤 대통령 “업그레이드된 한·미 동맹, 청년에게 기회의 플랫폼 되어야”</p>,
#  <p class="cjs_dept_desc">윤 대통령 지지율 1.9%P 올라 34.5%···4주 만에 반등[리얼미터]</p>,
#  <p class="cjs_dept_desc">윤 대통령 귀국…‘미국 올인’ 후속 과제, 파도처럼 밀려온다</p>,
#  <p class="cjs_dept_desc">윤 대통령, 국빈 방미 마치고 서울공항 도착</p>,
#  <p class="cjs_dept_desc">대책 없는 영도구…딸 예서 잃은 아빠는 가슴 쳤다</p>,
#  <p class="cjs_dept_desc">보·차도 구분 없는 통학로, 스치듯 달리는 차량에 가슴 철렁</p>,
#  <p class="cjs_dept_desc">통학로 개선안 지난해 나왔는데…지자체 적용않고 뒷짐 “결국 인재”</p>,
#  <p class="cjs_dept_desc">사고 낸 업체대표, 지게차 면허도 없이 하역작업</p>,
#  <p class="cjs_dept_desc">[법정B컷]"전세사기요? 전 심부름만"…'빌라왕' 재판 판사의 분노</p>,
#  <p class="cjs_dept_desc">SSBN 부산에 기항…'비핵화 선언'과 모순 아니라고?[안보열전]</p>,
#  <p class="cjs_dept_desc">[그래?픽!]"저도 선생님 XX까요" 교권 추락…학생인권 때문이라고?</p>,
#  <p class="cjs_dept_desc">[딥뉴스]리버버스는 '골병라인'을 구할 수 있을까</p>,
#  <p class="cjs_dept_desc">세계가 주목하는 한국 임상시험… 서울로 몰리는 글로벌 제약기업들</p>,
#  <p class="cjs_dept_desc">임상시험 수치는 글로벌 '톱'… 정작 글로벌 신약은 '0'</p>,
#  <p class="cjs_dept_desc">글로벌 신약 2개·임상 점유율 3위… 종근당·대웅제약 '주도'</p>,
#  <p class="cjs_dept_desc">‘버섯 커피’ 일주일 마셨더니…내 몸에 어떤 변화?</p>,
#  <p class="cjs_dept_desc">﻿울긋불긋 여드름 예방에 효과적인 식습관 5</p>,
#  <p class="cjs_dept_desc">혈압 관리에 주의...나트륨 많이 든 뜻밖 식품 5</p>,
#  <p class="cjs_dept_desc">[명품 컷] 시간마저 천천히 흐르는 힐링의 섬 청산도</p>,
#  <p class="cjs_dept_desc">[정승조의 아트홀릭] 미술관이 가장 잘하는 걸 안 볼 이유는 없다</p>,
#  <p class="cjs_dept_desc">[아무튼, 자수] 꽃보다 그녀 ‘세월을 수놓다’</p>,
#  <p class="cjs_dept_desc">학원 뺑뺑이에 멍하니 창밖만… 외로움을 삼키는 아이들 [2023 대한민국 孤 리포트]</p>,
#  <p class="cjs_dept_desc">다문화 이중언어 경쟁력, ‘공생’ 너머 ‘상생’이 관건 [송민섭의 통계로 본 교육]</p>,
#  <p class="cjs_dept_desc">美의 탈중국 등에 업고 급부상… ‘세계의 공장’ 가속 채비 [심층기획-세계인구 1위 인도의 미래]</p>,
#  <p class="cjs_dept_desc">“우수 IT 인력, 인도 고속성장 주도적 역할 할 것” [심층기획-세계인구 1위 인도의 미래]</p>,
#  <p class="cjs_dept_desc">월경통 견디기 힘들다면… 약 '이 때' 드세요</p>,
#  <p class="cjs_dept_desc">나쁜 생각 꼬리에 꼬리를… '이 정신질환' 가능성</p>,
#  <p class="cjs_dept_desc">새벽 6시 전에 일어나는 여성이라면… '이런 상태'일 수도</p>,
#  <p class="cjs_dept_desc">손흥민 반칙하자 "무술 하네"‥인종 차별 논란</p>,
#  <p class="cjs_dept_desc">"문 열자마자 다 팔린다고?"‥무슨 맥주길래</p>,
#  <p class="cjs_dept_desc">"방이 없어요"‥결국 화장실서 '집단 투숙'</p>,
#  <p class="cjs_dept_desc">"갈매기 아니었어?"‥택시에서 먹이 받아 가는 까마귀</p>,
#  <p class="cjs_dept_desc">북핵 위협에 압도적 대응…'힘에 의한 평화' 방점[尹정부 개혁 1년]</p>,
#  <p class="cjs_dept_desc">'탈권위' 집무실 이전·용산공원 개방… '용산시대' 완성[尹정부 개혁 1년]</p>,
#  <p class="cjs_dept_desc">한미, 포괄적 전략동맹 격상…확장억제 명문화[尹정부 개혁 1년]</p>,
#  <p class="cjs_dept_desc">지지율로 본 尹정부 1년…최고 53%·최저 24%</p>,
#  <p class="cjs_dept_desc">"백신개발 10년→1년내 단축"…AI·빅데이터로 제약시장 새지평 [미리보는 서울포럼 2023]</p>,
#  <p class="cjs_dept_desc">농업혁신 '팜테크'·탄소감축 '바이오연료'…식량·기후 난제 푼다 [미리보는 서울포럼 2023]</p>,
#  <p class="cjs_dept_desc">美, mRNA 연구개발에만 41조 투입…韓은 105억 '쥐꼬리' 지원</p>,
#  <p class="cjs_dept_desc">이상엽 KAIST 연구부총장 "바이오경제 주도권 위해 합성생물학 키워야"</p>,
#  <p class="cjs_dept_desc">도대체 바닥은 어디일까...제주 아파트값 3억씩 ‘뚝뚝’ [김경민의 부동산NOW]</p>,
#  <p class="cjs_dept_desc">“이러다 20억 다시 찍으려나”...마포 집값 슬금슬금 오른다 [김경민의 부동산NOW]</p>,
#  <p class="cjs_dept_desc">용인 반도체 클러스터 수혜지 어디?...이천·동탄 등 경기 남부 ‘반세권’ 뜬다[김경민의 부동산NOW]</p>,
#  <p class="cjs_dept_desc">아파트 이름만 무려 25글자?...“길고 어려운 아파트명 쉽게 바꾸자”</p>,
#  <p class="cjs_dept_desc">AI 시대 우리는 무엇을 하고 살게 될까? 나의 미래 계급은? [SDF다이어리]</p>,
#  <p class="cjs_dept_desc">[씨네멘터리] 디자이너들이 꼽은 최고의 영화 포스터는?</p>,
#  <p class="cjs_dept_desc">[월드리포트] 확장억제 성과 논란…'말의 성찬'이 부른 후과</p>,
#  <p class="cjs_dept_desc">[월드리포트] 일본 남성 아이돌 대부 '성착취' 의혹…주류 언론 나서나</p>,
#  <p class="cjs_dept_desc">[기획] 中, 한미 밀착에 `경제보복` 예고</p>,
#  <p class="cjs_dept_desc">[경고음 커지는 對中 수출] 반도체·배터리·스마트폰도 고전… 對中 무역적자 굳어질수도</p>,
#  <p class="cjs_dept_desc">[경고음 커지는 對中 수출] 尹 방미로 냉랭해진 中… 당분간 갈등 기류 불가피</p>,
#  <p class="cjs_dept_desc">한·일 ‘셔틀외교’ 완전 복원… 尹 ‘저자세 외교’ 부담 덜었다</p>,
#  <p class="cjs_dept_desc">기시다 ‘조기 답방’… 반일 여론 달래고 美 요구 수용</p>,
#  <p class="cjs_dept_desc">[단독] ‘5말 6초’ 쇄신 개각… 이젠 內治 드라이브</p>,
#  <p class="cjs_dept_desc">[르포]베일에 싸인 '라덕연 최측근'… 집에도, BAR에도 없었다</p>,
#  <p class="cjs_dept_desc">檢, 'SG발 주식방 게이트' 라덕연 시세조종 혐의로 입건</p>,
#  <p class="cjs_dept_desc">"라덕연, 기업 회장들과 친분 말하며 투자 유도" 의혹 제기</p>,
#  <p class="cjs_dept_desc">'휴온스 그룹' 윤성태 회장도 라덕연 통해 고액투자 의혹</p>,
#  <p class="cjs_dept_desc">키움증권 사장 ‘직’ 걸었지만…김익래 회장 내통설 일파만파</p>,
#  <p class="cjs_dept_desc">‘무더기 하한가’ 투자자 10명 고소장 제출…법정공방 예고</p>,
#  <p class="cjs_dept_desc">“부작용 드러낸 CFD, 증시 뇌관 우려…완전 중단해야”</p>,
#  <p class="cjs_dept_desc">가족모임 많은 5월, "외식비 부담돼요"…치킨·삼겹살 등 줄인상</p>,
#  <p class="cjs_dept_desc">[남궁창성의 용산리포트] 16. 김건희 여사의 국빈방미 내조 외교</p>,
#  <p class="cjs_dept_desc">1분기 전국 아파트 거래 4명중 1명은 30대…2019년 이후 최대</p>,
#  <p class="cjs_dept_desc">[최동열의 산썰(山說)] 6.산에서 어명을 받은 소나무들</p>,
#  <p class="cjs_dept_desc">[오늘과학] 동료의 퇴사, 남은 직원들에게 미치는 영향은</p>,
#  <p class="cjs_dept_desc">[오늘과학] 남성 육아휴직, 가족 구성원 성평등 의식 높인다</p>,
#  <p class="cjs_dept_desc">[오늘과학] 북미서 발견된 5000만년 전 고추 화석</p>,
#  <p class="cjs_dept_desc">[오늘과학] 하얗게 세어버린 머리카락 되돌리는 법</p>,
#  <p class="cjs_dept_desc">[현장 카메라]길 막는 아파트…밀려나는 등굣길</p>,
#  <p class="cjs_dept_desc">[아는기자]한미 정상, 5차례 이상 만나…양국, 국빈 방문 평가는?</p>,
#  <p class="cjs_dept_desc">[세계를 보다]줄타기 외교 끊고 줄 서는 아시아</p>,
#  <p class="cjs_dept_desc">[세계를 가다]물가 뛴다고…이집트 정부, 닭발 먹기 캠페인</p>,
#  <p class="cjs_dept_desc">“기시다, 韓 피해자들 만나야” “日 국익 위해서라도 사죄 표명을”</p>,
#  <p class="cjs_dept_desc">日기시다 “7~8일 방한 조정… 尹대통령과 깊은 신뢰”</p>,
#  <p class="cjs_dept_desc">[사설]기시다 방한 추진… ‘과거사 성의’ 보여야 미래로 갈 수 있다</p>,
#  <p class="cjs_dept_desc">日언론 “기시다, 尹대통령 본받으면 어떨까” 이례적 논평</p>,
#  <p class="cjs_dept_desc">세상에 없던 문화예술 플랫폼 아르떼가 문을 활짝 열었습니다</p>,
#  <p class="cjs_dept_desc">조수미·임지영 칼럼까지…최고의 리뷰, '아르떼'서 만나보세요</p>,
#  <p class="cjs_dept_desc">공연·영화·미술관 프라이빗 투어가 무료…"댓글로 신청하세요"</p>,
#  <p class="cjs_dept_desc">터치하면 내 주변 공연·전시 정보가 '한눈에'</p>,
#  <p class="cjs_dept_desc">"재차 금리 동결했는데" 부동산 시장은 '…'</p>,
#  <p class="cjs_dept_desc">부동산 규제지역 단순화…수요자 혼선 줄어 "환영"</p>,
#  <p class="cjs_dept_desc">아파트 매매 증가하는데…빌라·오피스텔 거래량은 '뚝'</p>,
#  <p class="cjs_dept_desc">'따뜻한 아이스아메리카노' 논란 부른 부동산규제</p>,
#  <p class="cjs_dept_desc">사상 최대 규모 ‘영월~양구 강원 내륙고속도’ 정부 첫 검토 착수</p>,
#  <p class="cjs_dept_desc">국수본 ‘전세 사기꾼’ 동해 망상지구 특혜 의혹 내사</p>,
#  <p class="cjs_dept_desc">‘분신 시도’ 건설노조 강원지부 간부 3명 구속영장 기각</p>,
#  <p class="cjs_dept_desc">횡성 교차로서 덤프트럭-화물차 충돌…2명 사상</p>,
#  <p class="cjs_dept_desc">구글, 애플… '쥐꼬리 이익률' 속 탐욕과 농락 [視리즈]</p>,
#  <p class="cjs_dept_desc">'내 돈'에 손댄 은행사람들… 사라진 양심과 제식구 감싸기 [SCOOP 관점]</p>,
#  <p class="cjs_dept_desc">냉면, 비빔밥… 1만원으로 먹을 게 없는 야속한 시절</p>,
#  <p class="cjs_dept_desc">문 닫는 도봉고등학교 가보니… 사라질 공간에 남은 흔적들</p>,
#  <p class="cjs_dept_desc">사회초년생·신혼부부 울린 인천 미추홀 '전세사기'</p>,
#  <p class="cjs_dept_desc">'전세사기 피해자'가 되기 위한 조건?</p>,
#  <p class="cjs_dept_desc">국가 개입은 '전세사기'로 제한…깡통전세는 어쩌나</p>,
#  <p class="cjs_dept_desc">K-콘텐츠 점령한 ‘센 언니’들…유리 천장 뚫는 여성 서사의 진화[K-콘텐츠 뒤흔드는 걸크러쉬]</p>,
#  <p class="cjs_dept_desc">콘텐츠가 앞서간 알파걸의 시대 [K-콘텐츠 뒤흔드는 걸크러쉬]</p>,
#  <p class="cjs_dept_desc">조선의 걸 크러시와 K-컬처의 여전사들 [EDITOR's LETTER]</p>,
#  <p class="cjs_dept_desc">“나 빼고 다 해외 가네”…5월 연휴 내내 SNS엔 여행 사진이</p>,
#  <p class="cjs_dept_desc">김해서 대규모 꽃축제…“꽃의 바다에 푹 빠져보세요”</p>,
#  <p class="cjs_dept_desc">등골 휘는 5월 ‘가정의 달’…“어버이날·어린이날 부담”</p>,
#  <p class="cjs_dept_desc">매년 1억~4억명의 생명을 위협하는 ‘OOO’ 감염</p>,
#  <p class="cjs_dept_desc">[제보는Y] "누가 내 통장을 개설해?"...무턱대고 전화하면 '보이스피싱'</p>,
#  <p class="cjs_dept_desc">[단독] 서울 은평구도 '빌라 100채' 전세사기..."최소 200억 피해"</p>,
#  <p class="cjs_dept_desc">[제보는Y] 거동 불편한 노인 괴롭히는 사회복무요원...학대? 장난?</p>,
#  <p class="cjs_dept_desc">[팩트와이] 우리 교과서는 '강제노동' 충실히 기록?...日 교과서 보기도 민망</p>,
#  <p class="cjs_dept_desc">수출 7개월째 감소… 반도체는 반토막 [尹정부 1년 성과와 전망 (2)부진 늪에 빠진 수출]</p>,
#  <p class="cjs_dept_desc">'반도체 착시' 끝나자 무너진 수출… 정부 총력전도 안먹힌다 [尹정부 1년 성과와 전망 (2)부진 늪에 빠진 수출]</p>,
#  <p class="cjs_dept_desc">민간 주도 혁신성장 궤도 올랐지만… 감세發 세수펑크 우려 '딜레마'[尹정부 1년 성과와 전망]</p>,
#  <p class="cjs_dept_desc">[굿모닝경제]JP모건, 퍼스트리퍼블릭은행 인수/ 전세사기 우선매수 '가격 상한선'/ 제주~베이징 직항 재개</p>,
#  <p class="cjs_dept_desc">[굿모닝월드]"캠핑은 못 참지" 대관식을 기다리는 사람들</p>,
#  <p class="cjs_dept_desc">[굿모닝월드]환경운동도 좋지만...토론회 무단난입한 남성</p>,
#  <p class="cjs_dept_desc">[굿모닝월드]이제는 죄수 대신 관광객을, 호주 교도소 호텔</p>,
#  <p class="cjs_dept_desc">“매달 월급처럼 배당금이 또박또박” 요즘 인기 모으는 월배당 ETF</p>,
#  <p class="cjs_dept_desc">‘노랜딩’ 가능성 날린 SVB 파산, 다음 악재는 국제유가?</p>,
#  <p class="cjs_dept_desc">“KB? 미래에셋? 어느 게 좋나요” 목돈 마련 돕는 다양한 청년 펀드들</p>,
#  <p class="cjs_dept_desc">월 소득 4000만 원으로 주담대 먼저 갚으세요</p>,
#  <p class="cjs_dept_desc">근로자의 날, 대규모 집결한 민주노총 '노동탄압 규탄' [TF사진관]</p>,
#  <p class="cjs_dept_desc">인파로 가득한 '서울페스타 2023 명동 페스티벌' [TF사진관]</p>,
#  <p class="cjs_dept_desc">윤석열, '5박 7일간 국빈 방미' 마치고 귀국 [TF사진관]</p>,
#  <p class="cjs_dept_desc">서울 밤하늘에 펼쳐진 '화려한 드론 쇼' [TF사진관]</p>,
#  <p class="cjs_dept_desc">“내 몸 내가” 솔로의 선택… 35세 김대리 ‘110세 어른이보험’ 꽂혔다</p>,
#  <p class="cjs_dept_desc">“나 죽으면 보험금 탈 가족 없어” 종신보험, 인구와 함께 사라지다 [인구가 모든 것의 모든 것이다]</p>,
#  <p class="cjs_dept_desc">저출산·고령화로 난감해진 국내 보험사…‘인구대국’ 中·인도네시아·베트남서 ‘기회’</p>,
#  <p class="cjs_dept_desc">[尹정부 1년]④외교에 죽고 외교에 산다…'글로벌 3중고' 돌파</p>,
#  <p class="cjs_dept_desc">[尹정부 1년]②첫 검사 출신 대통령…좌충우돌 정치열전</p>,
#  <p class="cjs_dept_desc">[尹정부 1년]③"대한민국 1호 영업사원"… 핵심 키워드 '민생 경제'</p>,
#  <p class="cjs_dept_desc">[尹정부 1년]⑤지지부진한 3대 개혁…돌파구는?</p>,
#  <p class="cjs_dept_desc">첫사랑 속삭이던 우리말로 '조선족 이야기' 쓴다</p>,
#  <p class="cjs_dept_desc">마른 몸에 대한 욕망, 뚱뚱해지는 것에 대한 두려움</p>,
#  <p class="cjs_dept_desc">"검사 때 해외연수?" 尹 영어연설 띄우기 진심이었던 언론 </p>,
#  <p class="cjs_dept_desc">"지하철 사회복무요원은 노동자가 아닌 노예인가"</p>,
#  <p class="cjs_dept_desc">TK 국회의원 발언 키워드는…'코로나 704회' '북한 592회' 공항 '530회'</p>,
#  <p class="cjs_dept_desc">류성걸 670회 최다 발언…김승수 5688·윤재옥 3227회 [TK 정치권 국회 회의록]</p>,
#  <p class="cjs_dept_desc">벌써 '물밑 행보' 시동…대구 내년 4·10 총선 출마 예상자는?</p>,
#  <p class="cjs_dept_desc">외신 "美, 韓 핵무장론 달래기 시도…핵잠 기항 동북아 불안정 키울 것"</p>,
#  <p class="cjs_dept_desc">워싱턴선언 '동상이몽'? 대통령실 "사실상 핵공유" 美당국자 "핵공유 아냐"</p>,
#  <p class="cjs_dept_desc">尹대통령 '워싱턴선언' 후속행보, 한미 '핵공유' 온도차</p>,
#  <p class="cjs_dept_desc">'자체 핵무장' 주장 태영호 "尹대통령에 영업왕 칭호까지 줘야겠다"</p>,
#  <p class="cjs_dept_desc">양곡법 거부, 대통령이 사상 처음으로 농민을 걷어찼다</p>,
#  <p class="cjs_dept_desc">농민 갈라치기로 끝난 양곡법 개정안 논란</p>,
#  <p class="cjs_dept_desc">‘쌀값 대치’ 사태, “정치가 정치이기를 포기한 일”</p>,
#  <p class="cjs_dept_desc">[따져보니] '고공행진' 비행기표 값, 왜 안 내릴까?</p>,
#  <p class="cjs_dept_desc">[단독] '마약 투약' 40대 남성, 도심 주택가 '나체 난동'</p>,
#  <p class="cjs_dept_desc">[뉴스야?!] 전세 사기에 침묵하는 친文?</p>,
#  <p class="cjs_dept_desc">[따져보니] '지역사회'가 뭐길래…'간호법' 대립 이유는?</p>,
#  <p class="cjs_dept_desc">에코프로 수혜주(?) 증권사…거래량 증가에 ‘흑자 전환’ 성공 [투자360]</p>,
#  <p class="cjs_dept_desc">“미국 눈치 보여도 중국은 필요해” K배터리의 ‘결단’ 통할까 [비즈360]</p>,
#  <p class="cjs_dept_desc">에드워드 호퍼 그림으로 소설을 쓴다면... [어떤 울림]</p>,
#  <p class="cjs_dept_desc">뒤에만 ‘삼각별이 다섯개’…11세대 E클래스, 뭐가 달라졌니? [여車저車]</p>,
#  <p class="cjs_dept_desc">美 "中, 과잉 반응할 이유 없다"…'워싱턴 선언' 北·中 반발 일축</p>,
#  <p class="cjs_dept_desc">뉴욕증시, JP모간의 퍼스트리퍼블릭 인수에 안도 소폭 하락 ‘테슬라 1.15%↓’…유가·비트코인 하락 [출근전 꼭 글로벌브리핑]</p>,
#  <p class="cjs_dept_desc">"中군기지서 대형비행선 포착"…이번엔 '하늘 위 잠수함'?</p>,
#  <p class="cjs_dept_desc">"위험한 인공지능 기술 규제해야"…'AI 대부'의 일침</p>,
#  <p class="cjs_dept_desc">[오마이포토] '윤석열 OUT' '가자! 총파업' 민주노총 노동절대회</p>,
#  <p class="cjs_dept_desc">노동절에 거리에 나온 노동자들 "노동개악 윤석열정부 심판"</p>,
#  <p class="cjs_dept_desc">"윤석열 정권 노동자 탄압에 골몰, 퇴진 투쟁으로 나갈 것"</p>,
#  <p class="cjs_dept_desc">건설 노동자, 춘천지법 강릉지원 앞 분신... "의식 없어"</p>,
#  <p class="cjs_dept_desc">"빚 돌려막기 탈출구 안보여"… 30일 단기연체자 2배 넘게 급증</p>,
#  <p class="cjs_dept_desc">취약차주 '빚탕감 잔치' 안되게 일해서 원금갚게 고용지원 필요</p>,
#  <p class="cjs_dept_desc">개인 빚 연체대란…채무조정 44% 급증</p>,
#  <p class="cjs_dept_desc">“이 빚들, 언제 다 갚나”…1년 새 청년 다중채무자 4만명 늘었다</p>,
#  <p class="cjs_dept_desc">Samsung to raise wafer input for R&amp;D</p>,
#  <p class="cjs_dept_desc">Classical music returns to Gyechon Village with world-class performances</p>,
#  <p class="cjs_dept_desc">Tens of thousands hold Labor Day rallies nationwide</p>,
#  <p class="cjs_dept_desc">하한가 직전 '기막힌 매도' 300억 번 회장님들…SG발 폭락사태 수사 돌입</p>,
#  <p class="cjs_dept_desc">"주가급등 후 하따까지"…이 '작전' 어디서 봤더라?[손엄지의 주식살롱]</p>,
#  <p class="cjs_dept_desc">[단독]골퍼 A씨측 "라덕연 1년전 알게돼…라대표, 회사 사줄테니 관리해라"</p>,
#  <p class="cjs_dept_desc">[작전이 판친다]임창정도 30억?…연예인·골퍼·의사 엮인 주가조작판</p>,
#  <p class="cjs_dept_desc">[단독] 부산 대표 친환경기업 파나시아 발 빠른 연구 덕에 중견기업 됐다</p>,
#  <p class="cjs_dept_desc">[단독]핵탄두 탑재 SSBN 오는 19일 부산 첫 기항 유력</p>,
#  <p class="cjs_dept_desc">[단독]산업은행 부산행 ‘첫발’ 이전 공공기관 지정, 고시만 남았다</p>,
#  <p class="cjs_dept_desc">‘가을이 사건’ 가스라이팅 있었나… 친모 입에 쏠린 눈</p>,
#  <p class="cjs_dept_desc">[RSAC2023] 함께하면 강해진다? 한국 기업들에게 던져진 숙제</p>,
#  <p class="cjs_dept_desc">[RSAC2023] 한-미 사이버동맹, ‘파이브아이즈’ 수준으로 강화</p>,
#  <p class="cjs_dept_desc">[RSAC2023] 전시회 성황리 개막··· 보안 리더 기업 대부분 참여</p>,
#  <p class="cjs_dept_desc">[RSAC2023] “사이버보안에 AI 기술 활용코자 하는 움직임 확인”</p>,
#  <p class="cjs_dept_desc">수출 양대 축 ‘반도체·중국’서 ‘자동차·미국’으로?</p>,
#  <p class="cjs_dept_desc">고개 치켜세운 연체율, 저축銀 5% 대부업 10% 넘겼다</p>,
#  <p class="cjs_dept_desc">전세보증보험 한도 낮춰… 전세금 더 내릴 듯</p>,
#  <p class="cjs_dept_desc">[단독] 스마트폰 더 싸진다… 단통법 9년만에 폐지 가능성</p>,
#  <p class="cjs_dept_desc">[사설] 기시다 총리가 진정성 있게 호응할 차례다</p>,
#  <p class="cjs_dept_desc">[중앙시평] 지역 인구위기와 홍길동</p>,
#  <p class="cjs_dept_desc">[서경호의 시시각각] 쾌도난마와 현실 사이</p>,
#  <p class="cjs_dept_desc">[조민근의 시선] 선 넘는 정치, 방관하는 장관</p>,
#  <p class="cjs_dept_desc">[스페셜리포트]'매터' 인증 80%가 中…하반기 스마트홈 표준 경쟁 본격화</p>,
#  <p class="cjs_dept_desc">[스페셜리포트]美·中 주도 '매터' 시장, 서비스 경쟁력 확보 필요</p>,
#  <p class="cjs_dept_desc">삼성·LG, 국내 첫 스마트홈 표준사업 주도한다</p>,
#  <p class="cjs_dept_desc">첫 민간 주도 지능형 스마트홈 전략 나온다</p>,
#  <p class="cjs_dept_desc">알림 꺼도 계속 뜨는 ‘팝업창’…교묘한 압박 상술 [다크패턴 맹추격④]</p>,
#  <p class="cjs_dept_desc">가족사진, 무료 촬영이라더니…‘인화’ 추가비용에 당했다 [다크패턴 맹추격③]</p>,
#  <p class="cjs_dept_desc">갈수록 늘어나는 ‘미끼상품’…오늘도 모르게 낚였다 [다크패턴 맹추격②]</p>,
#  <p class="cjs_dept_desc">“갑자기 8만원이나 올랐네”…소비자 기만 숙박예약 플랫폼 [다크패턴 맹추격①]</p>,
#  <p class="cjs_dept_desc">'주가 폭락사태' 책임 공방전…처벌 가능성은?</p>,
#  <p class="cjs_dept_desc">폭락 사태 늑장대응…커지는 금융당국 책임론</p>,
#  <p class="cjs_dept_desc">라덕연 "대주주에 손배소"…키움 "라 대표 고소"</p>,
#  <p class="cjs_dept_desc">‘윤석열 특수활동비’ 6월 23일 공개된다</p>,
#  <p class="cjs_dept_desc">[주간 뉴스타파] 1,243일만의 승소... '검사' 윤석열, 검증의 시간</p>,
#  <p class="cjs_dept_desc">확정판결 검찰예산 신속히 공개 안 하면, '간접강제' 신청한다</p>,
#  <p class="cjs_dept_desc">검찰의 방패를 뚫고, 정보공개 최종 판결을 받아내기까지</p>,
#  <p class="cjs_dept_desc">[단독] '투자 큰손' 중엔 제약사 오너도…주가조작단 채널에 광고 집행</p>,
#  <p class="cjs_dept_desc">주가조작 핵심 세력 '수상한 회동'…"증거인멸 시도로 비칠 수 있어"</p>,
#  <p class="cjs_dept_desc">[단독] 폭락 전날에도 "지금이 매수 기회"…폭락 후엔 "다시 불려줄게"</p>,
#  <p class="cjs_dept_desc">전두환 손자 폭로는 인정 욕구와 가족 사랑의 발로 [+영상]</p>,
#  <p class="cjs_dept_desc">“석열아, 먼저 손 내밀고 더 많이 들어라” [+영상]</p>,
#  <p class="cjs_dept_desc">“尹, 술 마실 땐 ‘통 큰 사람’… 정치는 통 크게 못했다” [+영상]</p>,
#  <p class="cjs_dept_desc">‘길복순’ 전도연 “집에선 아이에게 쩔쩔매는 엄마예요”</p>,
#  <p class="cjs_dept_desc">[젊은 두뇌가 뛴다]⑫ 학위 대신 1조원 회사 일군 영재학교 출신 창업가 “사업도 연구도 문제 푸는 과정”</p>,
#  <p class="cjs_dept_desc">[젊은 두뇌가 뛴다]⑪ “우주산업은 시행착오 겪으며 크는 산업...실패해도 기회 줘야”</p>,
#  <p class="cjs_dept_desc">[젊은 두뇌가 뛴다]⑩ 분자 1개 크기 반도체 나온다... ‘무어의 법칙’에 도전한 화학자</p>,
#  <p class="cjs_dept_desc">[젊은 두뇌가 뛴다]⑨ 영장류 연구에서 난치병 해법 찾는 혈액학자</p>,
#  <p class="cjs_dept_desc">“내 땅이다”…현황도로 막아 주민과 갈등 빚는 前 양평군청 국장</p>,
#  <p class="cjs_dept_desc">경기일보 ‘근로자 재해 실태 보고서’ 일터의 생명을 깨우다</p>,
#  <p class="cjs_dept_desc">‘가정 위탁’ 가교역할에 초점... 제대로 된 이해·지원 시급 [가정의 달 특집 ‘우리는 가족’]</p>,
#  <p class="cjs_dept_desc">이혼할 때 男 '애증 교차'...女 '해방감'</p>,
#  <p class="cjs_dept_desc">'돈봉투 파문' 민주당은 여유 왜? '이정도 스캔들 별 문제 없어' 안일한 인식 탓" [촌철살인]</p>,
#  <p class="cjs_dept_desc">尹 대통령 방미 성과 "100% 만족하기 어려워도 너무 폄하할 필요는 없어" [촌철살인]</p>,
#  <p class="cjs_dept_desc">'구하라·박수홍' 변호인 "권경애, 변호사의 수치..법, 정의 실현하는지 의문"[여의도초대석]</p>,
#  <p class="cjs_dept_desc">장예찬 "송영길은 꼬리, 몸통은 이재명..연결고리 '키맨'은 바로 '이사람'"[여의도초대석]</p>,
#  <p class="cjs_dept_desc">"안지킨 기본 수칙 수두룩"..산안법 위반 592건</p>,
#  <p class="cjs_dept_desc">"무재해 사업장 거듭나겠다".. 여전히 '위험한 일터'</p>,
#  <p class="cjs_dept_desc">새만금잼버리 현장 점검.."텐트 치기 부적합"</p>,
#  <p class="cjs_dept_desc">"냉해는 보험료 2배"..누구를 위한 농작물보험?</p>,
#  <p class="cjs_dept_desc">당뇨병 환자가 가당 음료 마시면 생기는 위험은?</p>,
#  <p class="cjs_dept_desc">더 길어진 꽃가루시즌, 알레르기 대비법</p>,
#  <p class="cjs_dept_desc">다이어트 할 때 절대 먹어서는 안 되는 음식 5</p>,
#  <p class="cjs_dept_desc">따뜻한 날씨에 늘어난 호흡기감염병…예방·관리수칙은?</p>,
#  <p class="cjs_dept_desc">윤 대통령 미국서 ‘장진호 전투’ 언급, 중국은 왜 격분했나</p>,
#  <p class="cjs_dept_desc">‘아메리칸 파이’ 부르고 돌아온 윤 대통령</p>,
#  <p class="cjs_dept_desc">“미국 ‘경제안보’ 새 그물에 한국 반도체·배터리 잡힌 꼴”</p>,
#  <p class="cjs_dept_desc">김건희 여사 방미 단독 일정 7개…갤러리 관람만 취재 ‘허용’</p>,
#  <p class="cjs_dept_desc">[뉴스 즉설]시치미 뚝 송영길, 동문서답 이재명, '돈봉투 민주당' 뭐가 중한디?</p>,
#  <p class="cjs_dept_desc">[픽&amp;톡]"마스크 벗었다고 코로나 끝난 게 아니다"</p>,
#  <p class="cjs_dept_desc">[뉴스 즉설]영길이 형 아웃, 7인회 해체, 이재명 퇴진… 돈봉투 후폭풍 어디까지</p>,
#  <p class="cjs_dept_desc">[줌인] 충청 인구감소 가속화</p>,
#  <p class="cjs_dept_desc">[약손+] 아이들도 힘들다, '새 학기 증후군' ⑩ADHD와 약물치료</p>,
#  <p class="cjs_dept_desc">[영상+] "내 꼬리는 빨개" 가창 부채꼬리바위딱새</p>,
#  <p class="cjs_dept_desc">[만나보니] 국가인권위원회가 제시하는 이슬람 사원 갈등 해법은?</p>,
#  <p class="cjs_dept_desc">[들어보니] 우리는 보통 사람입니다 | 빅벙커</p>,
#  <p class="cjs_dept_desc">‘계곡살인’이은해, 항소심 무기징역 판결도 불복…대법원 상고</p>,
#  <p class="cjs_dept_desc">한국, 양육비 가장 비싼 나라 1위…2위는?</p>,
#  <p class="cjs_dept_desc">日, 북한 정찰위성 대비해 오키나와섬 3곳에 패트리엇 배치</p>,
#  <p class="cjs_dept_desc">검찰, ‘천화동인6호 실소유주 의혹’ 조우형 구속영장</p>,
#  <p class="cjs_dept_desc">'하얀 석유' 리튬 연 2000t 추출..75조 시장 공략한다</p>,
#  <p class="cjs_dept_desc">합작법인·지분투자 ‘활발’…폐배터리 선점 나선 기업들</p>,
#  <p class="cjs_dept_desc">고물이 보물로..600조 폐배터리 재활용시장 사활건 韓기업</p>,
#  <p class="cjs_dept_desc">“원통형·각형 제각각…폐배터리 재활용, ‘체계화’가 핵심”</p>,
#  <p class="cjs_dept_desc">핵협의그룹(NCG) 운영 방안이 관건…구체적 계획은?</p>,
#  <p class="cjs_dept_desc">노동절을 대하는 서로 다른 자세…“노란봉투법 철회” vs “학부모 주4일제”</p>,
#  <p class="cjs_dept_desc">가짜 면허증으로 2년간 약사 행세…5만 차례 불법 판매</p>,
#  <p class="cjs_dept_desc">“기시다 일본 총리 7~8일 방한”…‘과거사 사죄’는?</p>,
#  <p class="cjs_dept_desc">잃어버린 국익을 찾아서…미국은 ‘국익’, 한국은 ‘미익’</p>,
#  <p class="cjs_dept_desc">“냉전 때와 닮아…과거로 가는 동맹” [정상회담특집②]</p>,
#  <p class="cjs_dept_desc">과거사 사죄 요구가 ‘무릎 꿇리는’ 일인가</p>,
#  <p class="cjs_dept_desc">윤 대통령, 대만을 “세계적 문제”로 언급해 중국의 반발 부르다</p>,
#  <p class="cjs_dept_desc">국민연금 月 200만원 ↑ 고액수령자 한달새 3배 '껑충'...평균  수령액은?</p>,
#  <p class="cjs_dept_desc">"그나마 나아졌다고?" 여전히 팍팍한 물가.. 공공요금 부담 여전</p>,
#  <p class="cjs_dept_desc">태영호 녹취록 파장에 유승민 "불법 공천개입 누누히 경고" 수사  촉구</p>,
#  <p class="cjs_dept_desc">대통령실, 공천 거론 '한일관계 옹호 요청' 의혹...태영호 녹취록 후폭풍</p>,
#  <p class="cjs_dept_desc">여성을 가둔 감옥을 부수자, 마녀들과 춤추자</p>,
#  <p class="cjs_dept_desc">정통 워맨스, 그런데 킬힐 못 벗은 언니들의 '퀸메이커'</p>,
#  <p class="cjs_dept_desc">피해자 보호 관점 실종된 '나는 신이다' 열풍</p>,
#  <p class="cjs_dept_desc">60대에 '별의 순간' 양자경...트랜스젠더 연기로 8세에 은곰상</p>,
#  <p class="cjs_dept_desc">비대면 진료 초진 허용, 서로 물러설 수 없는 이유 [보건의료 리포트]</p>,
#  <p class="cjs_dept_desc">바이오헬스 인재 양성 나선 정부, 빠른 변화와 소통 필요하다 [보건의료 리포트]</p>,
#  <p class="cjs_dept_desc">바이오헬스 성장 위한 정부 '선물보따리'…'오답노트' 반복하나 [보건의료 리포트]</p>,
#  <p class="cjs_dept_desc">[보건의료 리포트] 길 잃은 ‘혁신형 제약기업’, 변신의 갈림길 서다</p>,
#  <p class="cjs_dept_desc">[어제장 오늘장] 주식 팔고 떠나야 하는 5월?…'셀인 메이' 공략법</p>,
#  <p class="cjs_dept_desc">[굿모닝 마켓] 뉴욕 증시 '소방수' JP모건…이익 26억 달러 추정</p>,
#  <p class="cjs_dept_desc">[김대호 박사의 오늘 기업·사람] 웨스팅하우스·한수원·넷플릭스·티빙·웨이브·뉴스케일·테라파워</p>,
#  <p class="cjs_dept_desc">[손에 잡히는 재테크] '굴비'로 만드는 '적금밥상'…돈도 재미도 잡는 적금?</p>,
#  <p class="_help_subscribe" style="display: none">구독하신 기자가 최근 48시간 이내 작성한 기사가 제공됩니다. 전체 구독 리스트는 구독 설정에서 확인하세요.</p>,
#  <p class="_help_nonSubscribe" style="display: block">기자별 기사를 자동 추천해 드립니다. 기자를 구독하시면 해당 기자의 최신 기사를 언론사별에서 확인할 수 있습니다.</p>,
#  <p class="_help_subscribe" style="display: none">구독한 연재 중 최근 48시간 이내 작성된 기사가 제공됩니다. 전체 구독 리스트는 구독 설정에서 확인하세요.</p>,
#  <p class="_help_nonSubscribe" style="display: block">다양한 연재 기사를 자동 추천해 드립니다. 연재를 구독하시면 해당 연재의 최신 기사를 언론사별에서 확인할 수 있습니다.</p>,
#  <p class="f_notice_text">기자·연재 카드 개선 안내</p>,
#  <p class="u_ftlkw _footer_login" id="u_ftlkw">
#  <a class="u_ftlk" data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' href="https://m.naver.com/services.html" onclick="nclk(event,'fot.serviceall','','');">전체서비스</a>
#  </p>,
#  <p class="u_cr">
#  <span class="u_ftm">
#  <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/term.html?type=1?type=1","p":"https://policy.naver.com/rules/service.html"}' href="https://policy.naver.com/policy-mobile/term.html?type=1?type=1" onclick="nclk(event,'fot.agreement','','');">이용약관</a></span>
#  <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/privacy.html","p":"https://policy.naver.com/rules/privacy.html"}' href="https://policy.naver.com/policy-mobile/privacy.html" onclick="nclk(event,'fot.privacy','','');"><strong>개인정보처리방침</strong></a></span>
#  <span class="u_cri u_cri_v1">청소년 보호 책임자 : 이희만</span>
#  <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/index","p":"https://news.naver.com/main/ombudsman/index.naver"}' href="https://m.news.naver.com/ombudsman/index" onclick="nclk(event,'fot.guide','','');">서비스안내</a></span>
#  </span>
#  <span class="u_cri">각 언론사가 직접 콘텐츠를 편집합니다.</span>
#  </p>]

# %%
## find(): 하나의 요소만 가져옴
## limit(): 태그의 양을 제한
print(bs.find_all('p', limit=1),'\n')
print(bs.find_all('p', limit=5))
# Out:
# [<p class="cjs_d">‘SG증권발(發) 주가 폭락 사태’ 피해자라 주장해온 가수 임창정이 주가조작단과 동업한 정황이 포착됐다. 주범으로 지목된 라덕연 H투자자문사 대표를 ‘종교’라 칭하며 신뢰를 표한 모습 또한 공개됐다. 1일 JTBC </p>]
#
# [<p class="cjs_d">‘SG증권발(發) 주가 폭락 사태’ 피해자라 주장해온 가수 임창정이 주가조작단과 동업한 정황이 포착됐다. 주범으로 지목된 라덕연 H투자자문사 대표를 ‘종교’라 칭하며 신뢰를 표한 모습 또한 공개됐다. 1일 JTBC </p>, <p class="cjs_d">최근 4년간 ‘SKY’로 불리는 서울대학교·연세대학교·고려대학교의 정시모집 합격자 중 71.6%가 수도권 출신인 것으로 확인됐다. 강득구 더불어민주당 의원(경기 안양만안)과 교육랩공공장은 최근 국회에서 기자회견을 열</p>, <p class="cjs_d">음주운전자에 의해 아까운 목숨들이 지고 있다. 지난 4월8일 대전시 둔산동 한 어린이보호구역에서 만취한 60대 운전자가 몰던 차량이 인도로 돌진했다. 차는 인도 위를 걸어가던 초등학생 4명을 덮쳤다. 배승아 양(만 </p>, <p class="cjs_d">회원 수 40만명에 육박하는 네이버 1위 명품 구매대행 카페에서 판매자가 물건을 주지 않은 채 돈만 가로챈 이른바 '먹튀' 사기 피해 잇따라 발생했다. 해당 카페에서 구매대행 판매자 A씨에게 물건을 받지 못했다는 피</p>, <p class="cjs_d">국민의힘 소속 양태석 거제시의원이 공식 석상에서 외국인 노동자 혐오 발언을 했다는 사실이 뒤늦게 알려져 여론의 뭇매를 맞고 있다. 지난달 20일, 양 의원은 거제시의회 경제관광위원회 외국인노동자 지원 조례안 심사 과</p>]

# %%
url = 'https://news.naver.com/'
html = requests.get(url).text
bs = BS(html, 'html.parser')

bs.find('p', class_='cjs_ht')
bs.find_all('p', {'class':'cjs_d'})
# Out:
# [<p class="cjs_d">화요일인 오늘(26일) 전국이 대체로 맑은 가운데 내륙을 중심으로 큰 일교차가 나타나겠습니다. 한낮 최고기온은 26도까지 오르겠습니다. 기상청에 따르면 오늘 따뜻한 남서풍의 영향을 받아 전국 대부분 지역 낮 기온이 </p>,
#  <p class="cjs_d">뉴스를 통해 우리를 웃고 울렸던 어제의 오늘을 다시 만나봅니다. 2015년 5월 2일. 이모씨(당시 25세)는 이날 밤 11시쯤 자신이 지내던 서울 관악구 신림동의 한 오피스텔에서 여자친구 김모씨(당시 26세)를 목</p>,
#  <p class="cjs_d">가수 겸 배우 임창정 씨가 주가조작단이 개최한 한 투자자 모임에서 라덕연 대표에 대해 “아주 종교야!”라고 말한 모습이 공개됐다. 임씨는 자신도 주가조작의 피해자라고 호소하고 있다. 가수 겸 배우 임창정 (사진=뉴시</p>,
#  <p class="cjs_d">10여년째 계획만 갖고 있는 청주동물원 이전 여부에 대해 청주시가 올해 안에 매듭을 짓겠다며 외부용역을 추진했는데 의회가 제동을 걸었습니다. 내년에 출범하는 시정연구원에 용역을 맡기라는 것인데 시간이 너무 지체된다는</p>,
#  <p class="cjs_d">20대 국회 출판기념회 79건, 절반이 '총선 5개월 전' 열려 '북적북적' 출판기념회, 시중 판매는 뒷전…21대 의원 중 단 3명 공개 국회의원이 '작가'로 소개되는 장소. 출판기념회에서 의원들은 '책'을 팔지만,</p>,
#  <p class="cjs_d">봉화산烽火山(920m) 우리나라에서 가장 흔한 산 이름이 봉화산이다. 5월 산행지로 추천하는 봉화산은 남원과 장수 경계에 있는 백두대간 주능선의 봉화산이다. 전북 남원시 아영면과 장수군 번암면의 경계를 이루는 이 산</p>,
#  <p class="cjs_d">이진복 대통령실 정무수석은 2일 국민의힘 태영호 최고위원과 관련해 '공천 문제를 거론하며 한일 관계에 대해 옹호 발언을 해달라고 요청했다'는 MBC 보도에 대해 "그런 얘기를 전혀 나눈 적이 없다"고 말했다. 이 수</p>,
#  <p class="cjs_d">살을 빼려고 식사량을 줄이고 열심히 걷기 운동을 하는 사람이 있다. 먹는 양을 갑자기 줄이고, 한 시간 동안 걷는 데도 늘어난 체중은 변하지 않는다. 다이어트 방법이 잘못된 것일까? 덜 먹고 운동하는 데도 살이 안 </p>,
#  <p class="cjs_d">“유명 연예인 광고 포기 못하더니” 국내 가상자산 거래소 코빗이 지난해 수백억원대 영업손실 기록했다. 가상자산 시장 침체로 인한 거래수수료 급감과 광고비 집행이 전년 대비 5배 늘어난 것이 적자의 주요 원인으로 풀이</p>,
#  <p class="cjs_d">내년에 적용될 최저임금 수준을 결정하기 위한 최저임금위원회 제1차 전원회의가 오늘(2일) 오후 3시 정부세종청사에서 열린다. 첫 전원회의는 당초 지난달 18일 열릴 예정이었지만, 노동계 인사들이 공익위원 간사인 권순</p>,
#  <p class="cjs_d">한국노총이 올해 26억원 규모의 정부 국고보조금 지원사업에서 탈락했다. 정부가 노조 회계자료 미제출을 빌미로 노동계 압박을 위해 본격적으로 돈줄을 쥐고 흔들고 나선 것으로, 노조 도움을 받던 ‘노동 약자’에게 피해가</p>,
#  <p class="cjs_d">중국 최대 포털사이트 바이두(百度)의 백과사전이 김치와 삼계탕에 이어 삼겹살이 중국의 요리라고 표현한 것과 관련해 서경덕 성신여대 교수가 "한식공정(韓食工程)을 막아내겠다"고 말했다. 서 교수는 2일 사회관계망서비스</p>,
#  <p class="cjs_d">소시에테제네랄(SG)증권발 폭락사태를 놓고 핵심 인사들이 공방을 벌이고 있다. 삼천리와 서울도시가스 등 8개 종목에서 증발된 자금만 모두 8조원. 가수 임창정을 포함해 고액을 투자한 자산가들은 주가조작 사태를 알지 </p>,
#  <p class="cjs_d">U.S. allies and security partners worldwide looking to re-stock their arsenals are increasingly turning to Korean defens</p>,
#  <p class="cjs_d">조 의원 “‘女 설치는 꼴 보기 싫다’는 부적절 민주, 尹 정부 ‘약한 고리’로 金만 파고 들어 ‘한 놈만 패자’는 전략, 유효기간 다돼” 지적 국회 소수당인 시대전환의 조정훈 의원은 윤석열 대통령 국빈 방미 과정에</p>,
#  <p class="cjs_d">민주당 '전당대회 돈봉투 의혹' 송영길, 서울중앙지검 자진 출두 ※CBS노컷뉴스는 여러분의 제보로 함께 세상을 바꿉니다. 각종 비리와 부당대우, 사건사고와 미담 등 모든 얘깃거리를 알려주세요.이메일 : 카카오톡 : </p>,
#  <p class="cjs_d">지난해 역대 최대 규모 적자를 낸 한국전력이 근로자의 날을 앞두고 직원들에게 10만원 상품권을 지급했다 회수하면서 빈축을 샀다. 최근 직장인 익명 커뮤니티 ‘블라인드’에는 한국전력 직원 A씨가 관련 내용을 공유한 글</p>,
#  <p class="cjs_d">최근 4년간 ‘SKY’로 불리는 서울대학교·연세대학교·고려대학교의 정시모집 합격자 중 71.6%가 수도권 출신인 것으로 확인됐다. 강득구 더불어민주당 의원(경기 안양만안)과 교육랩공공장은 최근 국회에서 기자회견을 열</p>,
#  <p class="cjs_d">■ JTBC 뉴스룸이 단독 보도한 '주가조작 의혹' 녹취파일 등의 저작권은 JTBC에 있습니다. 인용보도시 'JTBC 뉴스룸' 출처를 분명하게 인식할 수 있는 크기로 표기해 사용해주시기 바랍니다. 주가조작단은 자신들</p>,
#  <p class="cjs_d">이건산업이 알짜 사업 및 자회사를 이건창호에 몰아준 이유 박승준 사장 등이 법인 손해만큼 시세차익 거둬 논란 예상 이건그룹이 최근 2세 경영 체제로의 전환을 서두르고 있다. 지주회사인 이건홀딩스는 3월29일 주주총회</p>,
#  <p class="cjs_d">전북 완주경찰서는 음주운전을 하다가 보행자를 치어 숨지게 한 혐의(교통사고처리 특례법 위반 등)로 20대 A 씨에 대해 구속영장을 신청했다고 2일 밝혔다. A 씨는 전날 오후 4시 6분께 완주군 봉동읍의 한 도로에서</p>,
#  <p class="cjs_d">AV 배우 인터뷰한 &lt;성+인물&gt; 논란, 어떻게 봐야하나? "AV산업은 일본 내 ‘성착취 구조’의 첨단에 자리합니다. 그 구조에 대한 비판적 고려 없이 이를 콘텐츠화한다뇨." - 이나영 중앙대학교 사회학과 교수 AV(</p>,
#  <p class="cjs_d">인생에서 큰 행사 중 하나인 결혼식. 그런데 비용이 너무 많이 들면서, 젊은 부부들의 결혼식은 예전과 많이 달라진 모습입니다. 조금이라도 아끼면서 결혼하려는 사람들이 늘었는데, 어떻게 한 푼이라도 아끼면서 결혼식을 </p>,
#  <p class="cjs_d">윤석열 대통령의 미국 국빈 방문 성과를 두고 논란이 가중되는 가운데, 대통령실이 여당 지도부를 초청해 관련 논의를 위한 ‘뒤풀이’를 연다. 대통령실은 2일 저녁 용산 대통령실에서 국민의힘 지도부와 만찬을 하며 방미 </p>,
#  <p class="cjs_d">지난해 10월 한국수력원자력(이하 한수원)은 폴란드전력공사(PGE)와 폴란드 원전 건설과 관련한 협력의향서(LOI)을 체결했다. 사업 규모만 300억달러(약 40조원)에 달하는 대규모 수주였다. 그런데 최근 이 사업</p>,
#  <p class="cjs_d">지난달 27일 신형 테슬라 모델 X를 시승해봤습니다. 일반 스티어링 휠 장착됐고, 플래드 모델은 아닙니다. 지난 서울모빌리티쇼에서 보지 못했던 부분 위주로 추가 리뷰를 진행한 후, 오토파일럿 위주 주행 테스트도 했는</p>,
#  <p class="cjs_d">러시아-우크라이나 전쟁이 일 년을 훌쩍 넘겨 433일째(5월2일 기준)를 맞고 있다. 지난해 2월 시작된 전쟁이 교착국면에 빠져 장기화한 상태에서 오는 9일 러시아의 '전승절' 즈음에 우크라이나의 대반격이 임박했다는</p>,
#  <p class="cjs_d">● 진중권 “尹, 박근혜 정권보다 퇴행적” ● 박성민 “민주당 분열 가능성 60%” [+영상] 윤석열 1년을 말하다 [+영상] 국민의힘을 말하다 [+영상] 민주당을 말하다 2024년 4월 10일 치러지는 22대 총선</p>,
#  <p class="cjs_d">삼성전자와 LG전자가 글로벌 스마트홈 표준 '매터'(Matter)의 국내 적용·확산 사업에 나란히 참여한다. 정부 주도의 첫 매터 사업으로 8개 컨소시엄 간 치열한 수주전이 펼쳐진 가운데 삼성, LG는 각각 디바이스</p>,
#  <p class="cjs_d">5월로 들어서면서 계절감이 회복됐습니다. 당분간 기온 계속 비슷하면서 온화하겠는데요. 다만, 오늘은 일교차가 10도 내외로 크겠습니다. 따라서 체온 관리에 특별히 신경 써주시면 좋겠습니다. 오늘은 오랜만에 하늘 구경</p>,
#  <p class="cjs_d">음주운전자에 의해 아까운 목숨들이 지고 있다. 지난 4월8일 대전시 둔산동 한 어린이보호구역에서 만취한 60대 운전자가 몰던 차량이 인도로 돌진했다. 차는 인도 위를 걸어가던 초등학생 4명을 덮쳤다. 배승아 양(만 </p>,
#  <p class="cjs_d">회원 수 40만명에 육박하는 네이버 1위 명품 구매대행 카페에서 판매자가 물건을 주지 않은 채 돈만 가로챈 이른바 '먹튀' 사기 피해 잇따라 발생했다. 해당 카페에서 구매대행 판매자 A씨에게 물건을 받지 못했다는 피</p>,
#  <p class="cjs_d">일명 '계곡 살인' 혐의로 1심에 이어 2심에서도 무기징역이 선고된 이은해(32)가 판결에 불복해 상고했다. 2일 법조계 등에 따르면 이 씨는 전날 서울고법 형사6-1부(원종찬 박원철 이의영 부장판사)에 상고장을 제</p>,
#  <p class="cjs_d">더불어민주당 전당대회 돈봉투 의혹과 관련해 금품 살포의 최종 수혜자로 지목된 송영길 전 대표가 오늘(2일) 검찰 자진 출두를 강행합니다. 송 전 대표는 이날 오전 10시 서울중앙지방검찰청에 출두한 뒤, 기자회견을 통</p>,
#  <p class="cjs_d">최근 은행에서 주는 정기예금 이자의 약 90%는 연 3%대인 것으로 확인됐다. 기준금리와 비슷하거나 심지어는 밑도는 수준이다. 새 정기예금의 과반이 연 4~5%대 이자를 줬었던 지난해 말과 비교하면 불과 반년 만에 </p>,
#  <p class="cjs_d">뜨겁게 달아올랐던 배달앱 시장이 차갑게 식었다. 배달 대신 외식 수요가 증가한 데다, 고물가로 소비자들이 주머니를 닫아버린 탓이다. 높아진 배달비 부담도 소비자가 배달앱에 등을 돌리는 계기로 작용했다. '배달의민족'</p>,
#  <p class="cjs_d">편집자주한국은 의료 가성비가 좋다고 하죠. 아프면 예약 없이 3,000~4,000원에 전문의를 보는 나라, 흔치 않으니까요. 그러나 건보 흑자, 일부 의료인의 희생 덕에 양질의 의료를 누렸던 시대도 끝나 갑니다. 미</p>,
#  <p class="cjs_d">길가던 40대 부부가 음주 운전 차량에 치여 한 명이 숨졌습니다. 오늘(1일) 오후 4시쯤 완주군 봉동읍 한 도로에서 갓길을 걷던 40대 부부가 음주 상태인 20대가 몰던 승용차에 치여 부인이 숨졌습니다. 경찰은 붙</p>,
#  <p class="cjs_d">4월 소비자물가 상승률이 3.7%를 기록했다. 한국은행은 소비자물가 상승률이 올해 중반까지 뚜렷한 둔화 흐름을 나타낼 것이라고 전망하면서도 근원물가 상승률은 당분간 소비자물가에 비해 더딘 둔화 흐름을 이어갈 것으로 </p>,
#  <p class="cjs_d">국민연금으로 매달 200만원 이상을 받아 노후생활을 하는 사람이 1만5,000명을 넘어섰습니다. 국민연금공단에 따르면 1월 말 기준 월 200만원 이상 노령연금 수급자는 1만5,290명으로, 5,400여명이었던 지난</p>,
#  <p class="cjs_d">올 여름에는 7년 만에 닥칠 엘니뇨로 많은 비가 내릴 것으로 보인다. 기상청은 5~7월 태평양의 엘리뇨·랴니냐 감시구역(남위 5도부터 북위 5도, 서경 170~120도 구역)의 해수면 온도가 4월부터 급상승해, 5월</p>,
#  <p class="cjs_d">21대 국회의원의 국회 본회의 출석 전수조사 결과 국민의힘에선 김태호 의원(28회), 더불어민주당에서는 우상호 의원(27회)이 아무런 신고 없이 본회의에 불참한 횟수가 가장 많은 것으로 확인됐다. 두 의원을 포함한 </p>,
#  <p class="cjs_d">코로나19 이후 4년 만에 닷새 간의 황금연휴(4월 29일∼5월 3일)를 맞은 중국 곳곳이 '보복 관광'으로 인산인해를 이루고 있다. 숙소를 못 구한 이들이 화장실에서 밤을 지새우는가 하면, '낙타 신호등'까지 등장</p>,
#  <p class="cjs_d">정부가 저소득층 청년 저축액의 최대 3배까지 같은 금액을 추가 지원하는 '청년내일저축계좌' 신규 가입자 모집이 1일 시작된다. 중위소득 100% 이하 가구의 만19세~34세 일하는 청년이이라면 청년내일저축계좌를 개설</p>,
#  <p class="cjs_d">국민의힘 소속 양태석 거제시의원이 공식 석상에서 외국인 노동자 혐오 발언을 했다는 사실이 뒤늦게 알려져 여론의 뭇매를 맞고 있다. 지난달 20일, 양 의원은 거제시의회 경제관광위원회 외국인노동자 지원 조례안 심사 과</p>,
#  <p class="cjs_d">‘SG증권발(發) 주가 폭락 사태’ 피해자라 주장해온 가수 임창정이 주가조작단과 동업한 정황이 포착됐다. 주범으로 지목된 라덕연 H투자자문사 대표를 ‘종교’라 칭하며 신뢰를 표한 모습 또한 공개됐다. 1일 JTBC </p>,
#  <p class="cjs_d">어제(1일) 서울 서대문구 경찰청에서 열린 기자간담회에서 윤희근 경찰청장은 배우 유아인씨(37·본명 엄홍식)의 수사 계획을 밝혔습니다. 유씨는 현재 대마, 프로포폴, 코카인, 케타민 등 총 4종류의 마약류를 투약한 </p>,
#  <p class="cjs_d">송영길 전 더불어민주당 대표가 민주당 전당대회 돈봉투(불법 정치자금) 의혹을 수사 중인 서울중앙지검에 2일 자진 출석했다.</p>,
#  <p class="cjs_d">다우데이타·서울가스 회장, 매도 직전 블록딜로 수백억원 챙겨 “오너일가, 분기별로 계열사 주가 동향 보고받아...이상 반응 인지 가능” 일각선 “내 재산 수백억 왔다 갔다 하는 데 배경 안 찾아본다고? 말 안된다” </p>,
#  <p class="cjs_d">중국의 화성 탐사 무인이동 로봇(로버) ‘주룽(祝融)’이 화성 저위도 지표면에서 액체 상태의 물이 존재했던 증거를 찾았다. 화성 고위도가 아닌 저위도 지역에서 발견한 최초 증거다. 적도에 물이 존재할 가능성이 높다는</p>,
#  <p class="cjs_d">마지막 남은 블루오션 우주. 미국과 러시아, 중국, 인도 등은 일찌감치 우주의 가치에 눈을 뜨고 그 공간을 개척하고 있습니다. 우리나라도 자체 기술로 만든 위성발사용 로켓 누리호를 쏘아올리고 ‘우주항공청’을 설립하면</p>,
#  <p class="cjs_d">[속보] 정무수석, 태영호 녹취록 논란에 "공천은 당에서...논의조차 안해"</p>,
#  <p class="cjs_d">민주당 '돈봉투 의혹' 송영길 중앙지검 도착</p>,
#  <p class="cjs_d">남양주∙화성∙시흥∙용인의 초등∙고등학교에서 제공된 급식. 온라인 카페 캡처 최근 경기도내 일부 학교에서 급식이 부실하다는 지적이 잇따르면서 학생들의 영양 불균형이 심화될 수</p>,
#  <p class="cjs_d">- 질병관리청, 의심증상 신고자의 개인정보는 보호되고 있으므로 적극적인 신고 당부 - 모르는 사람과의 밀접접촉을 피하고 의심증상이 있을 경우 타인과의 접촉 삼가 질병관리청(청장 지영미)은 국내 42번째 엠폭스 확진환</p>,
#  <p class="cjs_d">올해 들어 퇴직 후에 국민연금을 매월 200만원 이상을 받는 사람이 1만5000명을 넘어섰다. 지난해 말 기준 5000명대와 비교하면 한 달 사이에 3배 가까이 급증했다. 2일 국민연금공단의 '2023년 1월 기준 </p>,
#  <p class="cjs_d">중국 노동절 황금연휴(4월 29일~5월 3일)를 맞아 중국 전역의 관광지가 인산인해를 이루고 있다. 일부 유명 관광지에는 호텔을 잡지 못한 관광객들이 화장실에서 쪽잠을 자는 진풍경도 펼쳐지고 있다. 2일 중국중앙TV</p>,
#  <p class="cjs_d">일본의 중노년 싱글여성 단체인 ‘와쿠와쿠 시니어 싱글즈’가 릿쿄대학 유자와 나오미(湯澤直美) 씨와 북경JAC 협력으로 중고령 싱글여성의 생활실태를 조사했다. ‘와쿠와쿠’(두근두근이라는 뜻)는 2016년에 50세 이상</p>,
#  <p class="cjs_d">암을 진단 받은 후 빨리 할수록 좋은 일이 있습니다. 바로 감정을 다스리는 일입니다. 국내 한 학회 설문 결과에 따르면, 암 환자들은 신체적 어려움(52%)만큼이나 정서적 어려움(42%)을 많이 겪습니다. 정서적 어</p>,
#  <p class="cjs_d">인스타그램엔 하루에 9천500만 장의 사진이 올라온다. 이중 상당수는 자신의 모습이 담긴 셀카다. 사람들은 왜 셀카를 찍을까. 흔히 생각하는 바와는 달리, 자신을 과시하고 싶어 셀카를 찍는 것만은 아니라는 연구 결과</p>,
#  <p class="cjs_d">프랑스계 증권사 소시에테제네랄(SG)증권발 폭락사태를 놓고 핵심 인사들이 공방을 벌이고 있다. 자신 또한 피해자이며 주가조작 사태를 알지 못했다는게 이들의 이야기다. 하지만 폭락사태의 대상이 된 삼천리와 서울도시가스</p>,
#  <p class="cjs_d">요즘 4대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다. 이명박 전 대통령(이하 존칭 생략)은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 4대강도 방문할 예정이라고 한다. 4대강 추진본부장이었던 심명필은</p>,
#  <p class="cjs_d">기사내용 요약 택배 사칭해 악성앱 유포하는 스미싱, 올해 들어 기승 가정의 달 맞아 가족이 보낸 택배 정보로 오인하지 말아야 【서울=뉴시스】송혜리 기자 = #[Web발신][CJ대한통운] 배송물가&amp;!:도로명불일치</p>,
#  <p class="cjs_d">서울에서 차를 타고 1시간여 만에 도착한 강원도 춘천 남산면에 위치한 더존비즈온 강촌캠퍼스. 이름 그대로 대학 캠퍼스를 방불케 하는 이곳의 지하1층에는 총면적 3300㎡ 규모의 데이터센터 'D-클라우드센터'가 자리 </p>,
#  <p class="cjs_d">2023년 4월 13일 국회 본회의에서 '대구경북신공항 건설을 위한 특별법'이 통과됐습니다. 대구경북신공항은 현재 대구 도심에 있는 군 공항인 K2와 대구국제공항을 경북 의성군 비안면과 군위군 소보면으로 새롭게 옮기</p>,
#  <p class="cjs_d">이진복 대통령실 정무수석은 2일 국민의힘 태영호 최고위원과 관련해 '공천 문제를 거론하며 한일 관계에 대해 옹호 발언을 해달라고 요청했다'는 MBC 보도와 관련해 "그런 얘기를 전혀 나눈 적이 없다"고 말했다. 이 </p>,
#  <p class="cjs_d">■ 'CFD는 코스닥 주가를 부풀릴 수 있다' 코스닥시장 종목들의 주가는 CFD 거래 후 상승한다. 2020년 발표된 한 논문의 결론이다. ( 레버리지 투자자의 매매 양태 분석-차액결제거래 계좌를 대상으로, 박수철)</p>,
#  <p class="cjs_d">대낮에 만취 운전을 한 20대 남성이 길을 가던 40대 부부를 들이받아 부인이 숨지는 사고가 발생했다. 2일 경찰에 따르면 전북 완주경찰서는 도로교통법상 음주운전 혐의로 20대 남성 A씨를 붙잡아 조사 중이다. A씨</p>,
#  <p class="cjs_d">흔히 네덜란드를 '세계 자전거의 수도'라고 부른다. 어린아이부터 노인까지 진심으로 자전거를 즐겨 탄다. 교통 수단 중 자전거가 차지하는 비중이 36% 남짓되고, 평균적으로 1인당 자전거를 1대 이상 가지고 있는 나라</p>,
#  <p class="cjs_d">감사원이 KBS를 상대로 실시한 국민감사에서 핵심 의혹에 대한 중대 위법 사실이 확인되지 않았다. KBS는 공식 입장을 내고 “국민감사를 통해 각종 억측과 왜곡으로부터 명예를 회복했다”고 밝혔다. 감사원은 1일 KB</p>,
#  <p class="cjs_d">“비상연락망을 확인하고, 고위험군인 주변인에게 연락할 것.” 성폭력 피해자 연대 활동을 하면서 매해 3~4월과 10~11월에 강조하는 일이다. 봄과 가을에는 계절성 우울증 등 여러 요인이 겹쳐 자살 고위험군인 피해자</p>,
#  <p class="cjs_d">서울 노원구 아파트값이 1년4개월 만에 반등에 성공했다. 직전 거래 가격보다 오른 가격에 팔리는 사례가 속속 생겨나면서 ‘영끌족’(영혼까지 끌어모아 대출로 집 산 사람)도 한숨을 돌리는 모습이다. 한국부동산원에 따르</p>,
#  <p class="cjs_d">1980년 5월 광주, 그가 목격한 장면과 소회 가 영화 &lt;송암동&gt;의 특별상영을 위한 펀딩을 진행합니다. 특전사 K의 새로운 증언을 비롯한 송암동 일대 사건을 연속 보도하면서, 5.18민주화운동 마지막 날인 5월 2</p>,
#  <p class="cjs_d">6월 美 파이브가이즈 국내 첫 오픈 결실… 한화 유통·서비스 부문 미래 성장동력 박차 미국 유명 수제버거 ‘파이브가이즈’가 6월 한국에 처음 매장을 연다. 김승연 한화그룹 회장의 삼남인 김동선 한화갤러리아 전략본부장</p>,
#  <p class="cjs_d">한 남성이 살아 있는 금붕어를 통째로 삼키는 장면을 공개해 논란이 일고 있다고 영국 매체 더 선이 최근 보도했다. 더선에 따르면 이 남성은 경주마 거래계에서 잘 알려진 유명 에이전트 해미쉬 마카오리로 아일랜드 더블린</p>,
#  <p class="cjs_d">GWANGJU -- In celebration of the 60th anniversary of diplomatic relations between Switzerland and South Korea, the Embas</p>,
#  <p class="cjs_d">며칠 전 부산에서 굴러온 화물이 등굣길을 덮치면서 10살 초등학생이 숨지는 사고가 있었죠. 숨진 딸을 기억하는 아빠의 글이 안타까움을 더하고 있습니다. 어제(1일) 한 온라인 커뮤니티에 '부산 영도구 청학동 A 양 </p>,
#  <p class="cjs_d">탈영병 속출에 만취 전투까지…. 러시아군이 병사들의 이런 심각한 기강 해이에 몸살을 앓고 있다. 급기야 문제 병사를 땅 구덩이 속에 넣는 등 중세 시대에나 했을 법한 가혹한 처벌로 내부 단속에 나섰다는 서방 군 당국</p>,
#  <p class="cjs_d">국민연금공단의 '2023년 1월 기준 국민연금 통계' 자료를 보면, 올해 1월 말 기준으로 월 200만원 이상의 노령연금(10년 이상 가입하면 노후에 수령하는 일반 형태의 국민연금)을 받는 수급자는 1만5천290명에</p>,
#  <p class="cjs_d">이른바 ‘계곡 살인사건’으로 1심과 항소심에서 모두 무기징역을 선고받은 이은해(32)가 판결에 불복해 상고했다. 1일 법조계에 따르면 이씨는 이날 서울고법 형사6-1부(부장판사 원종찬 박원철 이의영)에 상고장을 제출</p>,
#  <p class="cjs_d">태영호 국민의힘 최고위원이 이진복 대통령실 정무수석으로부터 한·일 관계와 관련해 윤석열 대통령을 옹호하는 발언을 해달라는 요청을 받았다는 녹취록에 대해 "사실 무근"이라는 입장을 밝혔다. 지난 1일 태 최고위원은 자</p>,
#  <p class="cjs_d">‘양심적 병역거부자’가 현행 대체복무제도가 위헌이라며 헌법재판소에 제기한 헌법소원은 100여 건에 달한다. 2021년 첫 헌법소원 접수 이후 약 2년 동안 제기된 숫자가 이렇다. 대체복무요원은 육군의 2배인 36개월</p>]

# %%
# 한글만 열방향으로 출력
texts = bs.find_all('p',{'class':'cjs_d'})

for i in texts:
    print(' '.join(re.findall('[가-힣0-9]+',i.text)))
# Out:
# 화요일인 오늘 26일 전국이 대체로 맑은 가운데 내륙을 중심으로 큰 일교차가 나타나겠습니다 한낮 최고기온은 26도까지 오르겠습니다 기상청에 따르면 오늘 따뜻한 남서풍의 영향을 받아 전국 대부분 지역 낮 기온이
# 뉴스를 통해 우리를 웃고 울렸던 어제의 오늘을 다시 만나봅니다 2015년 5월 2일 이모씨 당시 25세 는 이날 밤 11시쯤 자신이 지내던 서울 관악구 신림동의 한 오피스텔에서 여자친구 김모씨 당시 26세 를 목
# 가수 겸 배우 임창정 씨가 주가조작단이 개최한 한 투자자 모임에서 라덕연 대표에 대해 아주 종교야 라고 말한 모습이 공개됐다 임씨는 자신도 주가조작의 피해자라고 호소하고 있다 가수 겸 배우 임창정 사진 뉴시
# 10여년째 계획만 갖고 있는 청주동물원 이전 여부에 대해 청주시가 올해 안에 매듭을 짓겠다며 외부용역을 추진했는데 의회가 제동을 걸었습니다 내년에 출범하는 시정연구원에 용역을 맡기라는 것인데 시간이 너무 지체된다는
# 20대 국회 출판기념회 79건 절반이 총선 5개월 전 열려 북적북적 출판기념회 시중 판매는 뒷전 21대 의원 중 단 3명 공개 국회의원이 작가 로 소개되는 장소 출판기념회에서 의원들은 책 을 팔지만
# 봉화산 920 우리나라에서 가장 흔한 산 이름이 봉화산이다 5월 산행지로 추천하는 봉화산은 남원과 장수 경계에 있는 백두대간 주능선의 봉화산이다 전북 남원시 아영면과 장수군 번암면의 경계를 이루는 이 산
# 이진복 대통령실 정무수석은 2일 국민의힘 태영호 최고위원과 관련해 공천 문제를 거론하며 한일 관계에 대해 옹호 발언을 해달라고 요청했다 는 보도에 대해 그런 얘기를 전혀 나눈 적이 없다 고 말했다 이 수
# 살을 빼려고 식사량을 줄이고 열심히 걷기 운동을 하는 사람이 있다 먹는 양을 갑자기 줄이고 한 시간 동안 걷는 데도 늘어난 체중은 변하지 않는다 다이어트 방법이 잘못된 것일까 덜 먹고 운동하는 데도 살이 안
# 유명 연예인 광고 포기 못하더니 국내 가상자산 거래소 코빗이 지난해 수백억원대 영업손실 기록했다 가상자산 시장 침체로 인한 거래수수료 급감과 광고비 집행이 전년 대비 5배 늘어난 것이 적자의 주요 원인으로 풀이
# 내년에 적용될 최저임금 수준을 결정하기 위한 최저임금위원회 제1차 전원회의가 오늘 2일 오후 3시 정부세종청사에서 열린다 첫 전원회의는 당초 지난달 18일 열릴 예정이었지만 노동계 인사들이 공익위원 간사인 권순
# 한국노총이 올해 26억원 규모의 정부 국고보조금 지원사업에서 탈락했다 정부가 노조 회계자료 미제출을 빌미로 노동계 압박을 위해 본격적으로 돈줄을 쥐고 흔들고 나선 것으로 노조 도움을 받던 노동 약자 에게 피해가
# 중국 최대 포털사이트 바이두 의 백과사전이 김치와 삼계탕에 이어 삼겹살이 중국의 요리라고 표현한 것과 관련해 서경덕 성신여대 교수가 한식공정 을 막아내겠다 고 말했다 서 교수는 2일 사회관계망서비스
# 소시에테제네랄 증권발 폭락사태를 놓고 핵심 인사들이 공방을 벌이고 있다 삼천리와 서울도시가스 등 8개 종목에서 증발된 자금만 모두 8조원 가수 임창정을 포함해 고액을 투자한 자산가들은 주가조작 사태를 알지
#
# 조 의원 설치는 꼴 보기 싫다 는 부적절 민주 정부 약한 고리 로 만 파고 들어 한 놈만 패자 는 전략 유효기간 다돼 지적 국회 소수당인 시대전환의 조정훈 의원은 윤석열 대통령 국빈 방미 과정에
# 민주당 전당대회 돈봉투 의혹 송영길 서울중앙지검 자진 출두 노컷뉴스는 여러분의 제보로 함께 세상을 바꿉니다 각종 비리와 부당대우 사건사고와 미담 등 모든 얘깃거리를 알려주세요 이메일 카카오톡
# 지난해 역대 최대 규모 적자를 낸 한국전력이 근로자의 날을 앞두고 직원들에게 10만원 상품권을 지급했다 회수하면서 빈축을 샀다 최근 직장인 익명 커뮤니티 블라인드 에는 한국전력 직원 씨가 관련 내용을 공유한 글
# 최근 4년간 로 불리는 서울대학교 연세대학교 고려대학교의 정시모집 합격자 중 71 6 가 수도권 출신인 것으로 확인됐다 강득구 더불어민주당 의원 경기 안양만안 과 교육랩공공장은 최근 국회에서 기자회견을 열
# 뉴스룸이 단독 보도한 주가조작 의혹 녹취파일 등의 저작권은 에 있습니다 인용보도시 뉴스룸 출처를 분명하게 인식할 수 있는 크기로 표기해 사용해주시기 바랍니다 주가조작단은 자신들
# 이건산업이 알짜 사업 및 자회사를 이건창호에 몰아준 이유 박승준 사장 등이 법인 손해만큼 시세차익 거둬 논란 예상 이건그룹이 최근 2세 경영 체제로의 전환을 서두르고 있다 지주회사인 이건홀딩스는 3월29일 주주총회
# 전북 완주경찰서는 음주운전을 하다가 보행자를 치어 숨지게 한 혐의 교통사고처리 특례법 위반 등 로 20대 씨에 대해 구속영장을 신청했다고 2일 밝혔다 씨는 전날 오후 4시 6분께 완주군 봉동읍의 한 도로에서
# 배우 인터뷰한 성 인물 논란 어떻게 봐야하나 산업은 일본 내 성착취 구조 의 첨단에 자리합니다 그 구조에 대한 비판적 고려 없이 이를 콘텐츠화한다뇨 이나영 중앙대학교 사회학과 교수
# 인생에서 큰 행사 중 하나인 결혼식 그런데 비용이 너무 많이 들면서 젊은 부부들의 결혼식은 예전과 많이 달라진 모습입니다 조금이라도 아끼면서 결혼하려는 사람들이 늘었는데 어떻게 한 푼이라도 아끼면서 결혼식을
# 윤석열 대통령의 미국 국빈 방문 성과를 두고 논란이 가중되는 가운데 대통령실이 여당 지도부를 초청해 관련 논의를 위한 뒤풀이 를 연다 대통령실은 2일 저녁 용산 대통령실에서 국민의힘 지도부와 만찬을 하며 방미
# 지난해 10월 한국수력원자력 이하 한수원 은 폴란드전력공사 와 폴란드 원전 건설과 관련한 협력의향서 을 체결했다 사업 규모만 300억달러 약 40조원 에 달하는 대규모 수주였다 그런데 최근 이 사업
# 지난달 27일 신형 테슬라 모델 를 시승해봤습니다 일반 스티어링 휠 장착됐고 플래드 모델은 아닙니다 지난 서울모빌리티쇼에서 보지 못했던 부분 위주로 추가 리뷰를 진행한 후 오토파일럿 위주 주행 테스트도 했는
# 러시아 우크라이나 전쟁이 일 년을 훌쩍 넘겨 433일째 5월2일 기준 를 맞고 있다 지난해 2월 시작된 전쟁이 교착국면에 빠져 장기화한 상태에서 오는 9일 러시아의 전승절 즈음에 우크라이나의 대반격이 임박했다는
# 진중권 박근혜 정권보다 퇴행적 박성민 민주당 분열 가능성 60 영상 윤석열 1년을 말하다 영상 국민의힘을 말하다 영상 민주당을 말하다 2024년 4월 10일 치러지는 22대 총선
# 삼성전자와 전자가 글로벌 스마트홈 표준 매터 의 국내 적용 확산 사업에 나란히 참여한다 정부 주도의 첫 매터 사업으로 8개 컨소시엄 간 치열한 수주전이 펼쳐진 가운데 삼성 는 각각 디바이스
# 5월로 들어서면서 계절감이 회복됐습니다 당분간 기온 계속 비슷하면서 온화하겠는데요 다만 오늘은 일교차가 10도 내외로 크겠습니다 따라서 체온 관리에 특별히 신경 써주시면 좋겠습니다 오늘은 오랜만에 하늘 구경
# 음주운전자에 의해 아까운 목숨들이 지고 있다 지난 4월8일 대전시 둔산동 한 어린이보호구역에서 만취한 60대 운전자가 몰던 차량이 인도로 돌진했다 차는 인도 위를 걸어가던 초등학생 4명을 덮쳤다 배승아 양 만
# 회원 수 40만명에 육박하는 네이버 1위 명품 구매대행 카페에서 판매자가 물건을 주지 않은 채 돈만 가로챈 이른바 먹튀 사기 피해 잇따라 발생했다 해당 카페에서 구매대행 판매자 씨에게 물건을 받지 못했다는 피
# 일명 계곡 살인 혐의로 1심에 이어 2심에서도 무기징역이 선고된 이은해 32 가 판결에 불복해 상고했다 2일 법조계 등에 따르면 이 씨는 전날 서울고법 형사6 1부 원종찬 박원철 이의영 부장판사 에 상고장을 제
# 더불어민주당 전당대회 돈봉투 의혹과 관련해 금품 살포의 최종 수혜자로 지목된 송영길 전 대표가 오늘 2일 검찰 자진 출두를 강행합니다 송 전 대표는 이날 오전 10시 서울중앙지방검찰청에 출두한 뒤 기자회견을 통
# 최근 은행에서 주는 정기예금 이자의 약 90 는 연 3 대인 것으로 확인됐다 기준금리와 비슷하거나 심지어는 밑도는 수준이다 새 정기예금의 과반이 연 4 5 대 이자를 줬었던 지난해 말과 비교하면 불과 반년 만에
# 뜨겁게 달아올랐던 배달앱 시장이 차갑게 식었다 배달 대신 외식 수요가 증가한 데다 고물가로 소비자들이 주머니를 닫아버린 탓이다 높아진 배달비 부담도 소비자가 배달앱에 등을 돌리는 계기로 작용했다 배달의민족
# 편집자주한국은 의료 가성비가 좋다고 하죠 아프면 예약 없이 3 000 4 000원에 전문의를 보는 나라 흔치 않으니까요 그러나 건보 흑자 일부 의료인의 희생 덕에 양질의 의료를 누렸던 시대도 끝나 갑니다 미
# 길가던 40대 부부가 음주 운전 차량에 치여 한 명이 숨졌습니다 오늘 1일 오후 4시쯤 완주군 봉동읍 한 도로에서 갓길을 걷던 40대 부부가 음주 상태인 20대가 몰던 승용차에 치여 부인이 숨졌습니다 경찰은 붙
# 4월 소비자물가 상승률이 3 7 를 기록했다 한국은행은 소비자물가 상승률이 올해 중반까지 뚜렷한 둔화 흐름을 나타낼 것이라고 전망하면서도 근원물가 상승률은 당분간 소비자물가에 비해 더딘 둔화 흐름을 이어갈 것으로
# 국민연금으로 매달 200만원 이상을 받아 노후생활을 하는 사람이 1만5 000명을 넘어섰습니다 국민연금공단에 따르면 1월 말 기준 월 200만원 이상 노령연금 수급자는 1만5 290명으로 5 400여명이었던 지난
# 올 여름에는 7년 만에 닥칠 엘니뇨로 많은 비가 내릴 것으로 보인다 기상청은 5 7월 태평양의 엘리뇨 랴니냐 감시구역 남위 5도부터 북위 5도 서경 170 120도 구역 의 해수면 온도가 4월부터 급상승해 5월
# 21대 국회의원의 국회 본회의 출석 전수조사 결과 국민의힘에선 김태호 의원 28회 더불어민주당에서는 우상호 의원 27회 이 아무런 신고 없이 본회의에 불참한 횟수가 가장 많은 것으로 확인됐다 두 의원을 포함한
# 코로나19 이후 4년 만에 닷새 간의 황금연휴 4월 29일 5월 3일 를 맞은 중국 곳곳이 보복 관광 으로 인산인해를 이루고 있다 숙소를 못 구한 이들이 화장실에서 밤을 지새우는가 하면 낙타 신호등 까지 등장
# 정부가 저소득층 청년 저축액의 최대 3배까지 같은 금액을 추가 지원하는 청년내일저축계좌 신규 가입자 모집이 1일 시작된다 중위소득 100 이하 가구의 만19세 34세 일하는 청년이이라면 청년내일저축계좌를 개설
# 국민의힘 소속 양태석 거제시의원이 공식 석상에서 외국인 노동자 혐오 발언을 했다는 사실이 뒤늦게 알려져 여론의 뭇매를 맞고 있다 지난달 20일 양 의원은 거제시의회 경제관광위원회 외국인노동자 지원 조례안 심사 과
# 증권발 주가 폭락 사태 피해자라 주장해온 가수 임창정이 주가조작단과 동업한 정황이 포착됐다 주범으로 지목된 라덕연 투자자문사 대표를 종교 라 칭하며 신뢰를 표한 모습 또한 공개됐다 1일
# 어제 1일 서울 서대문구 경찰청에서 열린 기자간담회에서 윤희근 경찰청장은 배우 유아인씨 37 본명 엄홍식 의 수사 계획을 밝혔습니다 유씨는 현재 대마 프로포폴 코카인 케타민 등 총 4종류의 마약류를 투약한
# 송영길 전 더불어민주당 대표가 민주당 전당대회 돈봉투 불법 정치자금 의혹을 수사 중인 서울중앙지검에 2일 자진 출석했다
# 다우데이타 서울가스 회장 매도 직전 블록딜로 수백억원 챙겨 오너일가 분기별로 계열사 주가 동향 보고받아 이상 반응 인지 가능 일각선 내 재산 수백억 왔다 갔다 하는 데 배경 안 찾아본다고 말 안된다
# 중국의 화성 탐사 무인이동 로봇 로버 주룽 이 화성 저위도 지표면에서 액체 상태의 물이 존재했던 증거를 찾았다 화성 고위도가 아닌 저위도 지역에서 발견한 최초 증거다 적도에 물이 존재할 가능성이 높다는
# 마지막 남은 블루오션 우주 미국과 러시아 중국 인도 등은 일찌감치 우주의 가치에 눈을 뜨고 그 공간을 개척하고 있습니다 우리나라도 자체 기술로 만든 위성발사용 로켓 누리호를 쏘아올리고 우주항공청 을 설립하면
# 속보 정무수석 태영호 녹취록 논란에 공천은 당에서 논의조차 안해
# 민주당 돈봉투 의혹 송영길 중앙지검 도착
# 남양주 화성 시흥 용인의 초등 고등학교에서 제공된 급식 온라인 카페 캡처 최근 경기도내 일부 학교에서 급식이 부실하다는 지적이 잇따르면서 학생들의 영양 불균형이 심화될 수
# 질병관리청 의심증상 신고자의 개인정보는 보호되고 있으므로 적극적인 신고 당부 모르는 사람과의 밀접접촉을 피하고 의심증상이 있을 경우 타인과의 접촉 삼가 질병관리청 청장 지영미 은 국내 42번째 엠폭스 확진환
# 올해 들어 퇴직 후에 국민연금을 매월 200만원 이상을 받는 사람이 1만5000명을 넘어섰다 지난해 말 기준 5000명대와 비교하면 한 달 사이에 3배 가까이 급증했다 2일 국민연금공단의 2023년 1월 기준
# 중국 노동절 황금연휴 4월 29일 5월 3일 를 맞아 중국 전역의 관광지가 인산인해를 이루고 있다 일부 유명 관광지에는 호텔을 잡지 못한 관광객들이 화장실에서 쪽잠을 자는 진풍경도 펼쳐지고 있다 2일 중국중앙
# 일본의 중노년 싱글여성 단체인 와쿠와쿠 시니어 싱글즈 가 릿쿄대학 유자와 나오미 씨와 북경 협력으로 중고령 싱글여성의 생활실태를 조사했다 와쿠와쿠 두근두근이라는 뜻 는 2016년에 50세 이상
# 암을 진단 받은 후 빨리 할수록 좋은 일이 있습니다 바로 감정을 다스리는 일입니다 국내 한 학회 설문 결과에 따르면 암 환자들은 신체적 어려움 52 만큼이나 정서적 어려움 42 을 많이 겪습니다 정서적 어
# 인스타그램엔 하루에 9천500만 장의 사진이 올라온다 이중 상당수는 자신의 모습이 담긴 셀카다 사람들은 왜 셀카를 찍을까 흔히 생각하는 바와는 달리 자신을 과시하고 싶어 셀카를 찍는 것만은 아니라는 연구 결과
# 프랑스계 증권사 소시에테제네랄 증권발 폭락사태를 놓고 핵심 인사들이 공방을 벌이고 있다 자신 또한 피해자이며 주가조작 사태를 알지 못했다는게 이들의 이야기다 하지만 폭락사태의 대상이 된 삼천리와 서울도시가스
# 요즘 4대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다 이명박 전 대통령 이하 존칭 생략 은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 4대강도 방문할 예정이라고 한다 4대강 추진본부장이었던 심명필은
# 기사내용 요약 택배 사칭해 악성앱 유포하는 스미싱 올해 들어 기승 가정의 달 맞아 가족이 보낸 택배 정보로 오인하지 말아야 서울 뉴시스 송혜리 기자 발신 대한통운 배송물가 도로명불일치
# 서울에서 차를 타고 1시간여 만에 도착한 강원도 춘천 남산면에 위치한 더존비즈온 강촌캠퍼스 이름 그대로 대학 캠퍼스를 방불케 하는 이곳의 지하1층에는 총면적 3300 규모의 데이터센터 클라우드센터 가 자리
# 2023년 4월 13일 국회 본회의에서 대구경북신공항 건설을 위한 특별법 이 통과됐습니다 대구경북신공항은 현재 대구 도심에 있는 군 공항인 2와 대구국제공항을 경북 의성군 비안면과 군위군 소보면으로 새롭게 옮기
# 이진복 대통령실 정무수석은 2일 국민의힘 태영호 최고위원과 관련해 공천 문제를 거론하며 한일 관계에 대해 옹호 발언을 해달라고 요청했다 는 보도와 관련해 그런 얘기를 전혀 나눈 적이 없다 고 말했다 이
# 는 코스닥 주가를 부풀릴 수 있다 코스닥시장 종목들의 주가는 거래 후 상승한다 2020년 발표된 한 논문의 결론이다 레버리지 투자자의 매매 양태 분석 차액결제거래 계좌를 대상으로 박수철
# 대낮에 만취 운전을 한 20대 남성이 길을 가던 40대 부부를 들이받아 부인이 숨지는 사고가 발생했다 2일 경찰에 따르면 전북 완주경찰서는 도로교통법상 음주운전 혐의로 20대 남성 씨를 붙잡아 조사 중이다 씨
# 흔히 네덜란드를 세계 자전거의 수도 라고 부른다 어린아이부터 노인까지 진심으로 자전거를 즐겨 탄다 교통 수단 중 자전거가 차지하는 비중이 36 남짓되고 평균적으로 1인당 자전거를 1대 이상 가지고 있는 나라
# 감사원이 를 상대로 실시한 국민감사에서 핵심 의혹에 대한 중대 위법 사실이 확인되지 않았다 는 공식 입장을 내고 국민감사를 통해 각종 억측과 왜곡으로부터 명예를 회복했다 고 밝혔다 감사원은 1일
# 비상연락망을 확인하고 고위험군인 주변인에게 연락할 것 성폭력 피해자 연대 활동을 하면서 매해 3 4월과 10 11월에 강조하는 일이다 봄과 가을에는 계절성 우울증 등 여러 요인이 겹쳐 자살 고위험군인 피해자
# 서울 노원구 아파트값이 1년4개월 만에 반등에 성공했다 직전 거래 가격보다 오른 가격에 팔리는 사례가 속속 생겨나면서 영끌족 영혼까지 끌어모아 대출로 집 산 사람 도 한숨을 돌리는 모습이다 한국부동산원에 따르
# 1980년 5월 광주 그가 목격한 장면과 소회 가 영화 송암동 의 특별상영을 위한 펀딩을 진행합니다 특전사 의 새로운 증언을 비롯한 송암동 일대 사건을 연속 보도하면서 5 18민주화운동 마지막 날인 5월 2
# 6월 파이브가이즈 국내 첫 오픈 결실 한화 유통 서비스 부문 미래 성장동력 박차 미국 유명 수제버거 파이브가이즈 가 6월 한국에 처음 매장을 연다 김승연 한화그룹 회장의 삼남인 김동선 한화갤러리아 전략본부장
# 한 남성이 살아 있는 금붕어를 통째로 삼키는 장면을 공개해 논란이 일고 있다고 영국 매체 더 선이 최근 보도했다 더선에 따르면 이 남성은 경주마 거래계에서 잘 알려진 유명 에이전트 해미쉬 마카오리로 아일랜드 더블린
# 60
# 며칠 전 부산에서 굴러온 화물이 등굣길을 덮치면서 10살 초등학생이 숨지는 사고가 있었죠 숨진 딸을 기억하는 아빠의 글이 안타까움을 더하고 있습니다 어제 1일 한 온라인 커뮤니티에 부산 영도구 청학동 양
# 탈영병 속출에 만취 전투까지 러시아군이 병사들의 이런 심각한 기강 해이에 몸살을 앓고 있다 급기야 문제 병사를 땅 구덩이 속에 넣는 등 중세 시대에나 했을 법한 가혹한 처벌로 내부 단속에 나섰다는 서방 군 당국
# 국민연금공단의 2023년 1월 기준 국민연금 통계 자료를 보면 올해 1월 말 기준으로 월 200만원 이상의 노령연금 10년 이상 가입하면 노후에 수령하는 일반 형태의 국민연금 을 받는 수급자는 1만5천290명에
# 이른바 계곡 살인사건 으로 1심과 항소심에서 모두 무기징역을 선고받은 이은해 32 가 판결에 불복해 상고했다 1일 법조계에 따르면 이씨는 이날 서울고법 형사6 1부 부장판사 원종찬 박원철 이의영 에 상고장을 제출
# 태영호 국민의힘 최고위원이 이진복 대통령실 정무수석으로부터 한 일 관계와 관련해 윤석열 대통령을 옹호하는 발언을 해달라는 요청을 받았다는 녹취록에 대해 사실 무근 이라는 입장을 밝혔다 지난 1일 태 최고위원은 자
# 양심적 병역거부자 가 현행 대체복무제도가 위헌이라며 헌법재판소에 제기한 헌법소원은 100여 건에 달한다 2021년 첫 헌법소원 접수 이후 약 2년 동안 제기된 숫자가 이렇다 대체복무요원은 육군의 2배인 36개월

# %%
url = 'https://news.daum.net/politics'
r = requests.get(url).text
bs = BS(r,'html.parser')

for i in bs.find_all('h2', id='mainContent'):
    print(i.text)
    
bs.find_all('h2')
# Out:
# 정치
# [<h2 class="screen_out">뉴스 메인메뉴</h2>,
#  <h2 class="screen_out" id="mainContent">정치</h2>,
#  <h2 class="tit_direct">바로가기</h2>,
#  <h2 class="screen_out">서비스 이용정보</h2>]

# %%
url = 'https://serieson.naver.com/v3/movie/ranking/realtime'
html = urllib.request.urlopen(url)
bs = BS(html, 'html.parser')
# print(bs.prettify())

bs.find('span',class_="Title_title__s9o0D").text
# Out:
# '던전 앤 드래곤: 도적들의 명예'

# %%
html = """
<ul>
  <li><a href="hoge.html">hoge</li>
  <li><a href="https://example.com/fuga">fuga*</li>
  <li><a href="https://example.com/foo">foo*</li>
  <li><a href="http://example.com/aaa">aaa</li>
</ul>
"""
soup = BS(html, 'html.parser')

hi = soup.find_all(href=re.compile(r"^https://"))
for i in hi:
    print(i.attrs['href'])
# Out:
# https://example.com/fuga
# https://example.com/foo

# %% [markdown]
# ### CSS 선택자
# - 원하는 정보만 선별하여 수집하고 싶을 때 css선택자를 활용할 수 있음
# - (CSS 선택자 설명 추가)
# - F12 >> 수집하고 싶은 부분 클릭 >> 태그 선택 >> copy Selector
# - BeautifulSoup의 select_one, select 활용

# %%
url = 'https://news.daum.net/politics#1'
r = requests.get(url).text
bs = BS(r,'lxml')

li = 'body > div > main > section > div.main-sub > div > ul > li > strong > a'
# body > div.container-doc.cont-category > main > section > div.main-sub > div.box_g.box_news_major > ul > li:nth-child(1) > strong > a
# 'div.container-doc.cont-category', 'div.box_g.box_news_major' 등 태그만 남기고 세부경로 지우기
# 여러 뉴스의 헤드라인을 가져올 것이므로 'li:nth-child(1)' 지우기 (놔두면 1개만 나옴)

lines = bs.select(li)
body = '\n'.join([i.text for i in lines])

print(body, '\n')
print(' '.join(re.findall('[가-힣0-9]+',body)),'\n')   #한글/숫자만 쭉 출력

print(bs.select_one('body > div > main > section > div.main-sub > div > ul > li > strong > a').text)
print([i.text for i in bs.select('body > div > main > section > div.main-sub > div > ul > li:nth-child(1) > strong > a')])
# li:nth-child(1) 와 select_one 둘 다 같은 결과
# Out:
# [시선집중] "시진핑은 LG 공장까지 방문했는데.. 尹은 '장진호' 언급해 中 손절"
# 박광온 "지지자만으로 선거 못 이겨…확장성 싸움"
# 충주시, 사과·복숭아 공동 선별·출하 비용 지원 확대
# 태영호, ‘녹취록 파문’에 당내서도 역풍…“거짓말 멈추고 국회 떠나라”
# 노동절 다음날 ‘노조 때리기’ 들어간 與…“尹 노동개혁 뒷받침” [이런정치]
# 日기시다 “7~8일 방한 조정… 尹대통령과 깊은 신뢰”
# 포항시의회, 시내버스 보조금 과다 지급 질타
# [돌쇠토론]尹의 공천개입? 태영호 녹취록, 왜 공개됐을까?
# 박광온 "전세 사기는 사회적 재난…정부 태도 전환 촉구"
# 宋 자진출두에 엇갈린 여야...박광온, 與 윤재옥 예방
#
# 시선집중 시진핑은 공장까지 방문했는데 은 장진호 언급해 손절 박광온 지지자만으로 선거 못 이겨 확장성 싸움 충주시 사과 복숭아 공동 선별 출하 비용 지원 확대 태영호 녹취록 파문 에 당내서도 역풍 거짓말 멈추고 국회 떠나라 노동절 다음날 노조 때리기 들어간 노동개혁 뒷받침 이런정치 기시다 7 8일 방한 조정 대통령과 깊은 신뢰 포항시의회 시내버스 보조금 과다 지급 질타 돌쇠토론 의 공천개입 태영호 녹취록 왜 공개됐을까 박광온 전세 사기는 사회적 재난 정부 태도 전환 촉구 자진출두에 엇갈린 여야 박광온 윤재옥 예방
#
# [시선집중] "시진핑은 LG 공장까지 방문했는데.. 尹은 '장진호' 언급해 中 손절"
# ['[시선집중] "시진핑은 LG 공장까지 방문했는데.. 尹은 \'장진호\' 언급해 中 손절"']

# %%
url ='https://n.news.naver.com/mnews/article/032/0003161880?sid=101'

# %%
# 원하는 데이터 추출하기: 네이버증권 환전 고시 환율 가져오기
url = 'https://finance.naver.com/'
r = requests.get(url).text
bs = BS(r,'html.parser')
li='#content > div > div > div > table > tbody > tr > td'
li2='#content > div > div > div > table > tbody > tr > th > a'

for i in range(0,4):
    print(bs.select(li2)[i].text)
    print(bs.select(li)[i*2].text,':',bs.select(li)[i*2-1].text)
# Out:
# 미국USD
# 1,339.20 : 하락 0.50
# 일본JPY (100엔)
# 974.28 : 하락 1.80
# 유럽연합EUR
# 1,471.78 : 하락 3.23
# 중국CNY
# 192.49 : 하락 2.78

# %%
html="""
<head>
    <title>crawler</title>
</head>
<body>
    <p class="a" align="center"> text1</p>
    <p class="b" align="center"> text2</p>
    <p class="c" align="center"> text3</p>
    <div>
        <img src="/source" width="300" height="200">
    </div>
</body>
</html>
"""

# %%
soup = BS(html, 'html.parser')
con = soup.find('body')
for c in con.children:
    print(c)
# Out:
# <p align="center" class="a"> text1</p>
#
#
# <p align="center" class="b"> text2</p>
#
#
# <p align="center" class="c"> text3</p>
#
#
# <div>
# <img height="200" src="/source" width="300"/>
# </div>

# %%
res = urllib.request.urlopen('https://www.naver.com')
bdata = res.read()
html = bdata.decode('utf-8')
soup = BS(html, 'html.parser')

print(soup.find_all('a', {'class':'link_newsstand'}), '\n')
print(soup.findAll('a', {'class':'btn_sort'}))
# find_all = findAll 같음
# Out:
# [<a class="link_newsstand" data-clk="title" href="http://newsstand.naver.com/" target="_blank">뉴스스탠드</a>]
#
# [<a aria-controls="NM_NEWSSTAND_MY_LIST" aria-selected="false" class="btn_sort" data-clk="my" data-type="my" href="#" role="tab">구독한 언론사</a>, <a aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true" class="btn_sort" data-clk="all" data-type="all" href="#" role="tab">전체언론사</a>]

# %%
li = soup.find_all('a', {'class': {'link_newsstand','btn_sort'}})
# 2중 중괄호

for i in li:
    print(i.text)
# Out:
# 뉴스스탠드
# 구독한 언론사
# 전체언론사

# %%
html = bdata.decode('utf-8')
bs = BS(html, 'html.parser')

li = bs.findAll({'h1','h2','h3','h4','h5','h6'}, limit=5)
for i in li:
    print(i,'\n')
# Out:
# <h1 class="logo_default">
# <a class="logo_naver" data-clk="top.logo" href="/"><span class="blind">네이버</span></a>
# </h1>
#
# <h2 class="blind">뉴스스탠드</h2>
#
# <h2 class="blind">주제별 캐스트</h2>
#
# <h2 class="blind">Sign in</h2>
#
# <h2 class="blind">타임스퀘어</h2>

# %%
li = bs.findAll({'h1','h2','h3','h4','h5','h6'}, text='뉴스스탠드')
print(li)
# Out:
# [<h2 class="blind">뉴스스탠드</h2>]

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = "https://n.news.naver.com/mnews/article/032/0003161880?sid=101" # 네이버 기사 본문 페이지

req = requests.get(url, headers=headers)
soup = BS(req.content, "html.parser")

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://n.news.naver.com/mnews/article/032/0003161880?sid=101" property="og:url"/>
# <meta content="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=w800" property="og:image"/>
# <meta content="서울 25개 자치구 어디에서나 쓸 수 있는 ‘서울사랑상품권(광역상품권)’이 오는 28일 추가 발행된다. 1차 발행 때처럼 동시접속자가 몰리는 것을 막기 위해 이번에는 출생연도를 기준으로 홀수는 오전 10시부터, 짝수" property="og:description"/>
# <meta content="경향신문 | 네이버" property="og:article:author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="경향신문" name="twitter:creator"/>
# <meta content="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=w800" name="twitter:image"/>
# <meta content="서울 25개 자치구 어디에서나 쓸 수 있는 ‘서울사랑상품권(광역상품권)’이 오는 28일 추가 발행된다. 1차 발행 때처럼 동시접속자가 몰리는 것을 막기 위해 이번에는 출생연도를 기준으로 홀수는 오전 10시부터, 짝수" name="twitter:description"/>
# <meta content="gdid=8800006B_000000000000000003161880,service=news,collection=news,section=102" name="napp-site-analysis"/>
# <title>‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”</title>
# <link href="https://static-nnews.pstatic.net/css/min/20230427/news.css" rel="stylesheet"/>
# <link href="https://mimgnews.pstatic.net/image/news/m/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" rel="apple-touch-icon-precomposed" size="72x72"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" rel="apple-touch-icon-precomposed" size="96x96"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" rel="apple-touch-icon-precomposed" size="144x144"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed" size="192x192"/>
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# <script>
# 			var g_ssc = nsc = "Mnews.v2";
# 			var g_default_area = "art";
#
# 			var svr = "one-service-r-20230427-230427-143655-596967dd69-rfxsw";
# 			var nelo = {
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "https://news.naver.com";
# 			var isAvailableDarkMode = false;
#
# 			var article = {
# 				isSubscribe: false,
# 				officeId: "032",
# 				articleId: "0003161880",
# 				sectionId : "102",
# 				gdid: "8800006B_000000000000000003161880",
# 				type: "1",
# 				sectionInfo: {
# 					firstSection: "102",
# 					secondSection: "256",
# 					thirdSection: "000"
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: true,
# 				isPressHome: true,
# 				name : "경향신문",
# 				category : "종합지"
# 			};
#
# 			var refererType = "UNKNOWN";
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setAdDeduplication("article_body_dedup");
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newsend",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "0",
# 					calp: false
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "0",
# 					calp: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (calp == true) {
# 						customParam.calp = "";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 		</script>
# <script src="https://static-nnews.pstatic.net/js/min/20230427/common.min.js"></script>
# </link></meta></head>
# <body class="n_news_mnews fs2 as_mp_layout">
# <div class="end_container">
# <div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# <header class="as_gnb_mnews" role="banner">
# <div class="header_inner">
# <div class="Ngnb">
# <div class="Ngnb_inner">
# <div class="Ngnb_both">
# <div class="Ngnb_left">
# <span class="Ngnb_logo"><a class="Nlogo_link _LINK" data-clk="gnb.naver" data-pc-url="https://www.naver.com/" data-url="https://m.naver.com/" href="https://m.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a class="_LINK" data-clk="gnb.news" data-pc-url="https://news.naver.com/" data-url="https://m.news.naver.com" href="https://m.news.naver.com"><span class="Nicon_service">뉴스</span></a></h1>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.entertain" data-pc-url="https://entertain.naver.com/home" data-url="https://m.entertain.naver.com" href="https://m.entertain.naver.com">
# <span class="Nicon_family Nicon_entertain">연예</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.sports" data-pc-url="https://sports.news.naver.com/index" data-url="https://m.sports.naver.com" href="https://m.sports.naver.com">
# <span class="Nicon_family Nicon_sports">스포츠</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.weather" href="https://weather.naver.com">
# <span class="Nicon_family Nicon_weather">날씨</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.premium" href="https://contents.premium.naver.com">
# <span class="Nicon_family Nicon_premium">프리미엄</span>
# </a>
# </span>
# </div>
# </div>
# <div class="Ngnb_right">
# <div class="Ngnb_group">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="Ngnb_search _SEARCH_WRAP is_hidden"></div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _SEARCH_CONTENT_TOGGLE_BUTTON" data-clk="gnb.scho" href="javascript:;"><span class="Nicon_search">검색</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Nlnb" data-scroll-fixed="true" id="_LNB_PARENT_WRAP" style="z-index:3000;">
# <div class="Nlnb_menu Ntype_scroll" id="_LNB_WRAP" style="position: relative;">
# <div class="Nlnb_menu_inner" id="_LNB">
# <ul class="Nlnb_menu_list" role="tablist">
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.press" href="https://news.naver.com/"><span class="Nitem_link_menu">언론사별</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.pol" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="Nitem_link_menu">정치</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM is_active" role="tab">
# <a class="Nitem_link" data-clk="lnb.eco" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="Nitem_link_menu">경제</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.soc" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="Nitem_link_menu">사회</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.lif" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="Nitem_link_menu">생활/문화</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.it" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="Nitem_link_menu">IT/과학</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.wor" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="Nitem_link_menu">세계</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.rank" href="https://news.naver.com/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="Nitem_link_menu">랭킹</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.paper" href="https://news.naver.com/newspaper/home"><span class="Nitem_link_menu">신문보기</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.opi" href="https://news.naver.com/main/opinion/home.naver"><span class="Nitem_link_menu">오피니언</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.tv" href="https://news.naver.com/main/tv/index.naver?mid=tvh"><span class="Nitem_link_menu">TV</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="tab">
# <a class="Nitem_link" data-clk="lnb.fact" href="https://news.naver.com/main/factcheck/main.naver"><span class="Nitem_link_menu">팩트체크</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </header>
# <hr/>
# <script>
# 	var svt = "20230502172130.452";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: false,
# 		entertain: false,
# 		sports: false,
# 		mnews: true,
# 		newsType: true
# 	};
# 	var serviceName = "mnews";
#
# 	var isProduction = true;
#
# 	var gnb_service = "news";
# 	var gnb_logout = encodeURIComponent(location.href);
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness = 3;
# </script>
# <div class="ct_wrap" id="ct_wrap">
# <div class="ct_scroll_wrapper">
# <div class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT"><div class="newsct" id="ct" role="main">
# <div class="media_end_head go_trans">
# <div class="media_end_head_top">
# <a class="media_end_head_top_logo" href="http://www.khan.co.kr/">
# <img alt="경향신문" class="media_end_head_top_logo_img light_type" height="32" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2020/09/15/logo_032_6_20200915155035.png" title="경향신문" width=""/>
# <img alt="경향신문" class="media_end_head_top_logo_img dark_type" height="32" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2020/09/15/dark_logo_032_6_20200915155021.png" title="경향신문" width=""/>
# </a>
# <div class="media_end_head_top_channel _CHANNEL_BUTTON_WRAP" style="display:none;">
# <button class="media_end_head_top_channel_add _CHANNEL_BUTTON" data-clk-add="chmain032" data-clk-remove="chdelete032" data-delay="1000" data-notification="true" data-notification-clk="notru" data-text="구독">구독</button>
# <a class="media_end_head_top_channel_layer _LINK" data-clk="chlook" data-url-type="NAVERAPP_NEWS_CHANNEL" href="#" id="_CHANNEL_LAYER_032_0003161880" style="display: none;">
# <span class="media_end_head_top_channel_layer_text"><strong>경향신문</strong> 언론사 구독되었습니다. <br/>메인 뉴스판에서  주요뉴스를 <br/> 볼 수 있습니다.</span>
# <span class="media_end_head_top_channel_layer_link">보러가기</span>
# </a>
# <p class="media_end_head_top_channel_layer" id="_CHANNEL_REMOVE_LAYER_032_0003161880" style="display: none;">
# <span class="media_end_head_top_channel_layer_text"><strong>경향신문</strong> 언론사 구독 해지되었습니다.</span>
# </p>
# </div>
# </div>
# <div class="media_end_head_title">
# <h2 class="media_end_head_headline" id="title_area"><span>‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”</span></h2>
# </div>
# <div class="media_end_head_info nv_notrans">
# <div class="media_end_head_info_datestamp">
# <div class="media_end_head_info_datestamp_bunch">
# <em class="media_end_head_info_datestamp_term">입력</em><span class="media_end_head_info_datestamp_time _ARTICLE_DATE_TIME" data-date-time="2022-07-24 11:16:01">2022.07.24. 오전 11:16</span>
# </div>
# <div class="media_end_head_info_datestamp_bunch">
# <em class="media_end_head_info_datestamp_term">수정</em><span class="media_end_head_info_datestamp_time _ARTICLE_MODIFY_DATE_TIME" data-modify-date-time="2022-07-24 11:24:01">2022.07.24. 오전 11:24</span>
# </div>
# <a class="media_end_head_origin_link" data-clk="are.ori" data-extra='{"lk":{"oid":"032","aid":"0d9de6d3c8ee8113"}}' data-gdid="032" href="https://www.khan.co.kr/national/national-general/article/202207241115001" target="_blank">기사원문</a>
# </div> <div class="media_end_head_journalist">
# <a class="media_end_head_journalist_box" data-clk="ummore" href="https://media.naver.com/journalist/032/56163">
# <div class="media_end_head_journalist_thumb">
# <img height="24" src="https://mimgnews.pstatic.net/image/upload/journalist/2019/02/18/%EC%9D%B4%EC%84%B1%ED%9D%AC.png?type=nf112_112" width="24"/>
# </div>
# <em class="media_end_head_journalist_name">이성희 기자</em>
# </a>
# <div class="media_end_head_journalist_layer _JOURNALIST_CARD" id="_JOURNALIST_LAYER" style="display: none;">
# <ul class="media_end_head_journalist_layer_list">
# <li class="media_end_head_journalist_layer_item _SUBSCRIBE_ELE" data-subscribe-type="JOURNALIST">
# <div class="media_end_head_journalist_layer_div _LIKE_HIDE _LAZY_LOADING_WRAP">
# <div class="media_end_head_journalist_layer_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/upload/journalist/2019/02/18/%EC%9D%B4%EC%84%B1%ED%9D%AC.png?type=nf112_112" height="38" width="38"/>
# </div>
# <div class="media_end_head_journalist_layer_text _reactionModule" data-ccounttype="period" data-cid="56163" data-sid="JOURNALIST" id="_cheer_56163_layer">
# <div class="media_end_head_journalist_layer_title">
# <em class="media_end_head_journalist_layer_name">이성희 기자</em>
# <div class="media_end_head_journalist_layer_btns _JOURNALIST_ID" data-journalistid="56163">
# <button class="media_end_head_journalist_btn_subscribe _SUBSCRIBE" data-channelkey="JOURNALIST_56163" data-clk="umsubs" type="button">구독</button>
# <button class="media_end_head_journalist_btn_subscribe is_on _UNSUBSCRIBE" data-channelkey="JOURNALIST_56163" data-clk="umunsubs" data-messagevalue="이성희" data-type="journalist" style="display:none;" type="button">구독중</button>
# </div>
# </div>
# <dl class="media_end_head_journalist_layer_subscriber _button" data-ishiddenlabelaszerocount="true" data-ishiddenzerocount="true" data-type="cheer">
# <div class="media_end_head_journalist_layer_definition_wrap _SUBSCRIBE_COUNT_TEXT_WRAP">
# <dt>구독자</dt>
# <dd class="_SUBSCRIBE_COUNT_TEXT" data-maxcount="99999">0</dd>
# </div>
# <div class="media_end_head_journalist_layer_definition_wrap">
# <dt class="_label">응원수</dt>
# <dd class="_count">0</dd>
# </div>
# </dl>
# </div>
# <a class="media_end_head_journalist_layer_link" data-clk="ummore" href="https://media.naver.com/journalist/032/56163">더보기</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="media_end_head_info_variety">
# <div class="media_end_head_info_variety_left" id="commentFontGroup">
# <div class="media_end_head_info_variety_likeit _LIKE_HIDE as_likeit_improve">
# <!-- 좋아요 -->
# <div class="_reactionModule u_likeit nv_notrans" data-cid="ne_032_0003161880" data-sid="NEWS">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face _LIKE_BUTTON" data-clk="RTL.face" data-label="recommend">
# <span class="u_likeit_icons _icons">
# <span class="u_likeit_icon __reaction__zeroface"></span>
# </span>
# <span class="u_likeit_text _count">추천</span>
# </a>
# <ul class="u_likeit_layer _faceLayer" role="menu">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.useful|RTL.unuseful" data-type="useful" href="#" role="button">
# <span class="u_likeit_list_name _label">쏠쏠정보</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list wow" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.wow|RTL.unwow" data-type="wow" href="#" role="button">
# <span class="u_likeit_list_name _label">흥미진진</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list touched" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.touched|RTL.untouched" data-type="touched" href="#" role="button">
# <span class="u_likeit_list_name _label">공감백배</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list analytical" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.analytical|RTL.unanalytical" data-type="analytical" href="#" role="button">
# <span class="u_likeit_list_name _label">분석탁월</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list recommend" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTL.recommend|RTL.unrecommend" data-type="recommend" href="#" role="button">
# <span class="u_likeit_list_name _label">후속강추</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul> </div>
# <!-- 좋아요 -->
# </div>
# <div class="media_end_head_info_variety_cmtcount _COMMENT_HIDE">
# <a class="media_end_head_cmtcount_button _COMMENT_COUNT_VIEW" data-clk="rplt" data-max-limit="true" data-zero-allow="false" href="/mnews/article/comment/032/0003161880?sid=101" id="comment_count">댓글</a>
# </div>
# </div>
# <div class="media_end_head_info_variety_right">
# <!-- 요약봇 -->
# <div class="media_end_head_autosummary _auto_summary_wrapper _SUMMARY _LIKE_HIDE" data-articleid="0003161880" data-officeid="032" id="_SUMMARY_BUTTON">
# <a class="media_end_head_autosummary_button _toggle_btn _SUMMARY_BTN" data-clk="sum" href="javascript:;"><span class="blind">본문 요약봇</span></a>
# <div class="media_end_head_autosummary_layer_dimmed _SUMMARY_DIMMED" style="display: none;"></div>
# <div class="media_end_head_autosummary_layer _auto_summary_contents _SUMMARY_LAYER" style="display: none;">
# <div class="media_end_head_autosummary_layer_head">
# <strong class="media_end_head_autosummary_layer_head_tit">본문 요약봇<a class="media_end_head_autosummary_help" data-clk="help" href="https://help.naver.com/alias/news/news_022.naver">도움말</a></strong>
# <span class="media_end_head_autosummary_layer_head_txt">자동 추출 기술로 요약된 내용입니다. 요약 기술의 특성상 본문의 주요 내용이 제외될 수 있어, 전체 맥락을 이해하기 위해서는 기사 본문 전체보기를 권장합니다.</span>
# <a class="media_end_head_autosummary_layer_close _close_button _SUMMARY_CLOSE_BTN" data-clk="close" href="javascript:;"><span class="blind">닫기</span></a>
# </div>
# <div class="media_end_head_autosummary_layer_body">
# <div class="_contents_body _SUMMARY_CONTENT_BODY"></div>
# </div>
# </div>
# </div>
# <!-- TTS -->
# <div class="media_end_head_tts nv_notrans" id="tts_player_div_wrap">
# <button class="media_end_head_tts_run _TTS_SETTING_BTN" data-clk="wtts" title="텍스트 음성 변환 서비스" type="button"><span class="blind">텍스트 음성 변환 서비스 사용하기</span></button>
# <div class="media_end_head_tts_setlayer nv_notrans _TTS_SETTING_LAYER">
# <div class="media_end_head_tts_setlayer_select">
# <div class="media_end_head_tts_setlayer_select_bunch" id="ttsSelectGender">
# <em class="media_end_head_tts_option_tit">성별</em>
# <button class="media_end_head_tts_option" data-clk="ttsma" type="button" value="m">남성</button>
# <button class="media_end_head_tts_option" data-clk="ttsfe" type="button" value="f">여성</button>
# </div>
# <div class="media_end_head_tts_setlayer_select_bunch" id="ttsSelectSpeed">
# <em class="media_end_head_tts_option_tit">말하기 속도</em>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="3">느림</button>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="2">보통</button>
# <button class="media_end_head_tts_option" data-clk="ttssp" type="button" value="0">빠름</button>
# </div>
# <p class="media_end_head_tts_desc">이동 통신망을 이용하여 음성을 재생하면 별도의 데이터 통화료가 부과될 수 있습니다.</p>
# <button class="media_end_head_tts_apply _TTS_LISTEN_BTN" data-clk="ttsstart" type="button">본문듣기 시작</button>
# </div>
# <button class="media_end_head_tts_setlayer_close _TTS_SETTING_LAYER_CLOSE_BTN" data-clk="ttsclose" type="button"><span class="blind">닫기</span></button>
# </div>
# </div>
# <div id="tts_player_div"></div> <!-- 폰트 사이즈 -->
# <div class="media_end_head_fontsize _font_size_config_wrapper _FONT_WRAP">
# <a class="media_end_head_fontsize_set _font_size_config_toggle_btn _FONT_BUTTON" data-clk="fsz" href="#"><span class="blind">글자 크기 변경하기</span></a>
# <div class="media_end_head_fontsize_setlayer _FONT_LAYER">
# <ul class="media_end_head_fontsize_setlayer_select">
# <li class="media_end_head_fontsize_option1 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz1" data-value="1" href="#">가<em class="blind">1단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz1" data-value="1" href="#">작게</a>
# </li>
# <li class="media_end_head_fontsize_option2 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz2" data-value="2" href="#">가<em class="blind">2단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz2" data-value="2" href="#">보통</a>
# </li>
# <li class="media_end_head_fontsize_option3 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz3" data-value="3" href="#">가<em class="blind">3단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz3" data-value="3" href="#">크게</a>
# </li>
# <li class="media_end_head_fontsize_option4 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz4" data-value="4" href="#">가<em class="blind">4단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz4" data-value="4" href="#">아주크게</a>
# </li>
# <li class="media_end_head_fontsize_option5 _opt">
# <a class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-clk="fsz5" data-value="5" href="#">가<em class="blind">5단계</em></a>
# <a class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-clk="fsz5" data-value="5" href="#">최대크게</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="media_end_head_share nv_notrans">
# <a class="u_btn_sns_share naver-splugin spi_sns_share nv_notrans _SHARE_BUTTON" data-band-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=band" data-blog-blog-id="naver" data-blog-source-type="3" data-blog-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=blog" data-cafe-source-type="3" data-cafe-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=cafe" data-calendar-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=calendar" data-canonical-url="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=sec&amp;oid=032&amp;aid=0003161880&amp;sid1=001" data-clk="ushr" data-facebook-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=facebook" data-friend-display="on" data-friend-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=friend" data-kakaostory-display="off" data-kakaotalk-image-url="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=nf300_200" data-kakaotalk-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=kakao" data-likecontentsid="ne_032_0003161880" data-likeserviceid="NEWS" data-line-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=line" data-mail-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=mail" data-memo-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=memo" data-mypeople-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=mypeople" data-style="type_a" data-title="‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”" data-twitter-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=twitter" data-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101" href="#" id="spiButton" onclick="return false">
# <span class="naver-splugin-c send_caption"><span class="u_hc">SNS 보내기</span></span>
# </a>
# </div>
# <div class="media_end_head_print">
# <a class="media_end_print_link _PRINT_BUTTON" data-clk="print" data-print-url="/mnews/article/print/032/0003161880" href="#"><span class="blind">인쇄하기</span></a>
# </div>
# </div>
# </div>
# </div>
# </div><div class="newsct_body" id="contents">
# <div class="newsct_article _article_body" id="newsct_article">
# <div class="go_trans _article_content" id="dic_area">
# <strong class="media_end_summary">1차는 6만4650명 구매···평균 39만원어치 팔려<br/>서울시 “서울페이플러스 회원 가입은 전날 미리”</strong><span class="end_photo_org"><div class="nbd_im_w _LAZY_LOADING_WRAP">
# <div class="nbd_a _LAZY_LOADING_ERROR_HIDE" id="img_a1">
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=w647" id="img1">
# </img></div>
# </div><em class="img_desc">한 시민이 초복을 하루 앞둔 지난 15일 서울 시내 대형마트에서 장을 보고 있다. |성동훈 기자</em></span><br/><br/>서울 25개 자치구 어디에서나 쓸 수 있는 ‘서울사랑상품권(광역상품권)’이 오는 28일 추가 발행된다. 1차 발행 때처럼 동시접속자가 몰리는 것을 막기 위해 이번에는 출생연도를 기준으로 홀수는 오전 10시부터, 짝수는 오후 2시부터 각각 4시간씩 구매할 수 있다.<br/><br/>서울시는 7% 할인금액으로 구매할 수 있는 광역상품권을 28일 발행한다고 24일 밝혔다. 발행 규모는 1차(250억원) 때보다 2배 많은 총 500억원이다. 시민들의 장바구니 물가 부담을 덜고 소상공인 매출증대를 통한 지역경제 활성화를 위해 2차 발행 규모를 늘렸다고 서울시는 설명했다.<br/><br/>광역상품권은 서울 25개 자치구 내 가맹점 어디에서나 사용할 수 있는 상품권으로 1인당 월 40만원까지 구매할 수 있다. 보유는 총 100만원까지 가능하다. 지난 14일 1차 발행 상품권을 구매한 소비자는 총 6만4650명이었으며, 평균 구매 금액은 약 38만7000원이었다.<br/><br/>서울시는 2차 광역상품권 발행을 28일 오전과 오후로 나눠 진행한다. 지난 1차 발행 당시 구매접속 폭주로 한때 시스템이 먹통됐던 만큼 시스템 부하 등을 막기 위해서다. 1차는 발행 1시간여 만에 완판됐다.<br/><br/>이번에는 출생년도에 따라 홀수는 오전 10시부터 오후 2시까지, 짝수는 오후 2시부터 오후 6시까지 구입할 수 있다. 발행금액은 각 250억원씩 총 500억원이다. 오후 6시 이후에는 판매가능 금액이 남아있을 경우 홀짝수에 관계 없이 누구나 구매할 수 있다. 구매는 서울페이플러스 외에도 티머니페이, 신한SOL, 머니트리 등과 같은 결제 애플리케이션에서도 가능하다.<br/><br/>서울시는 시민들이 불편없이 광역상품권을 구매할 수 있도록 서울페이플러스 서버 용량을 1차 발행 대비 2배 이상 늘렸다. 이에 따라 동시 거래처리량은 초당 200건에서 1000건으로 5배 늘었다. 또 장시간 대기를 막기 위해 상품권 구매·결제단계에 ‘대기자 유량관리시스템’을 도입해 처리속도를 높였으며, 접속량 폭증 시 자동 튕겨나감을 막기 위해 로그아웃 시간을 자동 연장하도록 했다. 특히 편법 구매가 가능한 것으로 알려진 휴대전화 비행기 모드 전환시 후순위 대기순번으로 세팅되며 중복구매를 막기 위한 시스템도 탑재했다.<br/><br/>다만 시스템 과부하를 마기 위해 발행 당일 선물하기, 회원가입, 가맹점찾기 등 일부 서비스는 중단된다. 서울시는 광역상품권 구매를 원할 경우 발행 전날에는 미리 서울페이플러스에 회원가입을 해달라고 당부했다.<br/><br/>서울시는 자치구별로 발행해 해당 자치구 내 가맹점에서만 사용 가능한 10% 할인 서울사랑상품권도 추석 전인 9월 초 3670억원 규모로 발행할 계획이다.
# 		</div>
# </div>
# <div class="byline">
# <p class="byline_p">
# <span class="byline_s">이성희 기자 mong2@kyunghyang.com</span>
# </p>
# </div>
# <div class="newsct_journalist">
# <div class="newsct_journalist_inner">
# <h4 class="blind">기자 프로필</h4>
# <div class="media_journalistcard _JOURNALIST_CARD _MORE_WRAP">
# <div class="media_journalistcard_inner" id="JOURNALIST_CARD_LIST">
# <div class="media_journalistcard_item _SUBSCRIBE_ELE" data-subscribe-type="JOURNALIST">
# <div class="media_journalistcard_item_inner">
# <div class="media_journalistcard_intro">
# <div class="media_journalistcard_summary">
# <span class="media_journalistcard_summary_press">
# <img alt="경향신문" class="media_journalistcard_summary_press_img light_type" height="24" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2020/09/15/logo_032_6_20200915155035.png" title=""/>
# <img alt="경향신문" class="media_journalistcard_summary_press_img dark_type" height="24" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2020/09/15/dark_logo_032_6_20200915155021.png" title=""/>
# </span>
# <div class="media_journalistcard_summary_inner _LAZY_LOADING_WRAP">
# <div class="media_journalistcard_summary_info">
# <a class="media_journalistcard_summary_photo _LAZY_LOADING_ERROR_HIDE" data-clk="mmore" href="https://media.naver.com/journalist/032/56163">
# <div class="media_journalistcard_summary_photo_inner">
# <img alt="" class="media_journalistcard_summary_photo_inner_img _LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/upload/journalist/2019/02/18/%EC%9D%B4%EC%84%B1%ED%9D%AC.png?type=nf112_112" height="40" style="display:none;" width="40"/>
# </div>
# </a>
# <a class="media_journalistcard_summary_text" data-clk="mmore" href="https://media.naver.com/journalist/032/56163">
# <span class="media_journalistcard_summary_name">
# <span class="media_journalistcard_summary_name_inner">
# <em class="media_journalistcard_summary_name_text">이성희 기자</em>
# </span>
# </span>
# </a>
# </div>
# <div class="subscribe_wrap _JOURNALIST_ID" data-journalistid="56163">
# <a class="subscribe _SUBSCRIBE" data-channelkey="JOURNALIST_56163" data-clk="msubs" href="#">
# <span class="subscribe_ico"><span>구독</span></span>
# </a>
# <a class="subscribe on _UNSUBSCRIBE" data-channelkey="JOURNALIST_56163" data-clk="munsubs" data-messagevalue="이성희" data-type="journalist" href="#" style="display:none;">
# <span class="subscribe_ico"><span>구독중</span></span>
# </a>
# </div>
# </div>
# <span class="media_journalistcard_summary_subscribe">
# <span class="media_journalistcard_summary_subscribe_inner _SUBSCRIBE_COUNT_TEXT_WRAP">
# <i class="media_journalistcard_summary_subscribe_item">구독자</i> <em class="media_journalistcard_summary_subscribe_value _SUBSCRIBE_COUNT_TEXT">0</em>
# </span>
# <span class="media_journalistcard_summary_subscribe_inner _LIKE_HIDE">
# <div class="u_likeit_list_module _reactionModule" data-ccounttype="period" data-cid="56163" data-sid="JOURNALIST" id="_cheer_56163_layer">
# <span class="u_likeit_list_btn _button" data-ishiddenlabelaszerocount="true" data-ishiddenzerocount="true" data-type="cheer">
# <em class="u_txt _label">응원수</em>
# <em class="u_cnt _count">0</em>
# </span>
# </div>
# </span>
# </span>
# </div>
# </div>
# <div class="media_journalistcard_word">
# <p class="media_journalistcard_word_text">다르게, 바르게 쓰겠습니다.</p>
# </div>
# <div class="media_journalistcard_morenews">
# <ul class="media_journalistcard_morenews_list">
# <li class="media_journalistcard_morenews_item">
# <a class="media_journalistcard_morenews_item_inner" data-clk="bestart" href="/mnews/article/032/0003220549?type=journalists">서울 청년 2만5000명에 10개월간 ‘월세 20만원' 지원한다</a>
# </li>
# <li class="media_journalistcard_morenews_item">
# <a class="media_journalistcard_morenews_item_inner" data-clk="bestart" href="/mnews/article/032/0003220599?type=journalists">서울 등촌역 전기실 화재···지하철 9호선, 1시간30분 가량 무정차 통과</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="media_journalistcard_recommend media_journalistcard_recommend_is_on" id="_RECOMMEND_JOURNALIST" style="display:none;">
# <div class="media_journalistcard_recommend_inner">
# <h4 class="media_journalistcard_recommend_title _RECOMMEND_JOURNALIST_WRAP">경향신문의 구독 많은 기자</h4>
# <script class="_RECOMMEND_JOURNALIST_TEMPLATE" type="x-tmpl-mustache">
# 							<ul class="media_journalistcard_recommend_list">
# 								{{#list}}
# 								<li class="media_journalistcard_recommend_item _SUBSCRIBE_ELE" data-subscribe-type="JOURNALIST">
# 									<div class="media_journalistcard_recommend_item_inner">
# 										<a href="{{reporterUrl}}" class="media_journalistcard_recommend_item_link" data-clk="bmmore">
# 											{{#imageUrl}}
# 											<span class="media_journalistcard_recommend_img_wrap"><img src="{{imageUrl}}" width="44" height="44" alt="" class="media_journalistcard_recommend_img"></span>
# 											{{/imageUrl}}
# 											<em class="media_journalistcard_recommend_name">{{reporterName}}</em>
# 										</a>
# 										{{#count}}
# 										<span class="media_journalistcard_recommend_subscribe">구독자 <em class="_SUBSCRIBE_COUNT_TEXT">{{count}}</em></span>
# 										{{/count}}
# 										<div class="subscribe_wrap">
# 											<a href="#" class="subscribe _SUBSCRIBE" data-channelKey="{{channelKey}}" data-clk="bmsubs">
# 												<span class="subscribe_ico"><span>구독</span></span>
# 											</a>
# 											<a href="#" class="subscribe on _UNSUBSCRIBE" data-channelKey="{{channelKey}}" data-type="journalist" data-messageValue="{{reporterName}}" data-clk="bmunsubs" style="display:none;">
# 												<span class="subscribe_ico"><span>구독중</span></span>
# 											</a>
# 										</div>
# 									</div>
# 								</li>
# 								{{/list}}
# 							</ul>
# 							</script>
# <div class="media_journalistcard_recommend_channel _JOURNALIST_CHANNEL_PROMOTION">
# <strong>경향신문</strong> 기사를 더 보고 싶다면?
# 								<button class="media_journalistcard_recommend_channel_add _JOURNALIST_CHANNEL_BANNER _CHANNEL_ADD" data-clk-add="chsub" data-clk-remove="chsubback" data-delay="1000" data-gdid="032" type="button">구독</button>
# <a class="media_journalistcard_recommend_channel_layer _LINK" data-url-type="NAVERAPP_NEWS_CHANNEL" href="#" id="_JOURNALIST_CHANNEL_LAYER_032_0003161880" style="display:none;">
# <span class="media_journalistcard_recommend_channel_layer_text"><strong>경향신문</strong> 언론사 구독되었습니다. <br/>메인 뉴스판에서 경향신문 주요뉴스를 <br/> 볼 수 있습니다.</span>
# <span class="media_journalistcard_recommend_channel_layer_link">보러가기</span>
# </a>
# <p class="media_journalistcard_recommend_channel_layer" id="_JOURNALIST_CHANNEL_REMOVE_LAYER_032_0003161880" style="display:none">
# <span class="media_journalistcard_recommend_channel_layer_text"><strong>경향신문</strong> 언론사 구독 해지되었습니다.</span>
# </p>
# </div>
# <a class="media_journalistcard_recommend_close _TOGGLE" data-clk="bmclose" data-target="_RECOMMEND_JOURNALIST" href="#">닫기</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="copyright">
# <div class="c_inner">
# <p class="c_text">Copyright ⓒ 경향신문. All rights reserved. 무단 전재 및 재배포 금지.</p>
# </div>
# </div> <div class="media_end_categorize">
# <a class="media_end_categorize_link _categorize_title _TOGGLE" data-target="_ARTICLE_SECTION_GUIDE_LAYER" href="#">이 기사는 언론사에서 <em class="media_end_categorize_item">사회</em> 섹션으로 분류했습니다.</a>
# <div class="media_end_categorize_ct" id="_ARTICLE_SECTION_GUIDE_LAYER">
# <em class="media_end_categorize_ct_title">기사 섹션 분류 안내</em>
# <p class="media_end_categorize_ct_p">기사의 섹션 정보는 해당 언론사의 분류를 따르고 있습니다. 언론사는 개별 기사를 2개 이상 섹션으로 중복 분류할 수 있습니다.</p>
# <a class="media_end_categorize_ct_close _CLOSE" data-target="_ARTICLE_SECTION_GUIDE_LAYER" href="#">닫기</a>
# </div>
# </div>
# <div id="channelBanner" style="display:none;">
# <div class="media_end_channel_banner _LAZY_LOADING_WRAP">
# <a class="media_end_channel_banner_link _CHANNEL_BANNER _CHANNEL_ADD" data-clk-add="chbanner032" data-clk-remove="chsee032" data-notification="true" data-notification-clk="notbb" href="#">
# <div class="media_end_channel_banner_head _LAZY_LOADING_ERROR_HIDE">
# <div class="media_end_channel_banner_img">
# <img alt="경향신문" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2018/10/11/logo_032_57_20181011174011.png" height="40" style="display:none;" width="40"/>
# </div>
# </div>
# <div class="media_end_channel_banner_body _before _CHANNEL_BANNER_ADD">
# <p class="media_end_channel_banner_add">구독</p>
# <p class="media_end_channel_banner_txt"><span class="media_end_channel_banner_span"><strong>메인에서</strong> 바로 보는 언론사 편집 뉴스 지금 바로 구독해보세요!</span></p>
# </div>
# <div class="media_end_channel_banner_body _after _CHANNEL_BANNER_REMOVE is_hidden">
# <p class="media_end_channel_banner_add is_disabled">구독중</p>
# <p class="media_end_channel_banner_txt"><span class="media_end_channel_banner_span"><strong>메인에서</strong> 바로 보는 언론사 편집 뉴스 지금 바로 확인해보세요!</span> <em>보러가기</em></p>
# </div>
# </a>
# </div>
# </div>
# <div id="channelBannerRecommendList"></div>
# <script class="_CHANNEL_BANNER_RECOMMEND_LIST" type="x-tmpl-mustache">
# 	<div class="office_preference _CHANNEL_BANNER_RECOMMEND_LIST_WRAP">
# 	<div class="ofpr_recommend">
# 		<div class="ofpr_recommend_inner">
# 			<div class="ofpr_more_link">
# 				<h4 class="ofpr_tit">추가 구독해보세요</h4>
# 			</div>
# 			<ul class="ofpr_channel">
# 				{{#recommendList}}
# 				<li class="ofpr_item">
# 					<a href="#" class="ofpr_a _ALL_OFFICES_ITEM" data-officeId="{{officeId}}" data-officename="{{name}}" data-logo="{{logo}}" role="checkbox" aria-checked="false" data-clk-add="chwith" data-clk-remove="chwithno" data-target="_CHANNEL_BANNER_RECOMMEND_LIST_WRAP">
# 						<div class="ofpr_thumb"><img src="{{logo}}" class="ofpr_m" alt=""></div>
# 						<div class="ofpr_text">{{name}}</div>
# 						<span class="ofpr_badge">언론사 추가</span>
# 					</a>
# 				</li>
# 				{{/recommendList}}
# 			</ul>
# 			<div class="ofpr_btn_wrap">
# 				<button type="button" class="ofpr_btn_more _ALL_OFFICE_LIST" data-clk="chwithall">언론사 전체보기</button>
# 				<button type="button" class="ofpr_btn_confirm _ALL_OFFICES_COMPLETE disabled" data-clk-disabled="chwithsetall" data-clk-enabled="chwithchoice" data-target="_CHANNEL_BANNER_RECOMMEND_LIST_WRAP">언론사 전체 선택</button>
# 			</div>
# 			<button type="button" class="ofpr_recommend_close _TOGGLE" data-target="channelBannerRecommendList" data-clk="chclosing">닫기</button>
# 		</div>
# 	</div>
# 	</div>
# 	</script>
# <div class="promotion">
# <ul class="p_list">
# <li class="p_item">
# <a class="p_link" data-clk="promo" href="https://www.khan.co.kr/life/life-general/article/202106031627011">[뉴스레터]좋은 식습관을 만드는 맛있는 정보</a>
# </li>
# <li class="p_item">
# <a class="p_link" data-clk="promo" href="https://contents.premium.naver.com/khan/noon">‘눈에 띄는 경제’와 함께 경제 상식을 레벨 업 해보세요!</a>
# </li>
# </ul>
# </div> <div class="media_end_linked">
# <h3 class="media_end_linked_title">
# <a class="media_end_linked_title_inner" href="http://www.khan.co.kr/">
# <img alt="경향신문" class="media_end_linked_title_img light_type" height="26" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2020/09/15/logo_032_6_20200915155035.png" title="경향신문" width=""/>
# <img alt="경향신문" class="media_end_linked_title_img dark_type" height="26" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2020/09/15/dark_logo_032_6_20200915155021.png" title="경향신문" width=""/>
# </a>
# 			주요뉴스<span class="media_end_linked_title_desc">해당 언론사에서 선정하며 <em>언론사 페이지(아웃링크)</em>로 이동해 볼 수 있습니다.</span>
# </h3>
# <ul class="media_end_linked_list">
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"032","aid":"3807563eb439f27e"}}' data-gdid="032" href="https://www.khan.co.kr/politics/politics-general/article/202207220714001/?utm_campaign=naver_news&amp;utm_source=naver&amp;utm_medium=related_news" target="_blank">윤 대통령 지지율 30.4%, 20%대 눈앞…부정평가는 67.2%</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"032","aid":"a815d6b924cec6b9"}}' data-gdid="032" href="https://www.khan.co.kr/national/national-general/article/202207181634021/?utm_campaign=naver_news&amp;utm_source=naver&amp;utm_medium=related_news" target="_blank">"대통령이 머드축제 갈 때냐"···시민들, 코로나 재유행 각자도생 맡긴 정부에 '분통'</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"032","aid":"628eaa0bed966f95"}}' data-gdid="032" href="http://sports.khan.co.kr/news/sk_index.html?art_id=202207241006003&amp;code=530101&amp;utm_campaign=naver_news&amp;utm_source=naver&amp;utm_medium=related_news" target="_blank">빙속 간판 김민석, 선수촌 내 음주운전···빙상에 또 먹구름</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"032","aid":"e131ca1ba7fd41c5"}}' data-gdid="032" href="https://www.khan.co.kr/politics/defense-diplomacy/article/202207221219011/?utm_campaign=naver_news&amp;utm_source=naver&amp;utm_medium=related_news" target="_blank">윤 대통령 "병사 봉급 200만원 인상 차질없이 추진"</a></li>
# <li class="media_end_linked_item"><a class="media_end_linked_item_inner" data-clk="are.link" data-extra='{"lk":{"oid":"032","aid":"ca18bea7f093c267"}}' data-gdid="032" href="https://www.khan.co.kr/politics/politics-general/article/202207221342011/?utm_campaign=naver_news&amp;utm_source=naver&amp;utm_medium=related_news" target="_blank">민주당 "윤석열, '과학방역' 큰소리치더니 '국민 각자도생 방역' 됐다"</a></li>
# </ul>
# </div>
# <div class="r_group_comp ad_box _da_banner is_border_none">
# <div class="ad_area _AD_WRAP _PERSIST_HEIGHT" data-article="false" data-mobileonly="false" data-persist="1_ad" data-sync="false" data-unitid="p_news_newsend" id="nmap_c_032_0003161880_102_1"></div>
# </div>
# <script>
# 	window.__htExternalUrl = window.__htExternalUrl || {};
# 	window.__htExternalUrl["like"] = "https://news.like.naver.com/js/reaction/dist/reaction.min.js";
# 	window.__htLikeOption = {
# 		type: "multi",
# 		cssId: "news",
# 		domain: "https://news.like.naver.com",
# 		isMobile: true,
# 		isHiddenLabel: false,
# 		isHiddenCount: false,
# 		isHiddenZeroCount: false,
# 		isUsedLabelAsZeroCount: false,
# 		isDebugMode: false,
# 		isDuplication: false,
# 		isHiddenLayerAfterSelection: true,
# 		clicklog: function(el, name) {
# 			nclkWrap.send({
# 				$this: $(el),
# 				sArea: name
# 			});
# 		}
# 	};
# 	window.__htLikeOption["isZeroFace"] = true;
# 	</script>
# <div class="ends_btn _PERSIST_HEIGHT _LIKE_HIDE as_likeit_improve" data-persist="0_faceLike">
# <div class="ends_btn_head">
# <strong class="ends_head_title">이 기사를 추천합니다</strong>
# <button class="ends_help_btn _TOGGLE" data-classvalue="is_hidden" data-clk="RTC.info" data-target="_LIKE_INFO_LAYER" type="button"></button>
# <div class="ends_help_layer is_hidden" id="_LIKE_INFO_LAYER">
# <p class="ends_help_desc">기사 추천은 24시간 내 50회까지 참여할 수 있습니다.</p>
# <button class="ends_help_close _TOGGLE" data-classvalue="is_hidden" data-clk="RTC.infoclose" data-target="_LIKE_INFO_LAYER"><span class="blind">닫기</span></button>
# </div>
# </div>
# <div class="_reactionModule u_likeit" data-cid="ne_032_0003161880" data-sid="NEWS" id="likeItCountViewDiv" style="visibility: visible;">
# <ul class="u_likeit_layer _faceLayer" role="menu">
# <li class="u_likeit_list useful" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.useful|RTC.unuseful" data-type="useful" href="#" role="button">
# <span class="u_likeit_list_name _label">쏠쏠정보</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list wow" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.wow|RTC.unwow" data-type="wow" href="#" role="button">
# <span class="u_likeit_list_name _label">흥미진진</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list touched" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.touched|RTC.untouched" data-type="touched" href="#" role="button">
# <span class="u_likeit_list_name _label">공감백배</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list analytical" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.analytical|RTC.unanalytical" data-type="analytical" href="#" role="button">
# <span class="u_likeit_list_name _label">분석탁월</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list recommend" role="menuitem">
# <a aria-pressed="false" aria-selected="false" class="u_likeit_list_button _button off" data-log="RTC.recommend|RTC.unrecommend" data-type="recommend" href="#" role="button">
# <span class="u_likeit_list_name _label">후속강추</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul> </div>
# <div class="u_likeit_module u_btn_likeit_on" id="likeItSTimeLineShareDiv" style="display:none"></div>
# <div class="u_likeit_module" id="likeItScrollDiv" style="display:none">
# <div class="u_likeit_friends" id="likeItFriendListDiv"></div>
# </div>
# </div> <div class="ends_addition" id="endAdditionContainer">
# <script>
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 			window.__htExternalUrl["share"] = "https://ssl.pstatic.net/spi/js/release/ko_KR/splugin.js";
# 			window.__htShareOption = {
# 				"scriptUrl": window.__htExternalUrl["share"],
# 				"evKey": "news",
# 				"dimmed": "fixed",
# 				"serviceName": "뉴스",
# 				"sourceName": "경향신문"
# 			};
# 			if (isAvailableDarkMode) {
# 				window.__htShareOption["darkMode"] = true;
# 			}
# 		</script>
# <div id="spiLayer" style="display:none;">
# <div class="spi_wrap layer_share_on">
# <div class="spi">
# <div class="spug">
# <a class="naver-splugin _spi_release spi_ico _btn_postbtn sns_share" data-band-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=band" data-blog-blog-id="naver" data-blog-source-type="3" data-blog-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=blog" data-button="postbtn" data-cafe-source-type="3" data-cafe-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=cafe" data-calendar-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=calendar" data-clk="dshr" data-facebook-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=facebook" data-friend-display="on" data-friend-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=friend" data-kakaostory-display="off" data-kakaotalk-image-url="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=nf300_200" data-kakaotalk-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=kakao" data-likecontentsid="ne_032_0003161880" data-likeserviceid="NEWS" data-line-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=line" data-mail-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=mail" data-memo-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=memo" data-mypeople-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=mypeople" data-style="type_a" data-title="‘7% 할인’ 서울광역상품권 또 풀린다···“출생연도 홀짝수로 구매시간 분리”" data-twitter-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101&amp;lfrom=twitter" data-url="https://n.news.naver.com/mnews/article/032/0003161880?sid=101" href="#"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="tomain_info _LIKE_HIDE" id="_TOMAIN_INFO" style="display: none;">
# <p class="tomain_info_layer">
# <strong class="tomain_info_head">모두에게 보여주고 싶은 기사라면<i>?</i><span class="tomain_info_betaicon">beta</span></strong>
# <span class="tomain_info_body">
# <strong class="tomain_info_point">이 기사를 추천합니다 </strong><span class="tomain_info_text">버튼을 눌러주세요. <br/> 집계 기간 동안 추천을 많이 받은 기사는 네이버 자동 기사배열 영역에 추천 요소로 활용됩니다.</span>
# </span>
# <a class="tomain_info_close _CLOSE" data-target="_TOMAIN_INFO" href="#">레이어 닫기</a>
# </p>
# </div>
# </div> <div class="_VALID_SERIES" data-component-id=""></div>
# <div class="media_end_linked_more">
# <div class="media_end_linked_more_inner">
# ...
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzAxMjZfMTAx/MDAxNjc0NzA5MDYxNzY2.vU_mWy50GeYnJZz7e4OXPtQo_8eQzNUikAtGfZjrvscg.yqRSDC3dckZiXSutrnhngcjd8utEI2-Ttey95u7AOJUg.PNG/image%7Cpremium%7Cchannel%7Cbookstaurant%7C2023%7C01%7C26%7C1674709061736.png?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">기록하는 사람들</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzA1MDFfMTIy/MDAxNjgyOTQwNTUzNDg4.zA-kQRqiRSmYF_4evmD7nywcqh1AfGXSe5MsKpRAKwMg.id_whpv4PaMTBA7Zh1d7ggeo5YsnhUA6oMEe8VPDgkUg.PNG/38._%EB%B8%94%EB%A1%9C%EA%B7%B8+AI_%EA%B8%80%EC%93%B0%EA%B8%B0.png?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="2.269865130339646" href="https://contents.premium.naver.com/tachyon/analysis/contents/230428173121312ja?from=news_arp_global">
# <div class="rl_content">
# <p class="rl_txt">
# 										이재용, 상속세 어떻게…엄마는 하와이 별장까지 팔았는데
# 									</p>
# <div class="rl_author">
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjAzMjRfMjAw/MDAxNjQ4MDk4MjM2ODUx.Phs-UDtiqiLOruvcwcgbGbmh3gVfcjw1VgCj4QawL2og.xj8KmtAJ_Oj-OizZwjJEvXq7xNSI3Y2h8AktKr85LG4g.PNG/image%7Cpremium%7Cchannel%7Ctachyon%7C2022%7C03%7C24%7C1648098236831.png?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">주식 첫 걸음, 기업 뽀개기</div>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-recommended-type="GLOBAL" data-score="0.8223161100621359" href="https://contents.premium.naver.com/linkinvest/linkinvestment/contents/230427081258132yk?from=news_arp_global">
# <div class="rl_content">
# <p class="rl_txt">
# 										금일 (04.27) 이슈 및 시장 관심 예상 종목
# 									</p>
# <div class="rl_author">
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMjA0MjZfOCAg/MDAxNjUwOTU2NzIxMTA0.j9pk1-ZB_cKcq_blgNoFs0hNzbpigZJti_ru2D8N4dUg.9X7XfSDFCxUmwvHaHwCuv_SXcZvFJ3ZPO-QMAi0bzmAg.JPEG/image%7Cpremium%7Cchannel%7Clinkinvest%7C2022%7C04%7C26%7C1650956720994.jpg?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">링크투자자문</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzA0MjdfMTM0/MDAxNjgyNTUwNjczNjE5.lVZij5E7EWJuR3Cl6gczk5EJQhPIgULou7O0Qk4TGqYg.3Jn_tR8CNRM5JCsDC2_-bxdyrsi5fz-QxvXqIeQCMKMg.JPEG/2023042701039910126001_b.jpg?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end" data-clk="arp.ptextg" data-promotion-end-datetime="2023-05-03T23:59:59.999000" data-promotion-start-datetime="2023-05-02T09:24:21.141000" data-recommended-type="GLOBAL" data-score="0.8558963460471369" href="https://contents.premium.naver.com/lpartners/lpartners23/contents/230502092425730eq?from=news_arp_global">
# <div class="rl_content">
# <p class="rl_txt">
# <mark class="rl_content_tag as_temp_free">기간한정무료</mark>
# 										개장 전 주요뉴스
# 									</p>
# <div class="rl_author">
# <div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzAxMTZfOCAg/MDAxNjczODYxMDgxOTQ5.-57Fw84qE9gsGwden2TbYoiFGSzSQWc46prSkjQWb1Yg.VkjER3he6AzPqaKMEtDS-kxA7QtI6hzhE5L0DCFv_oUg.JPEG/image%7Cpremium%7Cchannel%7Clpartners%7C2023%7C01%7C16%7C1673861081923.jpg?type=nfs200_200" height="18" width="18"/>
# </div>
# <div class="rl_author_name">엘인베스트먼트</div>
# </div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img class="_LAZY_LOADING" data-scroll="true" data-src="https://scs-phinf.pstatic.net/MjAyMzA1MDJfMTA3/MDAxNjgyOTg3MDQ1OTU5.QmeZSgRvZXqLE8mDD1WkBDFH0eq0jNwFu1sF61EyYtgg.7IimC8rvpE-S1592nVhVaA2sV3S8LQioHRBvxo51xqgg.PNG/%EB%84%A4%EC%9D%B4%EB%B2%84%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84%EC%BB%A8%ED%85%90%EC%B8%A0-006.png?type=nf190_130" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="pg ra_paginate">
# <div class="pg_num_area pg_num_area_v2">
# <button class="pg_btn_prev _FLICKING_PREV" data-clk="arp.bprv" type="button"><span class="blind">이전 콘텐츠들 보기</span></button>
# <div class="_FLICKING_INDICATOR" data-count="3"></div>
# <div class="pg_line"></div>
# <div class="pg_num pg_num">3</div>
# <button class="pg_btn_next _FLICKING_NEXT" data-clk="arp.bnxt" type="button"><span class="blind">다음 콘텐츠들 보기</span></button>
# </div>
# </div>
# <script class="_FLICKING_INDICATOR_TEMPLATE _PC" type="x-tmpl-mustache">
# 			{{#selected}}
# 			<div class="pg_num pg_num_cur">{{number}}</div>
# 			{{/selected}}
# 		</script>
# </div>
# </div>
# </div>
# <div class="outside_area _OUTSIDE_AREA">
# <div class="outside_area_inner _GRID_TEMPLATE_COLUMN_ASIDE _OUTSIDE_AREA_INNER"></div>
# </div>
# <aside class="main_aside _MAIN_ASIDE">
# <div class="main_aside_inner _MAIN_ASIDE_INNER">
# <h3 class="blind">구독</h3>
# <script class="_LAZY_LOADING_IFRAME" type="x-tmpl-mustache">
# 			<iframe class="_aside _GRID_TEMPLATE_ASIDE_IFRAME" src="https://news.naver.com/aside?oid=032" data-allow-domain="https://news.naver.com" style="visibility: hidden;" frameborder="no" scrolling="no" width="100%"></iframe>
# 			</script>
# </div>
# </aside>
# </div>
# </div>
# <div class="media_end_tts_ticker _FADE_LAYER" id="_media_end_tts_ticker" style="display: none;">
# <p class="media_end_tts_ticker_text" style="display: block;">본문 듣기를 <em class="media_end_tts_ticker_point">종료</em>하였습니다.</p>
# </div>
# <div class="tomain_ticker _TOMAIN_RECOMMAND_LAYER _FADE_LAYER" style="display: none;">이 기사를 <em class="tomain_ticker_point">추천</em>했습니다.
# </div>
# <div class="tomain_ticker _TOMAIN_CANCEL_LAYER _FADE_LAYER" style="display: none;">추천을 <em class="tomain_ticker_point">취소</em>했습니다.
# </div><hr/>
# <div class="u_ft _STICKY_FOOTER">
# <div class="u_ft_inner">
# <a class="r_pg_top show _MOVE_TOP" data-clk="fot.top" href="#" id="goTop" style="display:none;">맨위로</a>
# <footer role="contentinfo">
# <p class="u_ftlkw" id="u_ftlkw">
# <a class="u_ftlk _LINK" data-clk="fot.login" data-pc-url="https://nid.naver.com/nidlogin.login" data-url="https://nid.naver.com/nidlogin.login?svctype=262144" href="https://nid.naver.com/nidlogin.login?svctype=262144">로그인</a>
# <a class="u_ftlk _LINK" data-clk="fot.sitemap" data-pc-url="https://www.naver.com/more.html" data-url="https://m.naver.com/services.html?f=svc.news" href="https://m.naver.com/services.html?f=svc.news">전체서비스</a>
# </p>
# <p class="u_cr">
# <span class="u_ftm">
# <span class="u_cri u_cri_v1"><a class="u_cra _LINK" data-pc-url="https://news.naver.com/main/ombudsman/index.naver" data-url="https://m.news.naver.com/ombudsman/index" href="https://m.news.naver.com/ombudsman/index">서비스안내</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-clk="fot.help" href="https://help.naver.com/alias/news/news_007.naver">뉴스도움말</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-clk="fot.report" href="https://help.naver.com/alias/news/news_001.naver">오류신고</a></span>
# </span>
# <span class="u_copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며, 이를 무단<br/>이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</span>
# <span class="u_cri"><span class="copymark">ⓒ</span> <a class="u_cra_v1" data-clk="fot.navercorp" href="https://www.navercorp.com">NAVER Corp.</a></span>
# <span class="u_cri"><span class="copymark">ⓒ</span> <a class="u_cra_v1">경향신문</a></span>
# </p>
# </footer>
# </div>
# </div><div class="subscribe_dimmed is_hidden" id="_MY_FEED_CANCEL_MODAL" style="display:none;">
# <div class="subscribe_alert">
# <p class="subscribe_alert_p _message _MY_FFED_CANCEL_MODAL_MESSAGE">
# </p>
# <div class="subscribe_alert_btns">
# <a class="subscribe_alert_btn _CANCEL_YES_BTN _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">예</a>
# <a class="subscribe_alert_btn _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">아니오</a>
# </div>
# </div>
# </div>
# <script class="_MY_FEED_CANCEL_MODAL_TEMPLATE" type="x-tmpl-mustache">
# 			{{#series}}
# 			<span class="subscribe_alert_p_ellipsis">{{value}}</span><br>연재 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc">해당 기사는 <em>구독</em>에서 제외됩니다.</span>
# 			{{/series}}
# 			{{#journalist}}
# 			{{value}} 기자의 기사<br> 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc"><em>구독</em>에서 해당 기자의 기사가 제외됩니다.</span>
# 			{{/journalist}}
# </script>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_ALL"></div>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification is_single">
# 	<strong class="mn_ok">구독완료</strong>
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<p class="mn_p">언론사의 주요 콘텐츠를 <br> 네이버에서 빠르게 확인할 수 있습니다.</p>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">알림받기</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	<strong class="mn_ok">구독완료</strong>
# 	<div class="mn_text">
# 		<h4 class="mn_h">언론사의 주요 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<ul class="mn_list">
# 			{{#officeInfos}}
# 			<li class="mn_item">
# 				<div class="mn_head">
# 					<div class="mn_img">
# 						<img src="{{logo}}" alt="">
# 					</div>
# 					<div class="mn_name">{{officeName}}</div>
# 				</div>
# 				<div class="mn_body">
# 					<button type="button" class="mn_noti _ALL_OFFICES_NOTIFICATION_ITEM" data-oid="{{officeId}}" data-clk-add="notchnon" data-clk-remove="notchnoff">알림받기 사용함</button>
# 				</div>
# 			</li>
# 			{{/officeInfos}}
# 		</ul>
# 	</div>
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE _CHANNEL_BANNER_ITEM_NOTICE_COMPLETE" data-clk="{{nclk}}yes">완료</button>
# 	</div>
# </div>
# </script>
# <div id="_MODAL_COMMENT_FOLLOW_TUTORIAL" style="display: none;"></div>
# <script class="_MODAL_COMMENT_FOLLOW_TUTORIAL_TEMPLATE" type="x-tmpl-mustache">
# <div class="comment_follow_tutorial" role="dialog" aria-modal="true">
# 	<div class="comment_follow_tutorial_layer">
# 		<div class="comment_follow_tutorial_layer_dimmed"></div>
# 		<div class="comment_follow_tutorial_layer_container">
# 			<div class="comment_follow_tutorial_layer_content">
# 				<div class="comment_follow_tutorial_layer_item">
# 					<p class="{{className}}">{{text}}</p>
# 					<i class="comment_follow_tutorial_layer_closeicon"></i>
# 					<button type="button" class="comment_follow_tutorial_layer_close _MODAL_COMMENT_FOLLOW_TUTORIAL_CLOSE" data-clk="{{nclkPrefix}}tutclose">닫기</button>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </script>
# <div class="ticker" id="_TICKER_LAYER_FOR_NOTIFICATION" style="display: none;"></div>
# <script class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.</p>
# {{/officeInfos}}
# </script>
# <script src="https://static-nnews.pstatic.net/js/min/20230427/library.min.js"></script>
# <script src="https://static-nnews.pstatic.net/js/min/20230427/read.min.js"></script>
# <script>
# 	window.ntm = window.ntm || [];
# 	var ntmOption = {};
#
# 	if (ntmOption) {
#
# 		var section = {"id":"102","name":"사회"};
# 		var redirectSection = {"id":"101","name":"경제"};
#
# 		ntmOption["channelId"] = article.officeId;
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		var nilSendSectionId = "";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 			nilSendSectionId = section.id;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		ntmOption["hitType"] = "cv";
# 		ntmOption["eventCategory"] = "post_view";
# 		ntmOption["uri"] = "http://news.naver.com/main/read.nhn?oid=032&aid=0003161880";
# 		ntmOption["gdid"] = article.gdid;
# 		ntmOption["dimension1"] = encodeURIComponent(nilSendSectionName);
# 		ntmOption["dimension4"] = articleTypeName;
# 		ntmOption["optional2"] = nilSendSectionId;
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			ntmOption["dimension3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			ntmOption["dimension5"] = "y";
# 		}
#
# 		if (service.sports) {
# 			ntmOption["dimension2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		var seriesComponentId = $("._VALID_SERIES").attr("data-component-id");
# 		ntmOption["dimension6"] = seriesComponentId;
#
# 		if (/[?|&]type=breakingnews(&|$)/.test(location.href) === true) {
# 			if (/(m\.naver\.com)|(media\.naver\.com)|(news\.naver\.com\/?$)/.test(document.referrer) === true) {
# 				ntmOption["dimension7"] = "breaking";
# 			}
# 		}
#
# 		var ntmLeaveOption = $.extend({}, ntmOption);
# 		ntmLeaveOption["hitType"] = "event";
# 		ntmLeaveOption["eventCategory"] = "action";
# 		ntmLeaveOption["eventAction"] = "leave";
#
# 		if (/\/article\/comment\//.test(location.href) == false) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				}, false);
# 				window.addEventListener("unload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				});
# 				window.attachEvent("onunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				});
# 			} else {
# 				var fnOnUnload = window.onunload;
# 				window.onunload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
# </script>
# </div>
# <script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				lcs_do_gdid("8800006B_000000000000000003161880");
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": (/\/article\/comment\//.test(location.href) == true) ? "댓글" : "본문",
# 					},
# 					"extraInfo": {
# 						"articleId": article.articleId,
# 						"sectionId": article.sectionId,
# 						"officeId": article.officeId,
# 						"articleType": article.type
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data,
# 						contentBodyEl: document.querySelector("._article_content"),
# 						contentBodyVideoWrapperSelector: "._VIDEO_AREA"
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
# 			});
# 		</script>
# </body>
# </html>

# %%
# 이미지 주소 추출 : #img1
target = soup.select_one("#img1")
print(target,'\n')

target = target["data-src"]
print(target)
# Out:
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=w647" id="img1">
# </img>
#
# https://imgnews.pstatic.net/image/032/2022/07/24/0003161880_001_20220724112401144.jpg?type=w647

# %%
# 네이버 환율 가져오기 : #exchangeList > li.on > a.head.usd > div > span.value
url = "https://finance.naver.com/marketindex/"
res = urllib.request.urlopen(url)
soup = BS(res, "html.parser")
print(soup)
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindo.1.5.3.element-text-patch.js" type="text/javascript"></script>
# <div id="container" style="padding-bottom:0px;">
# <div class="market_include">
# <div class="market_data">
# <div class="market1">
# <div class="title">
# <h2 class="h_market1"><span>환전 고시 환율</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="exchangeList">
# <li class="on">
# <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
# <div class="head_info point_up">
# <span class="value">1,341.50</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change">0.50</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2023.05.02 17:09</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">448</span>회</span>
# </div>
# </li>
# <li class="">
# <a class="head jpy" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_JPYKRW" onclick="clickcr(this, 'fr1.jpyt', '', '', event);">
# <h3 class="h_lst"><span class="blind">일본 JPY(100엔)</span></h3>
# <div class="head_info point_dn">
# <span class="value">975.46</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 2.05</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_JPYKRW" onclick="clickcr(this, 'fr1.jpyc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_JPYKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2023.05.02 17:09</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">448</span>회</span>
# </div>
# </li>
# <li class="">
# <a class="head eur" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_EURKRW" onclick="clickcr(this, 'fr1.eurt', '', '', event);">
# <h3 class="h_lst"><span class="blind">유럽연합 EUR</span></h3>
# <div class="head_info point_dn">
# <span class="value">1,471.22</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 3.34</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_EURKRW" onclick="clickcr(this, 'fr1.eurc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_EURKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2023.05.02 17:09</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">448</span>회</span>
# </div>
# </li>
# <li class="">
# <a class="head cny" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_CNYKRW" onclick="clickcr(this, 'fr1.cnyt', '', '', event);">
# <h3 class="h_lst"><span class="blind">중국 CNY</span></h3>
# <div class="head_info point_dn">
# <span class="value">192.92</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 0.02</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_CNYKRW" onclick="clickcr(this, 'fr1.cnyc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_CNYKRW.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2023.05.02 17:09</span>
# <span class="source">하나은행 기준</span>
# <span class="count">고시회차<span class="num">448</span>회</span>
# </div>
# </li>
# </ul>
# </div>
# <!-- //data -->
# </div>
# <div class="market2">
# <div class="title">
# <h2 class="h_market2"><span>국제 시장 환율</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="worldExchangeList">
# <li class="on">
# <a class="head jpy_usd" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_USDJPY" onclick="clickcr(this, 'fr2.jpyut', '', '', event);">
# <h3 class="h_lst"><span class="blind">달러/일본 엔</span></h3>
# <div class="head_info point_up">
# <span class="value">137.2900</span>
# <span class="txt_jpy"><span class="blind">엔</span></span>
# <span class="change">0.9900</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_USDJPY" onclick="clickcr(this, 'fr2.jpyuc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDJPY.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2023.05.01</span>
# <span class="source">모닝스타 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head usd_eur" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_EURUSD" onclick="clickcr(this, 'fr2.eurdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">유로/달러</span></h3>
# <div class="head_info point_dn">
# <span class="value">1.0979</span>
# <span class="txt_usd"><span class="blind">달러</span></span>
# <span class="change"> 0.0149</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_EURUSD" onclick="clickcr(this, 'fr2.eurdc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_EURUSD.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2023.05.01</span>
# <span class="source">모닝스타 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head usd_gbp" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_GBPUSD" onclick="clickcr(this, 'fr2.gbpdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">영국 파운드/달러</span></h3>
# <div class="head_info point_dn">
# <span class="value">1.2517</span>
# <span class="txt_usd"><span class="blind">달러</span></span>
# <span class="change"> 0.0052</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_GBPUSD" onclick="clickcr(this, 'fr2.gbpdc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_GBPUSD.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2023.05.01</span>
# <span class="source">모닝스타 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head usd_idx" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_USDX" onclick="clickcr(this, 'fr2.indt', '', '', event);">
# <h3 class="h_lst"><span class="blind">달러인덱스</span></h3>
# <div class="head_info point_up">
# <span class="value">101.9200</span>
# <span class="change">0.5200</span>
# <span class="blind">상승</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_USDX" onclick="clickcr(this, 'fr2.indc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDX.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2023.05.01</span>
# <span class="source">ICE 기준</span>
# </div>
# </li>
# </ul>
# </div>
# <!-- //data -->
# </div>
# <div class="market3">
# <div class="title">
# <h2 class="h_market3"><span>유가·금시세</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="oilGoldList">
# <li class="on">
# <a class="head wti" href="/marketindex/worldOilDetail.naver?marketindexCd=OIL_CL&amp;fdtc=2" onclick="clickcr(this, 'fr3.wtit', '', '', event);">
# <h3 class="h_lst"><span class="blind">WTI</span></h3>
# <div class="head_info point_dn">
# <span class="value">75.66</span>
# <span class="txt_usd"><span class="blind">달러</span></span>
# <span class="change"> 1.12</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldOilDetail.naver?marketindexCd=OIL_CL&amp;fdtc=2" onclick="clickcr(this, 'fr3.wtic', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/OIL_CL.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2023.05.01</span>
# <span class="source">NYMEX(뉴욕상업거래소) 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head gasoline" href="/marketindex/oilDetail.naver?marketindexCd=OIL_GSL" onclick="clickcr(this, 'fr3.oilt', '', '', event);">
# <h3 class="h_lst"><span class="blind">휘발유</span></h3>
# <div class="head_info point_dn">
# <span class="value">1662.32</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 0.16</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/oilDetail.naver?marketindexCd=OIL_GSL" onclick="clickcr(this, 'fr3.oilc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/OIL_GSL.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2023.05.02</span>
# <span class="source">한국석유공사 Opinet 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head gold_inter" href="/marketindex/worldGoldDetail.naver?marketindexCd=CMDT_GC&amp;fdtc=2" onclick="clickcr(this, 'fr3.agoldt', '', '', event);">
# <h3 class="h_lst"><span class="blind">국제 금</span></h3>
# <div class="head_info point_dn">
# <span class="value">1992.2</span>
# <span class="txt_usd"><span class="blind">달러</span></span>
# <span class="change"> 6.90</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/worldGoldDetail.naver?marketindexCd=CMDT_GC&amp;fdtc=2" onclick="clickcr(this, 'fr3.agoldc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/CMDT_GC.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2023.05.01</span>
# <span class="source">COMEX(뉴욕상품거래소) 기준</span>
# </div>
# </li>
# <li class="">
# <a class="head gold_domestic" href="/marketindex/goldDetail.naver" onclick="clickcr(this, 'fr3.kgoldt', '', '', event);">
# <h3 class="h_lst"><span class="blind">국내 금</span></h3>
# <div class="head_info point_dn">
# <span class="value">85420.84</span>
# <span class="txt_krw"><span class="blind">원</span></span>
# <span class="change"> 7.69</span>
# <span class="blind">하락</span>
# </div>
# </a>
# <a class="graph_img" href="/marketindex/goldDetail.naver" onclick="clickcr(this, 'fr3.kgoldc', '', '', event);">
# <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/CMDT_GD.png" width="295"/>
# </a>
# <div class="graph_info">
# <span class="time">2023.05.02 17:09</span>
# <span class="source">신한은행 기준</span>
# 							(<span class="num">268</span>회차)
# 					</div>
# </li>
# </ul>
# </div>
# <!-- //data -->
# </div>
# </div>
# </div>
# <div class="marketindex_content" id="content">
# <div class="section_news">
# <h3 class="h_news2"><span>주요 뉴스</span></h3>
# <div class="list_area">
# <ul>
# <li>
# <p><a href="/marketindex/news/newsRead.naver?officeId=018&amp;articleId=0005477258&amp;category=" onclick="clickcr(this, 'mhn.list', '018_0005477258', '0', event);">호주 깜짝 금리 인상에도…환율, 1342.</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>05.02 15:55</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.naver?officeId=008&amp;articleId=0004882219&amp;category=" onclick="clickcr(this, 'mhn.list', '008_0004882219', '1', event);">업황 악화·원자재값 상승, '제지 1위' </a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>05.02 11:01</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.naver?officeId=008&amp;articleId=0004882135&amp;category=" onclick="clickcr(this, 'mhn.list', '008_0004882135', '2', event);">한은 "물가, 올해 중반까지 안정세…유가·</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>05.02 10:04</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.naver?officeId=011&amp;articleId=0004185631&amp;category=" onclick="clickcr(this, 'mhn.list', '011_0004185631', '3', event);">14개월만 3%대로 내려온 물가에도…국제유</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>05.02 09:58</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.naver?officeId=011&amp;articleId=0004185608&amp;category=" onclick="clickcr(this, 'mhn.list', '011_0004185608', '4', event);">한은 “소비자물가 올 중반까지 둔화 뚜렷…</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>05.02 09:39</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.naver?officeId=417&amp;articleId=0000917489&amp;category=" onclick="clickcr(this, 'mhn.list', '417_0000917489', '5', event);">[오늘의 환율전망] 美 연준 긴축 경계감에</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>05.02 08:10</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.naver?officeId=018&amp;articleId=0005476730&amp;category=" onclick="clickcr(this, 'mhn.list', '018_0005476730', '6', event);">美 FOMC 앞두고 달러 강세…또 1340</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>05.02 08:04</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.naver?officeId=001&amp;articleId=0013915300&amp;category=" onclick="clickcr(this, 'mhn.list', '001_0013915300', '7', event);">[뉴욕유가] 경기 둔화 우려에 하락</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>05.02 04:45</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.naver?officeId=015&amp;articleId=0004839649&amp;category=" onclick="clickcr(this, 'mhn.list', '015_0004839649', '8', event);">국제 유가, 글로벌경기둔화 우려로 하락세</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>05.02 00:12</span>
# </li>
# <li>
# <p><a href="/marketindex/news/newsRead.naver?officeId=032&amp;articleId=0003220832&amp;category=" onclick="clickcr(this, 'mhn.list', '032_0003220832', '9', event);">‘해외 배당’ 4월, 경상수지 적자 커지면</a><img alt="NEW" height="8" src="https://ssl.pstatic.net/static/nfinance/ico_new.gif" width="8"/></p>
# <span>05.01 21:05</span>
# </li>
# </ul>
# </div>
# <a class="btn_more" href="/marketindex/news/newsList.naver" onclick="clickcr(this, 'mhn.more', '', '', event);"><img alt="더보기" height="18" src="https://ssl.pstatic.net/static/nfinance/btn_more.gif" width="34"/></a>
# </div>
# <div class="tab_default1" id="tab_section">
# <ul>
# <li class="on"><a href="./?tabSel=exchange#tab_section" onclick="clickcr(this, 'mtb.exnoti', '', '', event);"><span class="tab1">환전고시 환율</span></a></li>
# <li class=""><a href="./?tabSel=worldExchange#tab_section" onclick="clickcr(this, 'mtb.interex', '', '', event);"><span class="tab2">국제시장 환율</span></a></li>
# <li class=""><a href="./?tabSel=gold#tab_section" onclick="clickcr(this, 'mtb.oilgold', '', '', event);"><span class="tab3">유가 금시세</span></a></li>
# <li class=""><a href="./?tabSel=materials#tab_section" onclick="clickcr(this, 'mtb.material', '', '', event);"><span class="tab4">원자재</span></a></li>
# </ul>
# <h2 class="blind">환전고시 환율</h2>
# </div>
# <div class="section_calculator">
# <h3 class="h_calculator"><span>환율계산기 (매매기준율 기준)</span></h3>
# <div class="calculator">
# <div class="inner">
# <div class="input">
# <div class="selectbox-noscript" id="sInput">
# <select class="selectbox-source" id="select_from">
# <option label="1" value="1">대한민국 원 KRW</option>
# <option class="selectbox-default" label="1" selected="selected" value="1341.5"> 미국 달러 USD</option>
# <option label="1" value="1341.5"> 미국 달러 USD</option>
# <option label="1" value="1471.22"> 유럽연합 유로 EUR</option>
# <option label="100" value="9.7546"> 일본 엔 JPY</option>
# <option label="1" value="192.92"> 중국 위안 CNY</option>
# <option label="1" value="170.89"> 홍콩 달러 HKD</option>
# <option label="1" value="43.52"> 대만 달러 TWD</option>
# <option label="1" value="1672.58"> 영국 파운드 GBP</option>
# <option label="1" value="3484.6"> 오만 리알 OMR</option>
# <option label="1" value="988.8"> 캐나다 달러 CAD</option>
# <option label="1" value="1492.88"> 스위스 프랑 CHF</option>
# <option label="1" value="130.0"> 스웨덴 크로나 SEK</option>
# <option label="1" value="897.66"> 호주 달러 AUD</option>
# <option label="1" value="830.52"> 뉴질랜드 달러 NZD</option>
# <option label="1" value="62.43"> 체코 코루나 CZK</option>
# <option label="1" value="1.66"> 칠레 페소 CLP</option>
# <option label="1" value="68.91"> 튀르키예 뉴리라 TRY</option>
# <option label="1" value="0.38"> 몽골 투그릭 MNT</option>
# <option label="1" value="371.23"> 이스라엘 세켈 ILS</option>
# <option label="1" value="197.36"> 덴마크 크로네 DKK</option>
# <option label="1" value="124.76"> 노르웨이 크로네 NOK</option>
# <option label="1" value="357.72"> 사우디아라비아 리얄 SAR</option>
# <option label="1" value="4375.69"> 쿠웨이트 디나르 KWD</option>
# <option label="1" value="3558.07"> 바레인 디나르 BHD</option>
# <option label="1" value="365.3"> 아랍에미리트 디르함 AED</option>
# <option label="1" value="1891.03"> 요르단 디나르 JOD</option>
# <option label="1" value="43.34"> 이집트 파운드 EGP</option>
# <option label="1" value="39.19"> 태국 바트 THB</option>
# <option label="1" value="1004.12"> 싱가포르 달러 SGD</option>
# <option label="1" value="300.62"> 말레이시아 링깃 MYR</option>
# <option label="100" value="0.09140000000000001"> 인도네시아 루피아 IDR</option>
# <option label="1" value="366.23"> 카타르 리얄 QAR</option>
# <option label="1" value="2.99"> 카자흐스탄 텡게 KZT</option>
# <option label="1" value="1004.12"> 브루나이 달러 BND</option>
# <option label="1" value="16.38"> 인도 루피 INR</option>
# <option label="1" value="4.73"> 파키스탄 루피 PKR</option>
# <option label="1" value="12.54"> 방글라데시 타카 BDT</option>
# <option label="1" value="24.25"> 필리핀 페소 PHP</option>
# <option label="1" value="74.75"> 멕시코 페소 MXN</option>
# <option label="1" value="268.87"> 브라질 레알 BRL</option>
# <option label="100" value="0.0572"> 베트남 동 VND</option>
# <option label="1" value="72.85"> 남아프리카 공화국 랜드 ZAR</option>
# <option label="1" value="16.78"> 러시아 루블 RUB</option>
# <option label="1" value="3.96"> 헝가리 포린트 HUF</option>
# <option label="1" value="320.0"> 폴란드 즈워티 PLN</option>
# <option label="1" value="4.19"> 스리랑카 루피 LKR</option>
# <option label="1" value="9.89"> 알제리 알제리 디나르 DZD</option>
# <option label="1" value="9.86"> 케냐 실링 KES</option>
# <option label="1" value="0.28"> 콜롬비아 페소 COP</option>
# <option label="1" value="0.57"> 탄자니아 실링 TZS</option>
# <option label="1" value="10.24"> 네팔 루피 NPR</option>
# <option label="1" value="298.53"> 루마니아 레우 RON</option>
# <option label="1" value="281.63"> 리비아 리비아 디나르 LYD</option>
# <option label="1" value="165.84"> 마카오 파타카 MOP</option>
# <option label="1" value="0.64"> 미얀마 짯 MMK</option>
# <option label="1" value="24.6"> 에티오피아 비르 ETB</option>
# <option label="1" value="0.12"> 우즈베키스탄 숨 UZS</option>
# <option label="1" value="0.33"> 캄보디아 리엘 KHR</option>
# <option label="1" value="605.08"> 피지 피지 달러 FJD</option>
# </select>
# <div class="selectbox-box" onclick="clickcr(this, 'exl*c.clist1', '', '', event);">
# <div class="selectbox-label"></div>
# </div>
# <div class="selectbox-layer ly_calculator">
# <div class="selectbox-list"></div>
# </div>
# </div>
# <div class="input_area" id="input_from">
# <input id="input_from_money" maxlength="10" onclick="clickcr(this, 'exl*c.unit1', '', '', event);" onfocus="changeActiveInput('from', 'to'); return false;" onkeyup="calcExchange('from', 'to', 'on', event);" type="text" value="1"/>
# <img alt="" height="13" id="img_from_monetary" src="https://ssl.pstatic.net/static/nfinance/img_money_USD.gif" width="26"/>
# </div>
# </div>
# <div class="same"><img alt="" height="15" src="https://ssl.pstatic.net/static/nfinance/ico_same.gif" width="28"/></div>
# <div class="view">
# <div class="selectbox-noscript" id="sView">
# <select class="selectbox-source" id="select_to">
# <option class="selectbox-default" label="1" value="1">대한민국 원 KRW</option>
# <option label="1" value="1">대한민국 원 KRW</option>
# <option label="1" value="1341.5">미국 달러 USD</option>
# <option label="1" value="1471.22">유럽연합 유로 EUR</option>
# <option label="100" value="9.7546">일본 엔 JPY</option>
# <option label="1" value="192.92">중국 위안 CNY</option>
# <option label="1" value="170.89">홍콩 달러 HKD</option>
# <option label="1" value="43.52">대만 달러 TWD</option>
# <option label="1" value="1672.58">영국 파운드 GBP</option>
# <option label="1" value="3484.6">오만 리알 OMR</option>
# <option label="1" value="988.8">캐나다 달러 CAD</option>
# <option label="1" value="1492.88">스위스 프랑 CHF</option>
# <option label="1" value="130.0">스웨덴 크로나 SEK</option>
# <option label="1" value="897.66">호주 달러 AUD</option>
# <option label="1" value="830.52">뉴질랜드 달러 NZD</option>
# <option label="1" value="62.43">체코 코루나 CZK</option>
# <option label="1" value="1.66">칠레 페소 CLP</option>
# <option label="1" value="68.91">튀르키예 뉴리라 TRY</option>
# <option label="1" value="0.38">몽골 투그릭 MNT</option>
# <option label="1" value="371.23">이스라엘 세켈 ILS</option>
# <option label="1" value="197.36">덴마크 크로네 DKK</option>
# <option label="1" value="124.76">노르웨이 크로네 NOK</option>
# <option label="1" value="357.72">사우디아라비아 리얄 SAR</option>
# <option label="1" value="4375.69">쿠웨이트 디나르 KWD</option>
# <option label="1" value="3558.07">바레인 디나르 BHD</option>
# <option label="1" value="365.3">아랍에미리트 디르함 AED</option>
# <option label="1" value="1891.03">요르단 디나르 JOD</option>
# <option label="1" value="43.34">이집트 파운드 EGP</option>
# <option label="1" value="39.19">태국 바트 THB</option>
# <option label="1" value="1004.12">싱가포르 달러 SGD</option>
# <option label="1" value="300.62">말레이시아 링깃 MYR</option>
# <option label="100" value="0.09140000000000001">인도네시아 루피아 IDR</option>
# <option label="1" value="366.23">카타르 리얄 QAR</option>
# <option label="1" value="2.99">카자흐스탄 텡게 KZT</option>
# <option label="1" value="1004.12">브루나이 달러 BND</option>
# <option label="1" value="16.38">인도 루피 INR</option>
# <option label="1" value="4.73">파키스탄 루피 PKR</option>
# <option label="1" value="12.54">방글라데시 타카 BDT</option>
# <option label="1" value="24.25">필리핀 페소 PHP</option>
# <option label="1" value="74.75">멕시코 페소 MXN</option>
# <option label="1" value="268.87">브라질 레알 BRL</option>
# <option label="100" value="0.0572">베트남 동 VND</option>
# <option label="1" value="72.85">남아프리카 공화국 랜드 ZAR</option>
# <option label="1" value="16.78">러시아 루블 RUB</option>
# <option label="1" value="3.96">헝가리 포린트 HUF</option>
# <option label="1" value="320.0">폴란드 즈워티 PLN</option>
# <option label="1" value="4.19">스리랑카 루피 LKR</option>
# <option label="1" value="9.89">알제리 알제리 디나르 DZD</option>
# <option label="1" value="9.86">케냐 실링 KES</option>
# <option label="1" value="0.28">콜롬비아 페소 COP</option>
# <option label="1" value="0.57">탄자니아 실링 TZS</option>
# <option label="1" value="10.24">네팔 루피 NPR</option>
# <option label="1" value="298.53">루마니아 레우 RON</option>
# <option label="1" value="281.63">리비아 리비아 디나르 LYD</option>
# <option label="1" value="165.84">마카오 파타카 MOP</option>
# <option label="1" value="0.64">미얀마 짯 MMK</option>
# <option label="1" value="24.6">에티오피아 비르 ETB</option>
# <option label="1" value="0.12">우즈베키스탄 숨 UZS</option>
# <option label="1" value="0.33">캄보디아 리엘 KHR</option>
# <option label="1" value="605.08">피지 피지 달러 FJD</option>
# </select>
# <div class="selectbox-box" onclick="clickcr(this, 'exl*c.clist2', '', '', event);">
# <div class="selectbox-label"></div>
# </div>
# <div class="selectbox-layer ly_calculator">
# <div class="selectbox-list"></div>
# </div>
# </div>
# <div class="input_area" id="input_to">
# <input id="input_to_money" maxlength="10" onclick="clickcr(this, 'exl*c.unit2', '', '', event);" onfocus="changeActiveInput('to', 'from'); return false;" onkeyup="calcExchange('to', 'from', 'on', event);" type="text"/>
# <img alt="" height="13" id="img_to_monetary" src="https://ssl.pstatic.net/static/nfinance/img_money_KRW.gif" width="26"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section_exchange">
# <div id="section_ex1">
# <h3 class="blind" id="exchange1">환전 고시 환율</h3>
# <div class="exchange_info">
# <span class="date">2023.05.02 17:09</span>
# <span class="standard">하나은행 기준</span>
# <span class="round">고시회차 <em>448</em>회</span>
# </div>
# <iframe frameborder="0" height="1800px" id="frame_ex1" marginheight="0" marginwidth="0" scrolling="no" src="/marketindex/exchangeList.naver" title="환전 고시 환율" width="100%"></iframe>
# </div>
# <ul class="tbl_info">
# <li>통화명과 심볼은 앞에 위치한 통화에 1이 생략된 형태로, 달러/일본 엔(심볼: USDJPY)인 경우 1 USD(달러)가 JPY(일본 엔)으로 얼마인가를 의미합니다.</li>
# </ul>
# </div>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindoComponent/jindo.Component.1.0.3.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindoComponent/jindo.UIComponent.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindoComponent/jindo.HTMLComponent.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindoComponent/jindo.Timer.1.0.3.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindoComponent/jindo.LayerManager.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindoComponent/jindo.LayerPosition.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindoComponent/jindo.RolloverArea.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindoComponent/jindo.RolloverClick.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindoComponent/jindo.SelectBox.1.0.1.js" type="text/javascript"></script>
# <script charset="euckr" language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindoComponent/jindo.TextRange.1.0.1.js" type="text/javascript"></script>
# <script charset="euckr" language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindoComponent/jindo.WatchInput.1.0.1.js" type="text/javascript"></script>
# <script charset="euckr" language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindoComponent/jindo.Formatter.1.1.0.js" type="text/javascript"></script>
# <script charset="euckr" language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindoComponent/jindo.NumberFormatter.1.0.1.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/exchange.js" type="text/javascript"></script>
# <script type="text/javascript">
# // exchangeDetail.jsp에도 동일 스크립트 있음 - 로딩시 디자인이 0.5초간 디자인이 안뜬다는 이슈로 include하지 않고 같은 스크립트를 두벌로 관리함
#
# //환율 계산
# function calcExchange(str1, str2, cssOn, event) {
# 	var oEvent = event || window.event;
#     var sKeyCode = (undefined === oEvent) ? undefined : jindo.$Event(oEvent).key().keyCode;
#
# 	if (sKeyCode != 13 && sKeyCode != 27 && sKeyCode != 37 && sKeyCode != 38 && sKeyCode != 110 && sKeyCode != 229) {
# 		if (str1 == '' && str2 == '') {
# 			if (jindo.$('input_to').className == 'input_area') {
# 				str1 = 'from';
# 				str2 = 'to';
# 			} else {
# 				str1 = 'to';
# 				str2 = 'from';
# 			}
# 		}
#
# 		var regExp = new RegExp("[^0-9\.\,]");
# 	    var sInputValue = jindo.$('input_' + str1 + '_money').value;
#
# 	    if(regExp.test(sInputValue)){
# 			alert('숫자, 소수점(.)만 입력하실 수 있습니다.');
# 			jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 			return false;
# 		}
#
# 		// 사용자가 입력한 콤마(,) 제거
# 	    if (sInputValue.substr(sInputValue.length - 1, 1) == ',') {
# 	    	jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 	    	return false;
# 	    }
#
# 		// 맨 앞에 있는 숫자 0 없애기
# 		if (sInputValue == '0' || sInputValue == '.' || sInputValue == ',') {
# 			jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 			return false;
# 		}
#
# 		// 소수점 2개가 없도록
# 		var match = sInputValue.match(/\./g);
# 		if (match != null && match.length >= 2) {
# 			jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 			return false;
# 		}
#
# 		// 소수점을 입력한 경우, 일단 대기
# 		var pointPosIndex = sInputValue.indexOf('.');
# 		if (pointPosIndex != -1 && pointPosIndex == sInputValue.length - 1) {
# 			return false;
# 		}
#
# 		// 소수점 2자리 유지
# 		if (pointPosIndex != -1 && sInputValue.substring(pointPosIndex + 1, sInputValue.length).length > 2) {
# 			jindo.$('input_' + str1 + '_money').value = revertInputText(sInputValue);
# 			return false;
# 		}
#
# 		var e_select_from	= jindo.$('select_'+str1);
# 		var e_select_to	= jindo.$('select_'+str2);
#
# 		var input_from_money	= jindo.$('input_'+str1+'_money').value ;
# 		var input_from		= e_select_from.options[e_select_from.selectedIndex].value ;
# 		var input_to		= e_select_to.options[e_select_to.selectedIndex].value ;
# 		var unit_from	= e_select_from.options[e_select_from.selectedIndex].text ;
# 		var unit_to		= e_select_to.options[e_select_to.selectedIndex].text ;
# 		input_from_money = input_from_money.replace(/ |,|\t/g, "") ;
# 		input_from	= input_from.replace(/ |,|\t/g, "") ;
# 		input_to	= input_to.replace(/ |,|\t/g, "") ;
# 		unit_from = unit_from.substr(unit_from.length-3, 3);
# 		unit_to = unit_to.substr(unit_to.length-3, 3);
#
# 		var str1_result = input_from_money * 1 ;
# 		var str1_str	= str1_result.toFixed(0) ;
# 		var str1_len = str1_str.length ;
# 		var str1_result_str = new String("") ;
#
# 		if(str1_str > str1_result)
# 			str1_str = new String(str1_str-1) ;
#
# 		if (str1_len >= 3) {
# 			for (i = str1_len - 3; i > 0; i-=3)
# 				str1_result_str = "," + str1_str.substr(i, 3) + str1_result_str ;
#
# 			str1_result_str = str1_str.substr(0, 3+i) + str1_result_str ;
#
# 			for (var i=0; i<input_from_money.length; i++) {
# 				if (input_from_money.substr(i,1) != '0') {
# 					input_from_money = input_from_money.substring(i,input_from_money.length) ;
# 					break;
# 				}
# 			}
#
# 			if (str1_str != input_from_money) {
# 				str1_result_str += str1_result.toFixed(input_from_money.split(".")[1].length).substr(str1_len, input_from_money.split(".")[1].length + 1) ;
# 			}
# 		} else
# 			str1_result_str = input_from_money ;
#
# 		var str2_result = input_from_money * input_from / input_to ;
# 		var str2_str	= str2_result.toFixed(0) ;
# 		var str2_len = str2_str.length ;
# 		var str2_result_str = new String("") ;
#
# 		if (str2_str > str2_result)
# 			str2_str = new String(str2_str-1) ;
#
# 		if (str2_len >= 3) {
# 			for (i = str2_len - 3; i > 0; i-=3)
# 				str2_result_str = "," + str2_str.substr(i, 3) + str2_result_str ;
#
# 			str2_result_str = str2_str.substr(0, 3+i) + str2_result_str ;
# 			str2_result_str += str2_result.toFixed(2).substr(str2_len, 3) ;
# 		} else
# 			str2_result_str = str2_result.toFixed(2) ;
#
# 		jindo.$('input_'+str1+'_money').value = str1_result_str;
# 		jindo.$('input_'+str2+'_money').value = str2_result_str;
# 		jindo.$('img_'+str1+'_monetary').src = "https://ssl.pstatic.net/static/nfinance/img_money_"+unit_from+".gif";
# 		jindo.$('img_'+str2+'_monetary').src = "https://ssl.pstatic.net/static/nfinance/img_money_"+unit_to+".gif";
# 		jindo.$Element(jindo.$('input_'+str1)).addClass("on");
# 		jindo.$Element(jindo.$('input_'+str2)).removeClass("on");
# 		if (cssOn == "off"){
# 			jindo.$Element(jindo.$('input_'+str1)).removeClass("on");
# 		}
# 	}
# }
#
# function revertInputText(sOrgText) {
# 	var sResult = sOrgText;
#
# 	if (sOrgText != '') {
# 		sResult = sOrgText.substr(0, sOrgText.length - 1);
# 	}
#
# 	return sResult;
# }
#
# jindo.$Fn(function(){
# 	chartMouseOverEvent('exchangeList');
#    }).attach(document, "domready");
# </script>
# </div>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/jindo_ellipse.js"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/util.js"></script>
# <script type="text/javascript">
#
# function ellipseTopNewsTitle() {
# 	jindo.EllipseText.factory(jindo.$$(".news_list ul li"), {nAssistWidth: 10});
# }
#
# var basicDates;
#
# function initDate() {
# 	basicDates = jindo.$H();
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# 	basicDates.add('', '');
# }
#
# var basicDescriptions;
#
# function initDescription() {
# 	basicDescriptions = jindo.$H();
# 	basicDescriptions.add('CMDT_CDY','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_PDY','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_NG','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_S','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_C','<em></em>  기준<span>단위:</span>');
# 	basicDescriptions.add('CMDT_SB','<em></em>  기준<span>단위:</span>');
# }
#
# function setEvent(num, imgChartUrl){
# 	var parentElemnt = jindo.$$('.tbl_market')[num];
# 	var elementList = jindo.$$('tr',parentElemnt);
#
# 	jindo.$Fn(function(e){
# 		var elementListSize = elementList.length;
#
# 		for(var i = 0 ; i < elementListSize ; i ++)
# 		{
# 			var selectedElement = jindo.$Element(elementList[i]);
# 			var selectedClassName = selectedElement.className();
# 			if (selectedClassName != "") {
# 				selectedElement.removeClass(selectedClassName);
# 				selectedElement.addClass(selectedClassName.replace("on",""));
# 			}
# 		}
#
# 		var ele = jindo.$Element(jindo.$Event(e).currentElement);
# 		var linkUrl = jindo.$$.getSingle('a' , ele.$value()).href;
# 		var marketindexCd = linkUrl.split('=')[1];
# 		var className = ele.className();
# 		ele.removeClass(className);
# 		ele.addClass(className+" on");
# 		var graphElement = jindo.$Element(jindo.$$('.thum')[num]);
# 		graphElement.html('<a href=\"'+linkUrl+'\"><img src=\"https://ssl.pstatic.net/imgfinance/chart/marketindex/' + marketindexCd + '.png\" width=\"295\" height=\"153\" alt=""></a>');
#
# 		if (basicDates.hasKey(marketindexCd)) {
# 			jindo.$Element("basicDate").text(basicDates.$(marketindexCd));
# 		}
# 		if (basicDescriptions.hasKey(marketindexCd)) {
# 			jindo.$Element("basicDescription").html(basicDescriptions.$(marketindexCd));
# 		}
#
# 	}).attach(elementList, "mouseover");
# }
#
# jindo.$Fn(function(){
# 		initDate();
# 		initDescription();
# 		chartMouseOverEvent('exchangeList');
# 		chartMouseOverEvent('worldExchangeList');
# 		chartMouseOverEvent('oilGoldList');
# 		jindo.$$('title')[0].innerHTML = "시장지표 : 네이버 증권";
# }).attach(document, "domready");
#
# </script>
# <div class="aside" id="marketindex_aside">
# <div class="section_aside">
# <h3 class="h_interest"><span>국내시장금리</span></h3>
# <table class="tbl_exchange market" summary="국제시장 환율 리스트">
# <caption>국내시장금리</caption>
# <colgroup>
# <col width="94"/>
# <col width="50"/>
# <col width="75"/>
# </colgroup>
# <thead>
# <tr>
# <th>구분</th>
# <th>금리</th>
# <th>등락율</th>
# </tr>
# </thead>
# <tbody>
# <tr class="up">
# <th class="th_inter4"><a href="/marketindex/interestDetail.naver?marketindexCd=IRR_CD91" onclick="clickcr(this, 'rid.local', 'IRR_CD91', '1', event);"><span>CD금리(91일)</span></a></th>
# <td>3.53</td>
# <td><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 0.01</td>
# </tr>
# <tr class="up">
# <th class="th_inter1"><a href="/marketindex/interestDetail.naver?marketindexCd=IRR_CALL" onclick="clickcr(this, 'met.8', 'IRR_CALL', '2', event);"><span>콜 금리</span></a></th>
# <td>3.54</td>
# <td><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 0.06</td>
# </tr>
# <tr class="up">
# <th class="th_inter2"><a href="/marketindex/interestDetail.naver?marketindexCd=IRR_GOVT03Y" onclick="clickcr(this, 'met.8', 'IRR_GOVT03Y', '3', event);"><span>국고채 (3년)</span></a></th>
# <td>3.33</td>
# <td><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 0.04</td>
# </tr>
# <tr class="up">
# <th class="th_inter3"><a href="/marketindex/interestDetail.naver?marketindexCd=IRR_CORP03Y" onclick="clickcr(this, 'met.8', 'IRR_CORP03Y', '4', event);"><span>회사채 (3년)</span></a></th>
# <td>4.14</td>
# <td><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 0.04</td>
# </tr>
# <tr class="up">
# <th class="th_inter5"><a href="/marketindex/interestDetail.naver?marketindexCd=IRR_COFIXBAL" onclick="clickcr(this, 'met.8', 'IRR_COFIXBAL', '5', event);"><span>COFIX 잔액</span></a></th>
# <td>3.71</td>
# <td><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 0.04</td>
# </tr>
# <tr class="up">
# <th class="th_inter6"><a href="/marketindex/interestDetail.naver?marketindexCd=IRR_COFIXNEW" onclick="clickcr(this, 'met.8', 'IRR_COFIXNEW', '6', event);"><span>COFIX 신규취급액</span></a></th>
# <td>3.56</td>
# <td><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 0.03</td>
# </tr>
# </tbody>
# </table>
# <table class="tbl_exchange tbl_exchange_v1 market" style="margin-top:10px;" summary="달러 인덱스">
# <caption>달러 인덱스</caption>
# <colgroup>
# <col width="88"/>
# <col width="46"/>
# <col width="66"/>
# </colgroup>
# <thead>
# <tr>
# <th>구분</th>
# <th>금리</th>
# <th>등락율</th>
# </tr>
# </thead>
# <tbody>
# <tr class="other_t1 up">
# <th class="th_inter7"><a href="/marketindex/worldExchangeDetail.naver?marketindexCd=FX_USDX&amp;fdtc=4" onclick="clickcr(this, 'rid.dollar', 'FX_USDX', '', event);"><span>달러 인덱스</span></a></th>
# <td>101.9200</td>
# <td><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 0.5200</td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="section_aside">
# <div class="tab_search search3">
# <a href="#" onclick="clickcr(this, 'rch.1', '', '', event); return false;"><span>최근조회</span></a>
# <a href="#" onclick="clickcr(this, 'rch.3', '', '', event); return false;"><span>MY STOCK</span></a>
# </div>
# <h3 class="blind">최근조회</h3>
# <table class="tbl_search" summary="최근조회 리스트">
# <caption>최근조회</caption>
# <colgroup>
# <col/>
# <col width="55"/>
# <col width="87"/>
# </colgroup>
# <thead>
# <tr>
# <th>업체명</th>
# <th>거래량</th>
# <th>전일비</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
# <div class="more_info">
# <span>
# <a href="#" onclick="clickcr(this, 'rch.5', '', '', event); return false;"><img alt="이전" height="15" src="https://ssl.pstatic.net/static/nfinance/btn_prev2.gif" width="17"/></a>
# <a href="#" onclick="clickcr(this, 'rch.6', '', '', event); return false;"><img alt="다음" height="15" src="https://ssl.pstatic.net/static/nfinance/btn_next2.gif" width="17"/></a>
# </span>
# <a class="btn_more _mystock_more_info" href="#" onclick="javascript:openMyitemNew('https://finance.naver.com'); clickcr(this, 'rch.7', '', '', event);"><img alt="더보기" height="10" src="https://ssl.pstatic.net/static/nfinance/btn_more5.gif" width="33"/></a>
# </div>
# </div>
# <div class="section_aside">
# <h3 class="h_report"><span>경제분석 리포트 </span></h3>
# <ul class="list_report">
# <li><a href="/research/economy_read.naver?nid=8595" onclick="clickcr(this, 'rer.list', '', '', event);">마지막 인상이 될까?</a></li>
# <li><a href="/research/economy_read.naver?nid=8594" onclick="clickcr(this, 'rer.list', '', '', event);">미 근원 PCE 데이터에 대한 냉...</a></li>
# <li><a href="/research/economy_read.naver?nid=8593" onclick="clickcr(this, 'rer.list', '', '', event);">4월 한국 수출: 아직은 미약한 ...</a></li>
# <li><a href="/research/economy_read.naver?nid=8592" onclick="clickcr(this, 'rer.list', '', '', event);">물가안정과 금융안정이 서로 만났을...</a></li>
# <li><a href="/research/economy_read.naver?nid=8591" onclick="clickcr(this, 'rer.list', '', '', event);">한국 수출 경기는 저점을 지나가는...</a></li>
# </ul>
# <a class="btn_more" href="/research/economy_list.naver" onclick="clickcr(this, 'rer.more', '', '', event);"><img alt="경제분석 리포트 더보기" height="18" src="https://ssl.pstatic.net/static/nfinance/btn_more.gif" width="34"/></a>
# </div>
# </div>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/info/myStock.js" type="text/javascript"></script>
# <script language="javascript" src="https://ssl.pstatic.net/imgstock/static.pc/20230426171159/js/util.js" type="text/javascript"></script>
# <script language="javascript">
#
# function toggleTabSearch(e){
# 	var currentElement = jindo.$Element(jindo.$Event(e).currentElement);
# 	var parentElement = currentElement.parent();
# 	var id = currentElement.className();
# 	var order = parentElement.indexOf(currentElement) + 3;
# 	parentElement.className("tab_search search"+ order);
#
# 	// 페이징을 위해서 order값에 따라 최근조회인지 mystock인지 type을 저장
# 	if (order == 3) {
# 		currentType = "recent";
# 	} else {
# 		currentType = "mystock";
# 	}
# }
#
# jindo.$Fn(function(){
# 	if ('true' == 'true') {
# 		getStockRightMenuData('000000', 'recent', 1, 'https://finance.naver.com', 'https://ssl.pstatic.net/static/nfinance');
#
# 		var tabSearchArea = jindo.$$.getSingle('.tab_search');
# 		var moreInfoArea = jindo.$Element(jindo.$$.getSingle('.tbl_search')).next().$value();
#
# 		jindo.$Fn(function(e) {toggleTabSearch(e); getStockRightMenuData('000000', 'recent', 1, 'https://finance.naver.com', 'https://ssl.pstatic.net/static/nfinance'); }).attach(jindo.$$.getSingle('a' ,tabSearchArea), 'click');
# 		jindo.$Fn(function(e) {toggleTabSearch(e); getStockRightMenuData('000000', 'mystock', 1, 'https://finance.naver.com', 'https://ssl.pstatic.net/static/nfinance'); }).attach(jindo.$$('a' ,tabSearchArea)[1], 'click');
# 		jindo.$Fn(function(e) {updatePageForPaging (currentType, 'up', 'https://finance.naver.com', 'https://ssl.pstatic.net/static/nfinance'); }).attach(jindo.$$.getSingle('a', moreInfoArea), 'click');
# 		jindo.$Fn(function(e) {updatePageForPaging (currentType, 'down', 'https://finance.naver.com', 'https://ssl.pstatic.net/static/nfinance'); }).attach(jindo.$$('a', moreInfoArea)[1], 'click');
# 	}
#
# }).attach(document,"domready");
#
# function openMyitemNew(stockHost) {
# 	var selectedElement = jindo.$Element(jindo.$$.getSingle(".tab_search"));
# 	if (selectedElement != null) {
# 		if (selectedElement.hasClass("search1")) {
# 			document.location.href = stockHost + '/mystock/recentSearchItemList.naver';
# 		} else {
# 			document.location.href = stockHost + '/mystock/itemList.naver';
# 		}
# 	}
# }
#
# </script>
# </div>
# <div id="footer">
# <ul>
# <li class="first">
# <a href="https://new-m.pay.naver.com/member/terms-policy/naver-financial-service" onclick="clickcr(this, 'fot.service', '', '', event);" target="_blank">이용약관</a>
# </li>
# <li>
# <a href="https://new-m.pay.naver.com/member/terms-policy/privacy" onclick="clickcr(this, 'fot.privacy', '', '', event);" target="_blank"><strong>개인정보처리방침</strong></a>
# </li>
# <li>
# <a href="/rules.naver" onclick="clickcr(this, 'fot.policy', '', '', event);" target="_blank">게시판 운영원칙</a>
# </li>
# <li>
# <a href="https://help.naver.com/service/5617/category/bookmark?lang=ko" onclick="clickcr(this, 'fot.help', '', '', event);" target="_blank">증권 고객센터</a>
# </li>
# </ul>
# <p class="desc">
# 		네이버파이낸셜(주)이 제공하는 금융 정보는 <a class="desc_help" href="javascript:;" onclick="togglePanelFooter('footerPanel0');">콘텐츠 제공업체</a>로부터 받는 투자 참고사항이며, 오류가 발생하거나 지연될 수 있습니다.<br/>
# 		네이버파이낸셜(주)과 콘텐츠 제공업체는 제공된 정보에 의한 투자 결과에 법적인 책임을 지지 않습니다. 게시된 정보는 무단으로 배포할 수 없습니다.
# 	</p>
# <div class="provider_layer" id="footerPanel0" onblur="hidePannel('footerPanel0')" style="display:none" tabindex="0">
# <strong class="provider_layer__tit">네이버파이낸셜에 콘텐츠 제공</strong>
# <div class="provider_layer__txt">
# <strong>에프앤가이드</strong> 기업 및 재무정보<br/>
# <strong>KG제로인</strong> 해외 시세, 시장지표 정보<br/>
# <strong>한국예탁결제원</strong> 주주총회일, 전자투표 정보<br/>
# <strong>인포스탁</strong> 국내 테마 정보
# 		</div>
# <div class="provider_layer__info">
# <strong class="provider_layer__tit">네이버에 콘텐츠 제공</strong>
# <div class="provider_layer__txt">
# <strong>코스콤</strong> 국내 시세 정보
# 			</div>
# </div>
# <button class="button_close" onclick="hidePannel('footerPanel0')" type="button">
# <img alt="닫기" height="20" src="https://ssl.pstatic.net/static/nfinance/2022/footer_close.png" width="20"/>
# </button>
# </div>
# <address>
# <a class="logo" href="https://www.naverfincorp.com/" onclick="clickcr(this, 'fot.nhn', '', '', event);" target="_blank"><img alt="NAVER FINANCIAL" height="12" src="https://ssl.pstatic.net/static/nfinance/img/logo_financial.png" width="160"/></a>
# </address>
# </div>
# <script type="text/javascript">
# function isVisible(obj) {
#     if (obj == document) return true
#
#     if (!obj) return false
#     if (!obj.parentNode) return false
#     if (obj.style) {
#         if (obj.style.display == 'none') return false
#         if (obj.style.visibility == 'hidden') return false
#     }
#
#     if (window.getComputedStyle) {
#         var style = window.getComputedStyle(obj, "")
#         if (style.display == 'none') return false
#         if (style.visibility == 'hidden') return false
#     }
#
#     var style = obj.currentStyle
#     if (style) {
#         if (style['display'] == 'none') return false
#         if (style['visibility'] == 'hidden') return false
#     }
#
#     return isVisible(obj.parentNode)
# }
#
# function isChildOf(myobj, containerObj) {
# 	while(myobj != undefined) {
# 		if (myobj == document.body) {
# 			break;
# 		}
# 		if (myobj == containerObj) {
# 			return true;
# 		}
# 		myobj = myobj.parentElement;
# 	}
# 	return false;
# }
#
# function gnbLayerClose(e){
# 	var target = e.target ? e.target : e.srcElement;
# 	if (isVisible(document.getElementById('gnb_service_lyr')) || isVisible(document.getElementById('gnb_notice_lyr')) ||isVisible(document.getElementById('gnb_my_lyr')) ) {
# 		if (!isChildOf(target, document.getElementById('gnb'))) {
# 			gnbAllLayerClose();
# 		}
# 	}
# }
#
# function showPannel(layerId){
# 	var layer = jindo.$(layerId);
# 	layer.style.display='block';
#
# 	if (layerId == "summary_lyr") {
# 		var layerHeight = jindo.$Element(layer).height();
# 		jindo.$Element("summary_ifr").height(layerHeight);
# 	}
# }
#
# function hidePannel(layerId){
# 	var layer = jindo.$(layerId);
# 	layer.style.display='none';
# }
#
# function togglePanelFooter(layerId) {
# 	var elTargetLayer = jindo.$Element(jindo.$$.getSingle("#" + layerId));
#
# 	if (elTargetLayer != null) {
# 		if (elTargetLayer.visible()) {
# 			hidePannel(layerId);
# 		} else {
# 			showPannel(layerId);
# 		}
# 	}
# }
#
# var isIE = (navigator.userAgent.toLowerCase().indexOf("msie")!=-1 && window.document.all) ? true:false;
# if (isIE) {
# 	document.attachEvent('onmousedown', gnbLayerClose);
# } else {
# 	window.addEventListener('mousedown', gnbLayerClose);
# }
# </script>

# %% [markdown]
# #### 과제(1): 'https://news.naver.com/'에서 title내용을 3가지 방법으로 출력하세요

# %%
url = 'https://news.naver.com/'
html = requests.get(url).text
bs = BS(html, 'html.parser')

print(bs.title.text)
print(bs.find('title').text)
print(bs.select_one('title').text)
# Out:
# 네이버 뉴스
# 네이버 뉴스
# 네이버 뉴스

# %% [markdown]
# #### 과제(2): 'https://news.naver.com'에서 span태그에 연결된 한글만 불필요한 공백을 제거해 출력하세요

# %%
url = 'https://news.naver.com'
html = requests.get(url).text
bs = BS(html, 'html.parser')
text=''

for i in bs.find_all('span'):
    text = text +' ' + ' '.join(re.findall('[가-힣]+',i.text))
    
print(text)
# Out:
#    뉴스 연예 연예 스포츠 스포츠 날씨 날씨 프리미엄 프리미엄 검색 언론사별 정치 경제 사회 생활 문화 과학 세계 랭킹 신문보기 오피니언  팩트체크 화 언론사편집 기자 연재  속보 속보 닫기 월 일 동영상 재생시간 재생시간 재생시간 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 동영상 재생시간 재생시간 재생시간 월 일 월 일 동영상 재생시간 재생시간 재생시간 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 동영상 재생시간 재생시간 재생시간 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 동영상 재생시간 재생시간 재생시간 월 일 월 일 월 일 동영상 재생시간 재생시간 재생시간 월 일 월 일 동영상 재생시간 재생시간 재생시간 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 동영상 재생시간 재생시간 재생시간 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 월 일 신문 면 모아보기 방송뉴스 도움말 닫기 언론사별 심층기획  월 일 뉴시스 월 일 더스쿠프 월 일 언론사별 심층기획 매경이코노미 월 일 조선비즈 월 일 전자신문 월 일 언론사별 심층기획  월 일 부산일보 월 일 연합뉴스 월 일 언론사별 심층기획 광주방송 월 일 헤럴드경제 월 일 한국경제 월 일 언론사별 심층기획 더팩트 월 일 디지털타임스 월 일  월 일 언론사별 심층기획 헬스조선 월 일 서울신문 월 일 서울경제 월 일 언론사별 심층기획 미디어오늘 월 일 시사 월 일 동아일보 월 일 언론사별 심층기획 한국일보 월 일 조선일보 월 일 코리아헤럴드 월 일 언론사별 심층기획  월 일 강원일보 월 일 오마이뉴스 월 일 언론사별 심층기획 경기일보 월 일  월 일 노컷뉴스 월 일 언론사별 심층기획 매일신문 월 일 한겨레 월 일 국민일보 월 일 언론사별 심층기획 문화일보 월 일 국제신문 월 일 연합뉴스 월 일 언론사별 심층기획 코메디닷컴 월 일  월 일  월 일 언론사별 심층기획 경향신문 월 일 뉴스타파 월 일 한국경제 월 일 언론사별 심층기획 동아사이언스 월 일 청주방송 월 일 대전일보 월 일 언론사별 심층기획 블로터 월 일 머니투데이 월 일 머니 월 일 언론사별 심층기획 한겨레 월 일 중앙일보 월 일 주간조선 월 일 언론사별 심층기획 비즈워치 월 일 신동아 월 일 세계일보 월 일 언론사별 심층기획 이코노미스트 월 일 주간동아 월 일 강원도민일보 월 일 언론사별 심층기획 데일리안 월 일 코리아중앙데일리 월 일 농민신문 월 일 언론사별 심층기획 프레시안 월 일 디지털데일리 월 일 조선 월 일 언론사별 심층기획 전주 월 일 아시아경제 월 일 아이뉴스 월 일 언론사별 심층기획 이데일리 월 일 파이낸셜뉴스 월 일  월 일 언론사별 심층기획 매일경제 월 일 한경비즈니스 월 일 대구 월 일 언론사별 심층기획 여성신문 월 일 뉴스 월 일 채널 월 일 내가 구독한 기자 개 개 기자를 구독해보세요 도움말 닫기   구독 그림 장사 잘하는 페 사장 한국 정면조준 구독 빚 많아져 요금 올려야 한다 던 가스공사 임원들 연봉 올랐다 구독 마지막에 돌아선 이의 죄명은 자살방조 처벌 너머 치료 필요하다 구독 충남 아산 공영주차장서 대 공무원 숨진 채 발견 구독 그 대학가긴 네가 너무 섹시하지 서 대학 낙방 파티 유행 구독 내 고장 무공훈장 영웅 찾기 캠페인 적극 동참 구독 와 일자리 경쟁보다 더 무서운 것 구독 기시다 일 방한 조율 한일관계 가속 논의 구독 워싱턴 선언 에 기시다 답방 당겨지나 일본 관계개선 필요성 재평가 구독 바스프에 재생에너지로 생산된 전기 공급한다 구독 입국 코로나 백신접종 증명 없앤다 구독 윤재옥 간호법 반대 단식 단체 만나 방법 찾겠다 구독 결성 년 되는 에어로 스미스 드디어 고별 투어 나섭니다 구독 데뷔를 조건으로 한 다이어트 죽음 앞두고서야 멈췄다 구독 민주 외교 실패 총리 방한 북한 여론전 구독 기준금리 어찌될까 숨죽인 시장 다우존스 구독 가습기살균제 심서 최신 연구 증거 채택 스모킹건 될까 구독 전세사기 특별법 논의 불발 피해자 기준 입장 차 구독 식물도 따라 맞춤 처방해야 애정 과하면 탈나요 구독 년 만에 엘니뇨 습격 올여름 폭우 잦아진다 내가 구독한 연재 개 개 연재를 구독해보세요 도움말 닫기    이상직 변호사의 디지털 창세기 전자신문 시간전 구독 왕비의 거울 과 등 인공지능  우보세 머니투데이 시간전 구독 삼성전자는 꽃길 만 걷지 않았다  나우 어스 헤럴드경제 시간전 구독 먹지마세요 외쳤지만 살아있는 금붕어 꿀꺽  역사 속의 문화일보 일전 구독 고통받는 어린이와 함께한 시간 행복 헵번 헌신의 삶  박성태의 다시보기  시간전 구독 피해자가 아니라 손해자일 뿐  모닝브리핑 한국경제 시간전 구독 은행 파산 여파 증시 소폭하락 최저임금위 첫 전원회의  필동정담 매일경제 시간전 구독 비상용품 태극기  싸움 헤럴드경제 시간전 구독 방미 효과에 지지율 반등 모멘텀 상승세로 이어질까  횡설수설 동아일보 시간전 구독 위안화 파워 대외 결제서 달러 첫 추월  인사이드 인사이트 동아일보 시간전 구독 전횡 막아야 대통령 거부권은 독선 악순환   한국일보 시간전 구독 선택적 엄벌주의  윤희영의 조선일보 시간전 구독 미국 대통령이어서 할 수 없는 것들  포토 이슈 서울신문 시간전 구독 오늘 근로자의 날 누군가에게는 추웠던 출근길  올댓차이나 뉴시스 시간전 구독 월 신축주택 가격 도시 수요 증가  경기시론 경기일보 시간전 구독 또 하나의 약속 관심있는 언론사를 더 구독해보세요 이용약관 개인정보처리방침 청소년 보호 책임자 이희만 서비스안내 이용약관 개인정보처리방침 청소년 보호 책임자 이희만 서비스안내 각 언론사가 직접 콘텐츠를 편집합니다

# %% [markdown]
# #### 과제(3): 'https://news.naver.com'에서 span 태그에 연결된 문자/숫자를 불필요한 공백을 제거한 후 출력

# %%
url = 'https://news.naver.com/'
html = requests.get(url).text
bs = BS(html, 'html.parser')
text=[]

for i in bs.find_all('span'):
    print(' '.join(re.findall('\w+',i.text)), end=' ')
# Out:
# NAVER NAVER 뉴스 연예 연예 스포츠 스포츠 날씨 날씨 프리미엄 프리미엄 검색 언론사별 정치 경제 사회 생활 문화 IT 과학 세계 랭킹 신문보기 오피니언 TV 팩트체크 화 언론사편집 기자 연재  속보 속보 닫기 05월 02일 10 05 05월 02일 10 02 05월 02일 10 04 05월 02일 08 59 05월 02일 09 15 05월 02일 08 39 05월 01일 22 32 동영상 재생시간00 23 재생시간00 23 재생시간 05월 02일 10 03 05월 02일 08 08 05월 02일 09 11 05월 02일 10 03 05월 02일 09 52 05월 02일 09 56 05월 02일 10 02 05월 02일 09 24 동영상 재생시간00 40 재생시간00 40 재생시간 05월 02일 09 13 05월 02일 10 00 05월 01일 18 17 05월 02일 08 56 05월 02일 09 51 동영상 재생시간02 27 재생시간02 27 재생시간 05월 02일 09 48 05월 02일 10 00 05월 02일 10 05 05월 02일 10 07 05월 02일 10 07 05월 02일 10 03 05월 02일 09 30 05월 02일 10 03 05월 02일 08 59 05월 02일 09 48 05월 02일 10 02 05월 02일 10 07 05월 01일 13 35 05월 02일 10 06 05월 02일 09 58 동영상 재생시간06 37 재생시간06 37 재생시간 05월 02일 10 06 05월 02일 09 55 05월 02일 10 05 05월 02일 10 07 05월 01일 17 58 05월 02일 09 27 05월 02일 09 59 05월 02일 10 03 05월 02일 09 57 동영상 재생시간01 17 재생시간01 17 재생시간 05월 02일 08 07 05월 02일 06 36 05월 02일 09 48 05월 02일 10 07 05월 02일 10 07 05월 02일 06 16 05월 02일 10 03 05월 02일 09 38 05월 02일 08 40 05월 02일 07 35 05월 02일 10 00 05월 02일 10 05 05월 02일 10 04 05월 02일 09 36 05월 01일 23 59 05월 02일 09 17 05월 02일 10 08 05월 02일 09 51 05월 02일 10 04 05월 02일 10 04 동영상 재생시간01 32 재생시간01 32 재생시간 05월 02일 10 06 05월 02일 09 17 05월 02일 10 07 05월 01일 12 30 05월 02일 10 04 05월 02일 10 07 05월 02일 10 05 05월 02일 09 58 동영상 재생시간01 35 재생시간01 35 재생시간 05월 02일 09 51 05월 02일 10 05 05월 01일 20 31 05월 02일 09 49 05월 02일 09 42 04월 28일 13 40 05월 02일 10 08 05월 02일 09 49 05월 02일 09 40 동영상 재생시간08 09 재생시간08 09 재생시간 05월 02일 08 57 신문1면 모아보기 방송뉴스 도움말 닫기 언론사별 심층기획 미디어오늘 05월 02일 07 27 전주MBC 05월 02일 08 49 MBC 05월 02일 10 04 언론사별 심층기획 서울경제 05월 01일 19 12 농민신문 05월 02일 06 28 주간조선 05월 01일 13 34 언론사별 심층기획 SBS 05월 01일 10 56 아이뉴스24 05월 02일 08 32 대구MBC 05월 02일 08 07 언론사별 심층기획 국제신문 05월 02일 08 53 CJB청주방송 05월 02일 07 55 동아일보 05월 02일 10 04 언론사별 심층기획 한경비즈니스 05월 01일 09 35 한겨레 05월 01일 20 46 코리아헤럴드 05월 02일 10 05 언론사별 심층기획 연합뉴스 05월 02일 10 01 한국경제 05월 02일 09 18 매경이코노미 04월 28일 08 42 언론사별 심층기획 디지털데일리 05월 01일 23 38 TV조선 05월 01일 22 41 국민일보 05월 02일 09 01 언론사별 심층기획 헤럴드경제 05월 02일 08 56 세계일보 05월 02일 09 52 전자신문 05월 02일 09 05 언론사별 심층기획 머니투데이 05월 02일 04 16 뉴스타파 04월 25일 14 55 강원도민일보 04월 30일 16 15 언론사별 심층기획 한국경제TV 05월 02일 09 25 YTN 05월 02일 05 48 비즈워치 05월 01일 12 56 언론사별 심층기획 이데일리 05월 02일 09 27 강원일보 05월 02일 09 05 문화일보 05월 02일 06 16 언론사별 심층기획 경향신문 05월 01일 19 09 뉴스1 05월 02일 09 19 노컷뉴스 04월 30일 15 46 언론사별 심층기획 헬스조선 05월 02일 09 41 JTBC 05월 02일 06 59 시사IN 05월 02일 07 34 언론사별 심층기획 매일신문 05월 02일 07 39 코메디닷컴 05월 02일 08 07 MBN 05월 02일 09 16 언론사별 심층기획 kbc광주방송 04월 29일 07 42 한국일보 05월 02일 10 00 뉴시스 05월 02일 08 25 언론사별 심층기획 파이낸셜뉴스 05월 01일 21 12 데일리안 05월 02일 09 38 부산일보 05월 02일 08 39 언론사별 심층기획 경기일보 05월 02일 09 19 채널A 05월 01일 13 17 서울신문 05월 02일 10 05 언론사별 심층기획 SBS Biz 05월 02일 09 48 중앙일보 05월 02일 06 26 더스쿠프 05월 02일 09 37 언론사별 심층기획 대전일보 04월 28일 17 36 프레시안 04월 28일 16 24 코리아중앙데일리 04월 26일 22 32 언론사별 심층기획 이코노미스트 05월 02일 09 25 동아사이언스 05월 01일 12 16 블로터 04월 25일 17 59 언론사별 심층기획 연합뉴스TV 05월 01일 22 04 조선비즈 05월 02일 07 28 아시아경제 05월 02일 10 01 언론사별 심층기획 신동아 04월 30일 17 20 디지털타임스 05월 01일 09 13 더팩트 05월 01일 14 25 언론사별 심층기획 주간동아 05월 01일 10 20 오마이뉴스 05월 01일 21 57 KBS 05월 01일 21 13 언론사별 심층기획 조선일보 05월 02일 09 39 여성신문 05월 01일 08 07 매일경제 05월 01일 22 44 언론사별 심층기획 한겨레21 05월 01일 16 39 JIBS 05월 02일 10 07 머니S 05월 01일 17 00 내가 구독한 기자0개 개 기자를 구독해보세요 도움말 닫기   구독 민주 외교 실패 총리 방한 북한 여론전 구독 충남 아산 공영주차장서 30대 공무원 숨진 채 발견 구독 기준금리 어찌될까 숨죽인 시장 다우존스 0 14 구독 데뷔를 조건으로 한 다이어트 죽음 앞두고서야 멈췄다 구독 SK E S 바스프에 재생에너지로 생산된 전기 공급한다 구독 가습기살균제 2심서 최신 연구 증거 채택 스모킹건 될까 구독 결성 53년 되는 에어로 스미스 드디어 고별 투어 나섭니다 구독 마지막에 돌아선 이의 죄명은 자살방조 처벌 너머 치료 필요하다 구독 전세사기 특별법 논의 불발 피해자 기준 입장 차 구독 그림 장사 잘하는 페 사장 한국 정면조준 구독 AI와 일자리 경쟁보다 더 무서운 것 구독 빚 많아져 요금 올려야 한다 던 가스공사 임원들 연봉 30 올랐다 구독 워싱턴 선언 에 기시다 답방 당겨지나 일본 관계개선 필요성 재평가 구독 美 입국 코로나 백신접종 증명 없앤다 구독 내 고장 무공훈장 영웅 찾기 캠페인 적극 동참 구독 기시다 7 8일 방한 조율 한일관계 가속 논의 구독 식물도 MBTI 따라 맞춤 처방해야 애정 과하면 탈나요 구독 與 윤재옥 간호법 반대 단식 단체 만나 방법 찾겠다 구독 3년 만에 엘니뇨 습격 올여름 폭우 잦아진다 구독 그 대학가긴 네가 너무 섹시하지 美서 대학 낙방 파티 유행 내가 구독한 연재0개 개 연재를 구독해보세요 도움말 닫기    우보세 머니투데이 5시간전 구독 삼성전자는 꽃길 만 걷지 않았다  36 5 C 한국일보 5시간전 구독 선택적 엄벌주의  ...

# %% [markdown]
# #### 과제(4): 'https://news.naver.com'에서 태그에 id가 있는 경우에 대해, 문자+숫자를 아래와 같이 출력
# - 해당되는 조건에 맞게 모두 출력
# - 한글만 열방향으로 출력
# - 불필요한 공백을 제거한 후 한글만 한줄에 출력

# %%
url = 'https://news.naver.com/'
html = requests.get(url).text
bs = BS(html, 'html.parser')
text=''

for i in bs.find_all(id=True):
    a = ' '.join(re.findall('\w+',i.text))
#     print(a)    #전체 출력 
    b = ' '.join(re.findall('[가-힣]+',i.text))
#     print(b)   #한글만 열방향 출력
    text +=b
print(text)   #한글만 한줄에 출력
# Out:
# 네이버 뉴스전체 언론사 뉴스스탠드 라이브러리콘텐츠 화 전체 언론사 뉴스스탠드 라이브러리 언론사편집 기자 연재 구독설정 속보 송영길 서울중앙지검 자진출석 이데일리 송영길 전 민주당 대표 검찰 자진 출두 머니투데이 내용작성전 돈봉투 의혹 송영길 서울중앙지검 자진 출두 연합뉴스 검찰 송영길 출석 거부 로비서 돌려보내 매일경제 내용작성전 검찰 송영길 출석 거부 로비서 돌려보내 중앙일보 내용작성전 검찰 송영길 출석 거부 로비서 돌려보내 이코노미스트 내용작성전 민주당 전당대회 돈봉투 의혹 송영길 서울중앙지검 자진 출두 노컷뉴스 검찰 송영길 출석 거부 로비서 돌려보내 한국경제 내용작성전 간호법 반발 일 총파업 내일부터 부분파업 돌입 뉴시스 내용작성전 검찰 송영길 출석 거부 로비서 돌려보내 연합뉴스 내용작성전 민주당 돈 봉투 의혹 송영길 검찰 자진 출석 더팩트 송영길 출석 강행 돈봉투 입장 밝힐 듯 국민일보 내용작성전 돈봉투 의혹 송영길 자진 출석 입장표명은 없어 머니 내용작성전 돈봉투 의혹 송영길 서울중앙지검 자진 출석 경향신문 내용작성전 돈 봉투 의혹 송영길 전 민주당 대표 서울중앙지검 자진 출두 송영길 전 대표 일방적으로 자진출석 조선 내용작성전 돈봉투 의혹 송영길 서울중앙지검 자진 출두 내용작성전 민주당 돈봉투 의혹 송영길 자진 출석 중앙지검 도착 내용작성전 정무수석 공천은 당에서 논의 안했다 태영호 사과 받아 문화일보 이진복 태영호와 공천 얘기 나눈 적 없다 공천 줄 위치 있는 사람 아냐 강원일보 이진복 태영호 녹취록에 공천 줄 위치 아냐 논의 안해 대전일보 내용작성전 이진복 정무수석 공천은 당에서 태영호와 공천 얘기 나눈 적 없다 강원도민일보 속보 닫기 뉴스타파 월 일 구독 현장에서 아직도 대강은 대운하가 아니다 라는 그들에게 요즘 대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다 이명박 전 대통령 이하 존칭 생략 은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 대강도 방문할 예정이라고 한다 대강 추진본부장이었던 심명필은 더스쿠프 월 일 구독 배민 알뜰배달이 알뜰할 수 없는 모순들 추적 뜨겁게 달아올랐던 배달앱 시장이 차갑게 식었다 배달 대신 외식 수요가 증가한 데다 고물가로 소비자들이 주머니를 닫아버린 탓이다 높아진 배달비 부담도 소비자가 배달앱에 등을 돌리는 계기로 작용했다 배달의민족 비즈워치 월 일 구독 더존 데이터센터가 춘천에 자리 잡은 까닭 서울에서 차를 타고 시간여 만에 도착한 강원도 춘천 남산면에 위치한 더존비즈온 강촌캠퍼스 이름 그대로 대학 캠퍼스를 방불케 하는 이곳의 지하 층에는 총면적 규모의 데이터센터 클라우드센터 가 자리 프레시안 월 일 구독 성행위 촬영물이 엔터 로 신동엽 뒤로 감춰진 성착취 배우 인터뷰한 성 인물 논란 어떻게 봐야하나 산업은 일본 내 성착취 구조 의 첨단에 자리합니다 그 구조에 대한 비판적 고려 없이 이를 콘텐츠화한다뇨 이나영 중앙대학교 사회학과 교수 시사저널 월 일 구독 단독 이건그룹 오너 세 길 터주려 모태회사 희생시켰나 이건산업이 알짜 사업 및 자회사를 이건창호에 몰아준 이유 박승준 사장 등이 법인 손해만큼 시세차익 거둬 논란 예상 이건그룹이 최근 세 경영 체제로의 전환을 서두르고 있다 지주회사인 이건홀딩스는 월 일 주주총회 새로보기 대전일보 월 일 구독 억 보험금 노린 계곡 살인 이은해 심 무기징역 불복 대법원 간다 일명 계곡 살인 혐의로 심에 이어 심에서도 무기징역이 선고된 이은해 가 판결에 불복해 상고했다 일 법조계 등에 따르면 이 씨는 전날 서울고법 형사 부 원종찬 박원철 이의영 부장판사 에 상고장을 제 데일리안 월 일 구독 속보 정무수석 태영호 녹취록 논란에 공천은 당에서 논의조차 안해 속보 정무수석 태영호 녹취록 논란에 공천은 당에서 논의조차 안해 코리아헤럴드 월 일 구독 조선비즈 월 일 구독 주가 동향 수시로 보고받았던 김익래 회장 작전세력 인지 가능성 정말 없나 다우데이타 서울가스 회장 매도 직전 블록딜로 수백억원 챙겨 오너일가 분기별로 계열사 주가 동향 보고받아 이상 반응 인지 가능 일각선 내 재산 수백억 왔다 갔다 하는 데 배경 안 찾아본다고 말 안된다 매일경제 월 일 구독 먹지마세요 소녀 애원했는데 살아 있는 금붕어 먹고 춤춘 이 남성 한 남성이 살아 있는 금붕어를 통째로 삼키는 장면을 공개해 논란이 일고 있다고 영국 매체 더 선이 최근 보도했다 더선에 따르면 이 남성은 경주마 거래계에서 잘 알려진 유명 에이전트 해미쉬 마카오리로 아일랜드 더블린 새로보기 월 일 구독 세력 은 있었다 아케고스와 루보 반복되는 금융의 탐욕 는 코스닥 주가를 부풀릴 수 있다 코스닥시장 종목들의 주가는 거래 후 상승한다 년 발표된 한 논문의 결론이다 레버리지 투자자의 매매 양태 분석 차액결제거래 계좌를 대상으로 박수철 한국경제 월 일 구독 휴 영끌족 한숨 돌렸다 두 달 새 억씩 뛴 동네 서울 노원구 아파트값이 년 개월 만에 반등에 성공했다 직전 거래 가격보다 오른 가격에 팔리는 사례가 속속 생겨나면서 영끌족 영혼까지 끌어모아 대출로 집 산 사람 도 한숨을 돌리는 모습이다 한국부동산원에 따르 월 일 구독 국민의힘 시의원 베트남 애들 열 중 하나는 뽕 혐오 발언 국민의힘 소속 양태석 거제시의원이 공식 석상에서 외국인 노동자 혐오 발언을 했다는 사실이 뒤늦게 알려져 여론의 뭇매를 맞고 있다 지난달 일 양 의원은 거제시의회 경제관광위원회 외국인노동자 지원 조례안 심사 과 주간조선 월 일 구독 이진복 태영호와 공천 얘기한 적 없어 전화와 사과 이진복 대통령실 정무수석은 일 국민의힘 태영호 최고위원과 관련해 공천 문제를 거론하며 한일 관계에 대해 옹호 발언을 해달라고 요청했다 는 보도에 대해 그런 얘기를 전혀 나눈 적이 없다 고 말했다 이 수 한겨레 월 일 구독 단독 정부 한국노총 국고보조금 결국 끊었다 한국노총이 올해 억원 규모의 정부 국고보조금 지원사업에서 탈락했다 정부가 노조 회계자료 미제출을 빌미로 노동계 압박을 위해 본격적으로 돈줄을 쥐고 흔들고 나선 것으로 노조 도움을 받던 노동 약자 에게 피해가 새로보기 주간동아 월 일 구독 건강한 프리미엄 먹거리 로 승부수 던지는 김동선 월 파이브가이즈 국내 첫 오픈 결실 한화 유통 서비스 부문 미래 성장동력 박차 미국 유명 수제버거 파이브가이즈 가 월 한국에 처음 매장을 연다 김승연 한화그룹 회장의 삼남인 김동선 한화갤러리아 전략본부장 월 일 구독 전승절 대반격 빼앗긴 우크라 땅에도 봄은 오는가 러시아 우크라이나 전쟁이 일 년을 훌쩍 넘겨 일째 월 일 기준 를 맞고 있다 지난해 월 시작된 전쟁이 교착국면에 빠져 장기화한 상태에서 오는 일 러시아의 전승절 즈음에 우크라이나의 대반격이 임박했다는 머니투데이 월 일 구독 죽은 딸에게서 온 문자 억대 연봉 대 살해한 남친 뉴스속오늘 뉴스를 통해 우리를 웃고 울렸던 어제의 오늘을 다시 만나봅니다 년 월 일 이모씨 당시 세 는 이날 밤 시쯤 자신이 지내던 서울 관악구 신림동의 한 오피스텔에서 여자친구 김모씨 당시 세 를 목 월 일 구독 동영상 재생시간 제주날씨 월 기온 회복하며 출발 미세먼지 농도 좋음 월로 들어서면서 계절감이 회복됐습니다 당분간 기온 계속 비슷하면서 온화하겠는데요 다만 오늘은 일교차가 도 내외로 크겠습니다 따라서 체온 관리에 특별히 신경 써주시면 좋겠습니다 오늘은 오랜만에 하늘 구경 아이뉴스 월 일 구독 대 만취운전남 길 가던 대 부부 들이받아 아내 사망 대낮에 만취 운전을 한 대 남성이 길을 가던 대 부부를 들이받아 부인이 숨지는 사고가 발생했다 일 경찰에 따르면 전북 완주경찰서는 도로교통법상 음주운전 혐의로 대 남성 씨를 붙잡아 조사 중이다 씨 새로보기 파이낸셜뉴스 월 일 구독 화장실 바닥서 잠자고 그옆에서 볼일 보고 보복관광 나선 코로나 이후 년 만에 닷새 간의 황금연휴 월 일 월 일 를 맞은 중국 곳곳이 보복 관광 으로 인산인해를 이루고 있다 숙소를 못 구한 이들이 화장실에서 밤을 지새우는가 하면 낙타 신호등 까지 등장 지디넷코리아 월 일 구독 우리는 왜 셀카를 찍을까 인스타그램엔 하루에 천 만 장의 사진이 올라온다 이중 상당수는 자신의 모습이 담긴 셀카다 사람들은 왜 셀카를 찍을까 흔히 생각하는 바와는 달리 자신을 과시하고 싶어 셀카를 찍는 것만은 아니라는 연구 결과 오마이 ...

# %%
url = 'https://www.naver.com'
html = urllib.request.urlopen(url)
bs = BS(html, 'html.parser')
t = bs.find_all('a', id=True)

t = [i.get_text() for i in t]
for i in t:
    if re.search('[가-힣]+',i):  # 한글이 있으면 True
        print(i)
# id가 있는 <a> 중 한글이 없으면 출력되지 않음
# Out:
# 다운로드
# 네이버를 시작페이지로
# 한글 입력기
# 자동완성 레이어
# 관심주제 설정

# %% [markdown]
# #### 과제(5): 네이버 영화 랭킹 실시간 조회 데이터를 가져와 탑10 출력
# - 1: 000
# - 2: 0000
# <br>...
# - 10: 000 00

# %%
url = 'https://serieson.naver.com/v3/movie/ranking/realtime'
html = urllib.request.urlopen(url)
bs = BS(html, 'html.parser')
# print(bs.prettify())

for i in range(10):
    print(f'{i+1}:',bs.find_all('span', class_="Title_title__s9o0D")[i].text)
# Out:
# 1: 던전 앤 드래곤: 도적들의 명예
# 2: 아바타: 물의 길(부가영상 제공)
# 3: 앤트맨과 와스프: 퀀텀매니아(세트: 1~3편)
# 4: 존 윅 3: 파라벨룸
# 5: 파벨만스
# 6: 너의 이름은.
# 7: 코코(패키지: 자막판+더빙판+부가영상)
# 8: 덫: 치명적인 유혹
# 9: 소중한 날의 꿈
# 10: 웅남이

# %%
url = 'https://serieson.naver.com/v3/movie/ranking/realtime'
html = urllib.request.urlopen(url)
bs = BS(html, 'html.parser')

bs.find_all(string=re.compile('Title'))
# 태그 속이 아닌, 태그 사이의 문자열을 검색
# 즉, 속성값이나 class등은 검색할 수 없음

title = bs.find_all(class_=re.compile('.*Title.*'))
# 이렇게 class값이라고 지정해 준 경우에는 가능
for i in range(10):
    print(f'{i+1}: {title[i].text}')   # 출력
# Out:
# 1: 던전 앤 드래곤: 도적들의 명예
# 2: 아바타: 물의 길(부가영상 제공)
# 3: 앤트맨과 와스프: 퀀텀매니아(세트: 1~3편)
# 4: 존 윅 3: 파라벨룸
# 5: 파벨만스
# 6: 너의 이름은.
# 7: 코코(패키지: 자막판+더빙판+부가영상)
# 8: 덫: 치명적인 유혹
# 9: 소중한 날의 꿈
# 10: 웅남이

# %% [markdown]
# #### 과제(6): url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100' 사이트에서 뉴스기사 제목을 출력하세요.

# %%
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
html = requests.get(url, headers=headers).text
bs = BS(html, 'html.parser')

li='#main_content > div > div._persist > div > div > div.cluster_body > ul > li > div.cluster_text > a'
for i in bs.select(li):
    print(i.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17232\2172617390.py in <module>
#       1 url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'
#       2 headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
# ----> 3 html = requests.get(url, headers=headers).text
#       4 bs = BS(html, 'html.parser')
#       5
#
# NameError: name 'requests' is not defined

# %% [markdown]
# #### 과제(7): 네이버 뉴스 사회 분야 데이터를 가져와 다음을 수행
# - 첫번째 뉴스 제목과 href를 출력
# - 뉴스 전체 제목과 href를 출력(열방향)

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=102'

html = requests.get(url, headers=headers).text
bs = BS(html, 'html.parser')
li='#main_content > div > div._persist > div > div > div.cluster_body > ul > li > div.cluster_text > a'

one = bs.select_one(li, href=True)   #첫번째 뉴스
print(one.text, '\n'+one.attrs['href'], '\n')

for i in bs.select(li, href=True):   #전체 뉴스
    print(i.text, '\n' + i.attrs['href'])
# Out:
# 충남 첫 엠폭스 확진자 발생…"해외 여행력 없어"
# https://n.news.naver.com/mnews/article/015/0004839482?sid=102
#
# 충남 첫 엠폭스 확진자 발생…"해외 여행력 없어"
# https://n.news.naver.com/mnews/article/015/0004839482?sid=102
# '엠폭스' 확진 환자 5명 추가…누적 47명
# https://n.news.naver.com/mnews/article/277/0005253084?sid=102
# 엠폭스 위험도 국민 생각은 "보통"…백신·치료제 인지도는 떨어져
# https://n.news.naver.com/mnews/article/277/0005253031?sid=102
# "엠폭스 치료제·백신 있나?" 묻자…5명 중 1명도 정답 못맞혀
# https://n.news.naver.com/mnews/article/015/0004839469?sid=102
# 승무원과 고의로 부딪힌 40대…상습 보험사기로 재판행
# https://n.news.naver.com/mnews/article/055/0001054573?sid=102
# 승무원에 고의로 부딪힌 40대, 한 달 여행 뒤 52일간 입원(종합)
# https://n.news.naver.com/mnews/article/001/0013914935?sid=102
# 승무원 지나갈 때 일부러 고개 '쑥'...40대 보험사기로 기소
# https://n.news.naver.com/mnews/article/215/0001098745?sid=102
# 승무원 지나갈때 머리 내밀어 ‘쾅’…52일 입원 후 보험금 타냈다
# https://n.news.naver.com/mnews/article/009/0005124169?sid=102
# “윤석열 정권 역사 심판대 세우자”…노동계 7월 총파업 예고
# https://n.news.naver.com/mnews/article/028/0002638063?sid=102
# 양대 노총 노동절 집회..."정부 노동 개악 규탄"
# https://n.news.naver.com/mnews/article/052/0001879712?sid=102
# 서울 도심 곳곳 대규모 노동절 집회…경찰, 현장 배치 계획
# https://n.news.naver.com/mnews/article/437/0000341307?sid=102
# 세종대로 가득 메운 민주노총…건설노조 간부 분신에 '전운'
# https://n.news.naver.com/mnews/article/018/0005476575?sid=102
# '계곡 살인' 이은해 2심 무기징역에 불복 상고…대법 판단 받는다
# https://n.news.naver.com/mnews/article/421/0006780521?sid=102
# '계곡 살인' 이은해, 항소심 무기징역도 불복…대법원 간다
# https://n.news.naver.com/mnews/article/015/0004839637?sid=102
# 이은해, 2심 무기징역도 불복…'계곡 살인' 사건 대법원으로
# https://n.news.naver.com/mnews/article/018/0005476634?sid=102
# ‘계곡살인’ 이은해, 무기징역 불복 상고…대법원 판단 받는다
# https://n.news.naver.com/mnews/article/056/0011476240?sid=102
# 대낮 음주운전 해 부부 덮친 차량…운전자 “앞 제대로 못봤다”
# https://n.news.naver.com/mnews/article/009/0005124431?sid=102
# 대낮 20대 음주운전 차량에 치인 40대 부부…아내는 숨져
# https://n.news.naver.com/mnews/article/029/0002798076?sid=102
# 원희룡 "음주운전 살인행위, 패가망신 시켜야"
# https://n.news.naver.com/mnews/article/018/0005476601?sid=102
# 9살 승아 숨졌는데도...2시간 동안 28명 '음주' 적발
# https://n.news.naver.com/mnews/article/052/0001879384?sid=102
# 윤재옥, 간호법 직역 단체 농성장 방문 "갈등 해소 위해 최선 다할것"
# https://n.news.naver.com/mnews/article/421/0006780870?sid=102
# 윤재옥, '간호법 반대' 간무협 농성장 찾아 "단식 중단하고 우리에게 맡겨달라"
# https://n.news.naver.com/mnews/article/003/0011834254?sid=102
# 서울시, 할인율 7% 온라인 전용 'e서울사랑상품권' 판매
# https://n.news.naver.com/mnews/article/421/0006781078?sid=102
# ‘온라인쇼핑몰 전용’ e서울사랑상품권, 3일부터 판매···7% 할인
# https://n.news.naver.com/mnews/article/032/0003220901?sid=102
# 내년 최저임금 1만원 넘을까…2일 첫 전원회의
# https://n.news.naver.com/mnews/article/119/0002708210?sid=102
# '내년 적용 최저임금' 1차 전원회의…'1만원 여부' 주목
# https://n.news.naver.com/mnews/article/437/0000341409?sid=102
# 송영길 "내일 자진출두"‥검찰 "그냥 돌려보낼 것"
# https://n.news.naver.com/mnews/article/214/0001269998?sid=102
# 국민의힘 “송영길 위장출두쇼… 반성하며 기다려라”
# https://n.news.naver.com/mnews/article/025/0003277062?sid=102
# ‘천화동인 6호 실소유자 지목’ 검, 조우형씨에 구속영장 청구
# https://n.news.naver.com/mnews/article/032/0003220847?sid=102
# [속보] 검찰, '대장동 비리' 천화동인 6호 실소유주 구속영장 청구
# https://n.news.naver.com/mnews/article/052/0001879713?sid=102
# 경찰, 민주노총 건설노조 부울경 지부장 구속영장
# https://n.news.naver.com/mnews/article/021/0002569415?sid=102
# 건설노조 간부 분신 법원 앞 조합원 600여 명 집회
# https://n.news.naver.com/mnews/article/052/0001879645?sid=102
# “베트남 애들 10명 중 1명은 뽕”… 거제시의원 혐오 발언 논란
# https://n.news.naver.com/mnews/article/081/0003358011?sid=102
# 국민의힘 시의원 "베트남 애들 열 중 하나는 뽕" 혐오 발언
# https://n.news.naver.com/mnews/article/052/0001879867?sid=102
# 부산시, ‘연구개발 중장기 투자전략’ 수립
# https://n.news.naver.com/mnews/article/032/0003220919?sid=102
# 부산시, ‘연구개발 중장기 투자전략(2023~2027)’ 수립
# https://n.news.naver.com/mnews/article/003/0011834532?sid=102
# 코로나19 신규확진 1만5741명…1주 전보다 930명 증가
# https://n.news.naver.com/mnews/article/056/0011476766?sid=102
# 코로나19 신규확진 1만5741명…1주 전보다 930명 증가(종합)
# https://n.news.naver.com/mnews/article/001/0013915659?sid=102
# 충북 옥천서 규모 3.1 지진..."진동 느꼈다" 신고만 80건
# https://n.news.naver.com/mnews/article/052/0001879447?sid=102
# 충북 옥천 동쪽에서 규모 3.1 지진 발생...피해 접수 없어
# https://n.news.naver.com/mnews/article/052/0001879430?sid=102

# %% [markdown]
# #### 과제(1): 네이버 뉴스 메인에서 연예, 날씨, 스포츠, 프리미엄을 찾아 출력

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url ='https://news.naver.com/'
html = requests.get(url, headers=headers).text
bs = BS(html, 'lxml')

for i in bs.find_all('span', class_='Nservice_subitem'):
    print(i.text.split())    # 깔끔하게 출력하고 싶으면 [0]인덱스 붙이기
#     print(i.text.split()[0])
# Out:
# ['연예']
# ['스포츠']
# ['날씨']
# ['프리미엄']
